# %% [markdown]
# # Complex TFA multiple Inversions

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os

from fatiando.vis import mpl
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
from datetime import datetime
today = datetime.today()
# dd/mm/YY
d4 = today.strftime("%d-%b-%Y-%Hh:%Mm")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open(path+'model.pickle') as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open(path+'data.pickle') as w:
        data = pickle.load(w)

# %%
dobs = data['tfa_obs']
xp = data['grid'][0]
yp = data['grid'][1]
zp = data['grid'][2]
N = data['grid'][3]

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 20 # number of vertices per prism
L = 10 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization direction
incs = model['inc']
decs = model['dec']

int_min = 10.
int_max = 15.
intensity = np.linspace(int_min, int_max, 6)

# depth to the top, thickness and radius
z0_min = 10.
z0_max = 210.
z0 = np.linspace(z0_min, z0_max, 6)
dz = 650.
r = 800.
x0 = -300.
y0 = 300.

# main field
inc, dec = data['main_field']

# %%
z0
# Out:
# array([ 10.,  50.,  90., 130., 170., 210.])

# %%
intensity
# Out:
# array([10., 11., 12., 13., 14., 15.])

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 10.
rmax = 3000.
x0min = -4000.
x0max = 4000.
y0min = -4000.
y0max = 4000.
dzmin = 200.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Derivatives

# %%
# variation for derivatives
deltax = 0.01*np.max(100.)
deltay = 0.01*np.max(100.)
deltar = 0.01*np.max(100.)
deltaz = 0.01*np.max(100.)

delta = np.array([deltax, deltay, deltar, deltaz])

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-5  # adjacent radial distances within each prism
a2 = 1.0e-6   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 1.0e-5    # vertically adjacent origins
a6 = 1.0e-8   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-6     # zero order Tikhonov on thickness of each prism

alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Folder to save the results

# %%
foldername = ''

# %%
if foldername == '':
    mypath = path+'l2-tfa-inversion/multiple-'+d4 #default folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)
else:
    mypath = path+'l2_tfa_inversion/multiple-'+foldername #defined folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-4     # stop criterion

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for j, z in enumerate(z0):
    for k, i in enumerate(intensity):
        alpha = np.array([a1, a2, a3, a4, a5, a6, a7])
        print 'inversion: %d  top: %d  intensity: %d' % (j*z0.size + k, z, i)
        model0, m0 = mfun.initial_cylinder(M, L, x0, y0, z, dz, r, inc, dec, incs, decs, i)
        d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(
            xp, yp, zp, m0, M, L, delta,
            itmax, itmax_marq, lamb,
            dlamb, tol, mmin, mmax,
            m_out, dobs, inc, dec,
            model0[0].props, alpha, z, dz
        )
        inversion_results.append([m_est, phi_list, model_list, dobs - d_fit])
# Out:
# inversion: 0  top: 10  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 4.11923e+04  fin obj.: 2.66888e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 2.66888e+04  fin obj.: 2.14728e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 2.14728e+04  fin obj.: 3.33363e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 2.14728e+04  fin obj.: 9.25549e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 9.25549e+03  fin obj.: 5.51520e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 9.25549e+03  fin obj.: 8.09536e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 8.09536e+03  fin obj.: 3.46518e+04
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 8.09536e+03  fin obj.: 8.17259e+03
# it:  4   it_marq:  2   lambda: 1e+01   init obj.: 8.09536e+03  fin obj.: 5.84197e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 5.84197e+03  fin obj.: 1.69038e+04
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 5.84197e+03  fin obj.: 5.17743e+03
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 5.17743e+03  fin obj.: 1.76162e+04
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 5.17743e+03  fin obj.: 7.23214e+03
# it:  6   it_marq:  2   lambda: 1e+02   init obj.: 5.17743e+03  fin obj.: 5.12588e+03
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 5.12588e+03  fin obj.: 7.26862e+03
# it:  7   it_marq:  1   lambda: 1e+02   init obj.: 5.12588e+03  fin obj.: 5.08081e+03
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 5.08081e+03  fin obj.: 7.49436e+03
# it:  8   it_marq:  1   lambda: 1e+02   init obj.: 5.08081e+03  fin obj.: 5.03961e+03
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 5.03961e+03  fin obj.: 1.21943e+04
# it:  9   it_marq:  1   lambda: 1e+02   init obj.: 5.03961e+03  fin obj.: 5.00430e+03
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 5.00430e+03  fin obj.: 7.38172e+03
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 5.00430e+03  fin obj.: 4.96500e+03
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 4.96500e+03  fin obj.: 4.66916e+03
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 4.66916e+03  fin obj.: 8.79934e+03
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 4.66916e+03  fin obj.: 4.43195e+03
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 4.43195e+03  fin obj.: 2.47407e+04
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 4.43195e+03  fin obj.: 2.17380e+04
# it: 13   it_marq:  2   lambda: 1e+02   init obj.: 4.43195e+03  fin obj.: 7.13210e+03
# it: 13   it_marq:  3   lambda: 1e+03   init obj.: 4.43195e+03  fin obj.: 6.28930e+03
# it: 13   it_marq:  4   lambda: 1e+04   init obj.: 4.43195e+03  fin obj.: 6.27563e+03
# it: 13   it_marq:  5   lambda: 1e+05   init obj.: 4.43195e+03  fin obj.: 6.26879e+03
# it: 13   it_marq:  6   lambda: 1e+06   init obj.: 4.43195e+03  fin obj.: 6.26878e+03
# it: 13   it_marq:  7   lambda: 1e+07   init obj.: 4.43195e+03  fin obj.: 6.26878e+03
# it: 13   it_marq:  8   lambda: 1e+08   init obj.: 4.43195e+03  fin obj.: 6.26878e+03
# it: 13   it_marq:  9   lambda: 1e+09   init obj.: 4.43195e+03  fin obj.: 6.26878e+03
# it: 14   it_marq:  0   lambda: 1e+10   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  1   lambda: 1e+11   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  2   lambda: 1e+12   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  3   lambda: 1e+13   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  4   lambda: 1e+14   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  5   lambda: 1e+15   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  6   lambda: 1e+16   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  7   lambda: 1e+17   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  8   lambda: 1e+18   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 14   it_marq:  9   lambda: 1e+19   init obj.: 4.43195e+03  fin obj.: 6.26937e+03
# it: 15   it_marq:  0   lambda: 1e+20   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  1   lambda: 1e+21   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  2   lambda: 1e+22   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  3   lambda: 1e+23   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  4   lambda: 1e+24   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  5   lambda: 1e+25   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  6   lambda: 1e+26   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  7   lambda: 1e+27   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  8   lambda: 1e+28   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 15   it_marq:  9   lambda: 1e+29   init obj.: 4.43195e+03  fin obj.: 6.26997e+03
# it: 16   it_marq:  0   lambda: 1e+30   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  1   lambda: 1e+31   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  2   lambda: 1e+32   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  3   lambda: 1e+33   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  4   lambda: 1e+34   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  5   lambda: 1e+35   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  6   lambda: 1e+36   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  7   lambda: 1e+37   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  8   lambda: 1e+38   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 16   it_marq:  9   lambda: 1e+39   init obj.: 4.43195e+03  fin obj.: 6.27056e+03
# it: 17   it_marq:  0   lambda: 1e+40   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  1   lambda: 1e+41   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  2   lambda: 1e+42   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  3   lambda: 1e+43   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  4   lambda: 1e+44   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  5   lambda: 1e+45   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  6   lambda: 1e+46   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  7   lambda: 1e+47   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  8   lambda: 1e+48   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 17   it_marq:  9   lambda: 1e+49   init obj.: 4.43195e+03  fin obj.: 6.27116e+03
# it: 18   it_marq:  0   lambda: 1e+50   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  1   lambda: 1e+51   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  2   lambda: 1e+52   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  3   lambda: 1e+53   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  4   lambda: 1e+54   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  5   lambda: 1e+55   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  6   lambda: 1e+56   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  7   lambda: 1e+57   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  8   lambda: 1e+58   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 18   it_marq:  9   lambda: 1e+59   init obj.: 4.43195e+03  fin obj.: 6.27175e+03
# it: 19   it_marq:  0   lambda: 1e+60   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  1   lambda: 1e+61   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  2   lambda: 1e+62   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  3   lambda: 1e+63   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  4   lambda: 1e+64   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  5   lambda: 1e+65   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  6   lambda: 1e+66   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  7   lambda: 1e+67   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  8   lambda: 1e+68   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 19   it_marq:  9   lambda: 1e+69   init obj.: 4.43195e+03  fin obj.: 6.27235e+03
# it: 20   it_marq:  0   lambda: 1e+70   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  1   lambda: 1e+71   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  2   lambda: 1e+72   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  3   lambda: 1e+73   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  4   lambda: 1e+74   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  5   lambda: 1e+75   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  6   lambda: 1e+76   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  7   lambda: 1e+77   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  8   lambda: 1e+78   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 20   it_marq:  9   lambda: 1e+79   init obj.: 4.43195e+03  fin obj.: 6.27295e+03
# it: 21   it_marq:  0   lambda: 1e+80   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  1   lambda: 1e+81   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  2   lambda: 1e+82   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  3   lambda: 1e+83   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  4   lambda: 1e+84   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  5   lambda: 1e+85   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  6   lambda: 1e+86   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  7   lambda: 1e+87   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  8   lambda: 1e+88   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 21   it_marq:  9   lambda: 1e+89   init obj.: 4.43195e+03  fin obj.: 6.27354e+03
# it: 22   it_marq:  0   lambda: 1e+90   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  1   lambda: 1e+91   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  2   lambda: 1e+92   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  3   lambda: 1e+93   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  4   lambda: 1e+94   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  5   lambda: 1e+95   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  6   lambda: 1e+96   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  7   lambda: 1e+97   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  8   lambda: 1e+98   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 22   it_marq:  9   lambda: 1e+99   init obj.: 4.43195e+03  fin obj.: 6.27414e+03
# it: 23   it_marq:  0   lambda: 1e+100   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  1   lambda: 1e+101   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  2   lambda: 1e+102   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  3   lambda: 1e+103   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  4   lambda: 1e+104   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  5   lambda: 1e+105   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  6   lambda: 1e+106   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  7   lambda: 1e+107   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  8   lambda: 1e+108   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 23   it_marq:  9   lambda: 1e+109   init obj.: 4.43195e+03  fin obj.: 6.27474e+03
# it: 24   it_marq:  0   lambda: 1e+110   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  1   lambda: 1e+111   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  2   lambda: 1e+112   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  3   lambda: 1e+113   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  4   lambda: 1e+114   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  5   lambda: 1e+115   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  6   lambda: 1e+116   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  7   lambda: 1e+117   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  8   lambda: 1e+118   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 24   it_marq:  9   lambda: 1e+119   init obj.: 4.43195e+03  fin obj.: 6.27534e+03
# it: 25   it_marq:  0   lambda: 1e+120   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  1   lambda: 1e+121   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  2   lambda: 1e+122   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  3   lambda: 1e+123   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  4   lambda: 1e+124   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  5   lambda: 1e+125   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  6   lambda: 1e+126   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  7   lambda: 1e+127   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  8   lambda: 1e+128   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 25   it_marq:  9   lambda: 1e+129   init obj.: 4.43195e+03  fin obj.: 6.27593e+03
# it: 26   it_marq:  0   lambda: 1e+130   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  1   lambda: 1e+131   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  2   lambda: 1e+132   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  3   lambda: 1e+133   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  4   lambda: 1e+134   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  5   lambda: 1e+135   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  6   lambda: 1e+136   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  7   lambda: 1e+137   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  8   lambda: 1e+138   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 26   it_marq:  9   lambda: 1e+139   init obj.: 4.43195e+03  fin obj.: 6.27653e+03
# it: 27   it_marq:  0   lambda: 1e+140   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  1   lambda: 1e+141   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  2   lambda: 1e+142   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  3   lambda: 1e+143   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  4   lambda: 1e+144   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  5   lambda: 1e+145   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  6   lambda: 1e+146   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  7   lambda: 1e+147   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  8   lambda: 1e+148   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 27   it_marq:  9   lambda: 1e+149   init obj.: 4.43195e+03  fin obj.: 6.27713e+03
# it: 28   it_marq:  0   lambda: 1e+150   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  1   lambda: 1e+151   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  2   lambda: 1e+152   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  3   lambda: 1e+153   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  4   lambda: 1e+154   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  5   lambda: 1e+155   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  6   lambda: 1e+156   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  7   lambda: 1e+157   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  8   lambda: 1e+158   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 28   it_marq:  9   lambda: 1e+159   init obj.: 4.43195e+03  fin obj.: 6.27773e+03
# it: 29   it_marq:  0   lambda: 1e+160   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  1   lambda: 1e+161   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  2   lambda: 1e+162   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  3   lambda: 1e+163   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  4   lambda: 1e+164   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  5   lambda: 1e+165   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  6   lambda: 1e+166   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  7   lambda: 1e+167   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  8   lambda: 1e+168   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# it: 29   it_marq:  9   lambda: 1e+169   init obj.: 4.43195e+03  fin obj.: 6.27833e+03
# inversion: 1  top: 10  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 6.07254e+04  fin obj.: 3.72261e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 3.72261e+04  fin obj.: 4.56540e+04
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 3.72261e+04  fin obj.: 2.86475e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 2.86475e+04  fin obj.: 7.98016e+04
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 2.86475e+04  fin obj.: 2.44693e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 2.44693e+04  fin obj.: 2.10728e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 2.44693e+04  fin obj.: 2.17518e+04
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 2.17518e+04  fin obj.: 1.57455e+05
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 2.17518e+04  fin obj.: 1.96464e+04
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.96464e+04  fin obj.: 1.29905e+05
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 1.96464e+04  fin obj.: 1.79357e+04
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 1.79357e+04  fin obj.: 2.37638e+05
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 1.79357e+04  fin obj.: 1.64761e+04
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 1.64761e+04  fin obj.: 3.16246e+05
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 1.64761e+04  fin obj.: 1.51898e+04
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 1.51898e+04  fin obj.: 3.42210e+05
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 1.51898e+04  fin obj.: 7.81650e+04
# it:  8   it_marq:  2   lambda: 1e+02   init obj.: 1.51898e+04  fin obj.: 7.85119e+04
# it:  8   it_marq:  3   lambda: 1e+03   init obj.: 1.51898e+04  fin obj.: 1.51728e+04
# it:  9   it_marq:  0   lambda: 1e+02   init obj.: 1.51728e+04  fin obj.: 1.50398e+04
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 1.50398e+04  fin obj.: 3.05244e+04
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 1.50398e+04  fin obj.: 1.49096e+04
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 1.49096e+04  fin obj.: 1.91453e+04
# it: 11   it_marq:  1   lambda: 1e+02   init obj.: 1.49096e+04  fin obj.: 1.47815e+04
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 1.47815e+04  fin obj.: 1.56301e+04
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 1.47815e+04  fin obj.: 1.46555e+04
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 1.46555e+04  fin obj.: 1.44177e+04
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 1.44177e+04  fin obj.: 9.36131e+03
# it: 15   it_marq:  0   lambda: 1e-01   init obj.: 9.36131e+03  fin obj.: 8.98728e+04
# it: 15   it_marq:  1   lambda: 1e+00   init obj.: 9.36131e+03  fin obj.: 6.27640e+03
# it: 16   it_marq:  0   lambda: 1e-01   init obj.: 6.27640e+03  fin obj.: 7.93641e+04
# it: 16   it_marq:  1   lambda: 1e+00   init obj.: 6.27640e+03  fin obj.: 6.46343e+03
# it: 16   it_marq:  2   lambda: 1e+01   init obj.: 6.27640e+03  fin obj.: 6.05993e+03
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 6.05993e+03  fin obj.: 5.22807e+03
# it: 18   it_marq:  0   lambda: 1e-01   init obj.: 5.22807e+03  fin obj.: 1.52216e+05
# it: 18   it_marq:  1   lambda: 1e+00   init obj.: 5.22807e+03  fin obj.: 4.94824e+03
# it: 19   it_marq:  0   lambda: 1e-01   init obj.: 4.94824e+03  fin obj.: 1.66115e+05
# it: 19   it_marq:  1   lambda: 1e+00   init obj.: 4.94824e+03  fin obj.: 4.24377e+03
# it: 20   it_marq:  0   lambda: 1e-01   init obj.: 4.24377e+03  fin obj.: 1.34883e+05
# it: 20   it_marq:  1   lambda: 1e+00   init obj.: 4.24377e+03  fin obj.: 2.35311e+04
# it: 20   it_marq:  2   lambda: 1e+01   init obj.: 4.24377e+03  fin obj.: 8.55517e+03
# it: 20   it_marq:  3   lambda: 1e+02   init obj.: 4.24377e+03  fin obj.: 5.81088e+03
# it: 20   it_marq:  4   lambda: 1e+03   init obj.: 4.24377e+03  fin obj.: 3.58364e+03
# it: 21   it_marq:  0   lambda: 1e+02   init obj.: 3.58364e+03  fin obj.: 5.46615e+04
# it: 21   it_marq:  1   lambda: 1e+03   init obj.: 3.58364e+03  fin obj.: 9.43773e+03
# it: 21   it_marq:  2   lambda: 1e+04   init obj.: 3.58364e+03  fin obj.: 7.46584e+03
# it: 21   it_marq:  3   lambda: 1e+05   init obj.: 3.58364e+03  fin obj.: 7.46568e+03
# it: 21   it_marq:  4   lambda: 1e+06   init obj.: 3.58364e+03  fin obj.: 4.34243e+03
# it: 21   it_marq:  5   lambda: 1e+07   init obj.: 3.58364e+03  fin obj.: 3.58892e+03
# it: 21   it_marq:  6   lambda: 1e+08   init obj.: 3.58364e+03  fin obj.: 3.58893e+03
# it: 21   it_marq:  7   lambda: 1e+09   init obj.: 3.58364e+03  fin obj.: 3.58893e+03
# it: 21   it_marq:  8   lambda: 1e+10   init obj.: 3.58364e+03  fin obj.: 3.58893e+03
# it: 21   it_marq:  9   lambda: 1e+11   init obj.: 3.58364e+03  fin obj.: 3.58890e+03
# it: 22   it_marq:  0   lambda: 1e+12   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  1   lambda: 1e+13   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  2   lambda: 1e+14   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  3   lambda: 1e+15   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  4   lambda: 1e+16   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  5   lambda: 1e+17   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  6   lambda: 1e+18   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  7   lambda: 1e+19   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  8   lambda: 1e+20   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 22   it_marq:  9   lambda: 1e+21   init obj.: 3.58364e+03  fin obj.: 3.58907e+03
# it: 23   it_marq:  0   lambda: 1e+22   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  1   lambda: 1e+23   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  2   lambda: 1e+24   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  3   lambda: 1e+25   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  4   lambda: 1e+26   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  5   lambda: 1e+27   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  6   lambda: 1e+28   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  7   lambda: 1e+29   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  8   lambda: 1e+30   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 23   it_marq:  9   lambda: 1e+31   init obj.: 3.58364e+03  fin obj.: 3.58923e+03
# it: 24   it_marq:  0   lambda: 1e+32   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  1   lambda: 1e+33   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  2   lambda: 1e+34   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  3   lambda: 1e+35   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  4   lambda: 1e+36   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  5   lambda: 1e+37   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  6   lambda: 1e+38   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  7   lambda: 1e+39   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  8   lambda: 1e+40   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 24   it_marq:  9   lambda: 1e+41   init obj.: 3.58364e+03  fin obj.: 3.58940e+03
# it: 25   it_marq:  0   lambda: 1e+42   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  1   lambda: 1e+43   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  2   lambda: 1e+44   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  3   lambda: 1e+45   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  4   lambda: 1e+46   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  5   lambda: 1e+47   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  6   lambda: 1e+48   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  7   lambda: 1e+49   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  8   lambda: 1e+50   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 25   it_marq:  9   lambda: 1e+51   init obj.: 3.58364e+03  fin obj.: 3.58956e+03
# it: 26   it_marq:  0   lambda: 1e+52   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  1   lambda: 1e+53   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  2   lambda: 1e+54   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  3   lambda: 1e+55   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  4   lambda: 1e+56   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  5   lambda: 1e+57   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  6   lambda: 1e+58   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  7   lambda: 1e+59   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  8   lambda: 1e+60   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 26   it_marq:  9   lambda: 1e+61   init obj.: 3.58364e+03  fin obj.: 3.58972e+03
# it: 27   it_marq:  0   lambda: 1e+62   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  1   lambda: 1e+63   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  2   lambda: 1e+64   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  3   lambda: 1e+65   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  4   lambda: 1e+66   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  5   lambda: 1e+67   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  6   lambda: 1e+68   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  7   lambda: 1e+69   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  8   lambda: 1e+70   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 27   it_marq:  9   lambda: 1e+71   init obj.: 3.58364e+03  fin obj.: 3.58989e+03
# it: 28   it_marq:  0   lambda: 1e+72   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  1   lambda: 1e+73   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  2   lambda: 1e+74   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  3   lambda: 1e+75   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  4   lambda: 1e+76   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  5   lambda: 1e+77   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  6   lambda: 1e+78   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  7   lambda: 1e+79   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  8   lambda: 1e+80   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 28   it_marq:  9   lambda: 1e+81   init obj.: 3.58364e+03  fin obj.: 3.59005e+03
# it: 29   it_marq:  0   lambda: 1e+82   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  1   lambda: 1e+83   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  2   lambda: 1e+84   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  3   lambda: 1e+85   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  4   lambda: 1e+86   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  5   lambda: 1e+87   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  6   lambda: 1e+88   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  7   lambda: 1e+89   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  8   lambda: 1e+90   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# it: 29   it_marq:  9   lambda: 1e+91   init obj.: 3.58364e+03  fin obj.: 3.59022e+03
# inversion: 2  top: 10  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 8.72172e+04  fin obj.: 5.16115e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 5.16115e+04  fin obj.: 8.74053e+04
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 5.16115e+04  fin obj.: 3.86699e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 3.86699e+04  fin obj.: 1.12757e+05
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 3.86699e+04  fin obj.: 3.23780e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 3.23780e+04  fin obj.: 3.06276e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 3.23780e+04  fin obj.: 2.85262e+04
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 2.85262e+04  fin obj.: 2.32341e+05
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 2.85262e+04  fin obj.: 2.58497e+04
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 2.58497e+04  fin obj.: 1.95117e+05
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 2.58497e+04  fin obj.: 2.36541e+04
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 2.36541e+04  fin obj.: 7.83020e+04
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 2.36541e+04  fin obj.: 2.16104e+04
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 2.16104e+04  fin obj.: 1.56387e+05
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 2.16104e+04  fin obj.: 1.97673e+04
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 1.97673e+04  fin obj.: 1.45058e+05
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 1.97673e+04  fin obj.: 1.81696e+04
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 1.81696e+04  fin obj.: 1.35104e+05
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 1.81696e+04  fin obj.: 1.68218e+04
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 1.68218e+04  fin obj.: 1.28011e+05
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 1.68218e+04  fin obj.: 1.56592e+04
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 1.56592e+04  fin obj.: 1.22511e+05
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 1.56592e+04  fin obj.: 1.46341e+04
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 1.46341e+04  fin obj.: 1.17995e+05
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 1.46341e+04  fin obj.: 1.38922e+04
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 1.38922e+04  fin obj.: 1.05465e+05
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 1.38922e+04  fin obj.: 1.29297e+04
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 1.29297e+04  fin obj.: 1.11095e+05
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 1.29297e+04  fin obj.: 9.91121e+04
# it: 14   it_marq:  2   lambda: 1e+02   init obj.: 1.29297e+04  fin obj.: 1.30221e+04
# it: 14   it_marq:  3   lambda: 1e+03   init obj.: 1.29297e+04  fin obj.: 1.29197e+04
# it: 15   it_marq:  0   lambda: 1e+02   init obj.: 1.29197e+04  fin obj.: 1.28308e+04
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 1.28308e+04  fin obj.: 9.31688e+04
# it: 16   it_marq:  1   lambda: 1e+02   init obj.: 1.28308e+04  fin obj.: 1.27456e+04
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 1.27456e+04  fin obj.: 9.32048e+04
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 1.27456e+04  fin obj.: 1.26629e+04
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 1.26629e+04  fin obj.: 9.31887e+04
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 1.26629e+04  fin obj.: 1.25820e+04
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 1.25820e+04  fin obj.: 9.31689e+04
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 1.25820e+04  fin obj.: 1.25025e+04
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 1.25025e+04  fin obj.: 9.31466e+04
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 1.25025e+04  fin obj.: 1.24243e+04
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 1.24243e+04  fin obj.: 9.31249e+04
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 1.24243e+04  fin obj.: 1.23471e+04
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 1.23471e+04  fin obj.: 9.31041e+04
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 1.23471e+04  fin obj.: 1.22710e+04
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 1.22710e+04  fin obj.: 9.30855e+04
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 1.22710e+04  fin obj.: 1.21959e+04
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 1.21959e+04  fin obj.: 9.30688e+04
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 1.21959e+04  fin obj.: 1.21217e+04
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 1.21217e+04  fin obj.: 9.30545e+04
# it: 25   it_marq:  1   lambda: 1e+02   init obj.: 1.21217e+04  fin obj.: 1.20484e+04
# it: 26   it_marq:  0   lambda: 1e+01   init obj.: 1.20484e+04  fin obj.: 9.30424e+04
# it: 26   it_marq:  1   lambda: 1e+02   init obj.: 1.20484e+04  fin obj.: 1.19759e+04
# it: 27   it_marq:  0   lambda: 1e+01   init obj.: 1.19759e+04  fin obj.: 9.30328e+04
# it: 27   it_marq:  1   lambda: 1e+02   init obj.: 1.19759e+04  fin obj.: 1.19043e+04
# it: 28   it_marq:  0   lambda: 1e+01   init obj.: 1.19043e+04  fin obj.: 9.30233e+04
# it: 28   it_marq:  1   lambda: 1e+02   init obj.: 1.19043e+04  fin obj.: 1.18335e+04
# it: 29   it_marq:  0   lambda: 1e+01   init obj.: 1.18335e+04  fin obj.: 9.30168e+04
# it: 29   it_marq:  1   lambda: 1e+02   init obj.: 1.18335e+04  fin obj.: 1.17635e+04
# inversion: 3  top: 10  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.20668e+05  fin obj.: 7.00387e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 7.00387e+04  fin obj.: 1.43323e+05
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 7.00387e+04  fin obj.: 5.18966e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 5.18966e+04  fin obj.: 1.51770e+05
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 5.18966e+04  fin obj.: 4.27745e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 4.27745e+04  fin obj.: 3.80634e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 4.27745e+04  fin obj.: 5.39916e+04
# it:  3   it_marq:  2   lambda: 1e+02   init obj.: 4.27745e+04  fin obj.: 4.10805e+04
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 4.10805e+04  fin obj.: 7.33079e+04
# it:  4   it_marq:  1   lambda: 1e+02   init obj.: 4.10805e+04  fin obj.: 4.00180e+04
# it:  5   it_marq:  0   lambda: 1e+01   init obj.: 4.00180e+04  fin obj.: 7.47981e+04
# it:  5   it_marq:  1   lambda: 1e+02   init obj.: 4.00180e+04  fin obj.: 3.93059e+04
# it:  6   it_marq:  0   lambda: 1e+01   init obj.: 3.93059e+04  fin obj.: 7.26128e+04
# it:  6   it_marq:  1   lambda: 1e+02   init obj.: 3.93059e+04  fin obj.: 3.87474e+04
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 3.87474e+04  fin obj.: 7.04042e+04
# it:  7   it_marq:  1   lambda: 1e+02   init obj.: 3.87474e+04  fin obj.: 3.82347e+04
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 3.82347e+04  fin obj.: 6.98918e+04
# it:  8   it_marq:  1   lambda: 1e+02   init obj.: 3.82347e+04  fin obj.: 3.77446e+04
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 3.77446e+04  fin obj.: 6.92711e+04
# it:  9   it_marq:  1   lambda: 1e+02   init obj.: 3.77446e+04  fin obj.: 3.72758e+04
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 3.72758e+04  fin obj.: 6.85556e+04
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 3.72758e+04  fin obj.: 3.68268e+04
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 3.68268e+04  fin obj.: 6.80671e+04
# it: 11   it_marq:  1   lambda: 1e+02   init obj.: 3.68268e+04  fin obj.: 3.63816e+04
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 3.63816e+04  fin obj.: 6.76092e+04
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 3.63816e+04  fin obj.: 3.59384e+04
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 3.59384e+04  fin obj.: 6.71748e+04
# it: 13   it_marq:  1   lambda: 1e+02   init obj.: 3.59384e+04  fin obj.: 3.54970e+04
# it: 14   it_marq:  0   lambda: 1e+01   init obj.: 3.54970e+04  fin obj.: 6.67747e+04
# it: 14   it_marq:  1   lambda: 1e+02   init obj.: 3.54970e+04  fin obj.: 3.50575e+04
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 3.50575e+04  fin obj.: 6.64234e+04
# it: 15   it_marq:  1   lambda: 1e+02   init obj.: 3.50575e+04  fin obj.: 3.46203e+04
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 3.46203e+04  fin obj.: 6.61398e+04
# it: 16   it_marq:  1   lambda: 1e+02   init obj.: 3.46203e+04  fin obj.: 3.41863e+04
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 3.41863e+04  fin obj.: 6.59446e+04
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 3.41863e+04  fin obj.: 3.37565e+04
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 3.37565e+04  fin obj.: 6.58430e+04
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 3.37565e+04  fin obj.: 3.33321e+04
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 3.33321e+04  fin obj.: 6.57961e+04
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 3.33321e+04  fin obj.: 3.29143e+04
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 3.29143e+04  fin obj.: 6.57386e+04
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 3.29143e+04  fin obj.: 3.25042e+04
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 3.25042e+04  fin obj.: 6.56553e+04
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 3.25042e+04  fin obj.: 3.21029e+04
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 3.21029e+04  fin obj.: 6.55767e+04
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 3.21029e+04  fin obj.: 3.17112e+04
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 3.17112e+04  fin obj.: 6.55179e+04
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 3.17112e+04  fin obj.: 3.13298e+04
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 3.13298e+04  fin obj.: 6.54626e+04
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 3.13298e+04  fin obj.: 3.09591e+04
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 3.09591e+04  fin obj.: 6.53790e+04
# it: 25   it_marq:  1   lambda: 1e+02   init obj.: 3.09591e+04  fin obj.: 3.05994e+04
# it: 26   it_marq:  0   lambda: 1e+01   init obj.: 3.05994e+04  fin obj.: 6.52491e+04
# it: 26   it_marq:  1   lambda: 1e+02   init obj.: 3.05994e+04  fin obj.: 3.02511e+04
# it: 27   it_marq:  0   lambda: 1e+01   init obj.: 3.02511e+04  fin obj.: 6.51103e+04
# it: 27   it_marq:  1   lambda: 1e+02   init obj.: 3.02511e+04  fin obj.: 2.99152e+04
# it: 28   it_marq:  0   lambda: 1e+01   init obj.: 2.99152e+04  fin obj.: 6.50673e+04
# it: 28   it_marq:  1   lambda: 1e+02   init obj.: 2.99152e+04  fin obj.: 2.95920e+04
# it: 29   it_marq:  0   lambda: 1e+01   init obj.: 2.95920e+04  fin obj.: 6.51678e+04
# it: 29   it_marq:  1   lambda: 1e+02   init obj.: 2.95920e+04  fin obj.: 2.92790e+04
# inversion: 4  top: 10  intensity: 14
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.61076e+05  fin obj.: 9.26464e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.26464e+04  fin obj.: 2.07125e+05
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 9.26464e+04  fin obj.: 6.85926e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 6.85926e+04  fin obj.: 1.95916e+05
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 6.85926e+04  fin obj.: 5.62764e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 5.62764e+04  fin obj.: 4.69379e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 5.62764e+04  fin obj.: 9.60908e+04
# it:  3   it_marq:  2   lambda: 1e+02   init obj.: 5.62764e+04  fin obj.: 5.41105e+04
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 5.41105e+04  fin obj.: 9.56080e+04
# it:  4   it_marq:  1   lambda: 1e+02   init obj.: 5.41105e+04  fin obj.: 5.28926e+04
# it:  5   it_marq:  0   lambda: 1e+01   init obj.: 5.28926e+04  fin obj.: 9.16673e+04
# it:  5   it_marq:  1   lambda: 1e+02   init obj.: 5.28926e+04  fin obj.: 5.19892e+04
# it:  6   it_marq:  0   lambda: 1e+01   init obj.: 5.19892e+04  fin obj.: 8.86155e+04
# it:  6   it_marq:  1   lambda: 1e+02   init obj.: 5.19892e+04  fin obj.: 5.10974e+04
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 5.10974e+04  fin obj.: 8.75448e+04
# it:  7   it_marq:  1   lambda: 1e+02   init obj.: 5.10974e+04  fin obj.: 5.03052e+04
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 5.03052e+04  fin obj.: 8.39732e+04
# it:  8   it_marq:  1   lambda: 1e+02   init obj.: 5.03052e+04  fin obj.: 4.94034e+04
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 4.94034e+04  fin obj.: 4.42749e+04
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 4.42749e+04  fin obj.: 2.19607e+05
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 4.42749e+04  fin obj.: 4.81148e+04
# it: 10   it_marq:  2   lambda: 1e+02   init obj.: 4.42749e+04  fin obj.: 4.35297e+04
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 4.35297e+04  fin obj.: 4.75974e+04
# it: 11   it_marq:  1   lambda: 1e+02   init obj.: 4.35297e+04  fin obj.: 4.28327e+04
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 4.28327e+04  fin obj.: 4.71410e+04
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 4.28327e+04  fin obj.: 4.21747e+04
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 4.21747e+04  fin obj.: 4.67201e+04
# it: 13   it_marq:  1   lambda: 1e+02   init obj.: 4.21747e+04  fin obj.: 4.15487e+04
# it: 14   it_marq:  0   lambda: 1e+01   init obj.: 4.15487e+04  fin obj.: 4.63157e+04
# it: 14   it_marq:  1   lambda: 1e+02   init obj.: 4.15487e+04  fin obj.: 4.09524e+04
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 4.09524e+04  fin obj.: 4.59250e+04
# it: 15   it_marq:  1   lambda: 1e+02   init obj.: 4.09524e+04  fin obj.: 4.03835e+04
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 4.03835e+04  fin obj.: 4.55462e+04
# it: 16   it_marq:  1   lambda: 1e+02   init obj.: 4.03835e+04  fin obj.: 3.98398e+04
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 3.98398e+04  fin obj.: 4.53270e+04
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 3.98398e+04  fin obj.: 3.93193e+04
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 3.93193e+04  fin obj.: 5.25869e+04
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 3.93193e+04  fin obj.: 3.88202e+04
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 3.88202e+04  fin obj.: 5.35246e+04
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 3.88202e+04  fin obj.: 3.83407e+04
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 3.83407e+04  fin obj.: 6.08451e+04
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 3.83407e+04  fin obj.: 3.78793e+04
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 3.78793e+04  fin obj.: 6.04500e+04
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 3.78793e+04  fin obj.: 3.74345e+04
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 3.74345e+04  fin obj.: 6.00585e+04
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 3.74345e+04  fin obj.: 3.70050e+04
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 3.70050e+04  fin obj.: 6.38054e+04
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 3.70050e+04  fin obj.: 3.65897e+04
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 3.65897e+04  fin obj.: 6.34136e+04
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 3.65897e+04  fin obj.: 3.61876e+04
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 3.61876e+04  fin obj.: 6.30311e+04
# it: 25   it_marq:  1   lambda: 1e+02   init obj.: 3.61876e+04  fin obj.: 3.57978e+04
# it: 26   it_marq:  0   lambda: 1e+01   init obj.: 3.57978e+04  fin obj.: 6.26580e+04
# it: 26   it_marq:  1   lambda: 1e+02   init obj.: 3.57978e+04  fin obj.: 3.54194e+04
# it: 27   it_marq:  0   lambda: 1e+01   init obj.: 3.54194e+04  fin obj.: 6.22957e+04
# it: 27   it_marq:  1   lambda: 1e+02   init obj.: 3.54194e+04  fin obj.: 3.50517e+04
# it: 28   it_marq:  0   lambda: 1e+01   init obj.: 3.50517e+04  fin obj.: 6.19447e+04
# it: 28   it_marq:  1   lambda: 1e+02   init obj.: 3.50517e+04  fin obj.: 3.46940e+04
# it: 29   it_marq:  0   lambda: 1e+01   init obj.: 3.46940e+04  fin obj.: 6.16061e+04
# it: 29   it_marq:  1   lambda: 1e+02   init obj.: 3.46940e+04  fin obj.: 3.43458e+04
# inversion: 5  top: 10  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.08444e+05  fin obj.: 1.19532e+05
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.19532e+05  fin obj.: 2.74303e+05
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 1.19532e+05  fin obj.: 8.89396e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 8.89396e+04  fin obj.: 2.44399e+05
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 8.89396e+04  fin obj.: 7.35334e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 7.35334e+04  fin obj.: 6.10531e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 7.35334e+04  fin obj.: 4.34834e+05
# it:  3   it_marq:  2   lambda: 1e+02   init obj.: 7.35334e+04  fin obj.: 7.09570e+04
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 7.09570e+04  fin obj.: 4.26087e+05
# it:  4   it_marq:  1   lambda: 1e+02   init obj.: 7.09570e+04  fin obj.: 6.90490e+04
# it:  5   it_marq:  0   lambda: 1e+01   init obj.: 6.90490e+04  fin obj.: 3.87787e+05
# it:  5   it_marq:  1   lambda: 1e+02   init obj.: 6.90490e+04  fin obj.: 6.88070e+04
# it:  6   it_marq:  0   lambda: 1e+01   init obj.: 6.88070e+04  fin obj.: 6.13024e+04
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 6.13024e+04  fin obj.: 2.68163e+05
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 6.13024e+04  fin obj.: 5.87282e+04
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 5.87282e+04  fin obj.: 8.01290e+04
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 5.87282e+04  fin obj.: 4.76675e+04
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 4.76675e+04  fin obj.: 3.35511e+05
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 4.76675e+04  fin obj.: 6.48904e+04
# it:  9   it_marq:  2   lambda: 1e+02   init obj.: 4.76675e+04  fin obj.: 5.15712e+05
# it:  9   it_marq:  3   lambda: 1e+03   init obj.: 4.76675e+04  fin obj.: 2.79799e+05
# it:  9   it_marq:  4   lambda: 1e+04   init obj.: 4.76675e+04  fin obj.: 4.76437e+04
# it: 10   it_marq:  0   lambda: 1e+03   init obj.: 4.76437e+04  fin obj.: 4.73586e+04
# it: 11   it_marq:  0   lambda: 1e+02   init obj.: 4.73586e+04  fin obj.: 4.67825e+04
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 4.67825e+04  fin obj.: 6.07494e+04
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 4.67825e+04  fin obj.: 4.62619e+04
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 4.62619e+04  fin obj.: 4.13483e+04
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 4.13483e+04  fin obj.: 2.69880e+05
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 4.13483e+04  fin obj.: 4.13661e+04
# it: 14   it_marq:  2   lambda: 1e+02   init obj.: 4.13483e+04  fin obj.: 5.42437e+04
# it: 14   it_marq:  3   lambda: 1e+03   init obj.: 4.13483e+04  fin obj.: 5.30566e+04
# it: 14   it_marq:  4   lambda: 1e+04   init obj.: 4.13483e+04  fin obj.: 4.13494e+04
# it: 14   it_marq:  5   lambda: 1e+05   init obj.: 4.13483e+04  fin obj.: 4.13497e+04
# it: 14   it_marq:  6   lambda: 1e+06   init obj.: 4.13483e+04  fin obj.: 4.13503e+04
# it: 14   it_marq:  7   lambda: 1e+07   init obj.: 4.13483e+04  fin obj.: 4.13504e+04
# it: 14   it_marq:  8   lambda: 1e+08   init obj.: 4.13483e+04  fin obj.: 4.13504e+04
# it: 14   it_marq:  9   lambda: 1e+09   init obj.: 4.13483e+04  fin obj.: 4.13504e+04
# inversion: 6  top: 50  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.60024e+04  fin obj.: 1.53172e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.53172e+04  fin obj.: 7.38958e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 7.38958e+03  fin obj.: 9.84551e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 7.38958e+03  fin obj.: 3.08777e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 3.08777e+03  fin obj.: 1.80529e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 3.08777e+03  fin obj.: 1.74412e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 1.74412e+03  fin obj.: 2.15169e+04
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 1.74412e+03  fin obj.: 1.28764e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 1.28764e+03  fin obj.: 7.21501e+03
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 1.28764e+03  fin obj.: 9.78090e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 9.78090e+02  fin obj.: 1.50389e+04
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 9.78090e+02  fin obj.: 1.99108e+03
# it:  6   it_marq:  2   lambda: 1e+01   init obj.: 9.78090e+02  fin obj.: 9.49038e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 9.49038e+02  fin obj.: 7.61192e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 9.49038e+02  fin obj.: 1.47632e+03
# ...
# it: 23   it_marq:  5   lambda: 1e+194   init obj.: 1.58269e+03  fin obj.: 2.28281e+03
# it: 23   it_marq:  6   lambda: 1e+195   init obj.: 1.58269e+03  fin obj.: 2.28281e+03
# it: 23   it_marq:  7   lambda: 1e+196   init obj.: 1.58269e+03  fin obj.: 2.28281e+03
# it: 23   it_marq:  8   lambda: 1e+197   init obj.: 1.58269e+03  fin obj.: 2.28281e+03
# it: 23   it_marq:  9   lambda: 1e+198   init obj.: 1.58269e+03  fin obj.: 2.28281e+03
# it: 24   it_marq:  0   lambda: 1e+199   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  1   lambda: 1e+200   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  2   lambda: 1e+201   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  3   lambda: 1e+202   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  4   lambda: 1e+203   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  5   lambda: 1e+204   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  6   lambda: 1e+205   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  7   lambda: 1e+206   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  8   lambda: 1e+207   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 24   it_marq:  9   lambda: 1e+208   init obj.: 1.58269e+03  fin obj.: 2.28289e+03
# it: 25   it_marq:  0   lambda: 1e+209   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  1   lambda: 1e+210   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  2   lambda: 1e+211   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  3   lambda: 1e+212   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  4   lambda: 1e+213   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  5   lambda: 1e+214   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  6   lambda: 1e+215   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  7   lambda: 1e+216   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  8   lambda: 1e+217   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 25   it_marq:  9   lambda: 1e+218   init obj.: 1.58269e+03  fin obj.: 2.28297e+03
# it: 26   it_marq:  0   lambda: 1e+219   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  1   lambda: 1e+220   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  2   lambda: 1e+221   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  3   lambda: 1e+222   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  4   lambda: 1e+223   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  5   lambda: 1e+224   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  6   lambda: 1e+225   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  7   lambda: 1e+226   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  8   lambda: 1e+227   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 26   it_marq:  9   lambda: 1e+228   init obj.: 1.58269e+03  fin obj.: 2.28304e+03
# it: 27   it_marq:  0   lambda: 1e+229   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  1   lambda: 1e+230   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  2   lambda: 1e+231   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  3   lambda: 1e+232   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  4   lambda: 1e+233   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  5   lambda: 1e+234   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  6   lambda: 1e+235   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  7   lambda: 1e+236   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  8   lambda: 1e+237   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 27   it_marq:  9   lambda: 1e+238   init obj.: 1.58269e+03  fin obj.: 2.28312e+03
# it: 28   it_marq:  0   lambda: 1e+239   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  1   lambda: 1e+240   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  2   lambda: 1e+241   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  3   lambda: 1e+242   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  4   lambda: 1e+243   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  5   lambda: 1e+244   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  6   lambda: 1e+245   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  7   lambda: 1e+246   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  8   lambda: 1e+247   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 28   it_marq:  9   lambda: 1e+248   init obj.: 1.58269e+03  fin obj.: 2.28319e+03
# it: 29   it_marq:  0   lambda: 1e+249   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  1   lambda: 1e+250   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  2   lambda: 1e+251   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  3   lambda: 1e+252   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  4   lambda: 1e+253   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  5   lambda: 1e+254   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  6   lambda: 1e+255   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  7   lambda: 1e+256   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  8   lambda: 1e+257   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# it: 29   it_marq:  9   lambda: 1e+258   init obj.: 1.58269e+03  fin obj.: 2.28327e+03
# inversion: 34  top: 210  intensity: 14
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.03428e+04  fin obj.: 1.00851e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.00851e+04  fin obj.: 1.72468e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.72468e+03  fin obj.: 1.21146e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.21146e+03  fin obj.: 1.40454e+05
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.21146e+03  fin obj.: 4.63070e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.21146e+03  fin obj.: 8.52563e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.21146e+03  fin obj.: 1.28544e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.21146e+03  fin obj.: 1.06512e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.06512e+03  fin obj.: 7.95865e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 7.95865e+02  fin obj.: 7.05849e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 7.05849e+02  fin obj.: 7.51874e+03
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 7.05849e+02  fin obj.: 7.13582e+02
# it:  6   it_marq:  2   lambda: 1e+01   init obj.: 7.05849e+02  fin obj.: 6.84254e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 6.84254e+02  fin obj.: 7.14010e+02
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 6.84254e+02  fin obj.: 6.79309e+02
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 6.79309e+02  fin obj.: 7.13845e+02
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 6.79309e+02  fin obj.: 6.77028e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 6.77028e+02  fin obj.: 7.13572e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 6.77028e+02  fin obj.: 6.75607e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 6.75607e+02  fin obj.: 7.13328e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 6.75607e+02  fin obj.: 6.74573e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 6.74573e+02  fin obj.: 7.13141e+02
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 6.74573e+02  fin obj.: 6.73747e+02
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 6.73747e+02  fin obj.: 7.13010e+02
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 6.73747e+02  fin obj.: 6.73050e+02
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 6.73050e+02  fin obj.: 7.12929e+02
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 6.73050e+02  fin obj.: 6.72437e+02
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 6.72437e+02  fin obj.: 7.12889e+02
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 6.72437e+02  fin obj.: 6.71886e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 6.71886e+02  fin obj.: 7.12884e+02
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 6.71886e+02  fin obj.: 6.71383e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 6.71383e+02  fin obj.: 7.12915e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 6.71383e+02  fin obj.: 6.70919e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 6.70919e+02  fin obj.: 7.12972e+02
# it: 17   it_marq:  1   lambda: 1e+01   init obj.: 6.70919e+02  fin obj.: 6.70487e+02
# it: 18   it_marq:  0   lambda: 1e+00   init obj.: 6.70487e+02  fin obj.: 7.13050e+02
# it: 18   it_marq:  1   lambda: 1e+01   init obj.: 6.70487e+02  fin obj.: 6.70081e+02
# it: 19   it_marq:  0   lambda: 1e+00   init obj.: 6.70081e+02  fin obj.: 7.13145e+02
# it: 19   it_marq:  1   lambda: 1e+01   init obj.: 6.70081e+02  fin obj.: 6.69699e+02
# it: 20   it_marq:  0   lambda: 1e+00   init obj.: 6.69699e+02  fin obj.: 7.13252e+02
# it: 20   it_marq:  1   lambda: 1e+01   init obj.: 6.69699e+02  fin obj.: 6.69337e+02
# it: 21   it_marq:  0   lambda: 1e+00   init obj.: 6.69337e+02  fin obj.: 7.13370e+02
# it: 21   it_marq:  1   lambda: 1e+01   init obj.: 6.69337e+02  fin obj.: 6.68993e+02
# it: 22   it_marq:  0   lambda: 1e+00   init obj.: 6.68993e+02  fin obj.: 7.13497e+02
# it: 22   it_marq:  1   lambda: 1e+01   init obj.: 6.68993e+02  fin obj.: 6.68665e+02
# it: 23   it_marq:  0   lambda: 1e+00   init obj.: 6.68665e+02  fin obj.: 7.13631e+02
# it: 23   it_marq:  1   lambda: 1e+01   init obj.: 6.68665e+02  fin obj.: 6.68352e+02
# it: 24   it_marq:  0   lambda: 1e+00   init obj.: 6.68352e+02  fin obj.: 7.13772e+02
# it: 24   it_marq:  1   lambda: 1e+01   init obj.: 6.68352e+02  fin obj.: 6.68053e+02
# it: 25   it_marq:  0   lambda: 1e+00   init obj.: 6.68053e+02  fin obj.: 7.13915e+02
# it: 25   it_marq:  1   lambda: 1e+01   init obj.: 6.68053e+02  fin obj.: 6.67766e+02
# it: 26   it_marq:  0   lambda: 1e+00   init obj.: 6.67766e+02  fin obj.: 7.14060e+02
# it: 26   it_marq:  1   lambda: 1e+01   init obj.: 6.67766e+02  fin obj.: 6.67490e+02
# it: 27   it_marq:  0   lambda: 1e+00   init obj.: 6.67490e+02  fin obj.: 7.14205e+02
# it: 27   it_marq:  1   lambda: 1e+01   init obj.: 6.67490e+02  fin obj.: 6.67226e+02
# it: 28   it_marq:  0   lambda: 1e+00   init obj.: 6.67226e+02  fin obj.: 7.14351e+02
# it: 28   it_marq:  1   lambda: 1e+01   init obj.: 6.67226e+02  fin obj.: 6.68040e+02
# it: 28   it_marq:  2   lambda: 1e+02   init obj.: 6.67226e+02  fin obj.: 7.74254e+03
# it: 28   it_marq:  3   lambda: 1e+03   init obj.: 6.67226e+02  fin obj.: 5.46653e+03
# it: 28   it_marq:  4   lambda: 1e+04   init obj.: 6.67226e+02  fin obj.: 1.14284e+03
# it: 28   it_marq:  5   lambda: 1e+05   init obj.: 6.67226e+02  fin obj.: 7.16160e+02
# it: 28   it_marq:  6   lambda: 1e+06   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 28   it_marq:  7   lambda: 1e+07   init obj.: 6.67226e+02  fin obj.: 7.11474e+02
# it: 28   it_marq:  8   lambda: 1e+08   init obj.: 6.67226e+02  fin obj.: 7.11474e+02
# it: 28   it_marq:  9   lambda: 1e+09   init obj.: 6.67226e+02  fin obj.: 7.11474e+02
# it: 29   it_marq:  0   lambda: 1e+10   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  1   lambda: 1e+11   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  2   lambda: 1e+12   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  3   lambda: 1e+13   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  4   lambda: 1e+14   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  5   lambda: 1e+15   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  6   lambda: 1e+16   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  7   lambda: 1e+17   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  8   lambda: 1e+18   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# it: 29   it_marq:  9   lambda: 1e+19   init obj.: 6.67226e+02  fin obj.: 7.11506e+02
# inversion: 35  top: 210  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 4.12097e+04  fin obj.: 1.24931e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.24931e+04  fin obj.: 1.91742e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.91742e+03  fin obj.: 4.81852e+02
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 4.81852e+02  fin obj.: 6.97235e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 4.81852e+02  fin obj.: 3.70462e+02
# it:  4   it_marq:  0   lambda: 1e-02   init obj.: 3.70462e+02  fin obj.: 5.36524e+04
# it:  4   it_marq:  1   lambda: 1e-01   init obj.: 3.70462e+02  fin obj.: 3.88957e+02
# it:  4   it_marq:  2   lambda: 1e+00   init obj.: 3.70462e+02  fin obj.: 3.21420e+02
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 3.21420e+02  fin obj.: 4.81976e+02
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 3.21420e+02  fin obj.: 3.18241e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 3.18241e+02  fin obj.: 4.99354e+02
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 3.18241e+02  fin obj.: 3.16848e+02
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 3.16848e+02  fin obj.: 4.93628e+02
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 3.16848e+02  fin obj.: 3.15911e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 3.15911e+02  fin obj.: 4.83838e+02
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 3.15911e+02  fin obj.: 3.15236e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 3.15236e+02  fin obj.: 4.76695e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 3.15236e+02  fin obj.: 3.14734e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 3.14734e+02  fin obj.: 4.68869e+02
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 3.14734e+02  fin obj.: 3.14348e+02
# it: 11   it_marq:  0   lambda: 1e-01   init obj.: 3.14348e+02  fin obj.: 4.53965e+02
# it: 11   it_marq:  1   lambda: 1e+00   init obj.: 3.14348e+02  fin obj.: 3.14040e+02
# it: 12   it_marq:  0   lambda: 1e-01   init obj.: 3.14040e+02  fin obj.: 4.32133e+02
# it: 12   it_marq:  1   lambda: 1e+00   init obj.: 3.14040e+02  fin obj.: 3.13783e+02
# it: 13   it_marq:  0   lambda: 1e-01   init obj.: 3.13783e+02  fin obj.: 4.20713e+02
# it: 13   it_marq:  1   lambda: 1e+00   init obj.: 3.13783e+02  fin obj.: 3.13561e+02
# it: 14   it_marq:  0   lambda: 1e-01   init obj.: 3.13561e+02  fin obj.: 4.25389e+02
# it: 14   it_marq:  1   lambda: 1e+00   init obj.: 3.13561e+02  fin obj.: 3.13364e+02
# it: 15   it_marq:  0   lambda: 1e-01   init obj.: 3.13364e+02  fin obj.: 4.27651e+02
# it: 15   it_marq:  1   lambda: 1e+00   init obj.: 3.13364e+02  fin obj.: 3.13188e+02
# it: 16   it_marq:  0   lambda: 1e-01   init obj.: 3.13188e+02  fin obj.: 4.25276e+02
# it: 16   it_marq:  1   lambda: 1e+00   init obj.: 3.13188e+02  fin obj.: 3.13032e+02
# it: 17   it_marq:  0   lambda: 1e-01   init obj.: 3.13032e+02  fin obj.: 4.26065e+02
# it: 17   it_marq:  1   lambda: 1e+00   init obj.: 3.13032e+02  fin obj.: 3.12896e+02
# it: 18   it_marq:  0   lambda: 1e-01   init obj.: 3.12896e+02  fin obj.: 4.30330e+02
# it: 18   it_marq:  1   lambda: 1e+00   init obj.: 3.12896e+02  fin obj.: 3.12779e+02
# it: 19   it_marq:  0   lambda: 1e-01   init obj.: 3.12779e+02  fin obj.: 4.34250e+02
# it: 19   it_marq:  1   lambda: 1e+00   init obj.: 3.12779e+02  fin obj.: 3.12681e+02
# it: 20   it_marq:  0   lambda: 1e-01   init obj.: 3.12681e+02  fin obj.: 4.40937e+02
# it: 20   it_marq:  1   lambda: 1e+00   init obj.: 3.12681e+02  fin obj.: 3.12602e+02
# it: 21   it_marq:  0   lambda: 1e-01   init obj.: 3.12602e+02  fin obj.: 5.10161e+02
# it: 21   it_marq:  1   lambda: 1e+00   init obj.: 3.12602e+02  fin obj.: 3.12543e+02
# it: 22   it_marq:  0   lambda: 1e-01   init obj.: 3.12543e+02  fin obj.: 7.31977e+02
# it: 22   it_marq:  1   lambda: 1e+00   init obj.: 3.12543e+02  fin obj.: 3.12507e+02
# it: 23   it_marq:  0   lambda: 1e-01   init obj.: 3.12507e+02  fin obj.: 1.02766e+03
# it: 23   it_marq:  1   lambda: 1e+00   init obj.: 3.12507e+02  fin obj.: 3.12496e+02

# %% [markdown]
# # Results

# %%
# output of inversion
inversion = dict()

inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = np.array([a1, a2, a3, a4, a5, a6, a7])
inversion['tol'] = tol
inversion['main_field'] = [inc, dec]
inversion['intensity'] = intensity
inversion['results'] = inversion_results

# %% [markdown]
# ### Saving results

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
