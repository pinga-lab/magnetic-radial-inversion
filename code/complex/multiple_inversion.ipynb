# %% [markdown]
# # Complex TFA multiple Inversions

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os

from fatiando.vis import mpl
# Out:
# /home/leo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
from datetime import datetime
today = datetime.today()
# dd/mm/YY
d4 = today.strftime("%d-%b-%Y-%Hh:%Mm")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('model.pickle') as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open('data.pickle') as w:
        data = pickle.load(w)

# %%
dobs = data['tfa_obs']
xp = data['x']
yp = data['y']
zp = data['z']
N = data['N']

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 20 # number of vertices per prism
L = 10 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization direction
incs = model['inc']
decs = model['dec']

int_min = 9.
int_max = 15.
intensity = np.linspace(int_min, int_max, 6)

# depth to the top, thickness and radius
z0_min = 30.
z0_max = 230.
z0 = np.linspace(z0_min, z0_max, 6)
dz = 650.
r = 800.
x0 = -300.
y0 = 300.

# main field
inc, dec = data['main_field']

# %%
z0
# Out:
# array([ 30.,  70., 110., 150., 190., 230.])

# %%
intensity
# Out:
# array([ 9. , 10.2, 11.4, 12.6, 13.8, 15. ])

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 10.
rmax = 3000.
x0min = -4000.
x0max = 4000.
y0min = -4000.
y0max = 4000.
dzmin = 200.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Derivatives

# %%
# variation for derivatives
deltax = 0.01*np.max(100.)
deltay = 0.01*np.max(100.)
deltar = 0.01*np.max(100.)
deltaz = 0.01*np.max(100.)

delta = np.array([deltax, deltay, deltar, deltaz])

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-5  # adjacent radial distances within each prism
a2 = 1.0e-4   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 1.0e-4    # vertically adjacent origins
a6 = 1.0e-7   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-6     # zero order Tikhonov on thickness of each prism

alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Folder to save the results

# %%
foldername = '54475'

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-3     # stop criterion

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for j, z in enumerate(z0):
    for k, i in enumerate(intensity):
        alpha = np.array([a1, a2, a3, a4, a5, a6, a7])
        print 'inversion: %d  top: %d  intensity: %d' % (j*z0.size + k, z, i)
        model0, m0 = mfun.initial_cylinder(M, L, x0, y0, z, dz, r, inc, dec, incs, decs, i)
        d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(
            xp, yp, zp, m0, M, L, delta,
            itmax, itmax_marq, lamb,
            dlamb, tol, mmin, mmax,
            m_out, dobs, inc, dec,
            model0[0].props, alpha, z, dz
        )
        inversion_results.append([m_est, phi_list, model_list, dobs - d_fit])
# Out:
# inversion: 0  top: 30  intensity: 9
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.31338e+04  fin obj.: 1.53275e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.53275e+04  fin obj.: 7.16046e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 7.16046e+03  fin obj.: 6.18751e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 6.18751e+03  fin obj.: 8.95275e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 6.18751e+03  fin obj.: 1.55631e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 6.18751e+03  fin obj.: 1.71716e+04
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 6.18751e+03  fin obj.: 5.47738e+03
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 5.47738e+03  fin obj.: 2.10168e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 2.10168e+03  fin obj.: 7.57972e+03
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 2.10168e+03  fin obj.: 1.43947e+03
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 1.43947e+03  fin obj.: 1.17578e+03
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 1.17578e+03  fin obj.: 2.93997e+03
# it:  7   it_marq:  1   lambda: 1e-01   init obj.: 1.17578e+03  fin obj.: 1.02119e+03
# it:  8   it_marq:  0   lambda: 1e-02   init obj.: 1.02119e+03  fin obj.: 2.15775e+03
# it:  8   it_marq:  1   lambda: 1e-01   init obj.: 1.02119e+03  fin obj.: 1.19421e+03
# it:  8   it_marq:  2   lambda: 1e+00   init obj.: 1.02119e+03  fin obj.: 7.80482e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 7.80482e+02  fin obj.: 9.00644e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 7.80482e+02  fin obj.: 7.48786e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 7.48786e+02  fin obj.: 9.04870e+02
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 7.48786e+02  fin obj.: 7.25100e+02
# it: 11   it_marq:  0   lambda: 1e-01   init obj.: 7.25100e+02  fin obj.: 8.81875e+02
# it: 11   it_marq:  1   lambda: 1e+00   init obj.: 7.25100e+02  fin obj.: 7.06527e+02
# it: 12   it_marq:  0   lambda: 1e-01   init obj.: 7.06527e+02  fin obj.: 8.59737e+02
# it: 12   it_marq:  1   lambda: 1e+00   init obj.: 7.06527e+02  fin obj.: 6.91084e+02
# it: 13   it_marq:  0   lambda: 1e-01   init obj.: 6.91084e+02  fin obj.: 8.39837e+02
# it: 13   it_marq:  1   lambda: 1e+00   init obj.: 6.91084e+02  fin obj.: 6.77628e+02
# it: 14   it_marq:  0   lambda: 1e-01   init obj.: 6.77628e+02  fin obj.: 8.21701e+02
# it: 14   it_marq:  1   lambda: 1e+00   init obj.: 6.77628e+02  fin obj.: 6.65580e+02
# it: 15   it_marq:  0   lambda: 1e-01   init obj.: 6.65580e+02  fin obj.: 8.05145e+02
# it: 15   it_marq:  1   lambda: 1e+00   init obj.: 6.65580e+02  fin obj.: 6.54608e+02
# it: 16   it_marq:  0   lambda: 1e-01   init obj.: 6.54608e+02  fin obj.: 7.90179e+02
# it: 16   it_marq:  1   lambda: 1e+00   init obj.: 6.54608e+02  fin obj.: 6.44498e+02
# it: 17   it_marq:  0   lambda: 1e-01   init obj.: 6.44498e+02  fin obj.: 7.76900e+02
# it: 17   it_marq:  1   lambda: 1e+00   init obj.: 6.44498e+02  fin obj.: 6.35097e+02
# it: 18   it_marq:  0   lambda: 1e-01   init obj.: 6.35097e+02  fin obj.: 7.65398e+02
# it: 18   it_marq:  1   lambda: 1e+00   init obj.: 6.35097e+02  fin obj.: 6.26283e+02
# it: 19   it_marq:  0   lambda: 1e-01   init obj.: 6.26283e+02  fin obj.: 7.55696e+02
# it: 19   it_marq:  1   lambda: 1e+00   init obj.: 6.26283e+02  fin obj.: 6.17949e+02
# it: 20   it_marq:  0   lambda: 1e-01   init obj.: 6.17949e+02  fin obj.: 7.47709e+02
# it: 20   it_marq:  1   lambda: 1e+00   init obj.: 6.17949e+02  fin obj.: 6.09994e+02
# it: 21   it_marq:  0   lambda: 1e-01   init obj.: 6.09994e+02  fin obj.: 7.41225e+02
# it: 21   it_marq:  1   lambda: 1e+00   init obj.: 6.09994e+02  fin obj.: 6.02313e+02
# it: 22   it_marq:  0   lambda: 1e-01   init obj.: 6.02313e+02  fin obj.: 7.35911e+02
# it: 22   it_marq:  1   lambda: 1e+00   init obj.: 6.02313e+02  fin obj.: 5.94794e+02
# it: 23   it_marq:  0   lambda: 1e-01   init obj.: 5.94794e+02  fin obj.: 7.31392e+02
# it: 23   it_marq:  1   lambda: 1e+00   init obj.: 5.94794e+02  fin obj.: 5.87295e+02
# it: 24   it_marq:  0   lambda: 1e-01   init obj.: 5.87295e+02  fin obj.: 7.27511e+02
# it: 24   it_marq:  1   lambda: 1e+00   init obj.: 5.87295e+02  fin obj.: 5.79665e+02
# it: 25   it_marq:  0   lambda: 1e-01   init obj.: 5.79665e+02  fin obj.: 7.24167e+02
# it: 25   it_marq:  1   lambda: 1e+00   init obj.: 5.79665e+02  fin obj.: 5.72005e+02
# it: 26   it_marq:  0   lambda: 1e-01   init obj.: 5.72005e+02  fin obj.: 7.20835e+02
# it: 26   it_marq:  1   lambda: 1e+00   init obj.: 5.72005e+02  fin obj.: 5.64269e+02
# it: 27   it_marq:  0   lambda: 1e-01   init obj.: 5.64269e+02  fin obj.: 7.17205e+02
# it: 27   it_marq:  1   lambda: 1e+00   init obj.: 5.64269e+02  fin obj.: 5.56374e+02
# it: 28   it_marq:  0   lambda: 1e-01   init obj.: 5.56374e+02  fin obj.: 7.13230e+02
# it: 28   it_marq:  1   lambda: 1e+00   init obj.: 5.56374e+02  fin obj.: 5.48279e+02
# it: 29   it_marq:  0   lambda: 1e-01   init obj.: 5.48279e+02  fin obj.: 7.08964e+02
# it: 29   it_marq:  1   lambda: 1e+00   init obj.: 5.48279e+02  fin obj.: 5.39961e+02
# inversion: 1  top: 30  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.48805e+04  fin obj.: 2.13681e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 2.13681e+04  fin obj.: 1.10197e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.10197e+04  fin obj.: 9.50856e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 9.50856e+03  fin obj.: 2.89262e+04
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 9.50856e+03  fin obj.: 1.44030e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 9.50856e+03  fin obj.: 9.28992e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 9.28992e+03  fin obj.: 3.28149e+03
# it:  5   it_marq:  0   lambda: 1e-02   init obj.: 3.28149e+03  fin obj.: 2.31949e+04
# it:  5   it_marq:  1   lambda: 1e-01   init obj.: 3.28149e+03  fin obj.: 1.90836e+04
# it:  5   it_marq:  2   lambda: 1e+00   init obj.: 3.28149e+03  fin obj.: 6.40819e+03
# it:  5   it_marq:  3   lambda: 1e+01   init obj.: 3.28149e+03  fin obj.: 1.82869e+03
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 1.82869e+03  fin obj.: 7.10339e+03
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 1.82869e+03  fin obj.: 1.49465e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 1.49465e+03  fin obj.: 7.47006e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 1.49465e+03  fin obj.: 5.49624e+03
# it:  7   it_marq:  2   lambda: 1e+02   init obj.: 1.49465e+03  fin obj.: 1.47423e+03
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 1.47423e+03  fin obj.: 5.51797e+03
# it:  8   it_marq:  1   lambda: 1e+02   init obj.: 1.47423e+03  fin obj.: 1.45721e+03
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 1.45721e+03  fin obj.: 5.53825e+03
# it:  9   it_marq:  1   lambda: 1e+02   init obj.: 1.45721e+03  fin obj.: 1.44267e+03
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 1.44267e+03  fin obj.: 1.45223e+03
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 1.44267e+03  fin obj.: 1.43751e+03
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 1.43751e+03  fin obj.: 1.35760e+03
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 1.35760e+03  fin obj.: 1.18222e+03
# it: 13   it_marq:  0   lambda: 1e-01   init obj.: 1.18222e+03  fin obj.: 1.02404e+03
# it: 14   it_marq:  0   lambda: 1e-02   init obj.: 1.02404e+03  fin obj.: 1.17453e+03
# it: 14   it_marq:  1   lambda: 1e-01   init obj.: 1.02404e+03  fin obj.: 1.14477e+03
# it: 14   it_marq:  2   lambda: 1e+00   init obj.: 1.02404e+03  fin obj.: 1.15329e+03
# it: 14   it_marq:  3   lambda: 1e+01   init obj.: 1.02404e+03  fin obj.: 1.05993e+03
# it: 14   it_marq:  4   lambda: 1e+02   init obj.: 1.02404e+03  fin obj.: 1.04328e+03
# it: 14   it_marq:  5   lambda: 1e+03   init obj.: 1.02404e+03  fin obj.: 9.94183e+02
# it: 15   it_marq:  0   lambda: 1e+02   init obj.: 9.94183e+02  fin obj.: 9.91500e+02
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 9.91500e+02  fin obj.: 9.80624e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 9.80624e+02  fin obj.: 9.54861e+02
# it: 18   it_marq:  0   lambda: 1e-01   init obj.: 9.54861e+02  fin obj.: 8.94661e+02
# it: 19   it_marq:  0   lambda: 1e-02   init obj.: 8.94661e+02  fin obj.: 1.00354e+03
# it: 19   it_marq:  1   lambda: 1e-01   init obj.: 8.94661e+02  fin obj.: 8.52974e+02
# it: 20   it_marq:  0   lambda: 1e-02   init obj.: 8.52974e+02  fin obj.: 9.55873e+02
# it: 20   it_marq:  1   lambda: 1e-01   init obj.: 8.52974e+02  fin obj.: 8.23938e+02
# it: 21   it_marq:  0   lambda: 1e-02   init obj.: 8.23938e+02  fin obj.: 3.33585e+03
# it: 21   it_marq:  1   lambda: 1e-01   init obj.: 8.23938e+02  fin obj.: 1.06537e+03
# it: 21   it_marq:  2   lambda: 1e+00   init obj.: 8.23938e+02  fin obj.: 2.26513e+03
# it: 21   it_marq:  3   lambda: 1e+01   init obj.: 8.23938e+02  fin obj.: 9.63182e+02
# it: 21   it_marq:  4   lambda: 1e+02   init obj.: 8.23938e+02  fin obj.: 8.47149e+02
# it: 21   it_marq:  5   lambda: 1e+03   init obj.: 8.23938e+02  fin obj.: 8.51253e+02
# it: 21   it_marq:  6   lambda: 1e+04   init obj.: 8.23938e+02  fin obj.: 8.51791e+02
# it: 21   it_marq:  7   lambda: 1e+05   init obj.: 8.23938e+02  fin obj.: 8.23887e+02
# inversion: 2  top: 30  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 5.58407e+04  fin obj.: 3.18939e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 3.18939e+04  fin obj.: 2.00771e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 2.00771e+04  fin obj.: 4.57204e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 2.00771e+04  fin obj.: 9.76581e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 9.76581e+03  fin obj.: 7.61495e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 9.76581e+03  fin obj.: 5.59687e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 5.59687e+03  fin obj.: 1.62869e+05
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 5.59687e+03  fin obj.: 4.40702e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 4.40702e+03  fin obj.: 1.76975e+04
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 4.40702e+03  fin obj.: 3.16475e+03
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 3.16475e+03  fin obj.: 5.81383e+04
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 3.16475e+03  fin obj.: 8.38117e+04
# it:  6   it_marq:  2   lambda: 1e+01   init obj.: 3.16475e+03  fin obj.: 7.73335e+04
# it:  6   it_marq:  3   lambda: 1e+02   init obj.: 3.16475e+03  fin obj.: 6.97555e+04
# it:  6   it_marq:  4   lambda: 1e+03   init obj.: 3.16475e+03  fin obj.: 3.25997e+03
# it:  6   it_marq:  5   lambda: 1e+04   init obj.: 3.16475e+03  fin obj.: 3.19927e+03
# it:  6   it_marq:  6   lambda: 1e+05   init obj.: 3.16475e+03  fin obj.: 3.16488e+03
# it:  6   it_marq:  7   lambda: 1e+06   init obj.: 3.16475e+03  fin obj.: 3.16491e+03
# it:  6   it_marq:  8   lambda: 1e+07   init obj.: 3.16475e+03  fin obj.: 3.16492e+03
# it:  6   it_marq:  9   lambda: 1e+08   init obj.: 3.16475e+03  fin obj.: 3.16492e+03
# inversion: 3  top: 30  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 8.60146e+04  fin obj.: 4.72428e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 4.72428e+04  fin obj.: 3.89781e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.89781e+04  fin obj.: 1.11186e+05
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.89781e+04  fin obj.: 1.72701e+04
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 1.72701e+04  fin obj.: 4.66893e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 1.72701e+04  fin obj.: 9.77314e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 9.77314e+03  fin obj.: 1.56850e+05
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 9.77314e+03  fin obj.: 6.11424e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 6.11424e+03  fin obj.: 1.57199e+05
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 6.11424e+03  fin obj.: 4.76421e+03
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 4.76421e+03  fin obj.: 6.64899e+04
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 4.76421e+03  fin obj.: 4.29103e+04
# it:  6   it_marq:  2   lambda: 1e+01   init obj.: 4.76421e+03  fin obj.: 4.73364e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 4.73364e+03  fin obj.: 1.39384e+04
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 4.73364e+03  fin obj.: 4.69734e+03
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 4.69734e+03  fin obj.: 4.29151e+04
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 4.69734e+03  fin obj.: 2.16373e+04
# it:  8   it_marq:  2   lambda: 1e+02   init obj.: 4.69734e+03  fin obj.: 4.57683e+03
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 4.57683e+03  fin obj.: 5.49856e+03
# it:  9   it_marq:  1   lambda: 1e+02   init obj.: 4.57683e+03  fin obj.: 4.69250e+03
# it:  9   it_marq:  2   lambda: 1e+03   init obj.: 4.57683e+03  fin obj.: 4.55916e+03
# it: 10   it_marq:  0   lambda: 1e+02   init obj.: 4.55916e+03  fin obj.: 2.75807e+05
# it: 10   it_marq:  1   lambda: 1e+03   init obj.: 4.55916e+03  fin obj.: 4.56460e+03
# it: 10   it_marq:  2   lambda: 1e+04   init obj.: 4.55916e+03  fin obj.: 4.55912e+03
# inversion: 4  top: 30  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.25402e+05  fin obj.: 6.76763e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 6.76763e+04  fin obj.: 7.12308e+04
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 6.76763e+04  fin obj.: 4.78992e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 4.78992e+04  fin obj.: 1.31645e+05
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 4.78992e+04  fin obj.: 3.84874e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 3.84874e+04  fin obj.: 2.23081e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 3.84874e+04  fin obj.: 3.39596e+04
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 3.39596e+04  fin obj.: 8.31945e+04
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 3.39596e+04  fin obj.: 3.01385e+04
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 3.01385e+04  fin obj.: 7.88744e+04
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 3.01385e+04  fin obj.: 2.66159e+04
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 2.66159e+04  fin obj.: 6.93205e+04
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 2.66159e+04  fin obj.: 2.37082e+04
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 2.37082e+04  fin obj.: 6.80303e+04
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 2.37082e+04  fin obj.: 2.15028e+04
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 2.15028e+04  fin obj.: 6.85713e+04
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 2.15028e+04  fin obj.: 1.98027e+04
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 1.98027e+04  fin obj.: 5.96418e+04
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 1.98027e+04  fin obj.: 2.77788e+04
# it:  9   it_marq:  2   lambda: 1e+02   init obj.: 1.98027e+04  fin obj.: 1.99871e+04
# it:  9   it_marq:  3   lambda: 1e+03   init obj.: 1.98027e+04  fin obj.: 2.01453e+04
# it:  9   it_marq:  4   lambda: 1e+04   init obj.: 1.98027e+04  fin obj.: 1.97998e+04
# inversion: 5  top: 30  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.74003e+05  fin obj.: 9.33744e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.33744e+04  fin obj.: 1.17507e+05
# it:  1   it_marq:  1   lambda: 1e+01   init obj.: 9.33744e+04  fin obj.: 6.65094e+04
# it:  2   it_marq:  0   lambda: 1e+00   init obj.: 6.65094e+04  fin obj.: 1.74806e+05
# it:  2   it_marq:  1   lambda: 1e+01   init obj.: 6.65094e+04  fin obj.: 5.42958e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 5.42958e+04  fin obj.: 1.55227e+05
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 5.42958e+04  fin obj.: 4.84135e+04
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 4.84135e+04  fin obj.: 9.48460e+04
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 4.84135e+04  fin obj.: 4.20744e+04
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 4.20744e+04  fin obj.: 3.40055e+04
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 3.40055e+04  fin obj.: 3.10697e+04
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 3.10697e+04  fin obj.: 1.87880e+04
# it:  8   it_marq:  0   lambda: 1e-03   init obj.: 1.87880e+04  fin obj.: 4.02379e+05
# it:  8   it_marq:  1   lambda: 1e-02   init obj.: 1.87880e+04  fin obj.: 5.41460e+05
# it:  8   it_marq:  2   lambda: 1e-01   init obj.: 1.87880e+04  fin obj.: 6.09885e+05
# it:  8   it_marq:  3   lambda: 1e+00   init obj.: 1.87880e+04  fin obj.: 2.08158e+05
# it:  8   it_marq:  4   lambda: 1e+01   init obj.: 1.87880e+04  fin obj.: 2.24091e+05
# it:  8   it_marq:  5   lambda: 1e+02   init obj.: 1.87880e+04  fin obj.: 2.07803e+05
# it:  8   it_marq:  6   lambda: 1e+03   init obj.: 1.87880e+04  fin obj.: 1.61793e+04
# it:  9   it_marq:  0   lambda: 1e+02   init obj.: 1.61793e+04  fin obj.: 2.36744e+05
# it:  9   it_marq:  1   lambda: 1e+03   init obj.: 1.61793e+04  fin obj.: 1.78164e+05
# it:  9   it_marq:  2   lambda: 1e+04   init obj.: 1.61793e+04  fin obj.: 4.36723e+04
# it:  9   it_marq:  3   lambda: 1e+05   init obj.: 1.61793e+04  fin obj.: 4.34578e+04
# it:  9   it_marq:  4   lambda: 1e+06   init obj.: 1.61793e+04  fin obj.: 2.42216e+04
# it:  9   it_marq:  5   lambda: 1e+07   init obj.: 1.61793e+04  fin obj.: 1.41433e+04
# it: 10   it_marq:  0   lambda: 1e+06   init obj.: 1.41433e+04  fin obj.: 1.41424e+04
# inversion: 6  top: 70  intensity: 9
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.76912e+04  fin obj.: 1.08627e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.08627e+04  fin obj.: 3.75486e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.75486e+03  fin obj.: 5.39295e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.75486e+03  fin obj.: 1.72923e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 1.72923e+03  fin obj.: 1.48249e+03
# it:  4   it_marq:  0   lambda: 1e-02   init obj.: 1.48249e+03  fin obj.: 2.14785e+03
# it:  4   it_marq:  1   lambda: 1e-01   init obj.: 1.48249e+03  fin obj.: 1.01674e+03
# it:  5   it_marq:  0   lambda: 1e-02   init obj.: 1.01674e+03  fin obj.: 3.33385e+03
# it:  5   it_marq:  1   lambda: 1e-01   init obj.: 1.01674e+03  fin obj.: 3.52839e+03
# it:  5   it_marq:  2   lambda: 1e+00   init obj.: 1.01674e+03  fin obj.: 7.14019e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 7.14019e+02  fin obj.: 9.19076e+02
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 7.14019e+02  fin obj.: 5.34668e+02
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 5.34668e+02  fin obj.: 9.18648e+02
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 5.34668e+02  fin obj.: 5.12409e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 5.12409e+02  fin obj.: 8.86624e+02
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 5.12409e+02  fin obj.: 4.97634e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 4.97634e+02  fin obj.: 8.68802e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 4.97634e+02  fin obj.: 4.86774e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 4.86774e+02  fin obj.: 8.55049e+02
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 4.86774e+02  fin obj.: 4.78873e+02
# it: 11   it_marq:  0   lambda: 1e-01   init obj.: 4.78873e+02  fin obj.: 8.55169e+02
# it: 11   it_marq:  1   lambda: 1e+00   init obj.: 4.78873e+02  fin obj.: 4.73611e+02
# it: 12   it_marq:  0   lambda: 1e-01   init obj.: 4.73611e+02  fin obj.: 8.61722e+02
# it: 12   it_marq:  1   lambda: 1e+00   init obj.: 4.73611e+02  fin obj.: 4.70830e+02
# it: 13   it_marq:  0   lambda: 1e-01   init obj.: 4.70830e+02  fin obj.: 8.74311e+02
# it: 13   it_marq:  1   lambda: 1e+00   init obj.: 4.70830e+02  fin obj.: 4.70661e+02
# inversion: 7  top: 70  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.29851e+04  fin obj.: 1.28452e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.28452e+04  fin obj.: 4.45885e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 4.45885e+03  fin obj.: 1.65385e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.65385e+03  fin obj.: 2.32237e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.65385e+03  fin obj.: 6.23473e+02
# it:  4   it_marq:  0   lambda: 1e-02   init obj.: 6.23473e+02  fin obj.: 6.23354e+02
# inversion: 8  top: 70  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.61450e+04  fin obj.: 1.83154e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.83154e+04  fin obj.: 7.83980e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 7.83980e+03  fin obj.: 1.43623e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 7.83980e+03  fin obj.: 3.25474e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 3.25474e+03  fin obj.: 7.39146e+03
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 3.25474e+03  fin obj.: 1.82696e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 1.82696e+03  fin obj.: 1.12591e+04
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 1.82696e+03  fin obj.: 1.30710e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 1.30710e+03  fin obj.: 5.47063e+03
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 1.30710e+03  fin obj.: 1.06020e+03
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 1.06020e+03  fin obj.: 2.93751e+03
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 1.06020e+03  fin obj.: 8.97424e+02
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 8.97424e+02  fin obj.: 1.78163e+03
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 8.97424e+02  fin obj.: 7.86037e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 7.86037e+02  fin obj.: 1.15956e+03
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 7.86037e+02  fin obj.: 7.10218e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 7.10218e+02  fin obj.: 1.09891e+03
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 7.10218e+02  fin obj.: 6.55111e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 6.55111e+02  fin obj.: 1.69250e+03
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 6.55111e+02  fin obj.: 8.00013e+02
# it: 10   it_marq:  2   lambda: 1e+01   init obj.: 6.55111e+02  fin obj.: 6.72311e+02
# it: 10   it_marq:  3   lambda: 1e+02   init obj.: 6.55111e+02  fin obj.: 6.54472e+02
# inversion: 9  top: 70  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 5.71709e+04  fin obj.: 2.75550e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 2.75550e+04  fin obj.: 1.69361e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.69361e+04  fin obj.: 7.84353e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 1.69361e+04  fin obj.: 6.81297e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 6.81297e+03  fin obj.: 3.36088e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 6.81297e+03  fin obj.: 3.78367e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 3.78367e+03  fin obj.: 1.09581e+05
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 3.78367e+03  fin obj.: 2.28505e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 2.28505e+03  fin obj.: 6.54881e+04
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 2.28505e+03  fin obj.: 1.76742e+03
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 1.76742e+03  fin obj.: 5.50282e+04
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 1.76742e+03  fin obj.: 1.51239e+03
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 1.51239e+03  fin obj.: 5.13659e+04
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 1.51239e+03  fin obj.: 1.34353e+03
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 1.34353e+03  fin obj.: 2.97015e+04
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 1.34353e+03  fin obj.: 1.22238e+03
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 1.22238e+03  fin obj.: 1.38799e+04
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 1.22238e+03  fin obj.: 1.13263e+03
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 1.13263e+03  fin obj.: 1.59113e+04
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 1.13263e+03  fin obj.: 2.63291e+05
# it: 10   it_marq:  2   lambda: 1e+01   init obj.: 1.13263e+03  fin obj.: 2.62564e+05
# it: 10   it_marq:  3   lambda: 1e+02   init obj.: 1.13263e+03  fin obj.: 2.81261e+05
# it: 10   it_marq:  4   lambda: 1e+03   init obj.: 1.13263e+03  fin obj.: 1.62983e+03
# it: 10   it_marq:  5   lambda: 1e+04   init obj.: 1.13263e+03  fin obj.: 1.60020e+03
# it: 10   it_marq:  6   lambda: 1e+05   init obj.: 1.13263e+03  fin obj.: 1.60010e+03
# it: 10   it_marq:  7   lambda: 1e+06   init obj.: 1.13263e+03  fin obj.: 1.60009e+03
# it: 10   it_marq:  8   lambda: 1e+07   init obj.: 1.13263e+03  fin obj.: 1.60009e+03
# it: 10   it_marq:  9   lambda: 1e+08   init obj.: 1.13263e+03  fin obj.: 1.60009e+03
# it: 11   it_marq:  0   lambda: 1e+09   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  1   lambda: 1e+10   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  2   lambda: 1e+11   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  3   lambda: 1e+12   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  4   lambda: 1e+13   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  5   lambda: 1e+14   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  6   lambda: 1e+15   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  7   lambda: 1e+16   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  8   lambda: 1e+17   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 11   it_marq:  9   lambda: 1e+18   init obj.: 1.13263e+03  fin obj.: 1.60016e+03
# it: 12   it_marq:  0   lambda: 1e+19   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  1   lambda: 1e+20   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  2   lambda: 1e+21   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  3   lambda: 1e+22   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  4   lambda: 1e+23   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  5   lambda: 1e+24   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  6   lambda: 1e+25   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  7   lambda: 1e+26   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  8   lambda: 1e+27   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 12   it_marq:  9   lambda: 1e+28   init obj.: 1.13263e+03  fin obj.: 1.60024e+03
# it: 13   it_marq:  0   lambda: 1e+29   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  1   lambda: 1e+30   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  2   lambda: 1e+31   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  3   lambda: 1e+32   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  4   lambda: 1e+33   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  5   lambda: 1e+34   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  6   lambda: 1e+35   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  7   lambda: 1e+36   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  8   lambda: 1e+37   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 13   it_marq:  9   lambda: 1e+38   init obj.: 1.13263e+03  fin obj.: 1.60032e+03
# it: 14   it_marq:  0   lambda: 1e+39   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  1   lambda: 1e+40   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  2   lambda: 1e+41   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  3   lambda: 1e+42   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  4   lambda: 1e+43   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  5   lambda: 1e+44   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  6   lambda: 1e+45   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  7   lambda: 1e+46   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  8   lambda: 1e+47   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 14   it_marq:  9   lambda: 1e+48   init obj.: 1.13263e+03  fin obj.: 1.60040e+03
# it: 15   it_marq:  0   lambda: 1e+49   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  1   lambda: 1e+50   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  2   lambda: 1e+51   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  3   lambda: 1e+52   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  4   lambda: 1e+53   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  5   lambda: 1e+54   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  6   lambda: 1e+55   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  7   lambda: 1e+56   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  8   lambda: 1e+57   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 15   it_marq:  9   lambda: 1e+58   init obj.: 1.13263e+03  fin obj.: 1.60048e+03
# it: 16   it_marq:  0   lambda: 1e+59   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  1   lambda: 1e+60   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  2   lambda: 1e+61   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  3   lambda: 1e+62   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  4   lambda: 1e+63   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  5   lambda: 1e+64   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  6   lambda: 1e+65   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  7   lambda: 1e+66   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  8   lambda: 1e+67   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 16   it_marq:  9   lambda: 1e+68   init obj.: 1.13263e+03  fin obj.: 1.60056e+03
# it: 17   it_marq:  0   lambda: 1e+69   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  1   lambda: 1e+70   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  2   lambda: 1e+71   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  3   lambda: 1e+72   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  4   lambda: 1e+73   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  5   lambda: 1e+74   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  6   lambda: 1e+75   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  7   lambda: 1e+76   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  8   lambda: 1e+77   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 17   it_marq:  9   lambda: 1e+78   init obj.: 1.13263e+03  fin obj.: 1.60064e+03
# it: 18   it_marq:  0   lambda: 1e+79   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  1   lambda: 1e+80   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  2   lambda: 1e+81   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  3   lambda: 1e+82   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  4   lambda: 1e+83   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  5   lambda: 1e+84   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  6   lambda: 1e+85   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  7   lambda: 1e+86   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  8   lambda: 1e+87   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 18   it_marq:  9   lambda: 1e+88   init obj.: 1.13263e+03  fin obj.: 1.60072e+03
# it: 19   it_marq:  0   lambda: 1e+89   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  1   lambda: 1e+90   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  2   lambda: 1e+91   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  3   lambda: 1e+92   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  4   lambda: 1e+93   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  5   lambda: 1e+94   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  6   lambda: 1e+95   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  7   lambda: 1e+96   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  8   lambda: 1e+97   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 19   it_marq:  9   lambda: 1e+98   init obj.: 1.13263e+03  fin obj.: 1.60080e+03
# it: 20   it_marq:  0   lambda: 1e+99   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  1   lambda: 1e+100   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  2   lambda: 1e+101   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  3   lambda: 1e+102   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  4   lambda: 1e+103   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  5   lambda: 1e+104   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  6   lambda: 1e+105   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  7   lambda: 1e+106   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  8   lambda: 1e+107   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 20   it_marq:  9   lambda: 1e+108   init obj.: 1.13263e+03  fin obj.: 1.60088e+03
# it: 21   it_marq:  0   lambda: 1e+109   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  1   lambda: 1e+110   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  2   lambda: 1e+111   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  3   lambda: 1e+112   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  4   lambda: 1e+113   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  5   lambda: 1e+114   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  6   lambda: 1e+115   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  7   lambda: 1e+116   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  8   lambda: 1e+117   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 21   it_marq:  9   lambda: 1e+118   init obj.: 1.13263e+03  fin obj.: 1.60096e+03
# it: 22   it_marq:  0   lambda: 1e+119   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  1   lambda: 1e+120   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  2   lambda: 1e+121   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  3   lambda: 1e+122   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  4   lambda: 1e+123   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  5   lambda: 1e+124   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  6   lambda: 1e+125   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  7   lambda: 1e+126   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  8   lambda: 1e+127   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 22   it_marq:  9   lambda: 1e+128   init obj.: 1.13263e+03  fin obj.: 1.60104e+03
# it: 23   it_marq:  0   lambda: 1e+129   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  1   lambda: 1e+130   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  2   lambda: 1e+131   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  3   lambda: 1e+132   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  4   lambda: 1e+133   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  5   lambda: 1e+134   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  6   lambda: 1e+135   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  7   lambda: 1e+136   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  8   lambda: 1e+137   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 23   it_marq:  9   lambda: 1e+138   init obj.: 1.13263e+03  fin obj.: 1.60112e+03
# it: 24   it_marq:  0   lambda: 1e+139   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  1   lambda: 1e+140   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  2   lambda: 1e+141   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  3   lambda: 1e+142   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  4   lambda: 1e+143   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  5   lambda: 1e+144   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  6   lambda: 1e+145   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  7   lambda: 1e+146   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  8   lambda: 1e+147   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 24   it_marq:  9   lambda: 1e+148   init obj.: 1.13263e+03  fin obj.: 1.60120e+03
# it: 25   it_marq:  0   lambda: 1e+149   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  1   lambda: 1e+150   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  2   lambda: 1e+151   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  3   lambda: 1e+152   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  4   lambda: 1e+153   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  5   lambda: 1e+154   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  6   lambda: 1e+155   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  7   lambda: 1e+156   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  8   lambda: 1e+157   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 25   it_marq:  9   lambda: 1e+158   init obj.: 1.13263e+03  fin obj.: 1.60128e+03
# it: 26   it_marq:  0   lambda: 1e+159   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  1   lambda: 1e+160   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  2   lambda: 1e+161   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  3   lambda: 1e+162   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  4   lambda: 1e+163   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  5   lambda: 1e+164   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  6   lambda: 1e+165   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  7   lambda: 1e+166   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  8   lambda: 1e+167   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 26   it_marq:  9   lambda: 1e+168   init obj.: 1.13263e+03  fin obj.: 1.60137e+03
# it: 27   it_marq:  0   lambda: 1e+169   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  1   lambda: 1e+170   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  2   lambda: 1e+171   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  3   lambda: 1e+172   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  4   lambda: 1e+173   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  5   lambda: 1e+174   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  6   lambda: 1e+175   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  7   lambda: 1e+176   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  8   lambda: 1e+177   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 27   it_marq:  9   lambda: 1e+178   init obj.: 1.13263e+03  fin obj.: 1.60145e+03
# it: 28   it_marq:  0   lambda: 1e+179   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  1   lambda: 1e+180   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  2   lambda: 1e+181   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  3   lambda: 1e+182   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  4   lambda: 1e+183   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  5   lambda: 1e+184   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  6   lambda: 1e+185   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  7   lambda: 1e+186   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  8   lambda: 1e+187   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 28   it_marq:  9   lambda: 1e+188   init obj.: 1.13263e+03  fin obj.: 1.60153e+03
# it: 29   it_marq:  0   lambda: 1e+189   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  1   lambda: 1e+190   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  2   lambda: 1e+191   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  3   lambda: 1e+192   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  4   lambda: 1e+193   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  5   lambda: 1e+194   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  6   lambda: 1e+195   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  7   lambda: 1e+196   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  8   lambda: 1e+197   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# it: 29   it_marq:  9   lambda: 1e+198   init obj.: 1.13263e+03  fin obj.: 1.60161e+03
# inversion: 10  top: 70  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 8.60628e+04  fin obj.: 4.08224e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 4.08224e+04  fin obj.: 3.68322e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.68322e+04  fin obj.: 1.42362e+05
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.68322e+04  fin obj.: 1.33988e+04
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 1.33988e+04  fin obj.: 7.07468e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 1.33988e+04  fin obj.: 6.84004e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 6.84004e+03  fin obj.: 3.99120e+03
# it:  5   it_marq:  0   lambda: 1e-02   init obj.: 3.99120e+03  fin obj.: 1.09307e+05
# it:  5   it_marq:  1   lambda: 1e-01   init obj.: 3.99120e+03  fin obj.: 2.22149e+04
# it:  5   it_marq:  2   lambda: 1e+00   init obj.: 3.99120e+03  fin obj.: 2.10347e+03
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 2.10347e+03  fin obj.: 2.84939e+03
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 2.10347e+03  fin obj.: 3.33034e+03
# it:  6   it_marq:  2   lambda: 1e+01   init obj.: 2.10347e+03  fin obj.: 1.93448e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 1.93448e+03  fin obj.: 2.83611e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 1.93448e+03  fin obj.: 2.45772e+04
# it:  7   it_marq:  2   lambda: 1e+02   init obj.: 1.93448e+03  fin obj.: 5.56252e+04
# it:  7   it_marq:  3   lambda: 1e+03   init obj.: 1.93448e+03  fin obj.: 1.93741e+04
# it:  7   it_marq:  4   lambda: 1e+04   init obj.: 1.93448e+03  fin obj.: 1.24594e+04
# it:  7   it_marq:  5   lambda: 1e+05   init obj.: 1.93448e+03  fin obj.: 1.23473e+04
# it:  7   it_marq:  6   lambda: 1e+06   init obj.: 1.93448e+03  fin obj.: 9.74736e+03
# it:  7   it_marq:  7   lambda: 1e+07   init obj.: 1.93448e+03  fin obj.: 4.40442e+03
# it:  7   it_marq:  8   lambda: 1e+08   init obj.: 1.93448e+03  fin obj.: 4.40500e+03
# it:  7   it_marq:  9   lambda: 1e+09   init obj.: 1.93448e+03  fin obj.: 2.41127e+03
# it:  8   it_marq:  0   lambda: 1e+10   init obj.: 1.93448e+03  fin obj.: 2.40816e+03
# it:  8   it_marq:  1   lambda: 1e+11   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  2   lambda: 1e+12   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  3   lambda: 1e+13   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  4   lambda: 1e+14   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  5   lambda: 1e+15   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  6   lambda: 1e+16   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  7   lambda: 1e+17   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  8   lambda: 1e+18   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  8   it_marq:  9   lambda: 1e+19   init obj.: 1.93448e+03  fin obj.: 2.41141e+03
# it:  9   it_marq:  0   lambda: 1e+20   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  1   lambda: 1e+21   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  2   lambda: 1e+22   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  3   lambda: 1e+23   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  4   lambda: 1e+24   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  5   lambda: 1e+25   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  6   lambda: 1e+26   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  7   lambda: 1e+27   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  8   lambda: 1e+28   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it:  9   it_marq:  9   lambda: 1e+29   init obj.: 1.93448e+03  fin obj.: 2.41156e+03
# it: 10   it_marq:  0   lambda: 1e+30   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  1   lambda: 1e+31   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  2   lambda: 1e+32   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  3   lambda: 1e+33   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  4   lambda: 1e+34   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  5   lambda: 1e+35   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  6   lambda: 1e+36   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  7   lambda: 1e+37   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  8   lambda: 1e+38   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 10   it_marq:  9   lambda: 1e+39   init obj.: 1.93448e+03  fin obj.: 2.41170e+03
# it: 11   it_marq:  0   lambda: 1e+40   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  1   lambda: 1e+41   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  2   lambda: 1e+42   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  3   lambda: 1e+43   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  4   lambda: 1e+44   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  5   lambda: 1e+45   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  6   lambda: 1e+46   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  7   lambda: 1e+47   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  8   lambda: 1e+48   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 11   it_marq:  9   lambda: 1e+49   init obj.: 1.93448e+03  fin obj.: 2.41184e+03
# it: 12   it_marq:  0   lambda: 1e+50   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  1   lambda: 1e+51   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  2   lambda: 1e+52   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  3   lambda: 1e+53   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  4   lambda: 1e+54   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  5   lambda: 1e+55   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  6   lambda: 1e+56   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  7   lambda: 1e+57   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  8   lambda: 1e+58   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 12   it_marq:  9   lambda: 1e+59   init obj.: 1.93448e+03  fin obj.: 2.41199e+03
# it: 13   it_marq:  0   lambda: 1e+60   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  1   lambda: 1e+61   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  2   lambda: 1e+62   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  3   lambda: 1e+63   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  4   lambda: 1e+64   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  5   lambda: 1e+65   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  6   lambda: 1e+66   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  7   lambda: 1e+67   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  8   lambda: 1e+68   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 13   it_marq:  9   lambda: 1e+69   init obj.: 1.93448e+03  fin obj.: 2.41213e+03
# it: 14   it_marq:  0   lambda: 1e+70   init obj.: 1.93448e+03  fin obj.: 2.41228e+03
# it: 14   it_marq:  1   lambda: 1e+71   init obj.: 1.93448e+03  fin obj.: 2.41228e+03
# it: 14   it_marq:  2   lambda: 1e+72   init obj.: 1.93448e+03  fin obj.: 2.41228e+03
# it: 14   it_marq:  3   lambda: 1e+73   init obj.: 1.93448e+03  fin obj.: 2.41228e+03
# it: 14   it_marq:  4   lambda: 1e+74   init obj.: 1.93448e+03  fin obj.: 2.41228e+03
# it: 14   it_marq:  5   lambda: 1e+75   init obj.: 1.93448e+03  fin obj.: 2.41228e+03
# ...
# it: 24   it_marq:  2   lambda: 1e+172   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  3   lambda: 1e+173   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  4   lambda: 1e+174   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  5   lambda: 1e+175   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  6   lambda: 1e+176   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  7   lambda: 1e+177   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  8   lambda: 1e+178   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 24   it_marq:  9   lambda: 1e+179   init obj.: 1.76801e+02  fin obj.: 9.45075e+03
# it: 25   it_marq:  0   lambda: 1e+180   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  1   lambda: 1e+181   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  2   lambda: 1e+182   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  3   lambda: 1e+183   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  4   lambda: 1e+184   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  5   lambda: 1e+185   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  6   lambda: 1e+186   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  7   lambda: 1e+187   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  8   lambda: 1e+188   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 25   it_marq:  9   lambda: 1e+189   init obj.: 1.76801e+02  fin obj.: 9.45108e+03
# it: 26   it_marq:  0   lambda: 1e+190   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  1   lambda: 1e+191   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  2   lambda: 1e+192   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  3   lambda: 1e+193   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  4   lambda: 1e+194   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  5   lambda: 1e+195   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  6   lambda: 1e+196   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  7   lambda: 1e+197   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  8   lambda: 1e+198   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 26   it_marq:  9   lambda: 1e+199   init obj.: 1.76801e+02  fin obj.: 9.45142e+03
# it: 27   it_marq:  0   lambda: 1e+200   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  1   lambda: 1e+201   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  2   lambda: 1e+202   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  3   lambda: 1e+203   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  4   lambda: 1e+204   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  5   lambda: 1e+205   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  6   lambda: 1e+206   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  7   lambda: 1e+207   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  8   lambda: 1e+208   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 27   it_marq:  9   lambda: 1e+209   init obj.: 1.76801e+02  fin obj.: 9.45175e+03
# it: 28   it_marq:  0   lambda: 1e+210   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  1   lambda: 1e+211   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  2   lambda: 1e+212   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  3   lambda: 1e+213   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  4   lambda: 1e+214   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  5   lambda: 1e+215   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  6   lambda: 1e+216   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  7   lambda: 1e+217   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  8   lambda: 1e+218   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 28   it_marq:  9   lambda: 1e+219   init obj.: 1.76801e+02  fin obj.: 9.45209e+03
# it: 29   it_marq:  0   lambda: 1e+220   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  1   lambda: 1e+221   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  2   lambda: 1e+222   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  3   lambda: 1e+223   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  4   lambda: 1e+224   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  5   lambda: 1e+225   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  6   lambda: 1e+226   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  7   lambda: 1e+227   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  8   lambda: 1e+228   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# it: 29   it_marq:  9   lambda: 1e+229   init obj.: 1.76801e+02  fin obj.: 9.45242e+03
# inversion: 30  top: 230  intensity: 9
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.89510e+04  fin obj.: 1.94092e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.94092e+04  fin obj.: 1.74034e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.74034e+04  fin obj.: 9.08558e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 1.74034e+04  fin obj.: 4.13252e+04
# it:  2   it_marq:  2   lambda: 1e+01   init obj.: 1.74034e+04  fin obj.: 1.59944e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 1.59944e+04  fin obj.: 1.83532e+04
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 1.59944e+04  fin obj.: 1.52673e+04
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 1.52673e+04  fin obj.: 1.94366e+04
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 1.52673e+04  fin obj.: 1.52161e+04
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.52161e+04  fin obj.: 2.23148e+04
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 1.52161e+04  fin obj.: 1.55078e+04
# it:  5   it_marq:  2   lambda: 1e+02   init obj.: 1.52161e+04  fin obj.: 1.53036e+04
# it:  5   it_marq:  3   lambda: 1e+03   init obj.: 1.52161e+04  fin obj.: 1.52874e+04
# it:  5   it_marq:  4   lambda: 1e+04   init obj.: 1.52161e+04  fin obj.: 1.52306e+04
# it:  5   it_marq:  5   lambda: 1e+05   init obj.: 1.52161e+04  fin obj.: 1.52307e+04
# it:  5   it_marq:  6   lambda: 1e+06   init obj.: 1.52161e+04  fin obj.: 1.52307e+04
# it:  5   it_marq:  7   lambda: 1e+07   init obj.: 1.52161e+04  fin obj.: 1.52307e+04
# it:  5   it_marq:  8   lambda: 1e+08   init obj.: 1.52161e+04  fin obj.: 1.52307e+04
# it:  5   it_marq:  9   lambda: 1e+09   init obj.: 1.52161e+04  fin obj.: 1.52183e+04
# inversion: 31  top: 230  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.14519e+04  fin obj.: 1.43743e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.43743e+04  fin obj.: 1.06271e+04
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.06271e+04  fin obj.: 1.04880e+05
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 1.06271e+04  fin obj.: 3.82801e+04
# it:  2   it_marq:  2   lambda: 1e+01   init obj.: 1.06271e+04  fin obj.: 1.03951e+04
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 1.03951e+04  fin obj.: 1.70299e+04
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 1.03951e+04  fin obj.: 9.89316e+03
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 9.89316e+03  fin obj.: 2.10065e+04
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 9.89316e+03  fin obj.: 9.77697e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 9.77697e+03  fin obj.: 1.80590e+04
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 9.77697e+03  fin obj.: 9.70858e+03
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 9.70858e+03  fin obj.: 1.30013e+04
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 9.70858e+03  fin obj.: 9.67519e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 9.67519e+03  fin obj.: 1.05441e+04
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 9.67519e+03  fin obj.: 9.65736e+03
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 9.65736e+03  fin obj.: 1.08022e+04
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 9.65736e+03  fin obj.: 9.64932e+03
# inversion: 32  top: 230  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.84554e+04  fin obj.: 1.11858e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.11858e+04  fin obj.: 6.41752e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 6.41752e+03  fin obj.: 1.26645e+05
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 6.41752e+03  fin obj.: 1.83467e+04
# it:  2   it_marq:  2   lambda: 1e+01   init obj.: 6.41752e+03  fin obj.: 6.09994e+03
# it:  3   it_marq:  0   lambda: 1e+00   init obj.: 6.09994e+03  fin obj.: 6.31105e+03
# it:  3   it_marq:  1   lambda: 1e+01   init obj.: 6.09994e+03  fin obj.: 5.99864e+03
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 5.99864e+03  fin obj.: 6.16907e+03
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 5.99864e+03  fin obj.: 5.94268e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 5.94268e+03  fin obj.: 6.24332e+03
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 5.94268e+03  fin obj.: 5.90793e+03
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 5.90793e+03  fin obj.: 6.24847e+03
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 5.90793e+03  fin obj.: 5.88446e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 5.88446e+03  fin obj.: 6.12730e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 5.88446e+03  fin obj.: 5.86724e+03
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 5.86724e+03  fin obj.: 6.23693e+03
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 5.86724e+03  fin obj.: 5.85294e+03
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 5.85294e+03  fin obj.: 8.24029e+03
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 5.85294e+03  fin obj.: 5.83919e+03
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 5.83919e+03  fin obj.: 8.11792e+03
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 5.83919e+03  fin obj.: 5.82647e+03
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 5.82647e+03  fin obj.: 6.71869e+03
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 5.82647e+03  fin obj.: 5.81628e+03
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 5.81628e+03  fin obj.: 6.12254e+03
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 5.81628e+03  fin obj.: 5.80848e+03
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 5.80848e+03  fin obj.: 6.35389e+03
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 5.80848e+03  fin obj.: 5.80261e+03
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 5.80261e+03  fin obj.: 6.47033e+03
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 5.80261e+03  fin obj.: 5.79848e+03
# inversion: 33  top: 230  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.99616e+04  fin obj.: 9.54097e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.54097e+03  fin obj.: 3.89297e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.89297e+03  fin obj.: 1.17892e+04
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.89297e+03  fin obj.: 3.48342e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 3.48342e+03  fin obj.: 4.69007e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 3.48342e+03  fin obj.: 3.62273e+03
# it:  3   it_marq:  2   lambda: 1e+01   init obj.: 3.48342e+03  fin obj.: 3.34276e+03
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 3.34276e+03  fin obj.: 3.42607e+03
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 3.34276e+03  fin obj.: 3.30859e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 3.30859e+03  fin obj.: 3.40102e+03
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 3.30859e+03  fin obj.: 3.29173e+03
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 3.29173e+03  fin obj.: 3.45844e+03
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 3.29173e+03  fin obj.: 3.28167e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 3.28167e+03  fin obj.: 3.52435e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 3.28167e+03  fin obj.: 3.27494e+03
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 3.27494e+03  fin obj.: 3.56711e+03
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 3.27494e+03  fin obj.: 3.27004e+03
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 3.27004e+03  fin obj.: 3.59211e+03
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 3.27004e+03  fin obj.: 3.26624e+03
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 3.26624e+03  fin obj.: 3.60284e+03
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 3.26624e+03  fin obj.: 3.26315e+03
# inversion: 34  top: 230  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.59703e+04  fin obj.: 9.47250e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.47250e+03  fin obj.: 2.42729e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 2.42729e+03  fin obj.: 4.62973e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 2.42729e+03  fin obj.: 1.81100e+03
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 1.81100e+03  fin obj.: 2.60764e+04
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 1.81100e+03  fin obj.: 1.76470e+03
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 1.76470e+03  fin obj.: 4.25452e+03
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 1.76470e+03  fin obj.: 1.83145e+03
# it:  4   it_marq:  2   lambda: 1e+01   init obj.: 1.76470e+03  fin obj.: 1.69561e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.69561e+03  fin obj.: 1.82826e+03
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 1.69561e+03  fin obj.: 1.68335e+03
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 1.68335e+03  fin obj.: 1.82462e+03
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 1.68335e+03  fin obj.: 1.67814e+03
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 1.67814e+03  fin obj.: 1.82014e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 1.67814e+03  fin obj.: 1.67496e+03
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 1.67496e+03  fin obj.: 1.81505e+03
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 1.67496e+03  fin obj.: 1.67263e+03
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 1.67263e+03  fin obj.: 1.81017e+03
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 1.67263e+03  fin obj.: 1.67071e+03
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 1.67071e+03  fin obj.: 1.80659e+03
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 1.67071e+03  fin obj.: 1.66905e+03
# inversion: 35  top: 230  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.64818e+04  fin obj.: 1.10993e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.10993e+04  fin obj.: 1.79017e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 1.79017e+03  fin obj.: 1.55230e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.55230e+03  fin obj.: 1.16837e+05
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.55230e+03  fin obj.: 3.19374e+03
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.55230e+03  fin obj.: 8.39197e+02
# it:  4   it_marq:  0   lambda: 1e-01   init obj.: 8.39197e+02  fin obj.: 1.44102e+03
# it:  4   it_marq:  1   lambda: 1e+00   init obj.: 8.39197e+02  fin obj.: 8.21875e+02
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 8.21875e+02  fin obj.: 1.42691e+03
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 8.21875e+02  fin obj.: 8.33482e+02
# it:  5   it_marq:  2   lambda: 1e+01   init obj.: 8.21875e+02  fin obj.: 7.90379e+02
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 7.90379e+02  fin obj.: 8.31489e+02
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 7.90379e+02  fin obj.: 7.86042e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 7.86042e+02  fin obj.: 8.30512e+02
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 7.86042e+02  fin obj.: 7.84495e+02
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 7.84495e+02  fin obj.: 8.30069e+02
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 7.84495e+02  fin obj.: 7.83654e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 7.83654e+02  fin obj.: 8.29865e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 7.83654e+02  fin obj.: 7.83089e+02

# %% [markdown]
# # Results

# %%
# output of inversion
inversion = dict()

inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['initial_r'] = r
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = np.array([a1, a2, a3, a4, a5, a6, a7])
inversion['tol'] = tol
inversion['main_field'] = [inc, dec]
inversion['intensity'] = intensity
inversion['results'] = inversion_results

# %% [markdown]
# ### Saving results

# %%
if foldername == '':
    mypath = 'results/multiple-'+d4 #default folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)
else:
    mypath = 'results/multiple-'+foldername #defined folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
