# %% [markdown]
# # Complex body TFA Inversion

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA) data on a regular grid of a model with a complex geometry.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
model_dir = 'data/model.pickle'
data_dir = 'data/flightlines_grid_2100pts_100km2_-150m/data.pickle'
#data_dir = 'eqlayer/direction_inc65_dec-40_h190m/eqlayer_depth190m.pickle'

# %%
with open(model_dir) as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open(data_dir) as w:
        data = pickle.load(w)

# %%
# observed data and observation points
dobs = data['tfa_upward_obs']
xp = data['grid'][0]
yp = data['grid'][1]
zp = data['grid'][2]
N = data['grid'][3]

# %% [raw]
# # observed data and observation points
# dobs = data['upward']
# xp = data['x']
# yp = data['y']
# zp = data['z']
# N = data['x'].size

# %%
shit = []
shit.append([1,2])

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 15 # number of vertices per prism
L = 8 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization
incs = model['inc']
decs = model['dec']
intensity = model['intensity']

# depth to the top, thickness and radius
z0 = model['z0']
dz = 600.
r = 500.

# total magnetization
props = {'magnetization': utils.ang2vec(
        intensity, incs, decs)}
rin = np.zeros(M) + r
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) 
m0 = np.hstack((m0, dz)) # inicial parameters vector
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms

varz = 100.
varint = 3.
varinc = 5.
vardec = 5.

param_list = mfun.varying_param(z0, varz, intensity,
                                 varint, incs, varinc, decs, vardec)

# main field
inc, dec = [-21.5, -18.7]

# predict data
d0 = polyprism.tf(xp, yp, zp, model0, inc, dec)

# %%
param_list[0]
# Out:
# [200.0, {'magnetization': array([ 3.21361447, -2.74468605,  9.06307787])}]

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 100.
rmax = 2000.
x0min = -1500.
x0max = 1500.
y0min = -1500.
y0max = 1500.
dzmin = 200.
dzmax = 700.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Variation

# %%
# variation for derivatives
deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)
deltaz = 0.01*np.max(dzmax)

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Folder to save the results

# %%
if data['grid'][4] == 'flightlines':
    if incs == model['inc'] and decs == model['dec']:
        mypath = data_dir[:-11]+'tfa_inversion/multiple_inc%d_dec%d_r%d_int%d_z0%d_dz%d_varz%d_varint%d_varinc%d_vardec%d' % (incs, decs, rin[0], np.linalg.norm(props['magnetization']), z0, dz, varz, varint, varinc, vardec)
        if not os.path.isdir(mypath):
           os.makedirs(mypath)

# %% [raw]
# mypath = data_dir[:-11]+'upward_tfa_inversion/inc%d_dec%d_r%d_int%d_z0%d_dz%d' % (incs, decs, rin[0], np.linalg.norm(props['magnetization']), z0, dz)
# if not os.path.isdir(mypath):
#     os.makedirs(mypath)

# %%
# output of inversion
inversion = dict()

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.00
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.0005  # adjacent radial distances within each prism
a2 = 0.003   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.05     # vertically adjacent origins
a6 = 0.00001   # zero order Tikhonov on adjacent radial distances
a7 = 0.04     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-4     # stop criterion

# %%
inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs

# %%
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['initial_estimate'] = model0
inversion['initial_data'] = d0
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = alpha
inversion['tol'] = tol
inversion['main_field'] = [-21.5, -18.7]
inversion['var'] = [varz, varint, varinc, vardec]

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for p in param_list:
    d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(
        xp, yp, zp, m0, M, L, delta,
        itmax, itmax_marq, lamb,
        dlamb, tol, mmin, mmax,
        m_out, dobs, inc, dec,
        p[1], alpha, p[0], dz
    )
    inversion_results.append([d_fit, m_est, model_est, phi_list, model_list, dobs - d_fit, res_list])
# Out:
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.09690e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.55749e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.33827e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.87493e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 5.19915e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 8.48288e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 4.50228e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.17376e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 4.46894e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.24326e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 3.15133e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 4.17124e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 6.14044e+03
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 2.94085e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.30705e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 2.79193e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.79411e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 2.66529e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 3.79129e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 2.55187e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 3.78354e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 2.69446e+02
# it: 11   it_marq:  2   lambda: 1e+03   misfit: 2.53538e+02
# it: 12   it_marq:  0   lambda: 1e+02   misfit: 2.43885e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 3.33256e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 2.41142e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 6.72096e+03
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 2.28306e+02
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 3.34005e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 2.73153e+03
# it: 15   it_marq:  2   lambda: 1e+03   misfit: 2.26091e+02
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 1.37801e+03
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 2.25453e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 1.17050e+03
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 2.24587e+02
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 2.58571e+02
# it: 18   it_marq:  1   lambda: 1e+03   misfit: 2.23958e+02
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 3.05634e+02
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 2.23101e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 2.97664e+02
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 2.22480e+02
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 2.33687e+02
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 2.21633e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 2.62630e+02
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 2.21019e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 2.39489e+02
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 2.20182e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 2.55120e+02
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 2.19576e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 2.31905e+02
# it: 25   it_marq:  1   lambda: 1e+03   misfit: 2.18748e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 2.51756e+02
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 2.18149e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 2.50573e+02
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 2.17331e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 2.50257e+02
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 2.16739e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 2.81319e+03
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 2.15929e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 6.14837e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 5.36245e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.66576e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.39072e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.59161e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.97461e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 2.76987e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 2.14361e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 1.53254e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 2.38363e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.13397e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 2.42376e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 4.36310e+03
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.07307e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.98687e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.03031e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 1.98501e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 9.97017e+01
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 1.98377e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 9.69637e+01
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.98285e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 9.45264e+01
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.98217e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 9.23126e+01
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.98168e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 9.03254e+01
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.98117e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 8.85904e+01
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 1.98062e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 8.74503e+01
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 1.63103e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 8.57910e+01
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 1.63012e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 8.41546e+01
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 1.62953e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 8.26609e+01
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 1.62913e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 8.12745e+01
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.62891e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 7.99775e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.62878e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 7.87550e+01
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.62805e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 7.76034e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 8.90164e+03
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 7.65017e+01
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 8.33518e+03
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 7.54548e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.97299e+03
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 7.44417e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.45608e+03
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 7.34615e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 8.73115e+02
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 7.25263e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 3.24012e+02
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 7.16311e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.24408e+02
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 7.07723e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.98958e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.75706e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.13024e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.12009e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.49653e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.88218e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 3.64249e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.20143e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 1.63490e+03
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.78322e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.14658e+03
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 3.46331e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 8.82218e+02
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 4.25096e+04
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 2.50759e+04
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 8.36185e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.09880e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 8.01242e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 1.52113e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 7.70067e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 4.44706e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 7.42458e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.78485e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 4.26397e+03
# it: 12   it_marq:  2   lambda: 1e+03   misfit: 7.38291e+02
# it: 13   it_marq:  0   lambda: 1e+02   misfit: 4.91246e+03
# it: 13   it_marq:  1   lambda: 1e+03   misfit: 7.35881e+02
# it: 14   it_marq:  0   lambda: 1e+02   misfit: 9.03393e+03
# it: 14   it_marq:  1   lambda: 1e+03   misfit: 7.32770e+02
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 8.15314e+03
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 7.30930e+02
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 6.58465e+03
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 7.27972e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 9.03020e+03
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 7.26172e+02
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 1.40181e+04
# it: 18   it_marq:  1   lambda: 1e+03   misfit: 7.23263e+02
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 1.40037e+04
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 7.21490e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 9.05759e+03
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 7.18605e+02
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 1.33698e+04
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 7.16859e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 1.26676e+04
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 7.14010e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 2.54465e+03
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 7.12703e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 6.93328e+02
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 3.35923e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 2.25280e+04
# it: 25   it_marq:  2   lambda: 1e+03   misfit: 7.09328e+02
# it: 25   it_marq:  3   lambda: 1e+04   misfit: 7.11202e+02
# it: 25   it_marq:  4   lambda: 1e+05   misfit: 6.91721e+02
# it: 26   it_marq:  0   lambda: 1e+04   misfit: 6.92841e+02
# it: 26   it_marq:  1   lambda: 1e+05   misfit: 6.93432e+02
# it: 26   it_marq:  2   lambda: 1e+06   misfit: 6.93520e+02
# it: 26   it_marq:  3   lambda: 1e+07   misfit: 6.93529e+02
# it: 26   it_marq:  4   lambda: 1e+08   misfit: 6.93530e+02
# it: 26   it_marq:  5   lambda: 1e+09   misfit: 6.93530e+02
# it: 26   it_marq:  6   lambda: 1e+10   misfit: 6.93530e+02
# it: 26   it_marq:  7   lambda: 1e+11   misfit: 6.93530e+02
# it: 26   it_marq:  8   lambda: 1e+12   misfit: 6.93530e+02
# it: 26   it_marq:  9   lambda: 1e+13   misfit: 6.93530e+02
# it: 27   it_marq:  0   lambda: 1e+14   misfit: 6.93646e+02
# it: 27   it_marq:  1   lambda: 1e+15   misfit: 6.93646e+02
# it: 27   it_marq:  2   lambda: 1e+16   misfit: 6.93646e+02
# it: 27   it_marq:  3   lambda: 1e+17   misfit: 6.93646e+02
# it: 27   it_marq:  4   lambda: 1e+18   misfit: 6.93646e+02
# it: 27   it_marq:  5   lambda: 1e+19   misfit: 6.93646e+02
# it: 27   it_marq:  6   lambda: 1e+20   misfit: 6.93646e+02
# it: 27   it_marq:  7   lambda: 1e+21   misfit: 6.93646e+02
# it: 27   it_marq:  8   lambda: 1e+22   misfit: 6.93646e+02
# it: 27   it_marq:  9   lambda: 1e+23   misfit: 6.93646e+02
# it: 28   it_marq:  0   lambda: 1e+24   misfit: 6.93763e+02
# it: 28   it_marq:  1   lambda: 1e+25   misfit: 6.93763e+02
# it: 28   it_marq:  2   lambda: 1e+26   misfit: 6.93763e+02
# it: 28   it_marq:  3   lambda: 1e+27   misfit: 6.93763e+02
# it: 28   it_marq:  4   lambda: 1e+28   misfit: 6.93763e+02
# it: 28   it_marq:  5   lambda: 1e+29   misfit: 6.93763e+02
# it: 28   it_marq:  6   lambda: 1e+30   misfit: 6.93763e+02
# it: 28   it_marq:  7   lambda: 1e+31   misfit: 6.93763e+02
# it: 28   it_marq:  8   lambda: 1e+32   misfit: 6.93763e+02
# it: 28   it_marq:  9   lambda: 1e+33   misfit: 6.93763e+02
# it: 29   it_marq:  0   lambda: 1e+34   misfit: 6.93879e+02
# it: 29   it_marq:  1   lambda: 1e+35   misfit: 6.93879e+02
# it: 29   it_marq:  2   lambda: 1e+36   misfit: 6.93879e+02
# it: 29   it_marq:  3   lambda: 1e+37   misfit: 6.93879e+02
# it: 29   it_marq:  4   lambda: 1e+38   misfit: 6.93879e+02
# it: 29   it_marq:  5   lambda: 1e+39   misfit: 6.93879e+02
# it: 29   it_marq:  6   lambda: 1e+40   misfit: 6.93879e+02
# it: 29   it_marq:  7   lambda: 1e+41   misfit: 6.93879e+02
# it: 29   it_marq:  8   lambda: 1e+42   misfit: 6.93879e+02
# it: 29   it_marq:  9   lambda: 1e+43   misfit: 6.93879e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 2.03422e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.68389e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 9.13688e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 9.25133e+03
# it:  3   it_marq:  1   lambda: 1e+01   misfit: 5.47645e+03
# it:  4   it_marq:  0   lambda: 1e+00   misfit: 8.78828e+03
# it:  4   it_marq:  1   lambda: 1e+01   misfit: 3.34689e+03
# it:  5   it_marq:  0   lambda: 1e+00   misfit: 6.89010e+04
# it:  5   it_marq:  1   lambda: 1e+01   misfit: 1.98189e+03
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.86305e+05
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.18608e+03
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.40786e+05
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 7.65047e+02
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 1.04155e+05
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 3.90270e+04
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 7.01553e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 5.23140e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 6.55926e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 6.43097e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 6.17861e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 9.24732e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.80616e+04
# it: 11   it_marq:  2   lambda: 1e+03   misfit: 6.13076e+02
# it: 12   it_marq:  0   lambda: 1e+02   misfit: 5.96741e+03
# it: 12   it_marq:  1   lambda: 1e+03   misfit: 6.09256e+02
# it: 13   it_marq:  0   lambda: 1e+02   misfit: 1.80625e+04
# it: 13   it_marq:  1   lambda: 1e+03   misfit: 6.05331e+02
# it: 14   it_marq:  0   lambda: 1e+02   misfit: 1.05182e+04
# it: 14   it_marq:  1   lambda: 1e+03   misfit: 6.02003e+02
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 1.80651e+04
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 5.98219e+02
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 1.80684e+04
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 5.94960e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 1.80533e+04
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 5.91248e+02
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 1.76770e+04
# it: 18   it_marq:  1   lambda: 1e+03   misfit: 5.88050e+02
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 1.14266e+04
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 5.84407e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 1.50319e+04
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 5.81266e+02
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 1.27587e+03
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 5.77685e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 5.57755e+03
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 5.74597e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 5.01630e+03
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 5.71078e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 4.10188e+03
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 5.68041e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 2.60458e+03
# it: 25   it_marq:  1   lambda: 1e+03   misfit: 5.64578e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 9.41769e+02
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 5.61590e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 6.23454e+02
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 5.58182e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 5.73880e+02
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 5.55242e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 5.57064e+02
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 5.51889e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 5.33900e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 4.91028e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.60832e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.28230e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.19059e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 3.63297e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 1.78140e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.56941e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 2.10561e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.71857e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.61267e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.70408e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 2.23410e+02
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.53377e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 9.14306e+02
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.47707e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.13478e+03
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 1.43074e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 6.52107e+03
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 1.38951e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.66388e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.35138e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.66185e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 1.31602e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.66023e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 1.28322e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.65889e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 1.25298e+02
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 1.65778e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 1.22569e+02
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 1.65676e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 1.20233e+02
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 1.62492e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 1.18143e+02
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 1.59069e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 1.16126e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 1.50421e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 1.14183e+02
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.37743e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.12311e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.29237e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.10504e+02
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.25119e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.08756e+02
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 1.06899e+04
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.07068e+02
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 1.05782e+04
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 1.05431e+02
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.03083e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.10943e+02
# it: 25   it_marq:  2   lambda: 1e+03   misfit: 1.05164e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 1.03679e+02
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 4.85674e+03
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 1.02152e+02
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 4.47605e+03
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 1.00656e+02
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 4.15359e+03
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 9.92089e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.15151e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.99593e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.55232e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.88466e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 5.13163e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 8.11746e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 4.53732e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.16417e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 4.28345e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.25555e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 3.01970e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 4.09745e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 6.27067e+03
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 2.81986e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.32668e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 2.68016e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.59128e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 2.55822e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 3.86696e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 2.45030e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 3.86155e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 2.66643e+02
# it: 11   it_marq:  2   lambda: 1e+03   misfit: 2.43437e+02
# it: 12   it_marq:  0   lambda: 1e+02   misfit: 2.34669e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 3.85612e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 2.26841e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 3.85097e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 2.19567e+02
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 3.40339e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 2.12655e+02
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 3.24733e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 2.17177e+02
# it: 16   it_marq:  2   lambda: 1e+03   misfit: 2.11589e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 2.18502e+02
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 2.11018e+02
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 2.04708e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 2.14009e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 2.10124e+02
# it: 19   it_marq:  2   lambda: 1e+03   misfit: 2.03731e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 1.97892e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 2.13351e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 2.12031e+02
# it: 21   it_marq:  2   lambda: 1e+03   misfit: 1.96943e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 1.91474e+02
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 2.12643e+04
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.94695e+02
# it: 23   it_marq:  2   lambda: 1e+03   misfit: 1.90579e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 1.97077e+02
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 1.90108e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 1.84874e+02
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.20297e+04
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 1.96648e+02
# it: 26   it_marq:  2   lambda: 1e+03   misfit: 1.84033e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 1.89938e+02
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 1.83592e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 2.01193e+02
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 1.82876e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 1.94782e+02
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 1.82442e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.04254e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.12282e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.12644e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.77767e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.99662e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 8.80199e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 4.45360e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.20004e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 4.67241e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.15728e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 3.31284e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 4.05934e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 8.76089e+03
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 3.09211e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.67734e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 2.92950e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.96529e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 2.79816e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 3.95706e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 2.68284e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 3.84121e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 2.57702e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 3.30156e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 2.47949e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 3.26356e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 2.75437e+02
# it: 13   it_marq:  2   lambda: 1e+03   misfit: 2.46501e+02
# it: 14   it_marq:  0   lambda: 1e+02   misfit: 2.59626e+02
# it: 14   it_marq:  1   lambda: 1e+03   misfit: 2.45603e+02
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 2.49800e+02
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 2.44410e+02
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 2.72077e+02
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 2.43531e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 2.70987e+02
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 2.42361e+02
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 2.69453e+02
# it: 18   it_marq:  1   lambda: 1e+03   misfit: 2.41502e+02
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 1.33194e+03
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 2.40355e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 2.68095e+02
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 2.39516e+02
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 1.45405e+03
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 2.38391e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 2.73477e+03
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 2.37572e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 2.61485e+02
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 2.36473e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 1.74549e+03
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 2.35677e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 1.08098e+03
# it: 25   it_marq:  1   lambda: 1e+03   misfit: 2.34607e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 2.51644e+02
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 2.33845e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 2.91082e+02
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 2.32830e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 2.67077e+02
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 2.32158e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 2.48540e+02
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 2.31281e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.15536e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.40375e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 4.55300e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.32750e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.88875e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 5.75890e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 5.74308e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.93973e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 2.58186e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 5.39513e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.73223e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 5.35314e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 1.19429e+04
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.60440e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 4.58665e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.51818e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 4.58582e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 1.45185e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 4.58728e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 1.39527e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 4.58831e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.34593e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 4.58650e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 1.47523e+02
# it: 12   it_marq:  2   lambda: 1e+03   misfit: 1.33865e+02
# it: 13   it_marq:  0   lambda: 1e+02   misfit: 1.29969e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 4.58128e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 1.38741e+02
# it: 14   it_marq:  2   lambda: 1e+03   misfit: 1.29398e+02
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 1.25913e+02
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 3.83718e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 1.66620e+02
# it: 16   it_marq:  2   lambda: 1e+03   misfit: 1.25374e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 1.22140e+02
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 3.80330e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 1.32352e+02
# it: 18   it_marq:  2   lambda: 1e+03   misfit: 1.21624e+02
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 1.18639e+02
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 3.61939e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.15698e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 3.34672e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.34547e+03
# it: 21   it_marq:  2   lambda: 1e+03   misfit: 1.15248e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 1.84900e+02
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 1.15020e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 1.66328e+02
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 1.14640e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 2.81908e+02
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 1.14415e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 1.67099e+02
# it: 25   it_marq:  1   lambda: 1e+03   misfit: 1.14041e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 3.38259e+02
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 1.13821e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 3.70181e+03
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 1.13452e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 4.68809e+03
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 1.13235e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 1.44314e+03
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 1.12872e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.30716e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 2.93250e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.31943e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.95895e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 6.81638e+03
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 1.49553e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 5.41821e+03
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 2.78887e+02
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 9.03763e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.42612e+03
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 7.41013e+01
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 6.17641e+03
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 6.63920e+01
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 5.84808e+03
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 1.43476e+03
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 6.50693e+01
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 1.45355e+03
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 6.40754e+01
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 2.08755e+03
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 6.32104e+01
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 2.69191e+03
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 6.24236e+01
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 2.69432e+03
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 6.17031e+01
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 2.69746e+03
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 6.10423e+01
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 2.70084e+03
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 6.04462e+01
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 2.70369e+03
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 5.99222e+01
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 2.70556e+03
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 5.94349e+01
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 2.70663e+03
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 5.89641e+01
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 2.70725e+03
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 6.35138e+01
# it: 18   it_marq:  2   lambda: 1e+03   misfit: 5.88911e+01
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 6.37344e+01
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 5.88608e+01
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 5.84169e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 2.70732e+03
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 6.32518e+01
# it: 21   it_marq:  2   lambda: 1e+03   misfit: 5.83481e+01
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 6.50645e+01
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 5.83193e+01
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 6.34940e+01
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 5.82561e+01
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 5.78451e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.21091e+03
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 5.74319e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.13291e+03
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 5.70277e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 9.64160e+02
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 5.66332e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 6.45120e+02
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 5.62551e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 2.84357e+02
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 5.58828e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 6.50513e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 5.64702e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.78020e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.38499e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.89416e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.84750e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 2.81880e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 2.17486e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 1.49212e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 2.33851e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.10032e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 2.37821e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 1.02129e+03
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.03958e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 2.01724e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 9.97864e+01
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 2.02975e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 9.63773e+01
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 2.02835e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 9.35312e+01
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 2.02736e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 9.11434e+01
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 2.02652e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 8.90514e+01
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 2.02580e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 8.72510e+01
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 2.02505e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 8.55976e+01
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 2.02436e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 8.40383e+01
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 2.02371e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 8.25702e+01
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 2.02310e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 8.11849e+01
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 2.02241e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 7.98744e+01
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 2.01775e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 7.86325e+01
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.11622e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 7.74500e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 9.32547e+03
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 8.73550e+01
# it: 21   it_marq:  2   lambda: 1e+03   misfit: 7.72651e+01
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 7.62110e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 4.10017e+03
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 7.51375e+01
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 3.31273e+03
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 7.40998e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 2.32222e+03
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 7.31101e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.35478e+03
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 7.21638e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 5.11620e+02
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 7.12574e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.61633e+02
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 7.03881e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 8.90049e+01
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 6.95540e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 5.82664e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 5.10977e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.56247e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.38211e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.33497e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 3.13758e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 2.67000e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.81785e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 1.60003e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 2.36594e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.19434e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 2.39659e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 4.31025e+03
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.13337e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.92632e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.09014e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 1.92469e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 1.05674e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 1.92352e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 1.02945e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.92260e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.00498e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.92187e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 9.82527e+01
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.92129e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 9.61864e+01
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.92075e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 9.42786e+01
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 1.92028e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 9.99424e+01
# it: 15   it_marq:  2   lambda: 1e+03   misfit: 9.39952e+01
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 9.97112e+01
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 9.38343e+01
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 9.86977e+01
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 9.35955e+01
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 9.19995e+01
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 1.22937e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 9.04527e+01
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.23031e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 8.90556e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.22825e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 8.77552e+01
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.14580e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 8.65115e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 1.32918e+03
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 9.63847e+01
# it: 23   it_marq:  2   lambda: 1e+03   misfit: 8.63256e+01
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 8.51881e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.20489e+03
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 8.40387e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 7.90044e+02
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 8.29337e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 4.17680e+02
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 8.18703e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 2.30982e+02
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 8.08452e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.49309e+02
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 7.98556e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.61746e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.09088e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.92833e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.26438e+04
# it:  3   it_marq:  1   lambda: 1e+01   misfit: 1.37136e+04
# it:  4   it_marq:  0   lambda: 1e+00   misfit: 2.32438e+04
# it:  4   it_marq:  1   lambda: 1e+01   misfit: 9.43256e+03
# it:  5   it_marq:  0   lambda: 1e+00   misfit: 5.15883e+04
# it:  5   it_marq:  1   lambda: 1e+01   misfit: 6.10663e+03
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 6.65439e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 3.87347e+03
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.04849e+05
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 1.22074e+04
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 3.48495e+03
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 2.32696e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 3.17574e+03
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 4.63439e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 2.92552e+03
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 4.68947e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 2.72210e+03
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 4.77405e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 2.55209e+03
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 4.73026e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 2.40537e+03
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 4.71270e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 2.27511e+03
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 4.71014e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 2.15728e+03
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 4.51185e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 2.05409e+03
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 5.09924e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 1.95823e+03
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 5.06569e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 1.86797e+03
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 6.36079e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 1.78484e+03
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 8.02442e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 1.71230e+03
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.28636e+05
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.65298e+03
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.20510e+05
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.57291e+03
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 9.06015e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.52084e+03
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 4.20276e+04
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 7.50003e+03
# it: 23   it_marq:  2   lambda: 1e+03   misfit: 7.92393e+03
# it: 23   it_marq:  3   lambda: 1e+04   misfit: 7.94077e+03
# it: 23   it_marq:  4   lambda: 1e+05   misfit: 7.94300e+03
# it: 23   it_marq:  5   lambda: 1e+06   misfit: 7.94329e+03
# it: 23   it_marq:  6   lambda: 1e+07   misfit: 7.94332e+03
# it: 23   it_marq:  7   lambda: 1e+08   misfit: 7.94390e+03
# it: 23   it_marq:  8   lambda: 1e+09   misfit: 1.52292e+03
# it: 23   it_marq:  9   lambda: 1e+10   misfit: 1.52293e+03
# it: 24   it_marq:  0   lambda: 1e+11   misfit: 1.52315e+03
# it: 24   it_marq:  1   lambda: 1e+12   misfit: 1.52315e+03
# it: 24   it_marq:  2   lambda: 1e+13   misfit: 1.52315e+03
# it: 24   it_marq:  3   lambda: 1e+14   misfit: 1.52315e+03
# it: 24   it_marq:  4   lambda: 1e+15   misfit: 1.52315e+03
# it: 24   it_marq:  5   lambda: 1e+16   misfit: 1.52315e+03
# it: 24   it_marq:  6   lambda: 1e+17   misfit: 1.52315e+03
# it: 24   it_marq:  7   lambda: 1e+18   misfit: 1.52315e+03
# it: 24   it_marq:  8   lambda: 1e+19   misfit: 1.52315e+03
# it: 24   it_marq:  9   lambda: 1e+20   misfit: 1.52315e+03
# it: 25   it_marq:  0   lambda: 1e+21   misfit: 1.52337e+03
# it: 25   it_marq:  1   lambda: 1e+22   misfit: 1.52337e+03
# it: 25   it_marq:  2   lambda: 1e+23   misfit: 1.52337e+03
# it: 25   it_marq:  3   lambda: 1e+24   misfit: 1.52337e+03
# it: 25   it_marq:  4   lambda: 1e+25   misfit: 1.52337e+03
# it: 25   it_marq:  5   lambda: 1e+26   misfit: 1.52337e+03
# it: 25   it_marq:  6   lambda: 1e+27   misfit: 1.52337e+03
# it: 25   it_marq:  7   lambda: 1e+28   misfit: 1.52337e+03
# it: 25   it_marq:  8   lambda: 1e+29   misfit: 1.52337e+03
# it: 25   it_marq:  9   lambda: 1e+30   misfit: 1.52337e+03
# it: 26   it_marq:  0   lambda: 1e+31   misfit: 1.52360e+03
# it: 26   it_marq:  1   lambda: 1e+32   misfit: 1.52360e+03
# it: 26   it_marq:  2   lambda: 1e+33   misfit: 1.52360e+03
# it: 26   it_marq:  3   lambda: 1e+34   misfit: 1.52360e+03
# it: 26   it_marq:  4   lambda: 1e+35   misfit: 1.52360e+03
# it: 26   it_marq:  5   lambda: 1e+36   misfit: 1.52360e+03
# it: 26   it_marq:  6   lambda: 1e+37   misfit: 1.52360e+03
# it: 26   it_marq:  7   lambda: 1e+38   misfit: 1.52360e+03
# it: 26   it_marq:  8   lambda: 1e+39   misfit: 1.52360e+03
# it: 26   it_marq:  9   lambda: 1e+40   misfit: 1.52360e+03
# it: 27   it_marq:  0   lambda: 1e+41   misfit: 1.52382e+03
# it: 27   it_marq:  1   lambda: 1e+42   misfit: 1.52382e+03
# it: 27   it_marq:  2   lambda: 1e+43   misfit: 1.52382e+03
# it: 27   it_marq:  3   lambda: 1e+44   misfit: 1.52382e+03
# it: 27   it_marq:  4   lambda: 1e+45   misfit: 1.52382e+03
# it: 27   it_marq:  5   lambda: 1e+46   misfit: 1.52382e+03
# it: 27   it_marq:  6   lambda: 1e+47   misfit: 1.52382e+03
# it: 27   it_marq:  7   lambda: 1e+48   misfit: 1.52382e+03
# it: 27   it_marq:  8   lambda: 1e+49   misfit: 1.52382e+03
# it: 27   it_marq:  9   lambda: 1e+50   misfit: 1.52382e+03
# it: 28   it_marq:  0   lambda: 1e+51   misfit: 1.52404e+03
# it: 28   it_marq:  1   lambda: 1e+52   misfit: 1.52404e+03
# it: 28   it_marq:  2   lambda: 1e+53   misfit: 1.52404e+03
# it: 28   it_marq:  3   lambda: 1e+54   misfit: 1.52404e+03
# it: 28   it_marq:  4   lambda: 1e+55   misfit: 1.52404e+03
# it: 28   it_marq:  5   lambda: 1e+56   misfit: 1.52404e+03
# it: 28   it_marq:  6   lambda: 1e+57   misfit: 1.52404e+03
# it: 28   it_marq:  7   lambda: 1e+58   misfit: 1.52404e+03
# it: 28   it_marq:  8   lambda: 1e+59   misfit: 1.52404e+03
# it: 28   it_marq:  9   lambda: 1e+60   misfit: 1.52404e+03
# it: 29   it_marq:  0   lambda: 1e+61   misfit: 1.52427e+03
# it: 29   it_marq:  1   lambda: 1e+62   misfit: 1.52427e+03
# it: 29   it_marq:  2   lambda: 1e+63   misfit: 1.52427e+03
# it: 29   it_marq:  3   lambda: 1e+64   misfit: 1.52427e+03
# it: 29   it_marq:  4   lambda: 1e+65   misfit: 1.52427e+03
# it: 29   it_marq:  5   lambda: 1e+66   misfit: 1.52427e+03
# it: 29   it_marq:  6   lambda: 1e+67   misfit: 1.52427e+03
# it: 29   it_marq:  7   lambda: 1e+68   misfit: 1.52427e+03
# it: 29   it_marq:  8   lambda: 1e+69   misfit: 1.52427e+03
# it: 29   it_marq:  9   lambda: 1e+70   misfit: 1.52427e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 9.32654e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 8.65639e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.57489e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.94613e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.48538e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 1.16625e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 2.99049e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.19171e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 6.96065e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 2.59566e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 5.97082e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.55837e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 4.32658e+02
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 2.57516e+04
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 2.43377e+04
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 1.54255e+04
# it:  8   it_marq:  3   lambda: 1e+03   misfit: 6.38398e+02
# it:  8   it_marq:  4   lambda: 1e+04   misfit: 4.26755e+02
# it:  9   it_marq:  0   lambda: 1e+03   misfit: 4.24250e+02
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 4.08058e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.35305e+03
# ...
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 1.40331e+02
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 1.90091e+04
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 1.26895e+02
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 1.89875e+04
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 1.16298e+02
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 2.41229e+04
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.09220e+02
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 2.97175e+04
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.05276e+02
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 2.97618e+04
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.02193e+02
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 3.32184e+04
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 1.14461e+02
# it: 18   it_marq:  2   lambda: 1e+02   misfit: 1.00667e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 1.13312e+02
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 9.95383e+01
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 5.74490e+02
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 9.86223e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.36269e+03
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 9.78319e+01
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 8.57446e+03
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 9.71213e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 8.58324e+03
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 9.64667e+01
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 1.35445e+04
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 9.58546e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.45622e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 9.52758e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.86549e+04
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 9.47264e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 1.91018e+04
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 9.42019e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.91035e+04
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 9.37002e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.91064e+04
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 9.32184e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 2.12700e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.75579e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 9.49395e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 9.34733e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.49174e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 1.70160e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 4.63871e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 2.63217e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 8.26380e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.22689e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 5.44095e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 4.16798e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 4.06029e+02
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 4.29623e+04
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 3.40545e+04
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 3.79386e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 4.93011e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 3.59723e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 2.62960e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 3.42738e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 7.48449e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 3.27268e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 4.08211e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 3.13109e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 4.07555e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 3.00061e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 7.17074e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 3.42171e+02
# it: 14   it_marq:  2   lambda: 1e+03   misfit: 2.98051e+02
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 2.86794e+02
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 4.40501e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 2.75060e+02
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 4.93818e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 2.64712e+02
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 6.73435e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 2.55861e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 4.92465e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 2.69471e+02
# it: 19   it_marq:  2   lambda: 1e+03   misfit: 2.54409e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 2.74048e+02
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 2.53744e+02
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 2.91249e+02
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 2.52539e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 3.31080e+02
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 2.51888e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 2.66273e+02
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 2.50710e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 2.80118e+02
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 2.50070e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 2.90319e+02
# it: 25   it_marq:  1   lambda: 1e+03   misfit: 2.48898e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 3.34741e+02
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 2.48268e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 3.46456e+02
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 2.47112e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 3.45581e+02
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 2.46493e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 5.29045e+02
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 2.45352e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.93533e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.60732e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 8.76343e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 8.93485e+03
# it:  3   it_marq:  1   lambda: 1e+01   misfit: 5.26568e+03
# it:  4   it_marq:  0   lambda: 1e+00   misfit: 8.86210e+03
# it:  4   it_marq:  1   lambda: 1e+01   misfit: 3.25350e+03
# it:  5   it_marq:  0   lambda: 1e+00   misfit: 6.76261e+04
# it:  5   it_marq:  1   lambda: 1e+01   misfit: 1.96232e+03
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.79911e+05
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.20547e+03
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.31181e+05
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 7.98416e+02
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 1.01166e+05
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 3.21863e+04
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 7.34794e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 4.64963e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 6.89326e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 5.08727e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 6.52675e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 6.24310e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 6.20962e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 8.91758e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 5.66717e+03
# it: 12   it_marq:  2   lambda: 1e+03   misfit: 6.16949e+02
# it: 13   it_marq:  0   lambda: 1e+02   misfit: 5.60789e+03
# it: 13   it_marq:  1   lambda: 1e+03   misfit: 6.13810e+02
# it: 14   it_marq:  0   lambda: 1e+02   misfit: 1.73697e+04
# it: 14   it_marq:  1   lambda: 1e+03   misfit: 6.10225e+02
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 5.81363e+03
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 6.07143e+02
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 1.73747e+04
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 6.03620e+02
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 1.73775e+04
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 6.00593e+02
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 1.64755e+04
# it: 18   it_marq:  1   lambda: 1e+03   misfit: 5.97130e+02
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 1.73796e+04
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 5.94153e+02
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 1.70473e+04
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 5.90746e+02
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 1.22432e+04
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 5.87816e+02
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 6.36892e+03
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 5.84463e+02
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 1.08866e+04
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 5.81578e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 3.05613e+03
# it: 24   it_marq:  1   lambda: 1e+03   misfit: 5.78277e+02
# it: 25   it_marq:  0   lambda: 1e+02   misfit: 2.73403e+03
# it: 25   it_marq:  1   lambda: 1e+03   misfit: 5.75436e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 4.78579e+03
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 5.72185e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 3.93365e+03
# it: 27   it_marq:  1   lambda: 1e+03   misfit: 5.69386e+02
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 2.92303e+03
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 5.66184e+02
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 1.05130e+03
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 5.63427e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 5.60456e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 5.14222e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.70193e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.28910e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.24020e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 3.52960e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 1.81401e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.40183e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 2.04600e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.72626e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.55718e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.74491e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 1.64218e+02
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.47829e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.81045e+02
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.42506e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 1.54338e+03
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 1.38014e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 4.65128e+03
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 1.33909e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.69053e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.30147e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.70479e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 1.26711e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.70331e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 1.23638e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.70201e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 1.21020e+02
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 1.70076e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 1.18672e+02
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 1.69960e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 1.16422e+02
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 1.69853e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 1.14271e+02
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 1.69741e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 1.12212e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 1.68550e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 1.10239e+02
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.61614e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.08348e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.48751e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.06521e+02
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.00386e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.04780e+02
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 9.92041e+03
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.07349e+02
# it: 23   it_marq:  2   lambda: 1e+03   misfit: 1.04489e+02
# it: 24   it_marq:  0   lambda: 1e+02   misfit: 1.02920e+02
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 9.84935e+03
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.01337e+02
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 9.81164e+03
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 9.98552e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 7.70609e+03
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 9.85252e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 7.54003e+03
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 9.73718e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 7.04851e+03
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 1.03903e+02
# it: 29   it_marq:  2   lambda: 1e+03   misfit: 9.71856e+01
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 5.11037e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 4.71154e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.51963e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.26049e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.02970e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 3.74037e+02
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 1.72046e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.67665e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 2.18348e+02
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.66560e+04
# it:  6   it_marq:  1   lambda: 1e+01   misfit: 1.68685e+02
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.64971e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 2.21294e+02
# it:  7   it_marq:  2   lambda: 1e+02   misfit: 1.60782e+02
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 8.78043e+02
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.54792e+02
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.03588e+03
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 1.49721e+02
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 6.32183e+03
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 1.45528e+02
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.60730e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.41786e+02
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.60517e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 1.38288e+02
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.60340e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 1.35010e+02
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.60188e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 1.31930e+02
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 1.60060e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 1.29032e+02
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 1.59954e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 1.26308e+02
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 1.59864e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 1.23760e+02
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 1.59673e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 1.21414e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 1.56732e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 1.19352e+02
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.44161e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.17561e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.30218e+04
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.15828e+02
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.23363e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.14145e+02
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 1.20258e+04
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.12509e+02
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 1.18134e+04
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 1.10916e+02
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.13178e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.15615e+02
# it: 25   it_marq:  2   lambda: 1e+03   misfit: 1.10655e+02
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 1.09223e+02
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 5.65607e+03
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 1.07720e+02
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 5.26386e+03
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 1.06222e+02
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 4.79035e+03
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 1.04767e+02

# %% [markdown]
# # Results

# %%
inversion['results'] = inversion_results

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)

# %% [markdown]
# ###
