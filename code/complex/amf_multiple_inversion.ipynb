# %% [markdown]
# # Complex body TFA Inversion

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA) data on a regular grid of a model with a complex geometry.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# /home/leo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/leo/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
model_dir = 'data/model_real_obs_pts.pickle'
data_dir = 'data/real_obs_pts/data.pickle'
#data_dir = 'eqlayer/direction_inc65_dec-40_h190m/eqlayer_depth190m.pickle'

# %%
with open(model_dir) as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open(data_dir) as w:
        data = pickle.load(w)

# %%
# observed data and observation points
dobs = data['amf_obs']
xp = data['grid'][0]
yp = data['grid'][1]
zp = data['grid'][2]
N = data['grid'][3]

# %% [raw]
# # observed data and observation points
# dobs = data['upward']
# xp = data['x']
# yp = data['y']
# zp = data['z']
# N = data['x'].size

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 15 # number of vertices per prism
L = 10 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization
incs = model['inc']
decs = model['dec']
intensity = model['intensity']

# depth to the top, thickness and radius
z0 = model['z0']
dz = 720.
r = 650.

# total magnetization
props = {'magnetization': utils.ang2vec(
        intensity, incs, decs)}
rin = np.zeros(M) + r
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) 
m0 = np.hstack((m0, dz)) # inicial parameters vector
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms

varz = 100.
varint = 3.
varinc = 10.
vardec = 10.

param_list = mfun.varying_param(z0, varz, intensity,
                                 varint, incs, varinc, decs, vardec)

# main field
inc, dec = [-21.5, -18.7]

# predict data
d0 = np.sqrt(polyprism.bx(xp, yp, zp, model0)**2. + 
        polyprism.bx(xp, yp, zp, model0)**2. + 
        polyprism.bx(xp, yp, zp, model0)**2.)

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 100.
rmax = 2000.
x0min = -1500.
x0max = 1500.
y0min = -1500.
y0max = 1500.
dzmin = 200.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Variation

# %%
# variation for derivatives
deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)
deltaz = 0.01*np.max(dzmax)

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Folder to save the results

# %%
mypath = 'data/real_obs_pts/amf_inversion/multiple_inc%d_dec%d_r%d_int%d_z0%d_dz%d_varz%d_varint%d_varinc%d_vardec%d' % (incs, decs, rin[0], np.linalg.norm(props['magnetization']), z0, dz, varz, varint, varinc, vardec)
if not os.path.isdir(mypath):
   os.makedirs(mypath)

# %% [raw]
# mypath = data_dir[:-11]+'upward_tfa_inversion/inc%d_dec%d_r%d_int%d_z0%d_dz%d' % (incs, decs, rin[0], np.linalg.norm(props['magnetization']), z0, dz)
# if not os.path.isdir(mypath):
#     os.makedirs(mypath)

# %%
# output of inversion
inversion = dict()

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.00
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.0005  # adjacent radial distances within each prism
a2 = 0.0007   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.02     # vertically adjacent origins
a6 = 0.000001   # zero order Tikhonov on adjacent radial distances
a7 = 0.0001     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %%
itmax = 100
itmax_marq = 10
tol = 1.0e-4     # stop criterion

# %%
inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs

# %%
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['initial_estimate'] = model0
inversion['initial_data'] = d0
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = alpha
inversion['tol'] = tol
inversion['main_field'] = [-21.5, -18.7]
inversion['var'] = [varz, varint, varinc, vardec]

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for p in param_list:
    d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_amf(
        xp, yp, zp, m0, M, L, delta,
        itmax, itmax_marq, lamb,
        dlamb, tol, mmin, mmax,
        m_out, dobs, p[1], alpha,
        p[0], dz
    )
    inversion_results.append([d_fit, m_est, model_est, phi_list, model_list, dobs - d_fit, res_list])
# Out:
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.1482e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.0547e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3174e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.1924e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 5.3779e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 4.9559e+03
# it:  6   it_marq:  0   lambda: 1e-03   misfit: 4.5617e+03
# it:  7   it_marq:  0   lambda: 1e-04   misfit: 7.9839e+03
# it:  7   it_marq:  1   lambda: 1e-03   misfit: 2.4620e+03
# it:  8   it_marq:  0   lambda: 1e-04   misfit: 2.3437e+03
# it:  9   it_marq:  0   lambda: 1e-05   misfit: 1.5192e+03
# it: 10   it_marq:  0   lambda: 1e-06   misfit: 1.4798e+03
# it: 11   it_marq:  0   lambda: 1e-07   misfit: 6.5860e+02
# it: 12   it_marq:  0   lambda: 1e-08   misfit: 8.4652e+02
# it: 12   it_marq:  1   lambda: 1e-07   misfit: 8.4651e+02
# it: 12   it_marq:  2   lambda: 1e-06   misfit: 8.4643e+02
# it: 12   it_marq:  3   lambda: 1e-05   misfit: 8.4557e+02
# it: 12   it_marq:  4   lambda: 1e-04   misfit: 8.3734e+02
# it: 12   it_marq:  5   lambda: 1e-03   misfit: 7.8031e+02
# it: 12   it_marq:  6   lambda: 1e-02   misfit: 6.7666e+02
# it: 12   it_marq:  7   lambda: 1e-01   misfit: 6.2363e+02
# it: 13   it_marq:  0   lambda: 1e-02   misfit: 6.4179e+02
# it: 13   it_marq:  1   lambda: 1e-01   misfit: 5.8917e+02
# it: 14   it_marq:  0   lambda: 1e-02   misfit: 6.1012e+02
# it: 14   it_marq:  1   lambda: 1e-01   misfit: 5.5561e+02
# it: 15   it_marq:  0   lambda: 1e-02   misfit: 1.0029e+05
# it: 15   it_marq:  1   lambda: 1e-01   misfit: 5.3162e+02
# it: 16   it_marq:  0   lambda: 1e-02   misfit: 1.8821e+05
# it: 16   it_marq:  1   lambda: 1e-01   misfit: 2.8194e+03
# it: 16   it_marq:  2   lambda: 1e+00   misfit: 7.2312e+02
# it: 16   it_marq:  3   lambda: 1e+01   misfit: 5.1165e+02
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 3.7267e+03
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 5.0490e+02
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 7.5649e+03
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 9.3048e+02
# it: 18   it_marq:  2   lambda: 1e+02   misfit: 5.0408e+02
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 2.0790e+03
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 5.0352e+02
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.2675e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 5.0305e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 5.3487e+03
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 5.0263e+02
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 7.4875e+02
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 5.0226e+02
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 2.1545e+03
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 5.0191e+02
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 6.2762e+03
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 5.0158e+02
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 3.2165e+03
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 5.0127e+02
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 7.7361e+02
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 5.0097e+02
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 9.7189e+02
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 5.0068e+02
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 7.3899e+02
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 5.0040e+02
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 7.2856e+02
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 5.0012e+02
# it: 30   it_marq:  0   lambda: 1e+01   misfit: 4.9988e+02
# it: 31   it_marq:  0   lambda: 1e+00   misfit: 4.9411e+02
# it: 32   it_marq:  0   lambda: 1e-01   misfit: 5.0052e+02
# it: 32   it_marq:  1   lambda: 1e+00   misfit: 4.8927e+02
# it: 33   it_marq:  0   lambda: 1e-01   misfit: 4.9565e+02
# it: 33   it_marq:  1   lambda: 1e+00   misfit: 4.8463e+02
# it: 34   it_marq:  0   lambda: 1e-01   misfit: 4.9122e+02
# it: 34   it_marq:  1   lambda: 1e+00   misfit: 4.7912e+02
# it: 35   it_marq:  0   lambda: 1e-01   misfit: 4.8571e+02
# it: 35   it_marq:  1   lambda: 1e+00   misfit: 4.7531e+02
# it: 36   it_marq:  0   lambda: 1e-01   misfit: 4.8197e+02
# it: 36   it_marq:  1   lambda: 1e+00   misfit: 4.7175e+02
# it: 37   it_marq:  0   lambda: 1e-01   misfit: 4.7853e+02
# it: 37   it_marq:  1   lambda: 1e+00   misfit: 4.6867e+02
# it: 38   it_marq:  0   lambda: 1e-01   misfit: 4.7536e+02
# it: 38   it_marq:  1   lambda: 1e+00   misfit: 4.6601e+02
# it: 39   it_marq:  0   lambda: 1e-01   misfit: 4.7245e+02
# it: 39   it_marq:  1   lambda: 1e+00   misfit: 4.6375e+02
# it: 40   it_marq:  0   lambda: 1e-01   misfit: 4.6978e+02
# it: 40   it_marq:  1   lambda: 1e+00   misfit: 4.6182e+02
# it: 41   it_marq:  0   lambda: 1e-01   misfit: 4.6732e+02
# it: 41   it_marq:  1   lambda: 1e+00   misfit: 4.6016e+02
# it: 42   it_marq:  0   lambda: 1e-01   misfit: 4.6504e+02
# it: 42   it_marq:  1   lambda: 1e+00   misfit: 4.5871e+02
# it: 43   it_marq:  0   lambda: 1e-01   misfit: 4.6291e+02
# it: 43   it_marq:  1   lambda: 1e+00   misfit: 4.5742e+02
# it: 44   it_marq:  0   lambda: 1e-01   misfit: 4.6089e+02
# it: 44   it_marq:  1   lambda: 1e+00   misfit: 4.5621e+02
# it: 45   it_marq:  0   lambda: 1e-01   misfit: 4.5896e+02
# it: 45   it_marq:  1   lambda: 1e+00   misfit: 4.5507e+02
# it: 46   it_marq:  0   lambda: 1e-01   misfit: 4.5710e+02
# it: 46   it_marq:  1   lambda: 1e+00   misfit: 4.5395e+02
# it: 47   it_marq:  0   lambda: 1e-01   misfit: 4.5529e+02
# it: 47   it_marq:  1   lambda: 1e+00   misfit: 4.5284e+02
# it: 48   it_marq:  0   lambda: 1e-01   misfit: 4.5352e+02
# it: 48   it_marq:  1   lambda: 1e+00   misfit: 4.5171e+02
# it: 49   it_marq:  0   lambda: 1e-01   misfit: 6.8195e+02
# it: 49   it_marq:  1   lambda: 1e+00   misfit: 4.5055e+02
# it: 50   it_marq:  0   lambda: 1e-01   misfit: 6.8183e+02
# it: 50   it_marq:  1   lambda: 1e+00   misfit: 4.4936e+02
# it: 51   it_marq:  0   lambda: 1e-01   misfit: 6.8169e+02
# it: 51   it_marq:  1   lambda: 1e+00   misfit: 4.4814e+02
# it: 52   it_marq:  0   lambda: 1e-01   misfit: 4.4690e+02
# it: 53   it_marq:  0   lambda: 1e-02   misfit: 6.7047e+02
# it: 53   it_marq:  1   lambda: 1e-01   misfit: 4.4061e+02
# it: 54   it_marq:  0   lambda: 1e-02   misfit: 6.6656e+02
# it: 54   it_marq:  1   lambda: 1e-01   misfit: 4.3442e+02
# it: 55   it_marq:  0   lambda: 1e-02   misfit: 6.6568e+02
# it: 55   it_marq:  1   lambda: 1e-01   misfit: 4.3019e+02
# it: 56   it_marq:  0   lambda: 1e-02   misfit: 6.6567e+02
# it: 56   it_marq:  1   lambda: 1e-01   misfit: 4.2780e+02
# it: 57   it_marq:  0   lambda: 1e-02   misfit: 6.6588e+02
# it: 57   it_marq:  1   lambda: 1e-01   misfit: 4.2678e+02
# it: 58   it_marq:  0   lambda: 1e-02   misfit: 2.4735e+03
# it: 58   it_marq:  1   lambda: 1e-01   misfit: 4.2662e+02
# it: 59   it_marq:  0   lambda: 1e-02   misfit: 4.4965e+04
# it: 59   it_marq:  1   lambda: 1e-01   misfit: 4.2711e+02
# it: 59   it_marq:  2   lambda: 1e+00   misfit: 4.2423e+02
# it: 60   it_marq:  0   lambda: 1e-01   misfit: 9.0696e+02
# it: 60   it_marq:  1   lambda: 1e+00   misfit: 4.2395e+02
# it: 61   it_marq:  0   lambda: 1e-01   misfit: 9.0523e+02
# it: 61   it_marq:  1   lambda: 1e+00   misfit: 4.2444e+02
# it: 61   it_marq:  2   lambda: 1e+01   misfit: 4.2343e+02
# it: 62   it_marq:  0   lambda: 1e+00   misfit: 4.2435e+02
# it: 62   it_marq:  1   lambda: 1e+01   misfit: 4.2335e+02
# it: 63   it_marq:  0   lambda: 1e+00   misfit: 4.2443e+02
# it: 63   it_marq:  1   lambda: 1e+01   misfit: 4.2346e+02
# it: 63   it_marq:  2   lambda: 1e+02   misfit: 4.2328e+02
# it: 64   it_marq:  0   lambda: 1e+01   misfit: 4.2345e+02
# it: 64   it_marq:  1   lambda: 1e+02   misfit: 4.2327e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.3464e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.1017e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.3162e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.4487e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.1151e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 1.1716e+04
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 2.4864e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.4383e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 1.2115e+04
# it:  5   it_marq:  3   lambda: 1e+02   misfit: 1.1736e+04
# it:  5   it_marq:  4   lambda: 1e+03   misfit: 1.1716e+04
# it:  5   it_marq:  5   lambda: 1e+04   misfit: 1.1716e+04
# it:  5   it_marq:  6   lambda: 1e+05   misfit: 1.1716e+04
# it:  5   it_marq:  7   lambda: 1e+06   misfit: 1.1716e+04
# it:  5   it_marq:  8   lambda: 1e+07   misfit: 1.1716e+04
# it:  5   it_marq:  9   lambda: 1e+08   misfit: 1.1716e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7158e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.6385e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2748e+05
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 9.1986e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 6.9326e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 6.3293e+04
# it:  6   it_marq:  0   lambda: 1e-03   misfit: 5.1397e+04
# it:  7   it_marq:  0   lambda: 1e-04   misfit: 6.0352e+04
# it:  7   it_marq:  1   lambda: 1e-03   misfit: 5.8445e+04
# it:  7   it_marq:  2   lambda: 1e-02   misfit: 4.8048e+04
# it:  8   it_marq:  0   lambda: 1e-03   misfit: 1.7902e+05
# it:  8   it_marq:  1   lambda: 1e-02   misfit: 1.3969e+05
# it:  8   it_marq:  2   lambda: 1e-01   misfit: 1.2897e+05
# it:  8   it_marq:  3   lambda: 1e+00   misfit: 3.3640e+04
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.3812e+05
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 2.6015e+04
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.5853e+05
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 2.9445e+04
# it: 10   it_marq:  2   lambda: 1e+01   misfit: 3.0733e+04
# it: 10   it_marq:  3   lambda: 1e+02   misfit: 2.6371e+04
# it: 10   it_marq:  4   lambda: 1e+03   misfit: 2.6566e+04
# it: 10   it_marq:  5   lambda: 1e+04   misfit: 2.6042e+04
# it: 10   it_marq:  6   lambda: 1e+05   misfit: 2.6045e+04
# it: 10   it_marq:  7   lambda: 1e+06   misfit: 2.6045e+04
# it: 10   it_marq:  8   lambda: 1e+07   misfit: 2.6045e+04
# it: 10   it_marq:  9   lambda: 1e+08   misfit: 2.6045e+04
# it: 11   it_marq:  0   lambda: 1e+09   misfit: 2.6045e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.4835e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.3653e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 9.3199e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.8951e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 3.8569e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 6.2090e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 4.5619e+04
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 3.1032e+04
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 1.8522e+04
# it:  7   it_marq:  0   lambda: 1e-02   misfit: 7.1081e+04
# it:  7   it_marq:  1   lambda: 1e-01   misfit: 3.2539e+04
# it:  7   it_marq:  2   lambda: 1e+00   misfit: 2.5701e+04
# it:  7   it_marq:  3   lambda: 1e+01   misfit: 1.3535e+04
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 1.3126e+04
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 2.4557e+04
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.2654e+04
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 7.6269e+04
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.2181e+04
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 7.1927e+04
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.1779e+04
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 6.7581e+04
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.1381e+04
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 6.4074e+04
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 2.3450e+04
# it: 13   it_marq:  2   lambda: 1e+01   misfit: 1.1014e+04
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 1.0346e+05
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 1.0862e+04
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 1.0282e+05
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.0798e+04
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 1.0262e+05
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.0771e+04
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 1.0266e+05
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.0758e+04
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 1.0280e+05
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 1.0750e+04
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.0299e+05
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 1.0742e+04
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 1.0319e+05
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 1.0731e+04
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 1.0336e+05
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 1.0717e+04
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 1.0350e+05
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 1.0698e+04
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 1.0360e+05
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 1.0674e+04
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 1.0367e+05
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 1.0647e+04
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 1.0370e+05
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 1.0616e+04
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 1.0372e+05
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 1.0582e+04
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 1.0373e+05
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 1.0547e+04
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 1.0373e+05
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 1.0517e+04
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 1.0369e+05
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 1.0498e+04
# it: 30   it_marq:  0   lambda: 1e+00   misfit: 1.0359e+05
# it: 30   it_marq:  1   lambda: 1e+01   misfit: 1.0482e+04
# it: 31   it_marq:  0   lambda: 1e+00   misfit: 1.0349e+05
# it: 31   it_marq:  1   lambda: 1e+01   misfit: 1.0464e+04
# it: 32   it_marq:  0   lambda: 1e+00   misfit: 1.0339e+05
# it: 32   it_marq:  1   lambda: 1e+01   misfit: 1.0445e+04
# it: 33   it_marq:  0   lambda: 1e+00   misfit: 1.0330e+05
# it: 33   it_marq:  1   lambda: 1e+01   misfit: 1.0426e+04
# it: 34   it_marq:  0   lambda: 1e+00   misfit: 1.0321e+05
# it: 34   it_marq:  1   lambda: 1e+01   misfit: 1.0405e+04
# it: 35   it_marq:  0   lambda: 1e+00   misfit: 1.0313e+05
# it: 35   it_marq:  1   lambda: 1e+01   misfit: 1.0384e+04
# it: 36   it_marq:  0   lambda: 1e+00   misfit: 1.0306e+05
# it: 36   it_marq:  1   lambda: 1e+01   misfit: 1.0362e+04
# it: 37   it_marq:  0   lambda: 1e+00   misfit: 1.0299e+05
# it: 37   it_marq:  1   lambda: 1e+01   misfit: 1.0339e+04
# it: 38   it_marq:  0   lambda: 1e+00   misfit: 1.0293e+05
# it: 38   it_marq:  1   lambda: 1e+01   misfit: 1.0314e+04
# it: 39   it_marq:  0   lambda: 1e+00   misfit: 1.0287e+05
# it: 39   it_marq:  1   lambda: 1e+01   misfit: 1.0289e+04
# it: 40   it_marq:  0   lambda: 1e+00   misfit: 1.0281e+05
# it: 40   it_marq:  1   lambda: 1e+01   misfit: 1.0263e+04
# it: 41   it_marq:  0   lambda: 1e+00   misfit: 1.0276e+05
# it: 41   it_marq:  1   lambda: 1e+01   misfit: 1.0235e+04
# it: 42   it_marq:  0   lambda: 1e+00   misfit: 1.0271e+05
# it: 42   it_marq:  1   lambda: 1e+01   misfit: 1.0207e+04
# it: 43   it_marq:  0   lambda: 1e+00   misfit: 1.0266e+05
# it: 43   it_marq:  1   lambda: 1e+01   misfit: 1.0177e+04
# it: 44   it_marq:  0   lambda: 1e+00   misfit: 1.0261e+05
# it: 44   it_marq:  1   lambda: 1e+01   misfit: 1.0146e+04
# it: 45   it_marq:  0   lambda: 1e+00   misfit: 1.0257e+05
# it: 45   it_marq:  1   lambda: 1e+01   misfit: 1.0114e+04
# it: 46   it_marq:  0   lambda: 1e+00   misfit: 1.0252e+05
# it: 46   it_marq:  1   lambda: 1e+01   misfit: 1.0081e+04
# it: 47   it_marq:  0   lambda: 1e+00   misfit: 1.0248e+05
# it: 47   it_marq:  1   lambda: 1e+01   misfit: 1.0047e+04
# it: 48   it_marq:  0   lambda: 1e+00   misfit: 1.0243e+05
# it: 48   it_marq:  1   lambda: 1e+01   misfit: 1.0011e+04
# it: 49   it_marq:  0   lambda: 1e+00   misfit: 1.0238e+05
# it: 49   it_marq:  1   lambda: 1e+01   misfit: 9.9750e+03
# it: 50   it_marq:  0   lambda: 1e+00   misfit: 1.0234e+05
# it: 50   it_marq:  1   lambda: 1e+01   misfit: 9.9377e+03
# it: 51   it_marq:  0   lambda: 1e+00   misfit: 1.0229e+05
# it: 51   it_marq:  1   lambda: 1e+01   misfit: 9.8995e+03
# it: 52   it_marq:  0   lambda: 1e+00   misfit: 1.0224e+05
# it: 52   it_marq:  1   lambda: 1e+01   misfit: 9.8605e+03
# it: 53   it_marq:  0   lambda: 1e+00   misfit: 1.0219e+05
# it: 53   it_marq:  1   lambda: 1e+01   misfit: 9.8208e+03
# it: 54   it_marq:  0   lambda: 1e+00   misfit: 1.0214e+05
# it: 54   it_marq:  1   lambda: 1e+01   misfit: 9.7803e+03
# it: 55   it_marq:  0   lambda: 1e+00   misfit: 1.0210e+05
# it: 55   it_marq:  1   lambda: 1e+01   misfit: 9.7392e+03
# it: 56   it_marq:  0   lambda: 1e+00   misfit: 1.0206e+05
# it: 56   it_marq:  1   lambda: 1e+01   misfit: 9.6975e+03
# it: 57   it_marq:  0   lambda: 1e+00   misfit: 1.0203e+05
# it: 57   it_marq:  1   lambda: 1e+01   misfit: 9.6552e+03
# it: 58   it_marq:  0   lambda: 1e+00   misfit: 1.0191e+05
# it: 58   it_marq:  1   lambda: 1e+01   misfit: 9.6125e+03
# it: 59   it_marq:  0   lambda: 1e+00   misfit: 1.0134e+05
# it: 59   it_marq:  1   lambda: 1e+01   misfit: 9.5695e+03
# it: 60   it_marq:  0   lambda: 1e+00   misfit: 9.9421e+04
# it: 60   it_marq:  1   lambda: 1e+01   misfit: 9.5262e+03
# it: 61   it_marq:  0   lambda: 1e+00   misfit: 9.5354e+04
# it: 61   it_marq:  1   lambda: 1e+01   misfit: 9.4826e+03
# it: 62   it_marq:  0   lambda: 1e+00   misfit: 8.9533e+04
# it: 62   it_marq:  1   lambda: 1e+01   misfit: 9.4390e+03
# it: 63   it_marq:  0   lambda: 1e+00   misfit: 8.3620e+04
# it: 63   it_marq:  1   lambda: 1e+01   misfit: 9.3953e+03
# it: 64   it_marq:  0   lambda: 1e+00   misfit: 1.3864e+05
# it: 64   it_marq:  1   lambda: 1e+01   misfit: 9.3515e+03
# it: 65   it_marq:  0   lambda: 1e+00   misfit: 1.4229e+05
# it: 65   it_marq:  1   lambda: 1e+01   misfit: 9.3079e+03
# it: 66   it_marq:  0   lambda: 1e+00   misfit: 1.6118e+05
# it: 66   it_marq:  1   lambda: 1e+01   misfit: 9.2643e+03
# it: 67   it_marq:  0   lambda: 1e+00   misfit: 2.0292e+05
# it: 67   it_marq:  1   lambda: 1e+01   misfit: 9.2209e+03
# it: 68   it_marq:  0   lambda: 1e+00   misfit: 2.0485e+05
# it: 68   it_marq:  1   lambda: 1e+01   misfit: 9.1777e+03
# it: 69   it_marq:  0   lambda: 1e+00   misfit: 2.0432e+05
# it: 69   it_marq:  1   lambda: 1e+01   misfit: 9.1351e+03
# it: 70   it_marq:  0   lambda: 1e+00   misfit: 2.0410e+05
# it: 70   it_marq:  1   lambda: 1e+01   misfit: 9.0919e+03
# it: 71   it_marq:  0   lambda: 1e+00   misfit: 2.0407e+05
# it: 71   it_marq:  1   lambda: 1e+01   misfit: 9.0498e+03
# it: 72   it_marq:  0   lambda: 1e+00   misfit: 2.0422e+05
# it: 72   it_marq:  1   lambda: 1e+01   misfit: 9.0072e+03
# it: 73   it_marq:  0   lambda: 1e+00   misfit: 2.0443e+05
# it: 73   it_marq:  1   lambda: 1e+01   misfit: 8.9658e+03
# it: 74   it_marq:  0   lambda: 1e+00   misfit: 2.0475e+05
# it: 74   it_marq:  1   lambda: 1e+01   misfit: 8.9238e+03
# it: 75   it_marq:  0   lambda: 1e+00   misfit: 2.0507e+05
# it: 75   it_marq:  1   lambda: 1e+01   misfit: 8.8832e+03
# it: 76   it_marq:  0   lambda: 1e+00   misfit: 2.0545e+05
# it: 76   it_marq:  1   lambda: 1e+01   misfit: 8.8419e+03
# it: 77   it_marq:  0   lambda: 1e+00   misfit: 2.0582e+05
# it: 77   it_marq:  1   lambda: 1e+01   misfit: 8.8020e+03
# it: 78   it_marq:  0   lambda: 1e+00   misfit: 2.0621e+05
# it: 78   it_marq:  1   lambda: 1e+01   misfit: 8.7614e+03
# it: 79   it_marq:  0   lambda: 1e+00   misfit: 2.0656e+05
# it: 79   it_marq:  1   lambda: 1e+01   misfit: 8.7222e+03
# it: 80   it_marq:  0   lambda: 1e+00   misfit: 2.0694e+05
# it: 80   it_marq:  1   lambda: 1e+01   misfit: 8.6822e+03
# it: 81   it_marq:  0   lambda: 1e+00   misfit: 2.0727e+05
# it: 81   it_marq:  1   lambda: 1e+01   misfit: 8.6437e+03
# it: 82   it_marq:  0   lambda: 1e+00   misfit: 2.0761e+05
# it: 82   it_marq:  1   lambda: 1e+01   misfit: 8.6044e+03
# it: 83   it_marq:  0   lambda: 1e+00   misfit: 2.0790e+05
# it: 83   it_marq:  1   lambda: 1e+01   misfit: 8.5664e+03
# it: 84   it_marq:  0   lambda: 1e+00   misfit: 2.0817e+05
# it: 84   it_marq:  1   lambda: 1e+01   misfit: 8.8142e+03
# it: 84   it_marq:  2   lambda: 1e+02   misfit: 8.5605e+03
# it: 85   it_marq:  0   lambda: 1e+01   misfit: 8.5231e+03
# it: 86   it_marq:  0   lambda: 1e+00   misfit: 1.3516e+05
# it: 86   it_marq:  1   lambda: 1e+01   misfit: 8.9124e+03
# it: 86   it_marq:  2   lambda: 1e+02   misfit: 8.5166e+03
# it: 87   it_marq:  0   lambda: 1e+01   misfit: 8.6850e+03
# it: 87   it_marq:  1   lambda: 1e+02   misfit: 8.5125e+03
# it: 88   it_marq:  0   lambda: 1e+01   misfit: 8.8930e+03
# it: 88   it_marq:  1   lambda: 1e+02   misfit: 8.5068e+03
# it: 89   it_marq:  0   lambda: 1e+01   misfit: 8.8855e+03
# it: 89   it_marq:  1   lambda: 1e+02   misfit: 8.5036e+03
# it: 90   it_marq:  0   lambda: 1e+01   misfit: 8.8791e+03
# it: 90   it_marq:  1   lambda: 1e+02   misfit: 8.4986e+03
# it: 91   it_marq:  0   lambda: 1e+01   misfit: 8.8874e+03
# it: 91   it_marq:  1   lambda: 1e+02   misfit: 8.4960e+03
# it: 92   it_marq:  0   lambda: 1e+01   misfit: 9.6863e+03
# it: 92   it_marq:  1   lambda: 1e+02   misfit: 8.4914e+03
# it: 93   it_marq:  0   lambda: 1e+01   misfit: 1.9224e+04
# it: 93   it_marq:  1   lambda: 1e+02   misfit: 8.4891e+03
# it: 94   it_marq:  0   lambda: 1e+01   misfit: 1.9234e+04
# it: 94   it_marq:  1   lambda: 1e+02   misfit: 8.4847e+03
# it: 95   it_marq:  0   lambda: 1e+01   misfit: 1.9222e+04
# it: 95   it_marq:  1   lambda: 1e+02   misfit: 8.4825e+03
# it: 96   it_marq:  0   lambda: 1e+01   misfit: 4.0071e+04
# it: 96   it_marq:  1   lambda: 1e+02   misfit: 8.4789e+03
# it: 97   it_marq:  0   lambda: 1e+01   misfit: 1.9213e+04
# it: 97   it_marq:  1   lambda: 1e+02   misfit: 8.4757e+03
# it: 98   it_marq:  0   lambda: 1e+01   misfit: 4.0036e+04
# it: 98   it_marq:  1   lambda: 1e+02   misfit: 8.4726e+03
# it: 99   it_marq:  0   lambda: 1e+01   misfit: 1.9261e+04
# it: 99   it_marq:  1   lambda: 1e+02   misfit: 8.4702e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.6838e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.3090e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.2184e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.9925e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.1250e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 1.2708e+04
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 2.0348e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.4635e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 1.2949e+04
# it:  5   it_marq:  3   lambda: 1e+02   misfit: 1.2692e+04
# it:  6   it_marq:  0   lambda: 1e+01   misfit: 1.2987e+04
# it:  6   it_marq:  1   lambda: 1e+02   misfit: 1.2702e+04
# it:  6   it_marq:  2   lambda: 1e+03   misfit: 1.2691e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.0533e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.3620e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.2974e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.6471e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.4666e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 6.5226e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 3.9953e+03
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 1.0889e+04
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 5.0904e+03
# it:  6   it_marq:  2   lambda: 1e+00   misfit: 3.9662e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.4401e+03
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 4.2788e+03
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 3.9929e+03
# it:  7   it_marq:  3   lambda: 1e+02   misfit: 3.9633e+03
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 3.9983e+03
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 3.9635e+03
# it:  8   it_marq:  2   lambda: 1e+03   misfit: 3.9633e+03
# it:  8   it_marq:  3   lambda: 1e+04   misfit: 3.9635e+03
# it:  8   it_marq:  4   lambda: 1e+05   misfit: 3.9636e+03
# it:  8   it_marq:  5   lambda: 1e+06   misfit: 3.9636e+03
# it:  8   it_marq:  6   lambda: 1e+07   misfit: 3.9636e+03
# it:  8   it_marq:  7   lambda: 1e+08   misfit: 3.9636e+03
# it:  8   it_marq:  8   lambda: 1e+09   misfit: 3.9636e+03
# it:  8   it_marq:  9   lambda: 1e+10   misfit: 3.9636e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.2488e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.1661e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 7.2846e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.8383e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.8771e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 6.1814e+03
# it:  6   it_marq:  0   lambda: 1e-03   misfit: 4.5257e+04
# it:  6   it_marq:  1   lambda: 1e-02   misfit: 3.8522e+04
# it:  6   it_marq:  2   lambda: 1e-01   misfit: 1.2233e+05
# it:  6   it_marq:  3   lambda: 1e+00   misfit: 6.3592e+04
# it:  6   it_marq:  4   lambda: 1e+01   misfit: 3.7515e+03
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.7441e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 2.9482e+03
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 2.1534e+03
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.7645e+03
# it: 10   it_marq:  0   lambda: 1e-02   misfit: 3.6054e+04
# it: 10   it_marq:  1   lambda: 1e-01   misfit: 4.1893e+03
# it: 10   it_marq:  2   lambda: 1e+00   misfit: 1.4971e+03
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 3.8419e+03
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.3895e+03
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 2.9312e+04
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.3346e+03
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 6.9316e+04
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.3028e+03
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 7.0733e+04
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.2828e+03
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 5.1642e+04
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 1.2696e+03
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 4.1645e+04
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 1.2610e+03
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 4.0180e+04
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 1.2556e+03
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 3.9804e+04
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 1.2527e+03
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 3.9694e+04
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 1.4733e+03
# it: 19   it_marq:  2   lambda: 1e+01   misfit: 1.2534e+03
# it: 19   it_marq:  3   lambda: 1e+02   misfit: 1.2520e+03
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.2536e+03
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.2521e+03
# it: 20   it_marq:  2   lambda: 1e+03   misfit: 1.2519e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.0353e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.5460e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.4074e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.2450e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.6864e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 4.4560e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 2.3793e+03
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 7.3970e+03
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 3.6587e+03
# it:  6   it_marq:  2   lambda: 1e+00   misfit: 2.2762e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 4.5743e+03
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 2.5759e+03
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 2.2951e+03
# it:  7   it_marq:  3   lambda: 1e+02   misfit: 2.2731e+03
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 2.2983e+03
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 2.2723e+03
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 2.3021e+03
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 2.2731e+03
# it:  9   it_marq:  2   lambda: 1e+03   misfit: 2.2724e+03
# it:  9   it_marq:  3   lambda: 1e+04   misfit: 2.2724e+03
# it:  9   it_marq:  4   lambda: 1e+05   misfit: 2.2724e+03
# it:  9   it_marq:  5   lambda: 1e+06   misfit: 2.2724e+03
# it:  9   it_marq:  6   lambda: 1e+07   misfit: 2.2724e+03
# it:  9   it_marq:  7   lambda: 1e+08   misfit: 2.2724e+03
# it:  9   it_marq:  8   lambda: 1e+09   misfit: 2.2724e+03
# it:  9   it_marq:  9   lambda: 1e+10   misfit: 2.2724e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 2.2390e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.5601e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 7.2941e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.3011e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 7.5701e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 5.2643e+04
# it:  4   it_marq:  2   lambda: 1e+01   misfit: 4.4325e+04
# it:  4   it_marq:  3   lambda: 1e+02   misfit: 4.2862e+04
# it:  5   it_marq:  0   lambda: 1e+01   misfit: 4.4477e+04
# it:  5   it_marq:  1   lambda: 1e+02   misfit: 4.2890e+04
# it:  5   it_marq:  2   lambda: 1e+03   misfit: 4.2852e+04
# it:  6   it_marq:  0   lambda: 1e+02   misfit: 4.2896e+04
# it:  6   it_marq:  1   lambda: 1e+03   misfit: 4.2844e+04
# it:  7   it_marq:  0   lambda: 1e+02   misfit: 4.2903e+04
# it:  7   it_marq:  1   lambda: 1e+03   misfit: 4.2839e+04
# it:  8   it_marq:  0   lambda: 1e+02   misfit: 4.2912e+04
# it:  8   it_marq:  1   lambda: 1e+03   misfit: 4.2836e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.4279e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.1290e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.5603e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.2040e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.3760e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.5105e+04
# it:  4   it_marq:  2   lambda: 1e+01   misfit: 2.1933e+04
# it:  5   it_marq:  0   lambda: 1e+00   misfit: 2.6301e+04
# it:  5   it_marq:  1   lambda: 1e+01   misfit: 2.2358e+04
# it:  5   it_marq:  2   lambda: 1e+02   misfit: 2.1946e+04
# it:  5   it_marq:  3   lambda: 1e+03   misfit: 2.1932e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.2835e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.0811e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.2642e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.2200e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.1941e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.1707e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.1673e+04
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 9.1270e+04
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 1.6489e+04
# it:  6   it_marq:  2   lambda: 1e+00   misfit: 1.0278e+04
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.7851e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.0458e+04
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 1.0325e+04
# it:  7   it_marq:  3   lambda: 1e+02   misfit: 1.0277e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.3680e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.0209e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.2582e+05
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.1232e+05
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.1813e+05
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 1.5380e+05
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 1.8188e+05
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.3423e+05
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 2.0799e+05
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 1.3164e+05
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.4858e+05
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.0785e+05
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 1.6769e+05
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.5683e+05
# it:  8   it_marq:  2   lambda: 1e+01   misfit: 9.4782e+04
# it:  9   it_marq:  0   lambda: 1e+00   misfit: 1.1456e+05
# it:  9   it_marq:  1   lambda: 1e+01   misfit: 9.5866e+04
# it:  9   it_marq:  2   lambda: 1e+02   misfit: 9.4281e+04
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 9.5608e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 9.3882e+04
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 9.5395e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 9.3570e+04
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 9.5209e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 9.3345e+04
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 9.5050e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 9.3161e+04
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 9.4911e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 9.2990e+04
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 9.4789e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 9.2831e+04
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 9.4683e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 9.3013e+04
# it: 16   it_marq:  2   lambda: 1e+03   misfit: 9.2805e+04
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 9.2666e+04
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 9.4580e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 9.2517e+04
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 9.2319e+04
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 1.6735e+05
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 9.1495e+04
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 2.9339e+05
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 9.9524e+04
# it: 21   it_marq:  2   lambda: 1e+02   misfit: 9.0842e+04
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 9.8394e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 9.0758e+04
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 9.8296e+04
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 9.0683e+04
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 9.8206e+04
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 9.0613e+04
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 9.8126e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 9.0549e+04
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 9.8053e+04
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 9.0490e+04
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 9.7988e+04
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 9.0435e+04
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 9.7927e+04
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 9.0383e+04
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 9.7873e+04
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 9.0335e+04
# it: 30   it_marq:  0   lambda: 1e+01   misfit: 9.7822e+04
# it: 30   it_marq:  1   lambda: 1e+02   misfit: 9.0290e+04
# it: 31   it_marq:  0   lambda: 1e+01   misfit: 9.7776e+04
# it: 31   it_marq:  1   lambda: 1e+02   misfit: 9.0249e+04
# it: 32   it_marq:  0   lambda: 1e+01   misfit: 9.7732e+04
# it: 32   it_marq:  1   lambda: 1e+02   misfit: 9.0209e+04
# it: 33   it_marq:  0   lambda: 1e+01   misfit: 9.7692e+04
# it: 33   it_marq:  1   lambda: 1e+02   misfit: 9.0173e+04
# it: 34   it_marq:  0   lambda: 1e+01   misfit: 9.7654e+04
# it: 34   it_marq:  1   lambda: 1e+02   misfit: 9.0138e+04
# it: 35   it_marq:  0   lambda: 1e+01   misfit: 9.7618e+04
# it: 35   it_marq:  1   lambda: 1e+02   misfit: 9.0105e+04
# it: 36   it_marq:  0   lambda: 1e+01   misfit: 9.7583e+04
# it: 36   it_marq:  1   lambda: 1e+02   misfit: 9.0074e+04
# it: 37   it_marq:  0   lambda: 1e+01   misfit: 9.7550e+04
# it: 37   it_marq:  1   lambda: 1e+02   misfit: 9.0045e+04
# it: 38   it_marq:  0   lambda: 1e+01   misfit: 9.7517e+04
# it: 38   it_marq:  1   lambda: 1e+02   misfit: 9.0017e+04
# it: 39   it_marq:  0   lambda: 1e+01   misfit: 9.7485e+04
# it: 39   it_marq:  1   lambda: 1e+02   misfit: 8.9991e+04
# it: 40   it_marq:  0   lambda: 1e+01   misfit: 9.7453e+04
# it: 40   it_marq:  1   lambda: 1e+02   misfit: 8.9965e+04
# it: 41   it_marq:  0   lambda: 1e+01   misfit: 9.7420e+04
# it: 41   it_marq:  1   lambda: 1e+02   misfit: 8.9940e+04
# it: 42   it_marq:  0   lambda: 1e+01   misfit: 9.7387e+04
# it: 42   it_marq:  1   lambda: 1e+02   misfit: 8.9915e+04
# it: 43   it_marq:  0   lambda: 1e+01   misfit: 9.7351e+04
# it: 43   it_marq:  1   lambda: 1e+02   misfit: 8.9891e+04
# it: 44   it_marq:  0   lambda: 1e+01   misfit: 9.7315e+04
# it: 44   it_marq:  1   lambda: 1e+02   misfit: 8.9867e+04
# it: 45   it_marq:  0   lambda: 1e+01   misfit: 9.7275e+04
# it: 45   it_marq:  1   lambda: 1e+02   misfit: 8.9842e+04
# it: 46   it_marq:  0   lambda: 1e+01   misfit: 9.7233e+04
# it: 46   it_marq:  1   lambda: 1e+02   misfit: 8.9817e+04
# it: 47   it_marq:  0   lambda: 1e+01   misfit: 9.7186e+04
# it: 47   it_marq:  1   lambda: 1e+02   misfit: 8.9792e+04
# it: 48   it_marq:  0   lambda: 1e+01   misfit: 9.7135e+04
# it: 48   it_marq:  1   lambda: 1e+02   misfit: 8.9764e+04
# it: 49   it_marq:  0   lambda: 1e+01   misfit: 9.7077e+04
# it: 49   it_marq:  1   lambda: 1e+02   misfit: 8.9735e+04
# it: 50   it_marq:  0   lambda: 1e+01   misfit: 9.7012e+04
# it: 50   it_marq:  1   lambda: 1e+02   misfit: 8.9703e+04
# it: 51   it_marq:  0   lambda: 1e+01   misfit: 9.6924e+04
# it: 51   it_marq:  1   lambda: 1e+02   misfit: 8.9668e+04
# it: 52   it_marq:  0   lambda: 1e+01   misfit: 9.6664e+04
# it: 52   it_marq:  1   lambda: 1e+02   misfit: 8.9628e+04
# it: 53   it_marq:  0   lambda: 1e+01   misfit: 9.5728e+04
# it: 53   it_marq:  1   lambda: 1e+02   misfit: 8.9584e+04
# it: 54   it_marq:  0   lambda: 1e+01   misfit: 9.5721e+04
# it: 54   it_marq:  1   lambda: 1e+02   misfit: 8.9534e+04
# it: 55   it_marq:  0   lambda: 1e+01   misfit: 9.3364e+04
# it: 55   it_marq:  1   lambda: 1e+02   misfit: 8.9476e+04
# it: 56   it_marq:  0   lambda: 1e+01   misfit: 9.1692e+04
# it: 56   it_marq:  1   lambda: 1e+02   misfit: 8.9411e+04
# it: 57   it_marq:  0   lambda: 1e+01   misfit: 9.4842e+04
# it: 57   it_marq:  1   lambda: 1e+02   misfit: 8.9335e+04
# it: 58   it_marq:  0   lambda: 1e+01   misfit: 2.0080e+05
# it: 58   it_marq:  1   lambda: 1e+02   misfit: 8.9249e+04
# it: 59   it_marq:  0   lambda: 1e+01   misfit: 2.0938e+05
# it: 59   it_marq:  1   lambda: 1e+02   misfit: 8.9150e+04
# it: 60   it_marq:  0   lambda: 1e+01   misfit: 2.0668e+05
# it: 60   it_marq:  1   lambda: 1e+02   misfit: 8.9037e+04
# it: 61   it_marq:  0   lambda: 1e+01   misfit: 2.0488e+05
# it: 61   it_marq:  1   lambda: 1e+02   misfit: 8.8909e+04
# it: 62   it_marq:  0   lambda: 1e+01   misfit: 2.0364e+05
# it: 62   it_marq:  1   lambda: 1e+02   misfit: 8.8765e+04
# it: 63   it_marq:  0   lambda: 1e+01   misfit: 2.0275e+05
# it: 63   it_marq:  1   lambda: 1e+02   misfit: 8.8605e+04
# it: 64   it_marq:  0   lambda: 1e+01   misfit: 2.0213e+05
# it: 64   it_marq:  1   lambda: 1e+02   misfit: 8.8431e+04
# it: 65   it_marq:  0   lambda: 1e+01   misfit: 2.0168e+05
# it: 65   it_marq:  1   lambda: 1e+02   misfit: 8.8244e+04
# it: 66   it_marq:  0   lambda: 1e+01   misfit: 2.0137e+05
# it: 66   it_marq:  1   lambda: 1e+02   misfit: 8.8051e+04
# it: 67   it_marq:  0   lambda: 1e+01   misfit: 2.0115e+05
# it: 67   it_marq:  1   lambda: 1e+02   misfit: 8.7865e+04
# it: 68   it_marq:  0   lambda: 1e+01   misfit: 2.0101e+05
# it: 68   it_marq:  1   lambda: 1e+02   misfit: 8.7689e+04
# it: 69   it_marq:  0   lambda: 1e+01   misfit: 2.0091e+05
# it: 69   it_marq:  1   lambda: 1e+02   misfit: 8.7521e+04
# it: 70   it_marq:  0   lambda: 1e+01   misfit: 2.0084e+05
# it: 70   it_marq:  1   lambda: 1e+02   misfit: 8.7379e+04
# it: 71   it_marq:  0   lambda: 1e+01   misfit: 2.0077e+05
# it: 71   it_marq:  1   lambda: 1e+02   misfit: 8.7254e+04
# it: 72   it_marq:  0   lambda: 1e+01   misfit: 2.0071e+05
# it: 72   it_marq:  1   lambda: 1e+02   misfit: 8.7126e+04
# it: 73   it_marq:  0   lambda: 1e+01   misfit: 2.0066e+05
# it: 73   it_marq:  1   lambda: 1e+02   misfit: 8.6996e+04
# it: 74   it_marq:  0   lambda: 1e+01   misfit: 2.0062e+05
# it: 74   it_marq:  1   lambda: 1e+02   misfit: 8.6866e+04
# it: 75   it_marq:  0   lambda: 1e+01   misfit: 2.0058e+05
# it: 75   it_marq:  1   lambda: 1e+02   misfit: 8.6735e+04
# it: 76   it_marq:  0   lambda: 1e+01   misfit: 2.0055e+05
# it: 76   it_marq:  1   lambda: 1e+02   misfit: 8.6602e+04
# it: 77   it_marq:  0   lambda: 1e+01   misfit: 2.0052e+05
# it: 77   it_marq:  1   lambda: 1e+02   misfit: 8.6469e+04
# it: 78   it_marq:  0   lambda: 1e+01   misfit: 2.0049e+05
# it: 78   it_marq:  1   lambda: 1e+02   misfit: 8.6335e+04
# it: 79   it_marq:  0   lambda: 1e+01   misfit: 2.0046e+05
# it: 79   it_marq:  1   lambda: 1e+02   misfit: 8.6200e+04
# it: 80   it_marq:  0   lambda: 1e+01   misfit: 2.0043e+05
# it: 80   it_marq:  1   lambda: 1e+02   misfit: 8.6064e+04
# it: 81   it_marq:  0   lambda: 1e+01   misfit: 2.0041e+05
# it: 81   it_marq:  1   lambda: 1e+02   misfit: 8.5927e+04
# it: 82   it_marq:  0   lambda: 1e+01   misfit: 2.0038e+05
# it: 82   it_marq:  1   lambda: 1e+02   misfit: 8.5789e+04
# it: 83   it_marq:  0   lambda: 1e+01   misfit: 2.0035e+05
# it: 83   it_marq:  1   lambda: 1e+02   misfit: 8.5651e+04
# it: 84   it_marq:  0   lambda: 1e+01   misfit: 2.0033e+05
# it: 84   it_marq:  1   lambda: 1e+02   misfit: 8.5511e+04
# it: 85   it_marq:  0   lambda: 1e+01   misfit: 2.0030e+05
# it: 85   it_marq:  1   lambda: 1e+02   misfit: 8.5371e+04
# it: 86   it_marq:  0   lambda: 1e+01   misfit: 2.0028e+05
# it: 86   it_marq:  1   lambda: 1e+02   misfit: 8.5230e+04
# it: 87   it_marq:  0   lambda: 1e+01   misfit: 2.0025e+05
# it: 87   it_marq:  1   lambda: 1e+02   misfit: 8.5087e+04
# it: 88   it_marq:  0   lambda: 1e+01   misfit: 2.0022e+05
# it: 88   it_marq:  1   lambda: 1e+02   misfit: 8.4944e+04
# it: 89   it_marq:  0   lambda: 1e+01   misfit: 2.0020e+05
# it: 89   it_marq:  1   lambda: 1e+02   misfit: 8.4800e+04
# it: 90   it_marq:  0   lambda: 1e+01   misfit: 2.0017e+05
# it: 90   it_marq:  1   lambda: 1e+02   misfit: 8.4655e+04
# it: 91   it_marq:  0   lambda: 1e+01   misfit: 2.0014e+05
# it: 91   it_marq:  1   lambda: 1e+02   misfit: 8.4509e+04
# it: 92   it_marq:  0   lambda: 1e+01   misfit: 2.0012e+05
# it: 92   it_marq:  1   lambda: 1e+02   misfit: 8.4362e+04
# it: 93   it_marq:  0   lambda: 1e+01   misfit: 2.0009e+05
# it: 93   it_marq:  1   lambda: 1e+02   misfit: 8.4215e+04
# it: 94   it_marq:  0   lambda: 1e+01   misfit: 2.0006e+05
# it: 94   it_marq:  1   lambda: 1e+02   misfit: 8.4066e+04
# it: 95   it_marq:  0   lambda: 1e+01   misfit: 2.0003e+05
# it: 95   it_marq:  1   lambda: 1e+02   misfit: 8.3916e+04
# it: 96   it_marq:  0   lambda: 1e+01   misfit: 2.0000e+05
# it: 96   it_marq:  1   lambda: 1e+02   misfit: 8.3765e+04
# it: 97   it_marq:  0   lambda: 1e+01   misfit: 1.9997e+05
# it: 97   it_marq:  1   lambda: 1e+02   misfit: 8.3613e+04
# it: 98   it_marq:  0   lambda: 1e+01   misfit: 1.9994e+05
# it: 98   it_marq:  1   lambda: 1e+02   misfit: 8.3460e+04
# it: 99   it_marq:  0   lambda: 1e+01   misfit: 1.9990e+05
# it: 99   it_marq:  1   lambda: 1e+02   misfit: 8.3305e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.4172e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.2823e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 7.9861e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.1391e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.5484e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 1.2730e+04
# it:  6   it_marq:  0   lambda: 1e-03   misfit: 1.5069e+04
# it:  6   it_marq:  1   lambda: 1e-02   misfit: 1.2629e+04
# it:  7   it_marq:  0   lambda: 1e-03   misfit: 1.6795e+04
# it:  7   it_marq:  1   lambda: 1e-02   misfit: 1.0082e+04
# it:  8   it_marq:  0   lambda: 1e-03   misfit: 1.3527e+04
# it:  8   it_marq:  1   lambda: 1e-02   misfit: 9.1774e+03
# it:  9   it_marq:  0   lambda: 1e-03   misfit: 8.3711e+03
# it: 10   it_marq:  0   lambda: 1e-04   misfit: 1.2073e+04
# it: 10   it_marq:  1   lambda: 1e-03   misfit: 1.0766e+04
# it: 10   it_marq:  2   lambda: 1e-02   misfit: 6.6376e+03
# it: 11   it_marq:  0   lambda: 1e-03   misfit: 6.7504e+03
# it: 11   it_marq:  1   lambda: 1e-02   misfit: 5.3682e+03
# it: 12   it_marq:  0   lambda: 1e-03   misfit: 1.8698e+04
# it: 12   it_marq:  1   lambda: 1e-02   misfit: 1.4087e+04
# it: 12   it_marq:  2   lambda: 1e-01   misfit: 6.4306e+03
# it: 12   it_marq:  3   lambda: 1e+00   misfit: 4.2731e+03
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 7.6292e+03
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 3.8744e+03
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 9.3207e+03
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 3.6022e+03
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 1.0678e+04
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 3.4018e+03
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 9.5622e+03
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 3.2552e+03
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.9595e+03
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 3.1351e+03
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.5190e+03
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 3.0361e+03
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.2098e+03
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 2.9509e+03
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.0218e+03
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 2.8818e+03
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 7.7576e+03
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 2.8251e+03
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 7.4097e+03
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 2.7789e+03
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 7.0470e+03
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 2.7394e+03
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 6.7533e+03
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 2.7090e+03
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 6.5918e+03
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 2.6847e+03
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 6.4907e+03
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 2.6673e+03
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 6.1513e+03
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 2.6534e+03
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 7.0390e+03
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 4.0059e+03
# it: 28   it_marq:  2   lambda: 1e+01   misfit: 2.6133e+03
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 3.9953e+03
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 2.5882e+03
# it: 30   it_marq:  0   lambda: 1e+00   misfit: 3.9622e+03
# it: 30   it_marq:  1   lambda: 1e+01   misfit: 2.5720e+03
# it: 31   it_marq:  0   lambda: 1e+00   misfit: 4.0211e+03
# it: 31   it_marq:  1   lambda: 1e+01   misfit: 2.5613e+03
# it: 32   it_marq:  0   lambda: 1e+00   misfit: 4.8967e+03
# it: 32   it_marq:  1   lambda: 1e+01   misfit: 2.5538e+03
# it: 33   it_marq:  0   lambda: 1e+00   misfit: 4.8952e+03
# it: 33   it_marq:  1   lambda: 1e+01   misfit: 2.5484e+03
# it: 34   it_marq:  0   lambda: 1e+00   misfit: 6.7652e+03
# it: 34   it_marq:  1   lambda: 1e+01   misfit: 2.5436e+03
# it: 35   it_marq:  0   lambda: 1e+00   misfit: 6.9920e+03
# it: 35   it_marq:  1   lambda: 1e+01   misfit: 2.5410e+03
# it: 36   it_marq:  0   lambda: 1e+00   misfit: 8.9008e+03
# it: 36   it_marq:  1   lambda: 1e+01   misfit: 2.5392e+03
# it: 37   it_marq:  0   lambda: 1e+00   misfit: 8.1135e+03
# it: 37   it_marq:  1   lambda: 1e+01   misfit: 2.5377e+03
# it: 38   it_marq:  0   lambda: 1e+00   misfit: 9.8753e+03
# it: 38   it_marq:  1   lambda: 1e+01   misfit: 2.5358e+03
# it: 39   it_marq:  0   lambda: 1e+00   misfit: 8.8712e+03
# it: 39   it_marq:  1   lambda: 1e+01   misfit: 2.5354e+03
# it: 40   it_marq:  0   lambda: 1e+00   misfit: 1.3038e+04
# it: 40   it_marq:  1   lambda: 1e+01   misfit: 2.5352e+03
# it: 41   it_marq:  0   lambda: 1e+00   misfit: 1.0104e+04
# it: 41   it_marq:  1   lambda: 1e+01   misfit: 2.5349e+03
# it: 42   it_marq:  0   lambda: 1e+00   misfit: 1.3673e+04
# it: 42   it_marq:  1   lambda: 1e+01   misfit: 2.5339e+03
# it: 43   it_marq:  0   lambda: 1e+00   misfit: 1.0079e+04
# it: 43   it_marq:  1   lambda: 1e+01   misfit: 2.5344e+03
# it: 43   it_marq:  2   lambda: 1e+02   misfit: 2.5329e+03
# it: 44   it_marq:  0   lambda: 1e+01   misfit: 2.5336e+03
# it: 44   it_marq:  1   lambda: 1e+02   misfit: 2.5321e+03
# it: 45   it_marq:  0   lambda: 1e+01   misfit: 2.5330e+03
# it: 45   it_marq:  1   lambda: 1e+02   misfit: 2.5313e+03
# it: 46   it_marq:  0   lambda: 1e+01   misfit: 2.5325e+03
# it: 46   it_marq:  1   lambda: 1e+02   misfit: 2.5309e+03
# it: 47   it_marq:  0   lambda: 1e+01   misfit: 2.5320e+03
# it: 47   it_marq:  1   lambda: 1e+02   misfit: 2.5303e+03
# it: 48   it_marq:  0   lambda: 1e+01   misfit: 2.5317e+03
# it: 48   it_marq:  1   lambda: 1e+02   misfit: 2.5300e+03
# it: 49   it_marq:  0   lambda: 1e+01   misfit: 2.5313e+03
# it: 49   it_marq:  1   lambda: 1e+02   misfit: 2.5297e+03
# it: 50   it_marq:  0   lambda: 1e+01   misfit: 2.5311e+03
# it: 50   it_marq:  1   lambda: 1e+02   misfit: 2.5295e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.2834e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.2305e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 9.3007e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 5.9377e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.6882e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 5.2950e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 4.8201e+04
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.0190e+04
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 4.6792e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 3.5451e+04
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 3.8727e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 3.7259e+04
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 3.3397e+04
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 3.5841e+04
# ...
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 5.7559e+03
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.0051e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 5.7538e+03
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.0045e+04
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 5.7521e+03
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 1.0044e+04
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 5.7499e+03
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 4.1970e+04
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 5.7481e+03
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.9468e+04
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 5.7458e+03
# it: 30   it_marq:  0   lambda: 1e+01   misfit: 4.1226e+04
# it: 30   it_marq:  1   lambda: 1e+02   misfit: 5.7438e+03
# it: 31   it_marq:  0   lambda: 1e+01   misfit: 3.2892e+04
# it: 31   it_marq:  1   lambda: 1e+02   misfit: 5.7413e+03
# it: 32   it_marq:  0   lambda: 1e+01   misfit: 2.3811e+04
# it: 32   it_marq:  1   lambda: 1e+02   misfit: 5.7392e+03
# it: 33   it_marq:  0   lambda: 1e+01   misfit: 7.3737e+04
# it: 33   it_marq:  1   lambda: 1e+02   misfit: 5.7365e+03
# it: 34   it_marq:  0   lambda: 1e+01   misfit: 2.0555e+04
# it: 34   it_marq:  1   lambda: 1e+02   misfit: 5.7342e+03
# it: 35   it_marq:  0   lambda: 1e+01   misfit: 7.0752e+04
# it: 35   it_marq:  1   lambda: 1e+02   misfit: 5.7313e+03
# it: 36   it_marq:  0   lambda: 1e+01   misfit: 6.8240e+04
# it: 36   it_marq:  1   lambda: 1e+02   misfit: 5.7288e+03
# it: 37   it_marq:  0   lambda: 1e+01   misfit: 6.7927e+04
# it: 37   it_marq:  1   lambda: 1e+02   misfit: 5.7258e+03
# it: 38   it_marq:  0   lambda: 1e+01   misfit: 5.4242e+04
# it: 38   it_marq:  1   lambda: 1e+02   misfit: 5.7231e+03
# it: 39   it_marq:  0   lambda: 1e+01   misfit: 3.7763e+04
# it: 39   it_marq:  1   lambda: 1e+02   misfit: 5.7199e+03
# it: 40   it_marq:  0   lambda: 1e+01   misfit: 3.1868e+04
# it: 40   it_marq:  1   lambda: 1e+02   misfit: 5.7171e+03
# it: 41   it_marq:  0   lambda: 1e+01   misfit: 2.9932e+04
# it: 41   it_marq:  1   lambda: 1e+02   misfit: 5.7137e+03
# it: 42   it_marq:  0   lambda: 1e+01   misfit: 2.9215e+04
# it: 42   it_marq:  1   lambda: 1e+02   misfit: 5.7106e+03
# it: 43   it_marq:  0   lambda: 1e+01   misfit: 2.8868e+04
# it: 43   it_marq:  1   lambda: 1e+02   misfit: 5.7071e+03
# it: 44   it_marq:  0   lambda: 1e+01   misfit: 2.8694e+04
# it: 44   it_marq:  1   lambda: 1e+02   misfit: 5.7039e+03
# it: 45   it_marq:  0   lambda: 1e+01   misfit: 2.8586e+04
# it: 45   it_marq:  1   lambda: 1e+02   misfit: 5.7002e+03
# it: 46   it_marq:  0   lambda: 1e+01   misfit: 2.8524e+04
# it: 46   it_marq:  1   lambda: 1e+02   misfit: 5.6968e+03
# it: 47   it_marq:  0   lambda: 1e+01   misfit: 2.8480e+04
# it: 47   it_marq:  1   lambda: 1e+02   misfit: 5.6929e+03
# it: 48   it_marq:  0   lambda: 1e+01   misfit: 2.8455e+04
# it: 48   it_marq:  1   lambda: 1e+02   misfit: 5.6893e+03
# it: 49   it_marq:  0   lambda: 1e+01   misfit: 2.8434e+04
# it: 49   it_marq:  1   lambda: 1e+02   misfit: 5.6853e+03
# it: 50   it_marq:  0   lambda: 1e+01   misfit: 2.8422e+04
# it: 50   it_marq:  1   lambda: 1e+02   misfit: 5.6815e+03
# it: 51   it_marq:  0   lambda: 1e+01   misfit: 2.8413e+04
# it: 51   it_marq:  1   lambda: 1e+02   misfit: 5.6773e+03
# it: 52   it_marq:  0   lambda: 1e+01   misfit: 2.8410e+04
# it: 52   it_marq:  1   lambda: 1e+02   misfit: 5.6734e+03
# it: 53   it_marq:  0   lambda: 1e+01   misfit: 2.8407e+04
# it: 53   it_marq:  1   lambda: 1e+02   misfit: 5.6690e+03
# it: 54   it_marq:  0   lambda: 1e+01   misfit: 2.8405e+04
# it: 54   it_marq:  1   lambda: 1e+02   misfit: 5.6649e+03
# it: 55   it_marq:  0   lambda: 1e+01   misfit: 2.8204e+04
# it: 55   it_marq:  1   lambda: 1e+02   misfit: 5.6604e+03
# it: 56   it_marq:  0   lambda: 1e+01   misfit: 2.6428e+04
# it: 56   it_marq:  1   lambda: 1e+02   misfit: 5.6562e+03
# it: 57   it_marq:  0   lambda: 1e+01   misfit: 2.1138e+04
# it: 57   it_marq:  1   lambda: 1e+02   misfit: 5.6515e+03
# it: 58   it_marq:  0   lambda: 1e+01   misfit: 1.6182e+04
# it: 58   it_marq:  1   lambda: 1e+02   misfit: 5.6471e+03
# it: 59   it_marq:  0   lambda: 1e+01   misfit: 1.2028e+04
# it: 59   it_marq:  1   lambda: 1e+02   misfit: 5.6422e+03
# it: 60   it_marq:  0   lambda: 1e+01   misfit: 8.4583e+03
# it: 60   it_marq:  1   lambda: 1e+02   misfit: 5.6377e+03
# it: 61   it_marq:  0   lambda: 1e+01   misfit: 6.6511e+03
# it: 61   it_marq:  1   lambda: 1e+02   misfit: 5.6327e+03
# it: 62   it_marq:  0   lambda: 1e+01   misfit: 6.1146e+03
# it: 62   it_marq:  1   lambda: 1e+02   misfit: 5.6279e+03
# it: 63   it_marq:  0   lambda: 1e+01   misfit: 5.9285e+03
# it: 63   it_marq:  1   lambda: 1e+02   misfit: 5.6228e+03
# it: 64   it_marq:  0   lambda: 1e+01   misfit: 5.8579e+03
# it: 64   it_marq:  1   lambda: 1e+02   misfit: 5.6180e+03
# it: 65   it_marq:  0   lambda: 1e+01   misfit: 5.8208e+03
# it: 65   it_marq:  1   lambda: 1e+02   misfit: 5.6127e+03
# it: 66   it_marq:  0   lambda: 1e+01   misfit: 5.8000e+03
# it: 66   it_marq:  1   lambda: 1e+02   misfit: 5.6077e+03
# it: 67   it_marq:  0   lambda: 1e+01   misfit: 5.7818e+03
# it: 67   it_marq:  1   lambda: 1e+02   misfit: 5.6023e+03
# it: 68   it_marq:  0   lambda: 1e+01   misfit: 5.7396e+03
# it: 68   it_marq:  1   lambda: 1e+02   misfit: 5.5972e+03
# it: 69   it_marq:  0   lambda: 1e+01   misfit: 5.6286e+03
# it: 69   it_marq:  1   lambda: 1e+02   misfit: 5.5917e+03
# it: 70   it_marq:  0   lambda: 1e+01   misfit: 5.5430e+03
# it: 71   it_marq:  0   lambda: 1e+00   misfit: 5.6732e+03
# it: 71   it_marq:  1   lambda: 1e+01   misfit: 5.4757e+03
# it: 72   it_marq:  0   lambda: 1e+00   misfit: 5.5297e+03
# it: 72   it_marq:  1   lambda: 1e+01   misfit: 5.4236e+03
# it: 73   it_marq:  0   lambda: 1e+00   misfit: 5.4026e+03
# it: 74   it_marq:  0   lambda: 1e-01   misfit: 6.7930e+04
# it: 74   it_marq:  1   lambda: 1e+00   misfit: 4.9918e+03
# it: 75   it_marq:  0   lambda: 1e-01   misfit: 1.6095e+05
# it: 75   it_marq:  1   lambda: 1e+00   misfit: 4.7362e+03
# it: 76   it_marq:  0   lambda: 1e-01   misfit: 1.9758e+05
# it: 76   it_marq:  1   lambda: 1e+00   misfit: 1.2898e+04
# it: 76   it_marq:  2   lambda: 1e+01   misfit: 4.6328e+03
# it: 77   it_marq:  0   lambda: 1e+00   misfit: 6.6359e+04
# it: 77   it_marq:  1   lambda: 1e+01   misfit: 4.5984e+03
# it: 78   it_marq:  0   lambda: 1e+00   misfit: 1.0203e+05
# it: 78   it_marq:  1   lambda: 1e+01   misfit: 4.6081e+03
# it: 78   it_marq:  2   lambda: 1e+02   misfit: 4.5928e+03
# it: 79   it_marq:  0   lambda: 1e+01   misfit: 3.9284e+04
# it: 79   it_marq:  1   lambda: 1e+02   misfit: 4.5903e+03
# it: 80   it_marq:  0   lambda: 1e+01   misfit: 9.6693e+04
# it: 80   it_marq:  1   lambda: 1e+02   misfit: 4.5884e+03
# it: 81   it_marq:  0   lambda: 1e+01   misfit: 1.3913e+04
# it: 81   it_marq:  1   lambda: 1e+02   misfit: 4.5880e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.8619e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.6894e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.1626e+05
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 6.8514e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.8457e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.2247e+04
# it:  6   it_marq:  0   lambda: 1e-03   misfit: 5.4050e+04
# it:  6   it_marq:  1   lambda: 1e-02   misfit: 2.1894e+04
# it:  7   it_marq:  0   lambda: 1e-03   misfit: 2.0522e+04
# it:  8   it_marq:  0   lambda: 1e-04   misfit: 8.9304e+04
# it:  8   it_marq:  1   lambda: 1e-03   misfit: 8.7507e+04
# it:  8   it_marq:  2   lambda: 1e-02   misfit: 6.0468e+04
# it:  8   it_marq:  3   lambda: 1e-01   misfit: 9.1694e+03
# it:  9   it_marq:  0   lambda: 1e-02   misfit: 1.0982e+04
# it:  9   it_marq:  1   lambda: 1e-01   misfit: 9.9705e+03
# it:  9   it_marq:  2   lambda: 1e+00   misfit: 9.2890e+03
# it:  9   it_marq:  3   lambda: 1e+01   misfit: 9.7929e+03
# it:  9   it_marq:  4   lambda: 1e+02   misfit: 8.9432e+03
# it: 10   it_marq:  0   lambda: 1e+01   misfit: 1.0271e+04
# it: 10   it_marq:  1   lambda: 1e+02   misfit: 8.7974e+03
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 1.0649e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 8.6594e+03
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.2381e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 8.5338e+03
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.3883e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 8.4139e+03
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.3772e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 8.3042e+03
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 1.2540e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 8.1989e+03
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 1.0310e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 8.1026e+03
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 8.8434e+03
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 8.0096e+03
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 8.7846e+03
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 7.9246e+03
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 8.7357e+03
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 7.8423e+03
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 8.6780e+03
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 7.7672e+03
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 8.5749e+03
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 7.6942e+03
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 7.4928e+03
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 8.9087e+03
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 7.2149e+03
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 8.6905e+03
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 7.0380e+03
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 8.5372e+03
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 6.9222e+03
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 4.3525e+04
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 6.8418e+03
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 7.7461e+04
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 6.7842e+03
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 1.1488e+05
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 7.0828e+03
# it: 28   it_marq:  2   lambda: 1e+02   misfit: 6.7763e+03
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 2.1126e+04
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 6.7713e+03
# it: 30   it_marq:  0   lambda: 1e+01   misfit: 9.6816e+03
# it: 30   it_marq:  1   lambda: 1e+02   misfit: 6.7656e+03
# it: 31   it_marq:  0   lambda: 1e+01   misfit: 2.8582e+04
# it: 31   it_marq:  1   lambda: 1e+02   misfit: 6.7612e+03
# it: 32   it_marq:  0   lambda: 1e+01   misfit: 2.7889e+04
# it: 32   it_marq:  1   lambda: 1e+02   misfit: 6.7560e+03
# it: 33   it_marq:  0   lambda: 1e+01   misfit: 2.8066e+04
# it: 33   it_marq:  1   lambda: 1e+02   misfit: 6.7521e+03
# it: 34   it_marq:  0   lambda: 1e+01   misfit: 2.9380e+04
# it: 34   it_marq:  1   lambda: 1e+02   misfit: 6.7475e+03
# it: 35   it_marq:  0   lambda: 1e+01   misfit: 2.9346e+04
# it: 35   it_marq:  1   lambda: 1e+02   misfit: 6.7440e+03
# it: 36   it_marq:  0   lambda: 1e+01   misfit: 3.2253e+04
# it: 36   it_marq:  1   lambda: 1e+02   misfit: 6.7397e+03
# it: 37   it_marq:  0   lambda: 1e+01   misfit: 2.9224e+04
# it: 37   it_marq:  1   lambda: 1e+02   misfit: 6.7365e+03
# it: 38   it_marq:  0   lambda: 1e+01   misfit: 3.2950e+04
# it: 38   it_marq:  1   lambda: 1e+02   misfit: 6.7325e+03
# it: 39   it_marq:  0   lambda: 1e+01   misfit: 2.1414e+04
# it: 39   it_marq:  1   lambda: 1e+02   misfit: 6.7296e+03
# it: 40   it_marq:  0   lambda: 1e+01   misfit: 9.4440e+03
# it: 40   it_marq:  1   lambda: 1e+02   misfit: 6.7260e+03
# it: 41   it_marq:  0   lambda: 1e+01   misfit: 2.0111e+04
# it: 41   it_marq:  1   lambda: 1e+02   misfit: 6.7233e+03
# it: 42   it_marq:  0   lambda: 1e+01   misfit: 7.8669e+03
# it: 42   it_marq:  1   lambda: 1e+02   misfit: 6.7198e+03
# it: 43   it_marq:  0   lambda: 1e+01   misfit: 1.0926e+05
# it: 43   it_marq:  1   lambda: 1e+02   misfit: 6.7174e+03
# it: 44   it_marq:  0   lambda: 1e+01   misfit: 5.7952e+04
# it: 44   it_marq:  1   lambda: 1e+02   misfit: 6.7141e+03
# it: 45   it_marq:  0   lambda: 1e+01   misfit: 1.0814e+05
# it: 45   it_marq:  1   lambda: 1e+02   misfit: 6.7118e+03
# it: 46   it_marq:  0   lambda: 1e+01   misfit: 1.0890e+05
# it: 46   it_marq:  1   lambda: 1e+02   misfit: 6.7088e+03
# it: 47   it_marq:  0   lambda: 1e+01   misfit: 1.4320e+05
# it: 47   it_marq:  1   lambda: 1e+02   misfit: 6.7066e+03
# it: 48   it_marq:  0   lambda: 1e+01   misfit: 1.1676e+05
# it: 48   it_marq:  1   lambda: 1e+02   misfit: 6.7037e+03
# it: 49   it_marq:  0   lambda: 1e+01   misfit: 1.4321e+05
# it: 49   it_marq:  1   lambda: 1e+02   misfit: 6.7017e+03
# it: 50   it_marq:  0   lambda: 1e+01   misfit: 1.4296e+05
# it: 50   it_marq:  1   lambda: 1e+02   misfit: 6.6989e+03
# it: 51   it_marq:  0   lambda: 1e+01   misfit: 1.8023e+05
# it: 51   it_marq:  1   lambda: 1e+02   misfit: 6.6970e+03
# it: 52   it_marq:  0   lambda: 1e+01   misfit: 1.4639e+05
# it: 52   it_marq:  1   lambda: 1e+02   misfit: 6.6943e+03
# it: 53   it_marq:  0   lambda: 1e+01   misfit: 1.8019e+05
# it: 53   it_marq:  1   lambda: 1e+02   misfit: 6.6925e+03
# it: 54   it_marq:  0   lambda: 1e+01   misfit: 1.7458e+05
# it: 54   it_marq:  1   lambda: 1e+02   misfit: 6.6899e+03
# it: 55   it_marq:  0   lambda: 1e+01   misfit: 1.5607e+05
# it: 55   it_marq:  1   lambda: 1e+02   misfit: 6.6882e+03
# it: 56   it_marq:  0   lambda: 1e+01   misfit: 1.3810e+05
# it: 56   it_marq:  1   lambda: 1e+02   misfit: 7.0094e+03
# it: 56   it_marq:  2   lambda: 1e+03   misfit: 6.6877e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7754e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.3380e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.5151e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.7308e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.0622e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.6733e+04
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 4.3655e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 3.1894e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 2.7430e+04
# it:  5   it_marq:  3   lambda: 1e+02   misfit: 2.6633e+04
# it:  6   it_marq:  0   lambda: 1e+01   misfit: 2.7520e+04
# it:  6   it_marq:  1   lambda: 1e+02   misfit: 2.6633e+04
# it:  6   it_marq:  2   lambda: 1e+03   misfit: 2.6626e+04
# it:  7   it_marq:  0   lambda: 1e+02   misfit: 2.6635e+04
# it:  7   it_marq:  1   lambda: 1e+03   misfit: 2.6620e+04
# it:  8   it_marq:  0   lambda: 1e+02   misfit: 2.6638e+04
# it:  8   it_marq:  1   lambda: 1e+03   misfit: 2.6615e+04
# it:  9   it_marq:  0   lambda: 1e+02   misfit: 2.6642e+04
# it:  9   it_marq:  1   lambda: 1e+03   misfit: 2.6612e+04
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 2.6646e+04
# it: 10   it_marq:  1   lambda: 1e+03   misfit: 2.6609e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.6075e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.2838e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.1217e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.8015e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.3219e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 1.4069e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 9.7481e+03
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 2.1576e+04
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 1.3396e+04
# it:  6   it_marq:  2   lambda: 1e+00   misfit: 9.4595e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.4529e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 9.9999e+03
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 9.5291e+03
# it:  7   it_marq:  3   lambda: 1e+02   misfit: 9.4432e+03
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 9.5441e+03
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 9.4418e+03
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 9.5612e+03
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 9.4492e+03
# it:  9   it_marq:  2   lambda: 1e+03   misfit: 9.4423e+03
# it:  9   it_marq:  3   lambda: 1e+04   misfit: 9.4422e+03
# it:  9   it_marq:  4   lambda: 1e+05   misfit: 9.4422e+03
# it:  9   it_marq:  5   lambda: 1e+06   misfit: 9.4422e+03
# it:  9   it_marq:  6   lambda: 1e+07   misfit: 9.4422e+03
# it:  9   it_marq:  7   lambda: 1e+08   misfit: 9.4422e+03
# it:  9   it_marq:  8   lambda: 1e+09   misfit: 9.4422e+03
# it:  9   it_marq:  9   lambda: 1e+10   misfit: 9.4422e+03

# %% [markdown]
# # Results

# %%
inversion['results'] = inversion_results

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
