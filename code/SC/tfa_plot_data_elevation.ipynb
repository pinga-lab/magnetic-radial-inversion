# %% [markdown]
# # Plot of data and elevation

# %% [markdown]
# This notebook plots the observed data and the elevation of the observations. Also it plots the projection of the initial appoximate.

# %%
import cPickle as pickle

# importing my functions
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
# importing the data and elevation
datapath = 'eqlayer_rs/direction_inc-37_dec-18_h-400m/eqlayer_depth-400m.pickle'

with open(datapath) as w:
        data = pickle.load(w)

# %%
# importing the pickle file of results
result_path = 'tfa_inversion/upward_multiple_int_min1_int_max5_z0_min-1200_z0_max-750_r1500_dz700_V30_L8Feb-17-2020/'

with open(result_path+'inversion.pickle') as w:
        inversion = pickle.load(w)

# %%
# directory to save the figure and filename
filename = '../../manuscript/figures/real_updata.png'

# %%
mfun.plot_obs_alt(data['x'], data['y'], data['xt'], data['yt'],
             data['upward'], data['topography'],
             inversion['results'][0][2][0][0], filename)
