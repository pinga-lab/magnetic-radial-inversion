# %% [markdown]
# # Complex TFA multiple Inversions

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os
import pandas as pd

from fatiando.vis import mpl
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
from datetime import datetime
today = datetime.today()
# dd/mm/YY
d4 = today.strftime("%d-%b-%Y-%Hh:%Mm")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../inclined/model.pickle') as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open('data.pickle') as w:
        d = pickle.load(w)

# %%
data = pd.read_csv('inclined_model_data.txt', skipinitialspace=True, delim_whitespace=True)

# %%
dobs = data['res_data'].get_values()
xp = data['x'].get_values()
yp = data['y'].get_values()
zp = data['z'].get_values()
N = xp.size

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 20 # number of vertices per prism
L = 5 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization direction
incs = model['inc']
decs = model['dec']

int_min = 10.
int_max = 15.
intensity = np.linspace(int_min, int_max, 6)

# depth to the top, thickness and radius
z0_min = 0.
z0_max = 100.
z0 = np.linspace(z0_min, z0_max, 6)
dz = 800.
r = 700.
x0 = -200.
y0 = 0.

# main field
inc, dec = d['main_field']

# %%
z0
# Out:
# array([  0.,  20.,  40.,  60.,  80., 100.])

# %%
intensity
# Out:
# array([10., 11., 12., 13., 14., 15.])

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
#m_out = np.zeros(M + 2)

m_out = np.zeros(M+2)
for i, (x,y) in enumerate(zip(model['prisms'][0].x,model['prisms'][0].y)):
    m_out[i] = np.sqrt(x**2 + y**2)

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 10.
rmax = 1200.
x0min = -4000.
x0max = 4000.
y0min = -4000.
y0max = 4000.
dzmin = 200.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Derivatives

# %%
# variation for derivatives
deltax = 0.01*np.max(100.)
deltay = 0.01*np.max(100.)
deltar = 0.01*np.max(100.)
deltaz = 0.01*np.max(100.)

delta = np.array([deltax, deltay, deltar, deltaz])

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-3  # adjacent radial distances within each prism
a2 = 1.0e-3   # vertically adjacent radial distances
a3 = 1.0e-5 # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 1.0e-6    # vertically adjacent origins
a6 = 1.0e-6   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-4     # zero order Tikhonov on thickness of each prism

alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Folder to save the results

# %%
foldername = 'outcrop-335664'

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-3     # stop criterion

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for j, z in enumerate(z0):
    for k, i in enumerate(intensity):
        alpha = np.array([a1, a2, a3, a4, a5, a6, a7])
        print 'inversion: %d  top: %d  intensity: %d' % (j*z0.size + k, z, i)
        model0, m0 = mfun.initial_cylinder(M, L, x0, y0, z, dz, r, inc, dec, incs, decs, i)
        d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(
            xp, yp, zp, m0, M, L, delta,
            itmax, itmax_marq, lamb,
            dlamb, tol, mmin, mmax,
            m_out, dobs, inc, dec,
            model0[0].props, alpha, z, dz
        )
        inversion_results.append([m_est, phi_list, model_list, dobs - d_fit])
# Out:
# inversion: 0  top: 0  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.39241e+04  fin obj.: 6.32735e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 6.32735e+03  fin obj.: 3.28530e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.28530e+03  fin obj.: 1.34497e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.34497e+03  fin obj.: 5.46104e+02
# it:  4   it_marq:  0   lambda: 1e-03   init obj.: 5.46104e+02  fin obj.: 6.89351e+02
# it:  4   it_marq:  1   lambda: 1e-02   init obj.: 5.46104e+02  fin obj.: 4.65792e+02
# it:  5   it_marq:  0   lambda: 1e-03   init obj.: 4.65792e+02  fin obj.: 7.37729e+02
# it:  5   it_marq:  1   lambda: 1e-02   init obj.: 4.65792e+02  fin obj.: 3.44815e+02
# it:  6   it_marq:  0   lambda: 1e-03   init obj.: 3.44815e+02  fin obj.: 1.52454e+03
# it:  6   it_marq:  1   lambda: 1e-02   init obj.: 3.44815e+02  fin obj.: 7.42567e+02
# it:  6   it_marq:  2   lambda: 1e-01   init obj.: 3.44815e+02  fin obj.: 3.45190e+02
# it:  6   it_marq:  3   lambda: 1e+00   init obj.: 3.44815e+02  fin obj.: 2.74710e+02
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 2.74710e+02  fin obj.: 2.63432e+02
# it:  8   it_marq:  0   lambda: 1e-02   init obj.: 2.63432e+02  fin obj.: 2.93021e+03
# it:  8   it_marq:  1   lambda: 1e-01   init obj.: 2.63432e+02  fin obj.: 1.11579e+03
# it:  8   it_marq:  2   lambda: 1e+00   init obj.: 2.63432e+02  fin obj.: 7.20778e+02
# it:  8   it_marq:  3   lambda: 1e+01   init obj.: 2.63432e+02  fin obj.: 2.50531e+03
# it:  8   it_marq:  4   lambda: 1e+02   init obj.: 2.63432e+02  fin obj.: 2.39435e+03
# it:  8   it_marq:  5   lambda: 1e+03   init obj.: 2.63432e+02  fin obj.: 1.61448e+02
# it:  9   it_marq:  0   lambda: 1e+02   init obj.: 1.61448e+02  fin obj.: 9.85457e+02
# it:  9   it_marq:  1   lambda: 1e+03   init obj.: 1.61448e+02  fin obj.: 7.61543e+02
# it:  9   it_marq:  2   lambda: 1e+04   init obj.: 1.61448e+02  fin obj.: 2.06547e+02
# it:  9   it_marq:  3   lambda: 1e+05   init obj.: 1.61448e+02  fin obj.: 2.06544e+02
# it:  9   it_marq:  4   lambda: 1e+06   init obj.: 1.61448e+02  fin obj.: 2.06547e+02
# it:  9   it_marq:  5   lambda: 1e+07   init obj.: 1.61448e+02  fin obj.: 2.06488e+02
# it:  9   it_marq:  6   lambda: 1e+08   init obj.: 1.61448e+02  fin obj.: 1.61466e+02
# it:  9   it_marq:  7   lambda: 1e+09   init obj.: 1.61448e+02  fin obj.: 1.61469e+02
# it:  9   it_marq:  8   lambda: 1e+10   init obj.: 1.61448e+02  fin obj.: 1.61460e+02
# it:  9   it_marq:  9   lambda: 1e+11   init obj.: 1.61448e+02  fin obj.: 1.61454e+02
# inversion: 1  top: 0  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.67577e+04  fin obj.: 7.23230e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 7.23230e+03  fin obj.: 3.30937e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.30937e+03  fin obj.: 1.39922e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.39922e+03  fin obj.: 6.91113e+02
# it:  4   it_marq:  0   lambda: 1e-03   init obj.: 6.91113e+02  fin obj.: 3.59429e+03
# it:  4   it_marq:  1   lambda: 1e-02   init obj.: 6.91113e+02  fin obj.: 2.16450e+03
# it:  4   it_marq:  2   lambda: 1e-01   init obj.: 6.91113e+02  fin obj.: 1.94848e+03
# it:  4   it_marq:  3   lambda: 1e+00   init obj.: 6.91113e+02  fin obj.: 1.15698e+03
# it:  4   it_marq:  4   lambda: 1e+01   init obj.: 6.91113e+02  fin obj.: 1.10252e+03
# it:  4   it_marq:  5   lambda: 1e+02   init obj.: 6.91113e+02  fin obj.: 1.19692e+03
# it:  4   it_marq:  6   lambda: 1e+03   init obj.: 6.91113e+02  fin obj.: 9.35223e+02
# it:  4   it_marq:  7   lambda: 1e+04   init obj.: 6.91113e+02  fin obj.: 6.06676e+02
# it:  5   it_marq:  0   lambda: 1e+03   init obj.: 6.06676e+02  fin obj.: 5.98445e+02
# it:  6   it_marq:  0   lambda: 1e+02   init obj.: 5.98445e+02  fin obj.: 5.29497e+02
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 5.29497e+02  fin obj.: 5.42648e+02
# it:  7   it_marq:  1   lambda: 1e+02   init obj.: 5.29497e+02  fin obj.: 4.86030e+02
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 4.86030e+02  fin obj.: 5.20341e+02
# it:  8   it_marq:  1   lambda: 1e+02   init obj.: 4.86030e+02  fin obj.: 4.51058e+02
# it:  9   it_marq:  0   lambda: 1e+01   init obj.: 4.51058e+02  fin obj.: 5.00736e+02
# it:  9   it_marq:  1   lambda: 1e+02   init obj.: 4.51058e+02  fin obj.: 4.22114e+02
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 4.22114e+02  fin obj.: 4.83429e+02
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 4.22114e+02  fin obj.: 3.97763e+02
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 3.97763e+02  fin obj.: 4.67981e+02
# it: 11   it_marq:  1   lambda: 1e+02   init obj.: 3.97763e+02  fin obj.: 3.76953e+02
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 3.76953e+02  fin obj.: 4.54168e+02
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 3.76953e+02  fin obj.: 3.59063e+02
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 3.59063e+02  fin obj.: 4.41673e+02
# it: 13   it_marq:  1   lambda: 1e+02   init obj.: 3.59063e+02  fin obj.: 3.43504e+02
# it: 14   it_marq:  0   lambda: 1e+01   init obj.: 3.43504e+02  fin obj.: 4.30303e+02
# it: 14   it_marq:  1   lambda: 1e+02   init obj.: 3.43504e+02  fin obj.: 3.29820e+02
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 3.29820e+02  fin obj.: 4.19881e+02
# it: 15   it_marq:  1   lambda: 1e+02   init obj.: 3.29820e+02  fin obj.: 3.17600e+02
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 3.17600e+02  fin obj.: 4.10354e+02
# it: 16   it_marq:  1   lambda: 1e+02   init obj.: 3.17600e+02  fin obj.: 3.06563e+02
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 3.06563e+02  fin obj.: 4.01638e+02
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 3.06563e+02  fin obj.: 3.73934e+02
# it: 17   it_marq:  2   lambda: 1e+03   init obj.: 3.06563e+02  fin obj.: 3.05388e+02
# it: 18   it_marq:  0   lambda: 1e+02   init obj.: 3.05388e+02  fin obj.: 3.73062e+02
# it: 18   it_marq:  1   lambda: 1e+03   init obj.: 3.05388e+02  fin obj.: 3.04366e+02
# it: 19   it_marq:  0   lambda: 1e+02   init obj.: 3.04366e+02  fin obj.: 2.94552e+02
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 2.94552e+02  fin obj.: 3.91980e+02
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 2.94552e+02  fin obj.: 2.85580e+02
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 2.85580e+02  fin obj.: 3.83138e+02
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 2.85580e+02  fin obj.: 2.77380e+02
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 2.77380e+02  fin obj.: 3.23554e+02
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 2.77380e+02  fin obj.: 2.69820e+02
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 2.69820e+02  fin obj.: 2.71441e+02
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 2.69820e+02  fin obj.: 2.62871e+02
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 2.62871e+02  fin obj.: 3.16135e+02
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 2.62871e+02  fin obj.: 2.56429e+02
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 2.56429e+02  fin obj.: 2.52240e+02
# it: 26   it_marq:  0   lambda: 1e+00   init obj.: 2.52240e+02  fin obj.: 1.84908e+02
# it: 27   it_marq:  0   lambda: 1e-01   init obj.: 1.84908e+02  fin obj.: 8.62805e+02
# it: 27   it_marq:  1   lambda: 1e+00   init obj.: 1.84908e+02  fin obj.: 5.67007e+02
# it: 27   it_marq:  2   lambda: 1e+01   init obj.: 1.84908e+02  fin obj.: 1.98996e+02
# it: 27   it_marq:  3   lambda: 1e+02   init obj.: 1.84908e+02  fin obj.: 1.65950e+03
# it: 27   it_marq:  4   lambda: 1e+03   init obj.: 1.84908e+02  fin obj.: 1.48716e+03
# it: 27   it_marq:  5   lambda: 1e+04   init obj.: 1.84908e+02  fin obj.: 1.84741e+02
# inversion: 2  top: 0  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.04339e+04  fin obj.: 8.37864e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 8.37864e+03  fin obj.: 3.44150e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.44150e+03  fin obj.: 1.48737e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.48737e+03  fin obj.: 2.90245e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.48737e+03  fin obj.: 7.92260e+03
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.48737e+03  fin obj.: 6.47233e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.48737e+03  fin obj.: 2.46259e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.48737e+03  fin obj.: 1.33637e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.33637e+03  fin obj.: 4.80070e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 4.80070e+02  fin obj.: 7.02392e+02
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 4.80070e+02  fin obj.: 4.66830e+02
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 4.66830e+02  fin obj.: 4.46367e+02
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 4.46367e+02  fin obj.: 6.64899e+02
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 4.46367e+02  fin obj.: 2.67117e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 2.67117e+02  fin obj.: 1.24034e+03
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 2.67117e+02  fin obj.: 4.05963e+02
# it:  8   it_marq:  2   lambda: 1e+01   init obj.: 2.67117e+02  fin obj.: 2.41038e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 2.41038e+02  fin obj.: 5.13744e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 2.41038e+02  fin obj.: 2.26423e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 2.26423e+02  fin obj.: 5.67170e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 2.26423e+02  fin obj.: 2.16678e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 2.16678e+02  fin obj.: 5.93062e+02
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 2.16678e+02  fin obj.: 2.09273e+02
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 2.09273e+02  fin obj.: 5.92486e+02
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 2.09273e+02  fin obj.: 2.03280e+02
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 2.03280e+02  fin obj.: 5.81060e+02
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 2.03280e+02  fin obj.: 1.98258e+02
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 1.98258e+02  fin obj.: 5.71106e+02
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 1.98258e+02  fin obj.: 1.93779e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 1.93779e+02  fin obj.: 5.62114e+02
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 1.93779e+02  fin obj.: 1.89660e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 1.89660e+02  fin obj.: 6.32767e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 1.89660e+02  fin obj.: 1.85844e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 1.85844e+02  fin obj.: 6.25272e+02
# it: 17   it_marq:  1   lambda: 1e+01   init obj.: 1.85844e+02  fin obj.: 1.96268e+02
# it: 17   it_marq:  2   lambda: 1e+02   init obj.: 1.85844e+02  fin obj.: 1.85092e+02
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 1.85092e+02  fin obj.: 2.19138e+02
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 1.85092e+02  fin obj.: 1.84445e+02
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 1.84445e+02  fin obj.: 2.87008e+02
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 1.84445e+02  fin obj.: 1.83806e+02
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 1.83806e+02  fin obj.: 2.84301e+02
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 1.83806e+02  fin obj.: 1.83246e+02
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 1.83246e+02  fin obj.: 2.84475e+02
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 1.83246e+02  fin obj.: 1.82685e+02
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 1.82685e+02  fin obj.: 2.83462e+02
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 1.82685e+02  fin obj.: 1.82188e+02
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 1.82188e+02  fin obj.: 3.58768e+02
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 1.82188e+02  fin obj.: 1.81687e+02
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 1.81687e+02  fin obj.: 3.40512e+02
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 1.81687e+02  fin obj.: 1.81235e+02
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 1.81235e+02  fin obj.: 3.56459e+02
# it: 25   it_marq:  1   lambda: 1e+02   init obj.: 1.81235e+02  fin obj.: 1.80768e+02
# it: 26   it_marq:  0   lambda: 1e+01   init obj.: 1.80768e+02  fin obj.: 3.55480e+02
# it: 26   it_marq:  1   lambda: 1e+02   init obj.: 1.80768e+02  fin obj.: 1.80343e+02
# it: 27   it_marq:  0   lambda: 1e+01   init obj.: 1.80343e+02  fin obj.: 3.54417e+02
# it: 27   it_marq:  1   lambda: 1e+02   init obj.: 1.80343e+02  fin obj.: 1.79901e+02
# it: 28   it_marq:  0   lambda: 1e+01   init obj.: 1.79901e+02  fin obj.: 3.53565e+02
# it: 28   it_marq:  1   lambda: 1e+02   init obj.: 1.79901e+02  fin obj.: 1.79498e+02
# it: 29   it_marq:  0   lambda: 1e+01   init obj.: 1.79498e+02  fin obj.: 3.52587e+02
# it: 29   it_marq:  1   lambda: 1e+02   init obj.: 1.79498e+02  fin obj.: 1.79076e+02
# inversion: 3  top: 0  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.49527e+04  fin obj.: 9.75867e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.75867e+03  fin obj.: 3.66845e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.66845e+03  fin obj.: 1.70810e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.70810e+03  fin obj.: 8.62730e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.70810e+03  fin obj.: 1.37448e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.70810e+03  fin obj.: 9.79094e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.70810e+03  fin obj.: 3.48619e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.70810e+03  fin obj.: 1.52615e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.52615e+03  fin obj.: 7.77814e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 7.77814e+02  fin obj.: 9.60677e+02
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 7.77814e+02  fin obj.: 1.20743e+03
# it:  5   it_marq:  2   lambda: 1e+02   init obj.: 7.77814e+02  fin obj.: 8.11361e+02
# it:  5   it_marq:  3   lambda: 1e+03   init obj.: 7.77814e+02  fin obj.: 8.06605e+02
# it:  5   it_marq:  4   lambda: 1e+04   init obj.: 7.77814e+02  fin obj.: 8.06460e+02
# it:  5   it_marq:  5   lambda: 1e+05   init obj.: 7.77814e+02  fin obj.: 7.77144e+02
# inversion: 4  top: 0  intensity: 14
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.03141e+04  fin obj.: 1.13707e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.13707e+04  fin obj.: 3.97980e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.97980e+03  fin obj.: 2.26193e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 2.26193e+03  fin obj.: 1.83919e+04
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 2.26193e+03  fin obj.: 1.72555e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 2.26193e+03  fin obj.: 1.19985e+04
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 2.26193e+03  fin obj.: 3.40699e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 2.26193e+03  fin obj.: 2.00379e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 2.00379e+03  fin obj.: 1.56039e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.56039e+03  fin obj.: 6.70002e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 6.70002e+02  fin obj.: 9.80821e+02
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 6.70002e+02  fin obj.: 7.14237e+02
# it:  6   it_marq:  2   lambda: 1e+01   init obj.: 6.70002e+02  fin obj.: 5.83117e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 5.83117e+02  fin obj.: 7.40039e+02
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 5.83117e+02  fin obj.: 6.32125e+02
# it:  7   it_marq:  2   lambda: 1e+02   init obj.: 5.83117e+02  fin obj.: 5.59285e+02
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 5.59285e+02  fin obj.: 5.18561e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 5.18561e+02  fin obj.: 6.73398e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 5.18561e+02  fin obj.: 4.89073e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 4.89073e+02  fin obj.: 5.10276e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 4.89073e+02  fin obj.: 3.94406e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 3.94406e+02  fin obj.: 6.74243e+02
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 3.94406e+02  fin obj.: 4.70031e+02
# it: 11   it_marq:  2   lambda: 1e+02   init obj.: 3.94406e+02  fin obj.: 3.91484e+02
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 3.91484e+02  fin obj.: 4.67850e+02
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 3.91484e+02  fin obj.: 3.88841e+02
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 3.88841e+02  fin obj.: 4.65584e+02
# it: 13   it_marq:  1   lambda: 1e+02   init obj.: 3.88841e+02  fin obj.: 3.86337e+02
# it: 14   it_marq:  0   lambda: 1e+01   init obj.: 3.86337e+02  fin obj.: 4.63343e+02
# it: 14   it_marq:  1   lambda: 1e+02   init obj.: 3.86337e+02  fin obj.: 3.83896e+02
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 3.83896e+02  fin obj.: 4.61055e+02
# it: 15   it_marq:  1   lambda: 1e+02   init obj.: 3.83896e+02  fin obj.: 3.81494e+02
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 3.81494e+02  fin obj.: 4.58811e+02
# it: 16   it_marq:  1   lambda: 1e+02   init obj.: 3.81494e+02  fin obj.: 3.79145e+02
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 3.79145e+02  fin obj.: 4.56512e+02
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 3.79145e+02  fin obj.: 3.76822e+02
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 3.76822e+02  fin obj.: 4.54281e+02
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 3.76822e+02  fin obj.: 3.74545e+02
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 3.74545e+02  fin obj.: 4.52011e+02
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 3.74545e+02  fin obj.: 3.72289e+02
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 3.72289e+02  fin obj.: 4.49812e+02
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 3.72289e+02  fin obj.: 3.70072e+02
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 3.70072e+02  fin obj.: 4.47629e+02
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 3.70072e+02  fin obj.: 3.67872e+02
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 3.67872e+02  fin obj.: 4.45685e+02
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 3.67872e+02  fin obj.: 3.65710e+02
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 3.65710e+02  fin obj.: 4.45547e+02
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 3.65710e+02  fin obj.: 3.63561e+02
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 3.63561e+02  fin obj.: 5.35368e+02
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 3.63561e+02  fin obj.: 3.61446e+02
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 3.61446e+02  fin obj.: 5.34177e+02
# it: 25   it_marq:  1   lambda: 1e+02   init obj.: 3.61446e+02  fin obj.: 3.59343e+02
# it: 26   it_marq:  0   lambda: 1e+01   init obj.: 3.59343e+02  fin obj.: 5.31729e+02
# it: 26   it_marq:  1   lambda: 1e+02   init obj.: 3.59343e+02  fin obj.: 3.57271e+02
# it: 27   it_marq:  0   lambda: 1e+01   init obj.: 3.57271e+02  fin obj.: 5.29248e+02
# it: 27   it_marq:  1   lambda: 1e+02   init obj.: 3.57271e+02  fin obj.: 3.55210e+02
# it: 28   it_marq:  0   lambda: 1e+01   init obj.: 3.55210e+02  fin obj.: 5.26853e+02
# it: 28   it_marq:  1   lambda: 1e+02   init obj.: 3.55210e+02  fin obj.: 3.53180e+02
# it: 29   it_marq:  0   lambda: 1e+01   init obj.: 3.53180e+02  fin obj.: 5.24413e+02
# it: 29   it_marq:  1   lambda: 1e+02   init obj.: 3.53180e+02  fin obj.: 3.51159e+02
# inversion: 5  top: 0  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.65180e+04  fin obj.: 1.32167e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.32167e+04  fin obj.: 4.36692e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 4.36692e+03  fin obj.: 3.60116e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 3.60116e+03  fin obj.: 2.58251e+04
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 3.60116e+03  fin obj.: 2.14391e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 3.60116e+03  fin obj.: 1.27089e+04
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 3.60116e+03  fin obj.: 3.26402e+03
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 3.26402e+03  fin obj.: 1.49904e+03
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 1.49904e+03  fin obj.: 3.32593e+03
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 1.49904e+03  fin obj.: 2.88035e+03
# it:  5   it_marq:  2   lambda: 1e+01   init obj.: 1.49904e+03  fin obj.: 2.50050e+03
# it:  5   it_marq:  3   lambda: 1e+02   init obj.: 1.49904e+03  fin obj.: 1.45170e+03
# it:  6   it_marq:  0   lambda: 1e+01   init obj.: 1.45170e+03  fin obj.: 1.53564e+03
# it:  6   it_marq:  1   lambda: 1e+02   init obj.: 1.45170e+03  fin obj.: 1.97839e+03
# it:  6   it_marq:  2   lambda: 1e+03   init obj.: 1.45170e+03  fin obj.: 1.57493e+03
# it:  6   it_marq:  3   lambda: 1e+04   init obj.: 1.45170e+03  fin obj.: 1.93134e+03
# it:  6   it_marq:  4   lambda: 1e+05   init obj.: 1.45170e+03  fin obj.: 1.94378e+03
# it:  6   it_marq:  5   lambda: 1e+06   init obj.: 1.45170e+03  fin obj.: 1.94396e+03
# it:  6   it_marq:  6   lambda: 1e+07   init obj.: 1.45170e+03  fin obj.: 1.94397e+03
# it:  6   it_marq:  7   lambda: 1e+08   init obj.: 1.45170e+03  fin obj.: 1.96217e+03
# it:  6   it_marq:  8   lambda: 1e+09   init obj.: 1.45170e+03  fin obj.: 1.46255e+03
# it:  6   it_marq:  9   lambda: 1e+10   init obj.: 1.45170e+03  fin obj.: 1.45255e+03
# inversion: 6  top: 20  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.33370e+04  fin obj.: 6.08959e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 6.08959e+03  fin obj.: 3.29217e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.29217e+03  fin obj.: 1.05841e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.05841e+03  fin obj.: 1.28828e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.05841e+03  fin obj.: 9.48443e+02
# it:  4   it_marq:  0   lambda: 1e-02   init obj.: 9.48443e+02  fin obj.: 1.08030e+03
# it:  4   it_marq:  1   lambda: 1e-01   init obj.: 9.48443e+02  fin obj.: 3.13179e+02
# it:  5   it_marq:  0   lambda: 1e-02   init obj.: 3.13179e+02  fin obj.: 3.58916e+03
# it:  5   it_marq:  1   lambda: 1e-01   init obj.: 3.13179e+02  fin obj.: 1.34487e+03
# it:  5   it_marq:  2   lambda: 1e+00   init obj.: 3.13179e+02  fin obj.: 5.96919e+02
# it:  5   it_marq:  3   lambda: 1e+01   init obj.: 3.13179e+02  fin obj.: 2.28784e+03
# it:  5   it_marq:  4   lambda: 1e+02   init obj.: 3.13179e+02  fin obj.: 1.99234e+03
# it:  5   it_marq:  5   lambda: 1e+03   init obj.: 3.13179e+02  fin obj.: 3.10172e+02
# it:  6   it_marq:  0   lambda: 1e+02   init obj.: 3.10172e+02  fin obj.: 2.88155e+02
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 2.88155e+02  fin obj.: 2.43505e+02
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 2.43505e+02  fin obj.: 1.67376e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 1.67376e+02  fin obj.: 1.98859e+03
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 1.67376e+02  fin obj.: 5.02905e+02
# it:  9   it_marq:  2   lambda: 1e+01   init obj.: 1.67376e+02  fin obj.: 4.65263e+02
# it:  9   it_marq:  3   lambda: 1e+02   init obj.: 1.67376e+02  fin obj.: 6.30730e+02
# it:  9   it_marq:  4   lambda: 1e+03   init obj.: 1.67376e+02  fin obj.: 1.85491e+02
# it:  9   it_marq:  5   lambda: 1e+04   init obj.: 1.67376e+02  fin obj.: 1.67304e+02
# inversion: 7  top: 20  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.58506e+04  fin obj.: 6.86037e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 6.86037e+03  fin obj.: 3.25970e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.25970e+03  fin obj.: 1.53561e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.53561e+03  fin obj.: 2.45140e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.53561e+03  fin obj.: 3.80152e+03
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.53561e+03  fin obj.: 3.08850e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.53561e+03  fin obj.: 1.04127e+03
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 1.04127e+03  fin obj.: 1.27783e+03
# it:  4   it_marq:  1   lambda: 1e+01   init obj.: 1.04127e+03  fin obj.: 1.61565e+03
# it:  4   it_marq:  2   lambda: 1e+02   init obj.: 1.04127e+03  fin obj.: 1.51167e+03
# it:  4   it_marq:  3   lambda: 1e+03   init obj.: 1.04127e+03  fin obj.: 1.53438e+03
# it:  4   it_marq:  4   lambda: 1e+04   init obj.: 1.04127e+03  fin obj.: 1.30630e+03
# it:  4   it_marq:  5   lambda: 1e+05   init obj.: 1.04127e+03  fin obj.: 1.01980e+03
# it:  5   it_marq:  0   lambda: 1e+04   init obj.: 1.01980e+03  fin obj.: 1.01740e+03
# it:  6   it_marq:  0   lambda: 1e+03   init obj.: 1.01740e+03  fin obj.: 9.96477e+02
# it:  7   it_marq:  0   lambda: 1e+02   init obj.: 9.96477e+02  fin obj.: 8.31948e+02
# it:  8   it_marq:  0   lambda: 1e+01   init obj.: 8.31948e+02  fin obj.: 4.25052e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 4.25052e+02  fin obj.: 1.12965e+03
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 4.25052e+02  fin obj.: 3.99163e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 3.99163e+02  fin obj.: 5.10013e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 3.99163e+02  fin obj.: 2.55506e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 2.55506e+02  fin obj.: 1.32569e+03
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 2.55506e+02  fin obj.: 6.78641e+02
# it: 11   it_marq:  2   lambda: 1e+02   init obj.: 2.55506e+02  fin obj.: 4.64977e+02
# it: 11   it_marq:  3   lambda: 1e+03   init obj.: 2.55506e+02  fin obj.: 2.86814e+02
# it: 11   it_marq:  4   lambda: 1e+04   init obj.: 2.55506e+02  fin obj.: 2.87157e+02
# it: 11   it_marq:  5   lambda: 1e+05   init obj.: 2.55506e+02  fin obj.: 2.87216e+02
# it: 11   it_marq:  6   lambda: 1e+06   init obj.: 2.55506e+02  fin obj.: 2.55505e+02
# inversion: 8  top: 20  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.91592e+04  fin obj.: 7.85322e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 7.85322e+03  fin obj.: 3.33107e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.33107e+03  fin obj.: 1.65211e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.65211e+03  fin obj.: 5.41930e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.65211e+03  fin obj.: 8.47632e+03
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.65211e+03  fin obj.: 6.87274e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.65211e+03  fin obj.: 3.22356e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.65211e+03  fin obj.: 1.03882e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.03882e+03  fin obj.: 6.94624e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 6.94624e+02  fin obj.: 1.09682e+03
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 6.94624e+02  fin obj.: 1.72597e+03
# it:  5   it_marq:  2   lambda: 1e+02   init obj.: 6.94624e+02  fin obj.: 1.60990e+03
# it:  5   it_marq:  3   lambda: 1e+03   init obj.: 6.94624e+02  fin obj.: 8.30494e+02
# it:  5   it_marq:  4   lambda: 1e+04   init obj.: 6.94624e+02  fin obj.: 7.50625e+02
# it:  5   it_marq:  5   lambda: 1e+05   init obj.: 6.94624e+02  fin obj.: 7.50691e+02
# it:  5   it_marq:  6   lambda: 1e+06   init obj.: 6.94624e+02  fin obj.: 7.50707e+02
# it:  5   it_marq:  7   lambda: 1e+07   init obj.: 6.94624e+02  fin obj.: 7.50709e+02
# it:  5   it_marq:  8   lambda: 1e+08   init obj.: 6.94624e+02  fin obj.: 6.94612e+02
# inversion: 9  top: 20  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.32628e+04  fin obj.: 9.05904e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.05904e+03  fin obj.: 3.49094e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.49094e+03  fin obj.: 1.92148e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.92148e+03  fin obj.: 1.34175e+04
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.92148e+03  fin obj.: 1.46102e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.92148e+03  fin obj.: 1.04301e+04
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.92148e+03  fin obj.: 5.00266e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.92148e+03  fin obj.: 1.33927e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.33927e+03  fin obj.: 1.20309e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.20309e+03  fin obj.: 9.96108e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 9.96108e+02  fin obj.: 4.24615e+02
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 4.24615e+02  fin obj.: 6.51395e+02
# it:  7   it_marq:  1   lambda: 1e-01   init obj.: 4.24615e+02  fin obj.: 2.66031e+02
# it:  8   it_marq:  0   lambda: 1e-02   init obj.: 2.66031e+02  fin obj.: 1.04573e+03
# it:  8   it_marq:  1   lambda: 1e-01   init obj.: 2.66031e+02  fin obj.: 8.57893e+02
# it:  8   it_marq:  2   lambda: 1e+00   init obj.: 2.66031e+02  fin obj.: 6.89727e+02
# it:  8   it_marq:  3   lambda: 1e+01   init obj.: 2.66031e+02  fin obj.: 9.84818e+02
# it:  8   it_marq:  4   lambda: 1e+02   init obj.: 2.66031e+02  fin obj.: 1.07028e+03
# it:  8   it_marq:  5   lambda: 1e+03   init obj.: 2.66031e+02  fin obj.: 9.05436e+02
# it:  8   it_marq:  6   lambda: 1e+04   init obj.: 2.66031e+02  fin obj.: 2.67491e+02
# it:  8   it_marq:  7   lambda: 1e+05   init obj.: 2.66031e+02  fin obj.: 2.67833e+02
# it:  8   it_marq:  8   lambda: 1e+06   init obj.: 2.66031e+02  fin obj.: 2.67856e+02
# it:  8   it_marq:  9   lambda: 1e+07   init obj.: 2.66031e+02  fin obj.: 2.67858e+02
# it:  9   it_marq:  0   lambda: 1e+08   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  1   lambda: 1e+09   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  2   lambda: 1e+10   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  3   lambda: 1e+11   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  4   lambda: 1e+12   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  5   lambda: 1e+13   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  6   lambda: 1e+14   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  7   lambda: 1e+15   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  8   lambda: 1e+16   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it:  9   it_marq:  9   lambda: 1e+17   init obj.: 2.66031e+02  fin obj.: 2.67852e+02
# it: 10   it_marq:  0   lambda: 1e+18   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  1   lambda: 1e+19   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  2   lambda: 1e+20   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  3   lambda: 1e+21   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  4   lambda: 1e+22   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  5   lambda: 1e+23   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  6   lambda: 1e+24   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  7   lambda: 1e+25   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  8   lambda: 1e+26   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 10   it_marq:  9   lambda: 1e+27   init obj.: 2.66031e+02  fin obj.: 2.67847e+02
# it: 11   it_marq:  0   lambda: 1e+28   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  1   lambda: 1e+29   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  2   lambda: 1e+30   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  3   lambda: 1e+31   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  4   lambda: 1e+32   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  5   lambda: 1e+33   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  6   lambda: 1e+34   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  7   lambda: 1e+35   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  8   lambda: 1e+36   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 11   it_marq:  9   lambda: 1e+37   init obj.: 2.66031e+02  fin obj.: 2.67841e+02
# it: 12   it_marq:  0   lambda: 1e+38   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  1   lambda: 1e+39   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  2   lambda: 1e+40   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  3   lambda: 1e+41   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  4   lambda: 1e+42   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  5   lambda: 1e+43   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  6   lambda: 1e+44   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  7   lambda: 1e+45   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  8   lambda: 1e+46   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 12   it_marq:  9   lambda: 1e+47   init obj.: 2.66031e+02  fin obj.: 2.67835e+02
# it: 13   it_marq:  0   lambda: 1e+48   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  1   lambda: 1e+49   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  2   lambda: 1e+50   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  3   lambda: 1e+51   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  4   lambda: 1e+52   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  5   lambda: 1e+53   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  6   lambda: 1e+54   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  7   lambda: 1e+55   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  8   lambda: 1e+56   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 13   it_marq:  9   lambda: 1e+57   init obj.: 2.66031e+02  fin obj.: 2.67830e+02
# it: 14   it_marq:  0   lambda: 1e+58   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  1   lambda: 1e+59   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  2   lambda: 1e+60   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  3   lambda: 1e+61   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  4   lambda: 1e+62   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  5   lambda: 1e+63   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  6   lambda: 1e+64   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  7   lambda: 1e+65   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  8   lambda: 1e+66   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 14   it_marq:  9   lambda: 1e+67   init obj.: 2.66031e+02  fin obj.: 2.67824e+02
# it: 15   it_marq:  0   lambda: 1e+68   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  1   lambda: 1e+69   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  2   lambda: 1e+70   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  3   lambda: 1e+71   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  4   lambda: 1e+72   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  5   lambda: 1e+73   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  6   lambda: 1e+74   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  7   lambda: 1e+75   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  8   lambda: 1e+76   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 15   it_marq:  9   lambda: 1e+77   init obj.: 2.66031e+02  fin obj.: 2.67818e+02
# it: 16   it_marq:  0   lambda: 1e+78   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  1   lambda: 1e+79   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  2   lambda: 1e+80   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  3   lambda: 1e+81   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  4   lambda: 1e+82   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  5   lambda: 1e+83   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  6   lambda: 1e+84   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  7   lambda: 1e+85   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  8   lambda: 1e+86   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 16   it_marq:  9   lambda: 1e+87   init obj.: 2.66031e+02  fin obj.: 2.67813e+02
# it: 17   it_marq:  0   lambda: 1e+88   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  1   lambda: 1e+89   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  2   lambda: 1e+90   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  3   lambda: 1e+91   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  4   lambda: 1e+92   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  5   lambda: 1e+93   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  6   lambda: 1e+94   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  7   lambda: 1e+95   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  8   lambda: 1e+96   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 17   it_marq:  9   lambda: 1e+97   init obj.: 2.66031e+02  fin obj.: 2.67807e+02
# it: 18   it_marq:  0   lambda: 1e+98   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  1   lambda: 1e+99   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  2   lambda: 1e+100   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  3   lambda: 1e+101   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  4   lambda: 1e+102   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  5   lambda: 1e+103   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  6   lambda: 1e+104   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  7   lambda: 1e+105   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  8   lambda: 1e+106   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 18   it_marq:  9   lambda: 1e+107   init obj.: 2.66031e+02  fin obj.: 2.67802e+02
# it: 19   it_marq:  0   lambda: 1e+108   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  1   lambda: 1e+109   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  2   lambda: 1e+110   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  3   lambda: 1e+111   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  4   lambda: 1e+112   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  5   lambda: 1e+113   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  6   lambda: 1e+114   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  7   lambda: 1e+115   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  8   lambda: 1e+116   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 19   it_marq:  9   lambda: 1e+117   init obj.: 2.66031e+02  fin obj.: 2.67796e+02
# it: 20   it_marq:  0   lambda: 1e+118   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  1   lambda: 1e+119   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  2   lambda: 1e+120   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  3   lambda: 1e+121   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  4   lambda: 1e+122   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  5   lambda: 1e+123   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  6   lambda: 1e+124   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  7   lambda: 1e+125   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  8   lambda: 1e+126   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 20   it_marq:  9   lambda: 1e+127   init obj.: 2.66031e+02  fin obj.: 2.67791e+02
# it: 21   it_marq:  0   lambda: 1e+128   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  1   lambda: 1e+129   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  2   lambda: 1e+130   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  3   lambda: 1e+131   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  4   lambda: 1e+132   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  5   lambda: 1e+133   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  6   lambda: 1e+134   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  7   lambda: 1e+135   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  8   lambda: 1e+136   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 21   it_marq:  9   lambda: 1e+137   init obj.: 2.66031e+02  fin obj.: 2.67785e+02
# it: 22   it_marq:  0   lambda: 1e+138   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  1   lambda: 1e+139   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  2   lambda: 1e+140   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  3   lambda: 1e+141   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  4   lambda: 1e+142   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  5   lambda: 1e+143   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  6   lambda: 1e+144   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  7   lambda: 1e+145   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  8   lambda: 1e+146   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 22   it_marq:  9   lambda: 1e+147   init obj.: 2.66031e+02  fin obj.: 2.67780e+02
# it: 23   it_marq:  0   lambda: 1e+148   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  1   lambda: 1e+149   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  2   lambda: 1e+150   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  3   lambda: 1e+151   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  4   lambda: 1e+152   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  5   lambda: 1e+153   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  6   lambda: 1e+154   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  7   lambda: 1e+155   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  8   lambda: 1e+156   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 23   it_marq:  9   lambda: 1e+157   init obj.: 2.66031e+02  fin obj.: 2.67774e+02
# it: 24   it_marq:  0   lambda: 1e+158   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  1   lambda: 1e+159   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  2   lambda: 1e+160   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  3   lambda: 1e+161   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  4   lambda: 1e+162   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  5   lambda: 1e+163   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  6   lambda: 1e+164   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  7   lambda: 1e+165   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  8   lambda: 1e+166   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 24   it_marq:  9   lambda: 1e+167   init obj.: 2.66031e+02  fin obj.: 2.67769e+02
# it: 25   it_marq:  0   lambda: 1e+168   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  1   lambda: 1e+169   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  2   lambda: 1e+170   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  3   lambda: 1e+171   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  4   lambda: 1e+172   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  5   lambda: 1e+173   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  6   lambda: 1e+174   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  7   lambda: 1e+175   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  8   lambda: 1e+176   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 25   it_marq:  9   lambda: 1e+177   init obj.: 2.66031e+02  fin obj.: 2.67763e+02
# it: 26   it_marq:  0   lambda: 1e+178   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  1   lambda: 1e+179   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  2   lambda: 1e+180   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  3   lambda: 1e+181   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  4   lambda: 1e+182   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  5   lambda: 1e+183   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  6   lambda: 1e+184   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  7   lambda: 1e+185   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  8   lambda: 1e+186   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 26   it_marq:  9   lambda: 1e+187   init obj.: 2.66031e+02  fin obj.: 2.67758e+02
# it: 27   it_marq:  0   lambda: 1e+188   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  1   lambda: 1e+189   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  2   lambda: 1e+190   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  3   lambda: 1e+191   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  4   lambda: 1e+192   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  5   lambda: 1e+193   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  6   lambda: 1e+194   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  7   lambda: 1e+195   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  8   lambda: 1e+196   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 27   it_marq:  9   lambda: 1e+197   init obj.: 2.66031e+02  fin obj.: 2.67752e+02
# it: 28   it_marq:  0   lambda: 1e+198   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  1   lambda: 1e+199   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  2   lambda: 1e+200   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  3   lambda: 1e+201   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  4   lambda: 1e+202   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  5   lambda: 1e+203   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  6   lambda: 1e+204   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  7   lambda: 1e+205   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  8   lambda: 1e+206   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 28   it_marq:  9   lambda: 1e+207   init obj.: 2.66031e+02  fin obj.: 2.67747e+02
# it: 29   it_marq:  0   lambda: 1e+208   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  1   lambda: 1e+209   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  2   lambda: 1e+210   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  3   lambda: 1e+211   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  4   lambda: 1e+212   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  5   lambda: 1e+213   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  6   lambda: 1e+214   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  7   lambda: 1e+215   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  8   lambda: 1e+216   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# it: 29   it_marq:  9   lambda: 1e+217   init obj.: 2.66031e+02  fin obj.: 2.67742e+02
# inversion: 10  top: 20  intensity: 14
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.81616e+04  fin obj.: 1.04750e+04
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 1.04750e+04  fin obj.: 3.72783e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.72783e+03  fin obj.: 2.44286e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 2.44286e+03  fin obj.: 2.14832e+04
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 2.44286e+03  fin obj.: 1.87187e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 2.44286e+03  fin obj.: 1.34722e+04
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 2.44286e+03  fin obj.: 5.79171e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 2.44286e+03  fin obj.: 2.00823e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 2.00823e+03  fin obj.: 1.24562e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.24562e+03  fin obj.: 9.48002e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 9.48002e+02  fin obj.: 5.13065e+02
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 5.13065e+02  fin obj.: 4.74772e+02
# it:  8   it_marq:  0   lambda: 1e-03   init obj.: 4.74772e+02  fin obj.: 8.90705e+02
# ...
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 2.66392e+02  fin obj.: 7.85460e+02
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 2.66392e+02  fin obj.: 2.29155e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 2.29155e+02  fin obj.: 7.02334e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 2.29155e+02  fin obj.: 2.05069e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 2.05069e+02  fin obj.: 1.41322e+03
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 2.05069e+02  fin obj.: 1.88587e+02
# it: 11   it_marq:  0   lambda: 1e-01   init obj.: 1.88587e+02  fin obj.: 1.33537e+03
# it: 11   it_marq:  1   lambda: 1e+00   init obj.: 1.88587e+02  fin obj.: 1.76915e+02
# it: 12   it_marq:  0   lambda: 1e-01   init obj.: 1.76915e+02  fin obj.: 1.27682e+03
# it: 12   it_marq:  1   lambda: 1e+00   init obj.: 1.76915e+02  fin obj.: 3.69809e+02
# it: 12   it_marq:  2   lambda: 1e+01   init obj.: 1.76915e+02  fin obj.: 1.70488e+02
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 1.70488e+02  fin obj.: 3.64708e+02
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 1.70488e+02  fin obj.: 1.66977e+02
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 1.66977e+02  fin obj.: 3.61683e+02
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 1.66977e+02  fin obj.: 1.64693e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 1.64693e+02  fin obj.: 5.01726e+02
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 1.64693e+02  fin obj.: 1.63039e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 1.63039e+02  fin obj.: 4.97496e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 1.63039e+02  fin obj.: 1.61752e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 1.61752e+02  fin obj.: 1.23530e+03
# it: 17   it_marq:  1   lambda: 1e+01   init obj.: 1.61752e+02  fin obj.: 1.60685e+02
# it: 18   it_marq:  0   lambda: 1e+00   init obj.: 1.60685e+02  fin obj.: 9.14825e+02
# it: 18   it_marq:  1   lambda: 1e+01   init obj.: 1.60685e+02  fin obj.: 1.59741e+02
# it: 19   it_marq:  0   lambda: 1e+00   init obj.: 1.59741e+02  fin obj.: 1.09854e+03
# it: 19   it_marq:  1   lambda: 1e+01   init obj.: 1.59741e+02  fin obj.: 1.58882e+02
# it: 20   it_marq:  0   lambda: 1e+00   init obj.: 1.58882e+02  fin obj.: 1.09356e+03
# it: 20   it_marq:  1   lambda: 1e+01   init obj.: 1.58882e+02  fin obj.: 1.58091e+02
# it: 21   it_marq:  0   lambda: 1e+00   init obj.: 1.58091e+02  fin obj.: 1.08961e+03
# it: 21   it_marq:  1   lambda: 1e+01   init obj.: 1.58091e+02  fin obj.: 1.57352e+02
# it: 22   it_marq:  0   lambda: 1e+00   init obj.: 1.57352e+02  fin obj.: 1.11576e+03
# it: 22   it_marq:  1   lambda: 1e+01   init obj.: 1.57352e+02  fin obj.: 1.56662e+02
# it: 23   it_marq:  0   lambda: 1e+00   init obj.: 1.56662e+02  fin obj.: 1.13204e+03
# it: 23   it_marq:  1   lambda: 1e+01   init obj.: 1.56662e+02  fin obj.: 1.56011e+02
# it: 24   it_marq:  0   lambda: 1e+00   init obj.: 1.56011e+02  fin obj.: 1.12794e+03
# it: 24   it_marq:  1   lambda: 1e+01   init obj.: 1.56011e+02  fin obj.: 1.55398e+02
# it: 25   it_marq:  0   lambda: 1e+00   init obj.: 1.55398e+02  fin obj.: 1.12387e+03
# it: 25   it_marq:  1   lambda: 1e+01   init obj.: 1.55398e+02  fin obj.: 1.54818e+02
# it: 26   it_marq:  0   lambda: 1e+00   init obj.: 1.54818e+02  fin obj.: 1.11963e+03
# it: 26   it_marq:  1   lambda: 1e+01   init obj.: 1.54818e+02  fin obj.: 1.54279e+02
# it: 27   it_marq:  0   lambda: 1e+00   init obj.: 1.54279e+02  fin obj.: 1.11541e+03
# it: 27   it_marq:  1   lambda: 1e+01   init obj.: 1.54279e+02  fin obj.: 4.07049e+02
# it: 27   it_marq:  2   lambda: 1e+02   init obj.: 1.54279e+02  fin obj.: 6.09509e+02
# it: 27   it_marq:  3   lambda: 1e+03   init obj.: 1.54279e+02  fin obj.: 6.08189e+02
# it: 27   it_marq:  4   lambda: 1e+04   init obj.: 1.54279e+02  fin obj.: 4.07742e+02
# it: 27   it_marq:  5   lambda: 1e+05   init obj.: 1.54279e+02  fin obj.: 4.07724e+02
# it: 27   it_marq:  6   lambda: 1e+06   init obj.: 1.54279e+02  fin obj.: 4.07716e+02
# it: 27   it_marq:  7   lambda: 1e+07   init obj.: 1.54279e+02  fin obj.: 4.07717e+02
# it: 27   it_marq:  8   lambda: 1e+08   init obj.: 1.54279e+02  fin obj.: 4.07717e+02
# it: 27   it_marq:  9   lambda: 1e+09   init obj.: 1.54279e+02  fin obj.: 4.07717e+02
# it: 28   it_marq:  0   lambda: 1e+10   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  1   lambda: 1e+11   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  2   lambda: 1e+12   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  3   lambda: 1e+13   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  4   lambda: 1e+14   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  5   lambda: 1e+15   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  6   lambda: 1e+16   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  7   lambda: 1e+17   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  8   lambda: 1e+18   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 28   it_marq:  9   lambda: 1e+19   init obj.: 1.54279e+02  fin obj.: 4.07667e+02
# it: 29   it_marq:  0   lambda: 1e+20   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  1   lambda: 1e+21   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  2   lambda: 1e+22   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  3   lambda: 1e+23   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  4   lambda: 1e+24   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  5   lambda: 1e+25   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  6   lambda: 1e+26   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  7   lambda: 1e+27   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  8   lambda: 1e+28   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# it: 29   it_marq:  9   lambda: 1e+29   init obj.: 1.54279e+02  fin obj.: 4.07617e+02
# inversion: 34  top: 100  intensity: 14
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.17222e+04  fin obj.: 8.14219e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 8.14219e+03  fin obj.: 3.30372e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.30372e+03  fin obj.: 4.92689e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.30372e+03  fin obj.: 7.67611e+02
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 7.67611e+02  fin obj.: 5.80374e+03
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 7.67611e+02  fin obj.: 5.91165e+03
# it:  3   it_marq:  2   lambda: 1e+01   init obj.: 7.67611e+02  fin obj.: 3.39606e+03
# it:  3   it_marq:  3   lambda: 1e+02   init obj.: 7.67611e+02  fin obj.: 6.76544e+02
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 6.76544e+02  fin obj.: 4.25546e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 4.25546e+02  fin obj.: 4.28114e+02
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 4.25546e+02  fin obj.: 3.61893e+02
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 3.61893e+02  fin obj.: 3.96774e+02
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 3.61893e+02  fin obj.: 3.27113e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 3.27113e+02  fin obj.: 3.74092e+02
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 3.27113e+02  fin obj.: 3.02900e+02
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 3.02900e+02  fin obj.: 3.96477e+02
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 3.02900e+02  fin obj.: 2.84581e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 2.84581e+02  fin obj.: 3.85053e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 2.84581e+02  fin obj.: 2.69928e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 2.69928e+02  fin obj.: 3.72762e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 2.69928e+02  fin obj.: 2.57969e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 2.57969e+02  fin obj.: 3.62626e+02
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 2.57969e+02  fin obj.: 2.47996e+02
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 2.47996e+02  fin obj.: 3.88940e+02
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 2.47996e+02  fin obj.: 2.39434e+02
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 2.39434e+02  fin obj.: 3.98676e+02
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 2.39434e+02  fin obj.: 2.31901e+02
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 2.31901e+02  fin obj.: 3.90391e+02
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 2.31901e+02  fin obj.: 2.25198e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 2.25198e+02  fin obj.: 5.18078e+02
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 2.25198e+02  fin obj.: 2.19199e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 2.19199e+02  fin obj.: 5.07984e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 2.19199e+02  fin obj.: 2.13800e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 2.13800e+02  fin obj.: 4.98485e+02
# it: 17   it_marq:  1   lambda: 1e+01   init obj.: 2.13800e+02  fin obj.: 2.08919e+02
# it: 18   it_marq:  0   lambda: 1e+00   init obj.: 2.08919e+02  fin obj.: 4.89836e+02
# it: 18   it_marq:  1   lambda: 1e+01   init obj.: 2.08919e+02  fin obj.: 2.04486e+02
# it: 19   it_marq:  0   lambda: 1e+00   init obj.: 2.04486e+02  fin obj.: 4.82019e+02
# it: 19   it_marq:  1   lambda: 1e+01   init obj.: 2.04486e+02  fin obj.: 2.00444e+02
# it: 20   it_marq:  0   lambda: 1e+00   init obj.: 2.00444e+02  fin obj.: 4.74951e+02
# it: 20   it_marq:  1   lambda: 1e+01   init obj.: 2.00444e+02  fin obj.: 1.96749e+02
# it: 21   it_marq:  0   lambda: 1e+00   init obj.: 1.96749e+02  fin obj.: 4.68530e+02
# it: 21   it_marq:  1   lambda: 1e+01   init obj.: 1.96749e+02  fin obj.: 1.93357e+02
# it: 22   it_marq:  0   lambda: 1e+00   init obj.: 1.93357e+02  fin obj.: 4.62663e+02
# it: 22   it_marq:  1   lambda: 1e+01   init obj.: 1.93357e+02  fin obj.: 1.90241e+02
# it: 23   it_marq:  0   lambda: 1e+00   init obj.: 1.90241e+02  fin obj.: 4.57162e+02
# it: 23   it_marq:  1   lambda: 1e+01   init obj.: 1.90241e+02  fin obj.: 1.87362e+02
# it: 24   it_marq:  0   lambda: 1e+00   init obj.: 1.87362e+02  fin obj.: 4.51980e+02
# it: 24   it_marq:  1   lambda: 1e+01   init obj.: 1.87362e+02  fin obj.: 1.84677e+02
# it: 25   it_marq:  0   lambda: 1e+00   init obj.: 1.84677e+02  fin obj.: 4.47204e+02
# it: 25   it_marq:  1   lambda: 1e+01   init obj.: 1.84677e+02  fin obj.: 1.82172e+02
# it: 26   it_marq:  0   lambda: 1e+00   init obj.: 1.82172e+02  fin obj.: 4.42867e+02
# it: 26   it_marq:  1   lambda: 1e+01   init obj.: 1.82172e+02  fin obj.: 1.79829e+02
# it: 27   it_marq:  0   lambda: 1e+00   init obj.: 1.79829e+02  fin obj.: 4.39114e+02
# it: 27   it_marq:  1   lambda: 1e+01   init obj.: 1.79829e+02  fin obj.: 1.77636e+02
# it: 28   it_marq:  0   lambda: 1e+00   init obj.: 1.77636e+02  fin obj.: 4.36329e+02
# it: 28   it_marq:  1   lambda: 1e+01   init obj.: 1.77636e+02  fin obj.: 1.75571e+02
# it: 29   it_marq:  0   lambda: 1e+00   init obj.: 1.75571e+02  fin obj.: 4.36022e+02
# it: 29   it_marq:  1   lambda: 1e+01   init obj.: 1.75571e+02  fin obj.: 1.73642e+02
# inversion: 35  top: 100  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.57657e+04  fin obj.: 9.13264e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.13264e+03  fin obj.: 3.40113e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.40113e+03  fin obj.: 5.36071e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.40113e+03  fin obj.: 8.33817e+02
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 8.33817e+02  fin obj.: 8.08185e+03
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 8.33817e+02  fin obj.: 8.31911e+03
# it:  3   it_marq:  2   lambda: 1e+01   init obj.: 8.33817e+02  fin obj.: 5.13491e+03
# it:  3   it_marq:  3   lambda: 1e+02   init obj.: 8.33817e+02  fin obj.: 6.76697e+02
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 6.76697e+02  fin obj.: 3.91762e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 3.91762e+02  fin obj.: 3.76014e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 3.76014e+02  fin obj.: 3.51845e+02
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 3.51845e+02  fin obj.: 8.67033e+02
# it:  7   it_marq:  1   lambda: 1e-01   init obj.: 3.51845e+02  fin obj.: 2.36236e+02
# it:  8   it_marq:  0   lambda: 1e-02   init obj.: 2.36236e+02  fin obj.: 6.15716e+02
# it:  8   it_marq:  1   lambda: 1e-01   init obj.: 2.36236e+02  fin obj.: 4.89755e+02
# it:  8   it_marq:  2   lambda: 1e+00   init obj.: 2.36236e+02  fin obj.: 1.40888e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 1.40888e+02  fin obj.: 4.58179e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 1.40888e+02  fin obj.: 4.27086e+02
# it:  9   it_marq:  2   lambda: 1e+01   init obj.: 1.40888e+02  fin obj.: 1.24884e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 1.24884e+02  fin obj.: 4.21152e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 1.24884e+02  fin obj.: 1.17420e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 1.17420e+02  fin obj.: 1.12392e+02
# it: 12   it_marq:  0   lambda: 1e-01   init obj.: 1.12392e+02  fin obj.: 4.58456e+02
# it: 12   it_marq:  1   lambda: 1e+00   init obj.: 1.12392e+02  fin obj.: 1.09394e+02
# it: 13   it_marq:  0   lambda: 1e-01   init obj.: 1.09394e+02  fin obj.: 4.47218e+02
# it: 13   it_marq:  1   lambda: 1e+00   init obj.: 1.09394e+02  fin obj.: 1.07740e+02
# it: 14   it_marq:  0   lambda: 1e-01   init obj.: 1.07740e+02  fin obj.: 4.36365e+02
# it: 14   it_marq:  1   lambda: 1e+00   init obj.: 1.07740e+02  fin obj.: 2.34685e+02
# it: 14   it_marq:  2   lambda: 1e+01   init obj.: 1.07740e+02  fin obj.: 1.06692e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 1.06692e+02  fin obj.: 2.31728e+02
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 1.06692e+02  fin obj.: 1.06050e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 1.06050e+02  fin obj.: 2.29428e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 1.06050e+02  fin obj.: 1.05889e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 1.05889e+02  fin obj.: 1.41340e+02
# it: 17   it_marq:  1   lambda: 1e+01   init obj.: 1.05889e+02  fin obj.: 1.05318e+02
# it: 18   it_marq:  0   lambda: 1e+00   init obj.: 1.05318e+02  fin obj.: 1.40018e+02
# it: 18   it_marq:  1   lambda: 1e+01   init obj.: 1.05318e+02  fin obj.: 1.04956e+02
# it: 19   it_marq:  0   lambda: 1e+00   init obj.: 1.04956e+02  fin obj.: 1.75709e+02
# it: 19   it_marq:  1   lambda: 1e+01   init obj.: 1.04956e+02  fin obj.: 1.04700e+02
# it: 20   it_marq:  0   lambda: 1e+00   init obj.: 1.04700e+02  fin obj.: 4.95197e+02
# it: 20   it_marq:  1   lambda: 1e+01   init obj.: 1.04700e+02  fin obj.: 1.04503e+02
# it: 21   it_marq:  0   lambda: 1e+00   init obj.: 1.04503e+02  fin obj.: 1.75997e+02
# it: 21   it_marq:  1   lambda: 1e+01   init obj.: 1.04503e+02  fin obj.: 1.04341e+02
# it: 22   it_marq:  0   lambda: 1e+00   init obj.: 1.04341e+02  fin obj.: 4.46345e+02
# it: 22   it_marq:  1   lambda: 1e+01   init obj.: 1.04341e+02  fin obj.: 1.04196e+02
# it: 23   it_marq:  0   lambda: 1e+00   init obj.: 1.04196e+02  fin obj.: 1.52989e+02
# it: 23   it_marq:  1   lambda: 1e+01   init obj.: 1.04196e+02  fin obj.: 1.04070e+02
# it: 24   it_marq:  0   lambda: 1e+00   init obj.: 1.04070e+02  fin obj.: 4.45518e+02
# it: 24   it_marq:  1   lambda: 1e+01   init obj.: 1.04070e+02  fin obj.: 1.03958e+02
# it: 25   it_marq:  0   lambda: 1e+00   init obj.: 1.03958e+02  fin obj.: 3.97493e+02
# it: 25   it_marq:  1   lambda: 1e+01   init obj.: 1.03958e+02  fin obj.: 1.41342e+02
# it: 25   it_marq:  2   lambda: 1e+02   init obj.: 1.03958e+02  fin obj.: 4.29399e+02
# it: 25   it_marq:  3   lambda: 1e+03   init obj.: 1.03958e+02  fin obj.: 8.75615e+02
# it: 25   it_marq:  4   lambda: 1e+04   init obj.: 1.03958e+02  fin obj.: 6.63900e+02
# it: 25   it_marq:  5   lambda: 1e+05   init obj.: 1.03958e+02  fin obj.: 6.63831e+02
# it: 25   it_marq:  6   lambda: 1e+06   init obj.: 1.03958e+02  fin obj.: 6.63820e+02
# it: 25   it_marq:  7   lambda: 1e+07   init obj.: 1.03958e+02  fin obj.: 2.13510e+02
# it: 25   it_marq:  8   lambda: 1e+08   init obj.: 1.03958e+02  fin obj.: 1.04022e+02
# it: 25   it_marq:  9   lambda: 1e+09   init obj.: 1.03958e+02  fin obj.: 1.03960e+02

# %% [markdown]
# # Results

# %%
# output of inversion
inversion = dict()

inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = np.array([a1, a2, a3, a4, a5, a6, a7])
inversion['tol'] = tol
inversion['main_field'] = [inc, dec]
inversion['intensity'] = intensity
inversion['results'] = inversion_results

# %% [markdown]
# ### Saving results

# %%
if foldername == '':
    mypath = 'l2-tfa-inversion/multiple-'+d4 #default folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)
else:
    mypath = 'l2-tfa-inversion/multiple-'+foldername #defined folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
