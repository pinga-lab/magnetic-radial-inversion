# %% [markdown]
# # Complex TFA multiple Inversions

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os
import pandas as pd

from fatiando.vis import mpl
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
from datetime import datetime
today = datetime.today()
# dd/mm/YY
d4 = today.strftime("%d-%b-%Y-%Hh:%Mm")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../inclined/model.pickle') as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open('data.pickle') as w:
        d = pickle.load(w)

# %%
data = pd.read_csv('inclined_model_data.txt', skipinitialspace=True, delim_whitespace=True)

# %%
dobs = data['res_data'].get_values()
xp = data['x'].get_values()
yp = data['y'].get_values()
zp = data['z'].get_values()
N = xp.size

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 20 # number of vertices per prism
L = 5 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization direction
incs = model['inc']
decs = model['dec']

int_min = 10.
int_max = 15.
intensity = np.linspace(int_min, int_max, 6)

# depth to the top, thickness and radius
z0_min = 0.
z0_max = 100.
z0 = np.linspace(z0_min, z0_max, 6)
dz = 800.
r = 700.
x0 = -200.
y0 = 0.

# main field
inc, dec = d['main_field']

# %%
z0
# Out:
# array([  0.,  20.,  40.,  60.,  80., 100.])

# %%
intensity
# Out:
# array([10., 11., 12., 13., 14., 15.])

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)

m_out = np.zeros(M+2)
for i, (x,y) in enumerate(zip(model['prisms'][0].x,model['prisms'][0].y)):
    m_out[i] = np.sqrt(x**2 + y**2)

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 10.
rmax = 1200.
x0min = -4000.
x0max = 4000.
y0min = -4000.
y0max = 4000.
dzmin = 200.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Derivatives

# %%
# variation for derivatives
deltax = 0.01*np.max(100.)
deltay = 0.01*np.max(100.)
deltar = 0.01*np.max(100.)
deltaz = 0.01*np.max(100.)

delta = np.array([deltax, deltay, deltar, deltaz])

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-3  # adjacent radial distances within each prism
a2 = 1.0e-3   # vertically adjacent radial distances
a3 = 1.0e-6   # outcropping cross-section
a4 = 1.0e-6   # outcropping origin
a5 = 1.0e-6    # vertically adjacent origins
a6 = 1.0e-6   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-5     # zero order Tikhonov on thickness of each prism

alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Folder to save the results

# %%
foldername = 'outcrop-3366665'

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-3     # stop criterion

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for j, z in enumerate(z0):
    for k, i in enumerate(intensity):
        alpha = np.array([a1, a2, a3, a4, a5, a6, a7])
        print 'inversion: %d  top: %d  intensity: %d' % (j*z0.size + k, z, i)
        model0, m0 = mfun.initial_cylinder(M, L, x0, y0, z, dz, r, inc, dec, incs, decs, i)
        d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(
            xp, yp, zp, m0, M, L, delta,
            itmax, itmax_marq, lamb,
            dlamb, tol, mmin, mmax,
            m_out, dobs, inc, dec,
            model0[0].props, alpha, z, dz
        )
        inversion_results.append([m_est, phi_list, model_list, dobs - d_fit])
# Out:
# inversion: 0  top: 0  intensity: 10
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.39241e+04  fin obj.: 6.31389e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 6.31389e+03  fin obj.: 3.27217e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.27217e+03  fin obj.: 1.29401e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.29401e+03  fin obj.: 7.29437e+02
# it:  4   it_marq:  0   lambda: 1e-03   init obj.: 7.29437e+02  fin obj.: 7.24675e+02
# it:  5   it_marq:  0   lambda: 1e-04   init obj.: 7.24675e+02  fin obj.: 5.34808e+02
# it:  6   it_marq:  0   lambda: 1e-05   init obj.: 5.34808e+02  fin obj.: 1.67745e+03
# it:  6   it_marq:  1   lambda: 1e-04   init obj.: 5.34808e+02  fin obj.: 1.67162e+03
# it:  6   it_marq:  2   lambda: 1e-03   init obj.: 5.34808e+02  fin obj.: 1.46104e+03
# it:  6   it_marq:  3   lambda: 1e-02   init obj.: 5.34808e+02  fin obj.: 1.40532e+03
# it:  6   it_marq:  4   lambda: 1e-01   init obj.: 5.34808e+02  fin obj.: 8.23839e+02
# it:  6   it_marq:  5   lambda: 1e+00   init obj.: 5.34808e+02  fin obj.: 5.79070e+02
# it:  6   it_marq:  6   lambda: 1e+01   init obj.: 5.34808e+02  fin obj.: 4.57847e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 4.57847e+02  fin obj.: 2.76354e+03
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 4.57847e+02  fin obj.: 2.68901e+03
# it:  7   it_marq:  2   lambda: 1e+02   init obj.: 4.57847e+02  fin obj.: 1.91432e+03
# it:  7   it_marq:  3   lambda: 1e+03   init obj.: 4.57847e+02  fin obj.: 2.41029e+03
# it:  7   it_marq:  4   lambda: 1e+04   init obj.: 4.57847e+02  fin obj.: 2.42718e+03
# it:  7   it_marq:  5   lambda: 1e+05   init obj.: 4.57847e+02  fin obj.: 2.42717e+03
# it:  7   it_marq:  6   lambda: 1e+06   init obj.: 4.57847e+02  fin obj.: 2.42715e+03
# it:  7   it_marq:  7   lambda: 1e+07   init obj.: 4.57847e+02  fin obj.: 2.42714e+03
# it:  7   it_marq:  8   lambda: 1e+08   init obj.: 4.57847e+02  fin obj.: 2.42714e+03
# it:  7   it_marq:  9   lambda: 1e+09   init obj.: 4.57847e+02  fin obj.: 2.42714e+03
# it:  8   it_marq:  0   lambda: 1e+10   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  1   lambda: 1e+11   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  2   lambda: 1e+12   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  3   lambda: 1e+13   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  4   lambda: 1e+14   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  5   lambda: 1e+15   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  6   lambda: 1e+16   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  7   lambda: 1e+17   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  8   lambda: 1e+18   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  8   it_marq:  9   lambda: 1e+19   init obj.: 4.57847e+02  fin obj.: 2.42711e+03
# it:  9   it_marq:  0   lambda: 1e+20   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  1   lambda: 1e+21   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  2   lambda: 1e+22   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  3   lambda: 1e+23   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  4   lambda: 1e+24   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  5   lambda: 1e+25   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  6   lambda: 1e+26   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  7   lambda: 1e+27   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  8   lambda: 1e+28   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it:  9   it_marq:  9   lambda: 1e+29   init obj.: 4.57847e+02  fin obj.: 2.42709e+03
# it: 10   it_marq:  0   lambda: 1e+30   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  1   lambda: 1e+31   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  2   lambda: 1e+32   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  3   lambda: 1e+33   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  4   lambda: 1e+34   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  5   lambda: 1e+35   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  6   lambda: 1e+36   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  7   lambda: 1e+37   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  8   lambda: 1e+38   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 10   it_marq:  9   lambda: 1e+39   init obj.: 4.57847e+02  fin obj.: 2.42706e+03
# it: 11   it_marq:  0   lambda: 1e+40   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  1   lambda: 1e+41   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  2   lambda: 1e+42   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  3   lambda: 1e+43   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  4   lambda: 1e+44   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  5   lambda: 1e+45   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  6   lambda: 1e+46   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  7   lambda: 1e+47   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  8   lambda: 1e+48   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 11   it_marq:  9   lambda: 1e+49   init obj.: 4.57847e+02  fin obj.: 2.42703e+03
# it: 12   it_marq:  0   lambda: 1e+50   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  1   lambda: 1e+51   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  2   lambda: 1e+52   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  3   lambda: 1e+53   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  4   lambda: 1e+54   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  5   lambda: 1e+55   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  6   lambda: 1e+56   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  7   lambda: 1e+57   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  8   lambda: 1e+58   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 12   it_marq:  9   lambda: 1e+59   init obj.: 4.57847e+02  fin obj.: 2.42700e+03
# it: 13   it_marq:  0   lambda: 1e+60   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  1   lambda: 1e+61   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  2   lambda: 1e+62   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  3   lambda: 1e+63   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  4   lambda: 1e+64   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  5   lambda: 1e+65   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  6   lambda: 1e+66   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  7   lambda: 1e+67   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  8   lambda: 1e+68   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 13   it_marq:  9   lambda: 1e+69   init obj.: 4.57847e+02  fin obj.: 2.42698e+03
# it: 14   it_marq:  0   lambda: 1e+70   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  1   lambda: 1e+71   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  2   lambda: 1e+72   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  3   lambda: 1e+73   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  4   lambda: 1e+74   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  5   lambda: 1e+75   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  6   lambda: 1e+76   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  7   lambda: 1e+77   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  8   lambda: 1e+78   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 14   it_marq:  9   lambda: 1e+79   init obj.: 4.57847e+02  fin obj.: 2.42695e+03
# it: 15   it_marq:  0   lambda: 1e+80   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  1   lambda: 1e+81   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  2   lambda: 1e+82   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  3   lambda: 1e+83   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  4   lambda: 1e+84   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  5   lambda: 1e+85   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  6   lambda: 1e+86   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  7   lambda: 1e+87   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  8   lambda: 1e+88   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 15   it_marq:  9   lambda: 1e+89   init obj.: 4.57847e+02  fin obj.: 2.42692e+03
# it: 16   it_marq:  0   lambda: 1e+90   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  1   lambda: 1e+91   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  2   lambda: 1e+92   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  3   lambda: 1e+93   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  4   lambda: 1e+94   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  5   lambda: 1e+95   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  6   lambda: 1e+96   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  7   lambda: 1e+97   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  8   lambda: 1e+98   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 16   it_marq:  9   lambda: 1e+99   init obj.: 4.57847e+02  fin obj.: 2.42689e+03
# it: 17   it_marq:  0   lambda: 1e+100   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  1   lambda: 1e+101   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  2   lambda: 1e+102   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  3   lambda: 1e+103   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  4   lambda: 1e+104   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  5   lambda: 1e+105   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  6   lambda: 1e+106   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  7   lambda: 1e+107   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  8   lambda: 1e+108   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 17   it_marq:  9   lambda: 1e+109   init obj.: 4.57847e+02  fin obj.: 2.42687e+03
# it: 18   it_marq:  0   lambda: 1e+110   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  1   lambda: 1e+111   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  2   lambda: 1e+112   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  3   lambda: 1e+113   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  4   lambda: 1e+114   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  5   lambda: 1e+115   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  6   lambda: 1e+116   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  7   lambda: 1e+117   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  8   lambda: 1e+118   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 18   it_marq:  9   lambda: 1e+119   init obj.: 4.57847e+02  fin obj.: 2.42684e+03
# it: 19   it_marq:  0   lambda: 1e+120   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  1   lambda: 1e+121   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  2   lambda: 1e+122   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  3   lambda: 1e+123   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  4   lambda: 1e+124   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  5   lambda: 1e+125   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  6   lambda: 1e+126   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  7   lambda: 1e+127   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  8   lambda: 1e+128   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 19   it_marq:  9   lambda: 1e+129   init obj.: 4.57847e+02  fin obj.: 2.42681e+03
# it: 20   it_marq:  0   lambda: 1e+130   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  1   lambda: 1e+131   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  2   lambda: 1e+132   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  3   lambda: 1e+133   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  4   lambda: 1e+134   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  5   lambda: 1e+135   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  6   lambda: 1e+136   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  7   lambda: 1e+137   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  8   lambda: 1e+138   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 20   it_marq:  9   lambda: 1e+139   init obj.: 4.57847e+02  fin obj.: 2.42678e+03
# it: 21   it_marq:  0   lambda: 1e+140   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  1   lambda: 1e+141   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  2   lambda: 1e+142   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  3   lambda: 1e+143   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  4   lambda: 1e+144   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  5   lambda: 1e+145   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  6   lambda: 1e+146   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  7   lambda: 1e+147   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  8   lambda: 1e+148   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 21   it_marq:  9   lambda: 1e+149   init obj.: 4.57847e+02  fin obj.: 2.42676e+03
# it: 22   it_marq:  0   lambda: 1e+150   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  1   lambda: 1e+151   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  2   lambda: 1e+152   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  3   lambda: 1e+153   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  4   lambda: 1e+154   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  5   lambda: 1e+155   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  6   lambda: 1e+156   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  7   lambda: 1e+157   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  8   lambda: 1e+158   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 22   it_marq:  9   lambda: 1e+159   init obj.: 4.57847e+02  fin obj.: 2.42673e+03
# it: 23   it_marq:  0   lambda: 1e+160   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  1   lambda: 1e+161   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  2   lambda: 1e+162   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  3   lambda: 1e+163   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  4   lambda: 1e+164   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  5   lambda: 1e+165   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  6   lambda: 1e+166   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  7   lambda: 1e+167   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  8   lambda: 1e+168   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 23   it_marq:  9   lambda: 1e+169   init obj.: 4.57847e+02  fin obj.: 2.42670e+03
# it: 24   it_marq:  0   lambda: 1e+170   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  1   lambda: 1e+171   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  2   lambda: 1e+172   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  3   lambda: 1e+173   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  4   lambda: 1e+174   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  5   lambda: 1e+175   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  6   lambda: 1e+176   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  7   lambda: 1e+177   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  8   lambda: 1e+178   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 24   it_marq:  9   lambda: 1e+179   init obj.: 4.57847e+02  fin obj.: 2.42668e+03
# it: 25   it_marq:  0   lambda: 1e+180   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  1   lambda: 1e+181   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  2   lambda: 1e+182   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  3   lambda: 1e+183   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  4   lambda: 1e+184   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  5   lambda: 1e+185   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  6   lambda: 1e+186   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  7   lambda: 1e+187   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  8   lambda: 1e+188   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 25   it_marq:  9   lambda: 1e+189   init obj.: 4.57847e+02  fin obj.: 2.42665e+03
# it: 26   it_marq:  0   lambda: 1e+190   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  1   lambda: 1e+191   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  2   lambda: 1e+192   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  3   lambda: 1e+193   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  4   lambda: 1e+194   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  5   lambda: 1e+195   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  6   lambda: 1e+196   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  7   lambda: 1e+197   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  8   lambda: 1e+198   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 26   it_marq:  9   lambda: 1e+199   init obj.: 4.57847e+02  fin obj.: 2.42662e+03
# it: 27   it_marq:  0   lambda: 1e+200   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  1   lambda: 1e+201   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  2   lambda: 1e+202   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  3   lambda: 1e+203   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  4   lambda: 1e+204   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  5   lambda: 1e+205   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  6   lambda: 1e+206   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  7   lambda: 1e+207   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  8   lambda: 1e+208   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 27   it_marq:  9   lambda: 1e+209   init obj.: 4.57847e+02  fin obj.: 2.42659e+03
# it: 28   it_marq:  0   lambda: 1e+210   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  1   lambda: 1e+211   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  2   lambda: 1e+212   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  3   lambda: 1e+213   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  4   lambda: 1e+214   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  5   lambda: 1e+215   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  6   lambda: 1e+216   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  7   lambda: 1e+217   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  8   lambda: 1e+218   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 28   it_marq:  9   lambda: 1e+219   init obj.: 4.57847e+02  fin obj.: 2.42657e+03
# it: 29   it_marq:  0   lambda: 1e+220   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  1   lambda: 1e+221   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  2   lambda: 1e+222   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  3   lambda: 1e+223   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  4   lambda: 1e+224   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  5   lambda: 1e+225   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  6   lambda: 1e+226   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  7   lambda: 1e+227   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  8   lambda: 1e+228   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# it: 29   it_marq:  9   lambda: 1e+229   init obj.: 4.57847e+02  fin obj.: 2.42654e+03
# inversion: 1  top: 0  intensity: 11
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.67577e+04  fin obj.: 7.21406e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 7.21406e+03  fin obj.: 3.28753e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.28753e+03  fin obj.: 1.40162e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.40162e+03  fin obj.: 1.38137e+03
# it:  4   it_marq:  0   lambda: 1e-03   init obj.: 1.38137e+03  fin obj.: 2.78276e+03
# it:  4   it_marq:  1   lambda: 1e-02   init obj.: 1.38137e+03  fin obj.: 2.02265e+03
# it:  4   it_marq:  2   lambda: 1e-01   init obj.: 1.38137e+03  fin obj.: 1.57740e+03
# it:  4   it_marq:  3   lambda: 1e+00   init obj.: 1.38137e+03  fin obj.: 1.60241e+03
# it:  4   it_marq:  4   lambda: 1e+01   init obj.: 1.38137e+03  fin obj.: 3.56333e+03
# it:  4   it_marq:  5   lambda: 1e+02   init obj.: 1.38137e+03  fin obj.: 2.91304e+03
# it:  4   it_marq:  6   lambda: 1e+03   init obj.: 1.38137e+03  fin obj.: 1.75165e+03
# it:  4   it_marq:  7   lambda: 1e+04   init obj.: 1.38137e+03  fin obj.: 1.14758e+03
# it:  5   it_marq:  0   lambda: 1e+03   init obj.: 1.14758e+03  fin obj.: 1.11672e+03
# it:  6   it_marq:  0   lambda: 1e+02   init obj.: 1.11672e+03  fin obj.: 8.71099e+02
# it:  7   it_marq:  0   lambda: 1e+01   init obj.: 8.71099e+02  fin obj.: 4.29883e+02
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 4.29883e+02  fin obj.: 4.58753e+02
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 4.29883e+02  fin obj.: 3.00279e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 3.00279e+02  fin obj.: 2.20367e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 2.20367e+02  fin obj.: 5.12619e+02
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 2.20367e+02  fin obj.: 1.86140e+02
# it: 11   it_marq:  0   lambda: 1e-01   init obj.: 1.86140e+02  fin obj.: 1.61785e+02
# it: 12   it_marq:  0   lambda: 1e-02   init obj.: 1.61785e+02  fin obj.: 2.79326e+02
# it: 12   it_marq:  1   lambda: 1e-01   init obj.: 1.61785e+02  fin obj.: 1.05980e+02
# it: 13   it_marq:  0   lambda: 1e-02   init obj.: 1.05980e+02  fin obj.: 1.25463e+02
# it: 13   it_marq:  1   lambda: 1e-01   init obj.: 1.05980e+02  fin obj.: 1.82798e+02
# it: 13   it_marq:  2   lambda: 1e+00   init obj.: 1.05980e+02  fin obj.: 1.26075e+02
# it: 13   it_marq:  3   lambda: 1e+01   init obj.: 1.05980e+02  fin obj.: 8.91376e+01
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 8.91376e+01  fin obj.: 9.60214e+01
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 8.91376e+01  fin obj.: 2.13344e+02
# it: 14   it_marq:  2   lambda: 1e+02   init obj.: 8.91376e+01  fin obj.: 8.78600e+01
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 8.78600e+01  fin obj.: 1.61314e+02
# it: 15   it_marq:  1   lambda: 1e+02   init obj.: 8.78600e+01  fin obj.: 1.43694e+02
# it: 15   it_marq:  2   lambda: 1e+03   init obj.: 8.78600e+01  fin obj.: 8.77407e+01
# it: 16   it_marq:  0   lambda: 1e+02   init obj.: 8.77407e+01  fin obj.: 1.43423e+02
# it: 16   it_marq:  1   lambda: 1e+03   init obj.: 8.77407e+01  fin obj.: 8.76172e+01
# it: 17   it_marq:  0   lambda: 1e+02   init obj.: 8.76172e+01  fin obj.: 8.66914e+01
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 8.66914e+01  fin obj.: 1.80548e+02
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 8.66914e+01  fin obj.: 8.59346e+01
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 8.59346e+01  fin obj.: 1.57098e+02
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 8.59346e+01  fin obj.: 8.53309e+01
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 8.53309e+01  fin obj.: 1.55329e+02
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 8.53309e+01  fin obj.: 8.48122e+01
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 8.48122e+01  fin obj.: 1.54367e+02
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 8.48122e+01  fin obj.: 8.44033e+01
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 8.44033e+01  fin obj.: 8.28163e+01
# it: 23   it_marq:  0   lambda: 1e+00   init obj.: 8.28163e+01  fin obj.: 9.49503e+01
# it: 23   it_marq:  1   lambda: 1e+01   init obj.: 8.28163e+01  fin obj.: 8.16911e+01
# it: 24   it_marq:  0   lambda: 1e+00   init obj.: 8.16911e+01  fin obj.: 1.45695e+02
# it: 24   it_marq:  1   lambda: 1e+01   init obj.: 8.16911e+01  fin obj.: 8.08639e+01
# it: 25   it_marq:  0   lambda: 1e+00   init obj.: 8.08639e+01  fin obj.: 1.44220e+02
# it: 25   it_marq:  1   lambda: 1e+01   init obj.: 8.08639e+01  fin obj.: 8.01909e+01
# it: 26   it_marq:  0   lambda: 1e+00   init obj.: 8.01909e+01  fin obj.: 2.10751e+02
# it: 26   it_marq:  1   lambda: 1e+01   init obj.: 8.01909e+01  fin obj.: 9.08623e+01
# it: 26   it_marq:  2   lambda: 1e+02   init obj.: 8.01909e+01  fin obj.: 2.03178e+02
# it: 26   it_marq:  3   lambda: 1e+03   init obj.: 8.01909e+01  fin obj.: 2.02515e+02
# it: 26   it_marq:  4   lambda: 1e+04   init obj.: 8.01909e+01  fin obj.: 1.60535e+02
# it: 26   it_marq:  5   lambda: 1e+05   init obj.: 8.01909e+01  fin obj.: 1.06242e+02
# it: 26   it_marq:  6   lambda: 1e+06   init obj.: 8.01909e+01  fin obj.: 1.06243e+02
# it: 26   it_marq:  7   lambda: 1e+07   init obj.: 8.01909e+01  fin obj.: 1.06243e+02
# it: 26   it_marq:  8   lambda: 1e+08   init obj.: 8.01909e+01  fin obj.: 1.06243e+02
# it: 26   it_marq:  9   lambda: 1e+09   init obj.: 8.01909e+01  fin obj.: 1.06242e+02
# it: 27   it_marq:  0   lambda: 1e+10   init obj.: 8.01909e+01  fin obj.: 1.06237e+02
# it: 27   it_marq:  1   lambda: 1e+11   init obj.: 8.01909e+01  fin obj.: 1.06237e+02
# it: 27   it_marq:  2   lambda: 1e+12   init obj.: 8.01909e+01  fin obj.: 1.06237e+02
# it: 27   it_marq:  3   lambda: 1e+13   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 27   it_marq:  4   lambda: 1e+14   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 27   it_marq:  5   lambda: 1e+15   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 27   it_marq:  6   lambda: 1e+16   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 27   it_marq:  7   lambda: 1e+17   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 27   it_marq:  8   lambda: 1e+18   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 27   it_marq:  9   lambda: 1e+19   init obj.: 8.01909e+01  fin obj.: 1.06236e+02
# it: 28   it_marq:  0   lambda: 1e+20   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  1   lambda: 1e+21   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  2   lambda: 1e+22   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  3   lambda: 1e+23   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  4   lambda: 1e+24   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  5   lambda: 1e+25   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  6   lambda: 1e+26   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  7   lambda: 1e+27   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  8   lambda: 1e+28   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 28   it_marq:  9   lambda: 1e+29   init obj.: 8.01909e+01  fin obj.: 1.06230e+02
# it: 29   it_marq:  0   lambda: 1e+30   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  1   lambda: 1e+31   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  2   lambda: 1e+32   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  3   lambda: 1e+33   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  4   lambda: 1e+34   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  5   lambda: 1e+35   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  6   lambda: 1e+36   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  7   lambda: 1e+37   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  8   lambda: 1e+38   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# it: 29   it_marq:  9   lambda: 1e+39   init obj.: 8.01909e+01  fin obj.: 1.06224e+02
# inversion: 2  top: 0  intensity: 12
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.04339e+04  fin obj.: 8.35476e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 8.35476e+03  fin obj.: 3.40853e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.40853e+03  fin obj.: 1.51854e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.51854e+03  fin obj.: 4.47584e+03
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.51854e+03  fin obj.: 7.90431e+03
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.51854e+03  fin obj.: 5.65081e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.51854e+03  fin obj.: 2.03025e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.51854e+03  fin obj.: 1.37939e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.37939e+03  fin obj.: 1.04845e+03
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 1.04845e+03  fin obj.: 9.03689e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 9.03689e+02  fin obj.: 4.63467e+02
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 4.63467e+02  fin obj.: 1.19839e+03
# it:  7   it_marq:  1   lambda: 1e-01   init obj.: 4.63467e+02  fin obj.: 1.44351e+03
# it:  7   it_marq:  2   lambda: 1e+00   init obj.: 4.63467e+02  fin obj.: 3.92946e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 3.92946e+02  fin obj.: 7.11273e+02
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 3.92946e+02  fin obj.: 1.53421e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 1.53421e+02  fin obj.: 6.48906e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 1.53421e+02  fin obj.: 7.69238e+02
# it:  9   it_marq:  2   lambda: 1e+01   init obj.: 1.53421e+02  fin obj.: 6.68035e+02
# it:  9   it_marq:  3   lambda: 1e+02   init obj.: 1.53421e+02  fin obj.: 1.51075e+02
# it: 10   it_marq:  0   lambda: 1e+01   init obj.: 1.51075e+02  fin obj.: 2.26560e+02
# it: 10   it_marq:  1   lambda: 1e+02   init obj.: 1.51075e+02  fin obj.: 1.48937e+02
# it: 11   it_marq:  0   lambda: 1e+01   init obj.: 1.48937e+02  fin obj.: 2.41803e+02
# it: 11   it_marq:  1   lambda: 1e+02   init obj.: 1.48937e+02  fin obj.: 1.47004e+02
# it: 12   it_marq:  0   lambda: 1e+01   init obj.: 1.47004e+02  fin obj.: 2.38430e+02
# it: 12   it_marq:  1   lambda: 1e+02   init obj.: 1.47004e+02  fin obj.: 1.45291e+02
# it: 13   it_marq:  0   lambda: 1e+01   init obj.: 1.45291e+02  fin obj.: 2.36939e+02
# it: 13   it_marq:  1   lambda: 1e+02   init obj.: 1.45291e+02  fin obj.: 1.43685e+02
# it: 14   it_marq:  0   lambda: 1e+01   init obj.: 1.43685e+02  fin obj.: 2.34945e+02
# it: 14   it_marq:  1   lambda: 1e+02   init obj.: 1.43685e+02  fin obj.: 1.42240e+02
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 1.42240e+02  fin obj.: 2.32722e+02
# it: 15   it_marq:  1   lambda: 1e+02   init obj.: 1.42240e+02  fin obj.: 1.40873e+02
# it: 16   it_marq:  0   lambda: 1e+01   init obj.: 1.40873e+02  fin obj.: 2.30944e+02
# it: 16   it_marq:  1   lambda: 1e+02   init obj.: 1.40873e+02  fin obj.: 1.39638e+02
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 1.39638e+02  fin obj.: 2.29449e+02
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 1.39638e+02  fin obj.: 1.38459e+02
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 1.38459e+02  fin obj.: 2.90979e+02
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 1.38459e+02  fin obj.: 1.37378e+02
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 1.37378e+02  fin obj.: 2.89253e+02
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 1.37378e+02  fin obj.: 1.36336e+02
# it: 20   it_marq:  0   lambda: 1e+01   init obj.: 1.36336e+02  fin obj.: 2.81896e+02
# it: 20   it_marq:  1   lambda: 1e+02   init obj.: 1.36336e+02  fin obj.: 1.35376e+02
# it: 21   it_marq:  0   lambda: 1e+01   init obj.: 1.35376e+02  fin obj.: 1.93839e+02
# it: 21   it_marq:  1   lambda: 1e+02   init obj.: 1.35376e+02  fin obj.: 1.34445e+02
# it: 22   it_marq:  0   lambda: 1e+01   init obj.: 1.34445e+02  fin obj.: 1.68460e+02
# it: 22   it_marq:  1   lambda: 1e+02   init obj.: 1.34445e+02  fin obj.: 1.33583e+02
# it: 23   it_marq:  0   lambda: 1e+01   init obj.: 1.33583e+02  fin obj.: 1.64016e+02
# it: 23   it_marq:  1   lambda: 1e+02   init obj.: 1.33583e+02  fin obj.: 1.32744e+02
# it: 24   it_marq:  0   lambda: 1e+01   init obj.: 1.32744e+02  fin obj.: 1.62235e+02
# it: 24   it_marq:  1   lambda: 1e+02   init obj.: 1.32744e+02  fin obj.: 1.31962e+02
# it: 25   it_marq:  0   lambda: 1e+01   init obj.: 1.31962e+02  fin obj.: 1.60988e+02
# it: 25   it_marq:  1   lambda: 1e+02   init obj.: 1.31962e+02  fin obj.: 1.35274e+02
# it: 25   it_marq:  2   lambda: 1e+03   init obj.: 1.31962e+02  fin obj.: 1.31864e+02
# inversion: 3  top: 0  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.49527e+04  fin obj.: 9.72828e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.72828e+03  fin obj.: 3.62207e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.62207e+03  fin obj.: 1.86244e+03
# it:  3   it_marq:  0   lambda: 1e-02   init obj.: 1.86244e+03  fin obj.: 1.20542e+04
# it:  3   it_marq:  1   lambda: 1e-01   init obj.: 1.86244e+03  fin obj.: 1.27213e+04
# it:  3   it_marq:  2   lambda: 1e+00   init obj.: 1.86244e+03  fin obj.: 8.76255e+03
# it:  3   it_marq:  3   lambda: 1e+01   init obj.: 1.86244e+03  fin obj.: 2.46717e+03
# it:  3   it_marq:  4   lambda: 1e+02   init obj.: 1.86244e+03  fin obj.: 1.64623e+03
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 1.64623e+03  fin obj.: 7.61866e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 7.61866e+02  fin obj.: 9.10306e+02
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 7.61866e+02  fin obj.: 1.06835e+03
# it:  5   it_marq:  2   lambda: 1e+02   init obj.: 7.61866e+02  fin obj.: 7.46888e+02
# it:  6   it_marq:  0   lambda: 1e+01   init obj.: 7.46888e+02  fin obj.: 7.02367e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 7.02367e+02  fin obj.: 4.64101e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 4.64101e+02  fin obj.: 1.33721e+03
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 4.64101e+02  fin obj.: 5.01434e+02
# it:  8   it_marq:  2   lambda: 1e+01   init obj.: 4.64101e+02  fin obj.: 3.52691e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 3.52691e+02  fin obj.: 7.04710e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 3.52691e+02  fin obj.: 8.22603e+02
# it:  9   it_marq:  2   lambda: 1e+02   init obj.: 3.52691e+02  fin obj.: 9.38047e+02
# it:  9   it_marq:  3   lambda: 1e+03   init obj.: 3.52691e+02  fin obj.: 7.05994e+02
# it:  9   it_marq:  4   lambda: 1e+04   init obj.: 3.52691e+02  fin obj.: 5.93352e+02
# it:  9   it_marq:  5   lambda: 1e+05   init obj.: 3.52691e+02  fin obj.: 5.93345e+02
# it:  9   it_marq:  6   lambda: 1e+06   init obj.: 3.52691e+02  fin obj.: 5.93348e+02
# it:  9   it_marq:  7   lambda: 1e+07   init obj.: 3.52691e+02  fin obj.: 5.93349e+02
# it:  9   it_marq:  8   lambda: 1e+08   init obj.: 3.52691e+02  fin obj.: 5.93349e+02
# it:  9   it_marq:  9   lambda: 1e+09   init obj.: 3.52691e+02  fin obj.: 5.93349e+02
# it: 10   it_marq:  0   lambda: 1e+10   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  1   lambda: 1e+11   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  2   lambda: 1e+12   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  3   lambda: 1e+13   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  4   lambda: 1e+14   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  5   lambda: 1e+15   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  6   lambda: 1e+16   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  7   lambda: 1e+17   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  8   lambda: 1e+18   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 10   it_marq:  9   lambda: 1e+19   init obj.: 3.52691e+02  fin obj.: 5.93316e+02
# it: 11   it_marq:  0   lambda: 1e+20   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  1   lambda: 1e+21   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  2   lambda: 1e+22   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  3   lambda: 1e+23   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  4   lambda: 1e+24   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  5   lambda: 1e+25   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  6   lambda: 1e+26   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  7   lambda: 1e+27   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  8   lambda: 1e+28   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 11   it_marq:  9   lambda: 1e+29   init obj.: 3.52691e+02  fin obj.: 5.93284e+02
# it: 12   it_marq:  0   lambda: 1e+30   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  1   lambda: 1e+31   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  2   lambda: 1e+32   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  3   lambda: 1e+33   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  4   lambda: 1e+34   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  5   lambda: 1e+35   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  6   lambda: 1e+36   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  7   lambda: 1e+37   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  8   lambda: 1e+38   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 12   it_marq:  9   lambda: 1e+39   init obj.: 3.52691e+02  fin obj.: 5.93252e+02
# it: 13   it_marq:  0   lambda: 1e+40   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  1   lambda: 1e+41   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  2   lambda: 1e+42   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  3   lambda: 1e+43   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  4   lambda: 1e+44   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  5   lambda: 1e+45   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  6   lambda: 1e+46   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  7   lambda: 1e+47   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  8   lambda: 1e+48   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 13   it_marq:  9   lambda: 1e+49   init obj.: 3.52691e+02  fin obj.: 5.93219e+02
# it: 14   it_marq:  0   lambda: 1e+50   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  1   lambda: 1e+51   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  2   lambda: 1e+52   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  3   lambda: 1e+53   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  4   lambda: 1e+54   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  5   lambda: 1e+55   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  6   lambda: 1e+56   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  7   lambda: 1e+57   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  8   lambda: 1e+58   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 14   it_marq:  9   lambda: 1e+59   init obj.: 3.52691e+02  fin obj.: 5.93187e+02
# it: 15   it_marq:  0   lambda: 1e+60   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  1   lambda: 1e+61   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  2   lambda: 1e+62   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  3   lambda: 1e+63   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  4   lambda: 1e+64   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  5   lambda: 1e+65   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  6   lambda: 1e+66   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  7   lambda: 1e+67   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  8   lambda: 1e+68   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 15   it_marq:  9   lambda: 1e+69   init obj.: 3.52691e+02  fin obj.: 5.93155e+02
# it: 16   it_marq:  0   lambda: 1e+70   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  1   lambda: 1e+71   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  2   lambda: 1e+72   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  3   lambda: 1e+73   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  4   lambda: 1e+74   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  5   lambda: 1e+75   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  6   lambda: 1e+76   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  7   lambda: 1e+77   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  8   lambda: 1e+78   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 16   it_marq:  9   lambda: 1e+79   init obj.: 3.52691e+02  fin obj.: 5.93122e+02
# it: 17   it_marq:  0   lambda: 1e+80   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  1   lambda: 1e+81   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  2   lambda: 1e+82   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  3   lambda: 1e+83   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  4   lambda: 1e+84   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  5   lambda: 1e+85   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  6   lambda: 1e+86   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  7   lambda: 1e+87   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  8   lambda: 1e+88   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 17   it_marq:  9   lambda: 1e+89   init obj.: 3.52691e+02  fin obj.: 5.93090e+02
# it: 18   it_marq:  0   lambda: 1e+90   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  1   lambda: 1e+91   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  2   lambda: 1e+92   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  3   lambda: 1e+93   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  4   lambda: 1e+94   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  5   lambda: 1e+95   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  6   lambda: 1e+96   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  7   lambda: 1e+97   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  8   lambda: 1e+98   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 18   it_marq:  9   lambda: 1e+99   init obj.: 3.52691e+02  fin obj.: 5.93058e+02
# it: 19   it_marq:  0   lambda: 1e+100   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  1   lambda: 1e+101   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  2   lambda: 1e+102   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  3   lambda: 1e+103   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  4   lambda: 1e+104   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  5   lambda: 1e+105   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  6   lambda: 1e+106   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  7   lambda: 1e+107   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  8   lambda: 1e+108   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 19   it_marq:  9   lambda: 1e+109   init obj.: 3.52691e+02  fin obj.: 5.93026e+02
# it: 20   it_marq:  0   lambda: 1e+110   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  1   lambda: 1e+111   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  2   lambda: 1e+112   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  3   lambda: 1e+113   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  4   lambda: 1e+114   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  5   lambda: 1e+115   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  6   lambda: 1e+116   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  7   lambda: 1e+117   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  8   lambda: 1e+118   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 20   it_marq:  9   lambda: 1e+119   init obj.: 3.52691e+02  fin obj.: 5.92994e+02
# it: 21   it_marq:  0   lambda: 1e+120   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  1   lambda: 1e+121   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  2   lambda: 1e+122   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  3   lambda: 1e+123   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  4   lambda: 1e+124   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  5   lambda: 1e+125   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  6   lambda: 1e+126   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  7   lambda: 1e+127   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  8   lambda: 1e+128   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 21   it_marq:  9   lambda: 1e+129   init obj.: 3.52691e+02  fin obj.: 5.92961e+02
# it: 22   it_marq:  0   lambda: 1e+130   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  1   lambda: 1e+131   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  2   lambda: 1e+132   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  3   lambda: 1e+133   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  4   lambda: 1e+134   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  5   lambda: 1e+135   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  6   lambda: 1e+136   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  7   lambda: 1e+137   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  8   lambda: 1e+138   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 22   it_marq:  9   lambda: 1e+139   init obj.: 3.52691e+02  fin obj.: 5.92929e+02
# it: 23   it_marq:  0   lambda: 1e+140   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  1   lambda: 1e+141   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  2   lambda: 1e+142   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  3   lambda: 1e+143   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  4   lambda: 1e+144   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  5   lambda: 1e+145   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  6   lambda: 1e+146   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  7   lambda: 1e+147   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  8   lambda: 1e+148   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 23   it_marq:  9   lambda: 1e+149   init obj.: 3.52691e+02  fin obj.: 5.92897e+02
# it: 24   it_marq:  0   lambda: 1e+150   init obj.: 3.52691e+02  fin obj.: 5.92865e+02
# it: 24   it_marq:  1   lambda: 1e+151   init obj.: 3.52691e+02  fin obj.: 5.92865e+02
# it: 24   it_marq:  2   lambda: 1e+152   init obj.: 3.52691e+02  fin obj.: 5.92865e+02
# it: 24   it_marq:  3   lambda: 1e+153   init obj.: 3.52691e+02  fin obj.: 5.92865e+02
# it: 24   it_marq:  4   lambda: 1e+154   init obj.: 3.52691e+02  fin obj.: 5.92865e+02
# it: 24   it_marq:  5   lambda: 1e+155   init obj.: 3.52691e+02  fin obj.: 5.92865e+02
# ...
# it: 25   it_marq:  4   lambda: 1e+213   init obj.: 1.51090e+03  fin obj.: 1.59451e+03
# it: 25   it_marq:  5   lambda: 1e+214   init obj.: 1.51090e+03  fin obj.: 1.59451e+03
# it: 25   it_marq:  6   lambda: 1e+215   init obj.: 1.51090e+03  fin obj.: 1.59451e+03
# it: 25   it_marq:  7   lambda: 1e+216   init obj.: 1.51090e+03  fin obj.: 1.59451e+03
# it: 25   it_marq:  8   lambda: 1e+217   init obj.: 1.51090e+03  fin obj.: 1.59451e+03
# it: 25   it_marq:  9   lambda: 1e+218   init obj.: 1.51090e+03  fin obj.: 1.59451e+03
# it: 26   it_marq:  0   lambda: 1e+219   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  1   lambda: 1e+220   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  2   lambda: 1e+221   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  3   lambda: 1e+222   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  4   lambda: 1e+223   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  5   lambda: 1e+224   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  6   lambda: 1e+225   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  7   lambda: 1e+226   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  8   lambda: 1e+227   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 26   it_marq:  9   lambda: 1e+228   init obj.: 1.51090e+03  fin obj.: 1.59460e+03
# it: 27   it_marq:  0   lambda: 1e+229   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  1   lambda: 1e+230   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  2   lambda: 1e+231   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  3   lambda: 1e+232   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  4   lambda: 1e+233   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  5   lambda: 1e+234   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  6   lambda: 1e+235   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  7   lambda: 1e+236   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  8   lambda: 1e+237   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 27   it_marq:  9   lambda: 1e+238   init obj.: 1.51090e+03  fin obj.: 1.59469e+03
# it: 28   it_marq:  0   lambda: 1e+239   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  1   lambda: 1e+240   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  2   lambda: 1e+241   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  3   lambda: 1e+242   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  4   lambda: 1e+243   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  5   lambda: 1e+244   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  6   lambda: 1e+245   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  7   lambda: 1e+246   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  8   lambda: 1e+247   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 28   it_marq:  9   lambda: 1e+248   init obj.: 1.51090e+03  fin obj.: 1.59479e+03
# it: 29   it_marq:  0   lambda: 1e+249   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  1   lambda: 1e+250   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  2   lambda: 1e+251   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  3   lambda: 1e+252   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  4   lambda: 1e+253   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  5   lambda: 1e+254   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  6   lambda: 1e+255   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  7   lambda: 1e+256   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  8   lambda: 1e+257   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# it: 29   it_marq:  9   lambda: 1e+258   init obj.: 1.51090e+03  fin obj.: 1.59488e+03
# inversion: 33  top: 100  intensity: 13
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 1.83150e+04  fin obj.: 7.27740e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 7.27740e+03  fin obj.: 3.24081e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.24081e+03  fin obj.: 4.65827e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.24081e+03  fin obj.: 6.58594e+02
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 6.58594e+02  fin obj.: 5.01461e+03
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 6.58594e+02  fin obj.: 3.71016e+03
# it:  3   it_marq:  2   lambda: 1e+01   init obj.: 6.58594e+02  fin obj.: 5.27026e+02
# it:  4   it_marq:  0   lambda: 1e+00   init obj.: 5.27026e+02  fin obj.: 4.02202e+02
# it:  5   it_marq:  0   lambda: 1e-01   init obj.: 4.02202e+02  fin obj.: 6.10541e+02
# it:  5   it_marq:  1   lambda: 1e+00   init obj.: 4.02202e+02  fin obj.: 3.18564e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 3.18564e+02  fin obj.: 5.08007e+02
# it:  6   it_marq:  1   lambda: 1e+00   init obj.: 3.18564e+02  fin obj.: 2.57764e+02
# it:  7   it_marq:  0   lambda: 1e-01   init obj.: 2.57764e+02  fin obj.: 7.84396e+02
# it:  7   it_marq:  1   lambda: 1e+00   init obj.: 2.57764e+02  fin obj.: 2.20863e+02
# it:  8   it_marq:  0   lambda: 1e-01   init obj.: 2.20863e+02  fin obj.: 1.51319e+03
# it:  8   it_marq:  1   lambda: 1e+00   init obj.: 2.20863e+02  fin obj.: 1.97418e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 1.97418e+02  fin obj.: 1.42285e+03
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 1.97418e+02  fin obj.: 1.81635e+02
# it: 10   it_marq:  0   lambda: 1e-01   init obj.: 1.81635e+02  fin obj.: 1.35353e+03
# it: 10   it_marq:  1   lambda: 1e+00   init obj.: 1.81635e+02  fin obj.: 3.74950e+02
# it: 10   it_marq:  2   lambda: 1e+01   init obj.: 1.81635e+02  fin obj.: 1.72648e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 1.72648e+02  fin obj.: 3.67994e+02
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 1.72648e+02  fin obj.: 1.67989e+02
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 1.67989e+02  fin obj.: 3.63884e+02
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 1.67989e+02  fin obj.: 1.65037e+02
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 1.65037e+02  fin obj.: 5.09185e+02
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 1.65037e+02  fin obj.: 1.62938e+02
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 1.62938e+02  fin obj.: 5.03667e+02
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 1.62938e+02  fin obj.: 1.61321e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 1.61321e+02  fin obj.: 1.21973e+03
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 1.61321e+02  fin obj.: 1.60002e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 1.60002e+02  fin obj.: 1.00470e+03
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 1.60002e+02  fin obj.: 2.20261e+02
# it: 16   it_marq:  2   lambda: 1e+02   init obj.: 1.60002e+02  fin obj.: 5.23822e+02
# it: 16   it_marq:  3   lambda: 1e+03   init obj.: 1.60002e+02  fin obj.: 2.21348e+02
# it: 16   it_marq:  4   lambda: 1e+04   init obj.: 1.60002e+02  fin obj.: 2.21365e+02
# it: 16   it_marq:  5   lambda: 1e+05   init obj.: 1.60002e+02  fin obj.: 2.21371e+02
# it: 16   it_marq:  6   lambda: 1e+06   init obj.: 1.60002e+02  fin obj.: 1.60045e+02
# it: 16   it_marq:  7   lambda: 1e+07   init obj.: 1.60002e+02  fin obj.: 1.60003e+02
# it: 16   it_marq:  8   lambda: 1e+08   init obj.: 1.60002e+02  fin obj.: 1.60003e+02
# it: 16   it_marq:  9   lambda: 1e+09   init obj.: 1.60002e+02  fin obj.: 1.60003e+02
# inversion: 34  top: 100  intensity: 14
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.17222e+04  fin obj.: 8.12005e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 8.12005e+03  fin obj.: 3.27705e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.27705e+03  fin obj.: 5.54888e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.27705e+03  fin obj.: 7.56513e+02
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 7.56513e+02  fin obj.: 6.29550e+03
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 7.56513e+02  fin obj.: 5.69138e+03
# it:  3   it_marq:  2   lambda: 1e+01   init obj.: 7.56513e+02  fin obj.: 2.87928e+03
# it:  3   it_marq:  3   lambda: 1e+02   init obj.: 7.56513e+02  fin obj.: 6.68003e+02
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 6.68003e+02  fin obj.: 4.18142e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 4.18142e+02  fin obj.: 4.21503e+02
# it:  5   it_marq:  1   lambda: 1e+01   init obj.: 4.18142e+02  fin obj.: 3.55105e+02
# it:  6   it_marq:  0   lambda: 1e+00   init obj.: 3.55105e+02  fin obj.: 3.90251e+02
# it:  6   it_marq:  1   lambda: 1e+01   init obj.: 3.55105e+02  fin obj.: 3.20375e+02
# it:  7   it_marq:  0   lambda: 1e+00   init obj.: 3.20375e+02  fin obj.: 3.67527e+02
# it:  7   it_marq:  1   lambda: 1e+01   init obj.: 3.20375e+02  fin obj.: 2.96125e+02
# it:  8   it_marq:  0   lambda: 1e+00   init obj.: 2.96125e+02  fin obj.: 3.89373e+02
# it:  8   it_marq:  1   lambda: 1e+01   init obj.: 2.96125e+02  fin obj.: 2.77814e+02
# it:  9   it_marq:  0   lambda: 1e+00   init obj.: 2.77814e+02  fin obj.: 3.78537e+02
# it:  9   it_marq:  1   lambda: 1e+01   init obj.: 2.77814e+02  fin obj.: 2.63156e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 2.63156e+02  fin obj.: 3.66143e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 2.63156e+02  fin obj.: 2.51161e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 2.51161e+02  fin obj.: 3.55877e+02
# it: 11   it_marq:  1   lambda: 1e+01   init obj.: 2.51161e+02  fin obj.: 2.41218e+02
# it: 12   it_marq:  0   lambda: 1e+00   init obj.: 2.41218e+02  fin obj.: 3.84735e+02
# it: 12   it_marq:  1   lambda: 1e+01   init obj.: 2.41218e+02  fin obj.: 2.32699e+02
# it: 13   it_marq:  0   lambda: 1e+00   init obj.: 2.32699e+02  fin obj.: 3.91082e+02
# it: 13   it_marq:  1   lambda: 1e+01   init obj.: 2.32699e+02  fin obj.: 2.25199e+02
# it: 14   it_marq:  0   lambda: 1e+00   init obj.: 2.25199e+02  fin obj.: 4.98546e+02
# it: 14   it_marq:  1   lambda: 1e+01   init obj.: 2.25199e+02  fin obj.: 2.18522e+02
# it: 15   it_marq:  0   lambda: 1e+00   init obj.: 2.18522e+02  fin obj.: 5.12315e+02
# it: 15   it_marq:  1   lambda: 1e+01   init obj.: 2.18522e+02  fin obj.: 2.12541e+02
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 2.12541e+02  fin obj.: 5.02322e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 2.12541e+02  fin obj.: 2.07153e+02
# it: 17   it_marq:  0   lambda: 1e+00   init obj.: 2.07153e+02  fin obj.: 4.93009e+02
# it: 17   it_marq:  1   lambda: 1e+01   init obj.: 2.07153e+02  fin obj.: 2.02274e+02
# it: 18   it_marq:  0   lambda: 1e+00   init obj.: 2.02274e+02  fin obj.: 4.84477e+02
# it: 18   it_marq:  1   lambda: 1e+01   init obj.: 2.02274e+02  fin obj.: 1.97836e+02
# it: 19   it_marq:  0   lambda: 1e+00   init obj.: 1.97836e+02  fin obj.: 4.76704e+02
# it: 19   it_marq:  1   lambda: 1e+01   init obj.: 1.97836e+02  fin obj.: 1.93781e+02
# it: 20   it_marq:  0   lambda: 1e+00   init obj.: 1.93781e+02  fin obj.: 4.69603e+02
# it: 20   it_marq:  1   lambda: 1e+01   init obj.: 1.93781e+02  fin obj.: 1.90064e+02
# it: 21   it_marq:  0   lambda: 1e+00   init obj.: 1.90064e+02  fin obj.: 4.63105e+02
# it: 21   it_marq:  1   lambda: 1e+01   init obj.: 1.90064e+02  fin obj.: 1.86643e+02
# it: 22   it_marq:  0   lambda: 1e+00   init obj.: 1.86643e+02  fin obj.: 4.57143e+02
# it: 22   it_marq:  1   lambda: 1e+01   init obj.: 1.86643e+02  fin obj.: 1.83486e+02
# it: 23   it_marq:  0   lambda: 1e+00   init obj.: 1.83486e+02  fin obj.: 4.51657e+02
# it: 23   it_marq:  1   lambda: 1e+01   init obj.: 1.83486e+02  fin obj.: 1.80564e+02
# it: 24   it_marq:  0   lambda: 1e+00   init obj.: 1.80564e+02  fin obj.: 4.46583e+02
# it: 24   it_marq:  1   lambda: 1e+01   init obj.: 1.80564e+02  fin obj.: 1.77853e+02
# it: 25   it_marq:  0   lambda: 1e+00   init obj.: 1.77853e+02  fin obj.: 4.41830e+02
# it: 25   it_marq:  1   lambda: 1e+01   init obj.: 1.77853e+02  fin obj.: 1.75320e+02
# it: 26   it_marq:  0   lambda: 1e+00   init obj.: 1.75320e+02  fin obj.: 4.37462e+02
# it: 26   it_marq:  1   lambda: 1e+01   init obj.: 1.75320e+02  fin obj.: 1.72941e+02
# it: 27   it_marq:  0   lambda: 1e+00   init obj.: 1.72941e+02  fin obj.: 4.33692e+02
# it: 27   it_marq:  1   lambda: 1e+01   init obj.: 1.72941e+02  fin obj.: 1.70707e+02
# it: 28   it_marq:  0   lambda: 1e+00   init obj.: 1.70707e+02  fin obj.: 4.30945e+02
# it: 28   it_marq:  1   lambda: 1e+01   init obj.: 1.70707e+02  fin obj.: 1.68602e+02
# it: 29   it_marq:  0   lambda: 1e+00   init obj.: 1.68602e+02  fin obj.: 4.31373e+02
# it: 29   it_marq:  1   lambda: 1e+01   init obj.: 1.68602e+02  fin obj.: 1.66618e+02
# inversion: 35  top: 100  intensity: 15
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 2.57657e+04  fin obj.: 9.10521e+03
# it:  1   it_marq:  0   lambda: 1e+00   init obj.: 9.10521e+03  fin obj.: 3.36524e+03
# it:  2   it_marq:  0   lambda: 1e-01   init obj.: 3.36524e+03  fin obj.: 6.30975e+03
# it:  2   it_marq:  1   lambda: 1e+00   init obj.: 3.36524e+03  fin obj.: 8.31390e+02
# it:  3   it_marq:  0   lambda: 1e-01   init obj.: 8.31390e+02  fin obj.: 8.52606e+03
# it:  3   it_marq:  1   lambda: 1e+00   init obj.: 8.31390e+02  fin obj.: 8.04943e+03
# it:  3   it_marq:  2   lambda: 1e+01   init obj.: 8.31390e+02  fin obj.: 4.65943e+03
# it:  3   it_marq:  3   lambda: 1e+02   init obj.: 8.31390e+02  fin obj.: 7.15372e+02
# it:  4   it_marq:  0   lambda: 1e+01   init obj.: 7.15372e+02  fin obj.: 4.16144e+02
# it:  5   it_marq:  0   lambda: 1e+00   init obj.: 4.16144e+02  fin obj.: 3.71328e+02
# it:  6   it_marq:  0   lambda: 1e-01   init obj.: 3.71328e+02  fin obj.: 3.44567e+02
# it:  7   it_marq:  0   lambda: 1e-02   init obj.: 3.44567e+02  fin obj.: 1.44785e+03
# it:  7   it_marq:  1   lambda: 1e-01   init obj.: 3.44567e+02  fin obj.: 2.10559e+02
# it:  8   it_marq:  0   lambda: 1e-02   init obj.: 2.10559e+02  fin obj.: 1.15016e+03
# it:  8   it_marq:  1   lambda: 1e-01   init obj.: 2.10559e+02  fin obj.: 4.47266e+02
# it:  8   it_marq:  2   lambda: 1e+00   init obj.: 2.10559e+02  fin obj.: 1.24387e+02
# it:  9   it_marq:  0   lambda: 1e-01   init obj.: 1.24387e+02  fin obj.: 4.41603e+02
# it:  9   it_marq:  1   lambda: 1e+00   init obj.: 1.24387e+02  fin obj.: 3.85771e+02
# it:  9   it_marq:  2   lambda: 1e+01   init obj.: 1.24387e+02  fin obj.: 1.12076e+02
# it: 10   it_marq:  0   lambda: 1e+00   init obj.: 1.12076e+02  fin obj.: 3.82214e+02
# it: 10   it_marq:  1   lambda: 1e+01   init obj.: 1.12076e+02  fin obj.: 1.05833e+02
# it: 11   it_marq:  0   lambda: 1e+00   init obj.: 1.05833e+02  fin obj.: 1.01615e+02
# it: 12   it_marq:  0   lambda: 1e-01   init obj.: 1.01615e+02  fin obj.: 1.10700e+02
# it: 12   it_marq:  1   lambda: 1e+00   init obj.: 1.01615e+02  fin obj.: 9.96027e+01
# it: 13   it_marq:  0   lambda: 1e-01   init obj.: 9.96027e+01  fin obj.: 1.23652e+02
# it: 13   it_marq:  1   lambda: 1e+00   init obj.: 9.96027e+01  fin obj.: 9.86323e+01
# it: 14   it_marq:  0   lambda: 1e-01   init obj.: 9.86323e+01  fin obj.: 2.22362e+02
# it: 14   it_marq:  1   lambda: 1e+00   init obj.: 9.86323e+01  fin obj.: 1.32681e+02
# it: 14   it_marq:  2   lambda: 1e+01   init obj.: 9.86323e+01  fin obj.: 1.98675e+02
# it: 14   it_marq:  3   lambda: 1e+02   init obj.: 9.86323e+01  fin obj.: 9.81921e+01
# it: 15   it_marq:  0   lambda: 1e+01   init obj.: 9.81921e+01  fin obj.: 9.73901e+01
# it: 16   it_marq:  0   lambda: 1e+00   init obj.: 9.73901e+01  fin obj.: 2.21854e+02
# it: 16   it_marq:  1   lambda: 1e+01   init obj.: 9.73901e+01  fin obj.: 1.39005e+02
# it: 16   it_marq:  2   lambda: 1e+02   init obj.: 9.73901e+01  fin obj.: 9.72344e+01
# it: 17   it_marq:  0   lambda: 1e+01   init obj.: 9.72344e+01  fin obj.: 1.38820e+02
# it: 17   it_marq:  1   lambda: 1e+02   init obj.: 9.72344e+01  fin obj.: 9.71108e+01
# it: 18   it_marq:  0   lambda: 1e+01   init obj.: 9.71108e+01  fin obj.: 1.37890e+02
# it: 18   it_marq:  1   lambda: 1e+02   init obj.: 9.71108e+01  fin obj.: 9.69918e+01
# it: 19   it_marq:  0   lambda: 1e+01   init obj.: 9.69918e+01  fin obj.: 1.38441e+02
# it: 19   it_marq:  1   lambda: 1e+02   init obj.: 9.69918e+01  fin obj.: 9.68961e+01

# %% [markdown]
# # Results

# %%
# output of inversion
inversion = dict()

inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = np.array([a1, a2, a3, a4, a5, a6, a7])
inversion['tol'] = tol
inversion['main_field'] = [inc, dec]
inversion['intensity'] = intensity
inversion['results'] = inversion_results

# %% [markdown]
# ### Saving results

# %%
if foldername == '':
    mypath = 'l2-tfa-inversion/multiple-'+d4 #default folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)
else:
    mypath = 'l2-tfa-inversion/multiple-'+foldername #defined folder name
    if not os.path.isdir(mypath):
       os.makedirs(mypath)

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
