# %% [markdown]
# # Complex body TFA Inversion

# %% [markdown]
# This notebook performs the inversion using Levenberg-Marquadt's algorithm of total field anomaly (TFA) data on a regular grid of a model with a complex geometry.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
model_dir = 'data/model_real_obs_pts.pickle'
data_dir = 'data/real_obs_pts/data.pickle'
#data_dir = 'eqlayer/direction_inc65_dec-40_h190m/eqlayer_depth190m.pickle'

# %%
with open(model_dir) as w:
        model = pickle.load(w)

# %% [markdown]
# ### Observation points and observed data

# %%
with open(data_dir) as w:
        data = pickle.load(w)

# %%
# observed data and observation points
dobs = data['tfa_obs']
xp = data['grid'][0]
yp = data['grid'][1]
zp = data['grid'][2]
N = data['grid'][3]

# %% [raw]
# # observed data and observation points
# dobs = data['upward']
# xp = data['x']
# yp = data['y']
# zp = data['z']
# N = data['x'].size

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 15 # number of vertices per prism
L = 10 # number of prisms
P = L*(M+2) + 1 # number of parameters

# magnetization
incs = model['inc']
decs = model['dec']
intensity = model['intensity']

# depth to the top, thickness and radius
z0 = model['z0']
dz = 800.
r = 650.

# total magnetization
props = {'magnetization': utils.ang2vec(
        intensity, incs, decs)}
rin = np.zeros(M) + r
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) 
m0 = np.hstack((m0, dz)) # inicial parameters vector
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms

varz = 100.
varint = 3.
varinc = 15.
vardec = 15.

param_list = mfun.varying_param(z0, varz, intensity,
                                 varint, incs, varinc, decs, vardec)

# main field
inc, dec = [-21.5, -18.7]

# predict data
d0 = polyprism.tf(xp, yp, zp, model0, inc, dec)

# %%
param_list[0]
# Out:
# [-300.0, {'magnetization': array([ 7.61848593,  1.20664963, -9.19253332])}]

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 100.
rmax = 2000.
x0min = -1500.
x0max = 1500.
y0min = -1500.
y0max = 1500.
dzmin = 200.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Variation

# %%
# variation for derivatives
deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)
deltaz = 0.01*np.max(dzmax)

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Folder to save the results

# %%
mypath = 'data/real_obs_pts/tfa_inversion/multiple_inc%d_dec%d_r%d_int%d_z0%d_dz%d_varz%d_varint%d_varinc%d_vardec%d' % (incs, decs, rin[0], np.linalg.norm(props['magnetization']), z0, dz, varz, varint, varinc, vardec)
if not os.path.isdir(mypath):
   os.makedirs(mypath)

# %% [raw]
# mypath = data_dir[:-11]+'upward_tfa_inversion/inc%d_dec%d_r%d_int%d_z0%d_dz%d' % (incs, decs, rin[0], np.linalg.norm(props['magnetization']), z0, dz)
# if not os.path.isdir(mypath):
#     os.makedirs(mypath)

# %%
# output of inversion
inversion = dict()

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.00
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.00007  # adjacent radial distances within each prism
a2 = 0.0001   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.008     # vertically adjacent origins
a6 = 0.0000001   # zero order Tikhonov on adjacent radial distances
a7 = 0.0005     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %%
itmax = 100
itmax_marq = 10
tol = 1.0e-4     # stop criterion

# %%
inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs

# %%
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['initial_estimate'] = model0
inversion['initial_data'] = d0
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = alpha
inversion['tol'] = tol
inversion['main_field'] = [-21.5, -18.7]
inversion['var'] = [varz, varint, varinc, vardec]

# %% [markdown]
# ### Inversion

# %%
inversion_results = []
for p in param_list:
    d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.levmarq_tf(
        xp, yp, zp, m0, M, L, delta,
        itmax, itmax_marq, lamb,
        dlamb, tol, mmin, mmax,
        m_out, dobs, inc, dec,
        p[1], alpha, p[0], dz
    )
    inversion_results.append([d_fit, m_est, model_est, phi_list, model_list, dobs - d_fit, res_list])
# Out:
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 8.78336e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 7.42846e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.34101e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.13862e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.26894e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.56664e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 3.55923e+04
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 3.32143e+04
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 2.45056e+04
# it:  5   it_marq:  4   lambda: 1e+02   misfit: 7.11591e+03
# it:  5   it_marq:  5   lambda: 1e+03   misfit: 2.23498e+03
# it:  6   it_marq:  0   lambda: 1e+02   misfit: 7.02757e+03
# it:  6   it_marq:  1   lambda: 1e+03   misfit: 2.20158e+03
# it:  7   it_marq:  0   lambda: 1e+02   misfit: 6.70776e+03
# it:  7   it_marq:  1   lambda: 1e+03   misfit: 2.16971e+03
# it:  8   it_marq:  0   lambda: 1e+02   misfit: 6.61333e+03
# it:  8   it_marq:  1   lambda: 1e+03   misfit: 2.13933e+03
# it:  9   it_marq:  0   lambda: 1e+02   misfit: 6.50677e+03
# it:  9   it_marq:  1   lambda: 1e+03   misfit: 2.11028e+03
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 6.42314e+03
# it: 10   it_marq:  1   lambda: 1e+03   misfit: 2.08255e+03
# it: 11   it_marq:  0   lambda: 1e+02   misfit: 6.34399e+03
# it: 11   it_marq:  1   lambda: 1e+03   misfit: 2.05599e+03
# it: 12   it_marq:  0   lambda: 1e+02   misfit: 5.43456e+03
# it: 12   it_marq:  1   lambda: 1e+03   misfit: 2.03059e+03
# it: 13   it_marq:  0   lambda: 1e+02   misfit: 2.93658e+03
# it: 13   it_marq:  1   lambda: 1e+03   misfit: 2.00623e+03
# it: 14   it_marq:  0   lambda: 1e+02   misfit: 2.22469e+03
# it: 14   it_marq:  1   lambda: 1e+03   misfit: 1.98289e+03
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 2.06310e+03
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 1.96047e+03
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 1.91332e+03
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 1.24539e+03
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 2.91263e+03
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 9.98753e+02
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 2.85451e+03
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 2.82843e+03
# it: 19   it_marq:  2   lambda: 1e+02   misfit: 9.79078e+02
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 2.80268e+03
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 9.60648e+02
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 2.77982e+03
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 9.43349e+02
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 2.43896e+03
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 9.27013e+02
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 8.90716e+02
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 4.64900e+02
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 2.03843e+03
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 3.41889e+02
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 1.26995e+03
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 2.83249e+02
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 6.21030e+02
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 2.67338e+02
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 5.28628e+02
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 3.01235e+02
# it: 28   it_marq:  2   lambda: 1e+01   misfit: 2.64079e+02
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 2.99183e+02
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 2.61343e+02
# it: 30   it_marq:  0   lambda: 1e+00   misfit: 2.42182e+02
# it: 31   it_marq:  0   lambda: 1e-01   misfit: 2.47324e+02
# it: 31   it_marq:  1   lambda: 1e+00   misfit: 2.29431e+02
# it: 32   it_marq:  0   lambda: 1e-01   misfit: 2.42307e+02
# it: 32   it_marq:  1   lambda: 1e+00   misfit: 2.20233e+02
# it: 33   it_marq:  0   lambda: 1e-01   misfit: 2.38668e+02
# it: 33   it_marq:  1   lambda: 1e+00   misfit: 2.31190e+02
# it: 33   it_marq:  2   lambda: 1e+01   misfit: 2.19313e+02
# it: 34   it_marq:  0   lambda: 1e+00   misfit: 2.12826e+02
# it: 35   it_marq:  0   lambda: 1e-01   misfit: 2.35965e+02
# it: 35   it_marq:  1   lambda: 1e+00   misfit: 2.07759e+02
# it: 36   it_marq:  0   lambda: 1e-01   misfit: 2.11335e+02
# it: 36   it_marq:  1   lambda: 1e+00   misfit: 2.03890e+02
# it: 37   it_marq:  0   lambda: 1e-01   misfit: 2.09992e+02
# it: 37   it_marq:  1   lambda: 1e+00   misfit: 2.00816e+02
# it: 38   it_marq:  0   lambda: 1e-01   misfit: 1.89690e+02
# it: 39   it_marq:  0   lambda: 1e-02   misfit: 1.78099e+02
# it: 40   it_marq:  0   lambda: 1e-03   misfit: 3.72851e+02
# it: 40   it_marq:  1   lambda: 1e-02   misfit: 3.07145e+02
# it: 40   it_marq:  2   lambda: 1e-01   misfit: 3.99075e+02
# it: 40   it_marq:  3   lambda: 1e+00   misfit: 3.83209e+02
# it: 40   it_marq:  4   lambda: 1e+01   misfit: 3.78013e+02
# it: 40   it_marq:  5   lambda: 1e+02   misfit: 3.41487e+02
# it: 40   it_marq:  6   lambda: 1e+03   misfit: 1.77389e+02
# it: 41   it_marq:  0   lambda: 1e+02   misfit: 1.74890e+02
# it: 42   it_marq:  0   lambda: 1e+01   misfit: 1.68980e+02
# it: 43   it_marq:  0   lambda: 1e+00   misfit: 1.64560e+02
# it: 44   it_marq:  0   lambda: 1e-01   misfit: 1.64708e+02
# it: 44   it_marq:  1   lambda: 1e+00   misfit: 1.63287e+02
# it: 45   it_marq:  0   lambda: 1e-01   misfit: 1.63992e+02
# it: 45   it_marq:  1   lambda: 1e+00   misfit: 1.62558e+02
# it: 46   it_marq:  0   lambda: 1e-01   misfit: 1.63424e+02
# it: 46   it_marq:  1   lambda: 1e+00   misfit: 1.62003e+02
# it: 47   it_marq:  0   lambda: 1e-01   misfit: 1.62937e+02
# it: 47   it_marq:  1   lambda: 1e+00   misfit: 1.61532e+02
# it: 48   it_marq:  0   lambda: 1e-01   misfit: 1.62503e+02
# it: 48   it_marq:  1   lambda: 1e+00   misfit: 1.61114e+02
# it: 49   it_marq:  0   lambda: 1e-01   misfit: 1.62107e+02
# it: 49   it_marq:  1   lambda: 1e+00   misfit: 1.60731e+02
# it: 50   it_marq:  0   lambda: 1e-01   misfit: 1.61740e+02
# it: 50   it_marq:  1   lambda: 1e+00   misfit: 1.60376e+02
# it: 51   it_marq:  0   lambda: 1e-01   misfit: 1.61398e+02
# it: 51   it_marq:  1   lambda: 1e+00   misfit: 1.60043e+02
# it: 52   it_marq:  0   lambda: 1e-01   misfit: 1.61076e+02
# it: 52   it_marq:  1   lambda: 1e+00   misfit: 1.59728e+02
# it: 53   it_marq:  0   lambda: 1e-01   misfit: 1.60771e+02
# it: 53   it_marq:  1   lambda: 1e+00   misfit: 1.59428e+02
# it: 54   it_marq:  0   lambda: 1e-01   misfit: 1.60481e+02
# it: 54   it_marq:  1   lambda: 1e+00   misfit: 1.59142e+02
# it: 55   it_marq:  0   lambda: 1e-01   misfit: 1.60204e+02
# it: 55   it_marq:  1   lambda: 1e+00   misfit: 1.58867e+02
# it: 56   it_marq:  0   lambda: 1e-01   misfit: 1.59937e+02
# it: 56   it_marq:  1   lambda: 1e+00   misfit: 1.58602e+02
# it: 57   it_marq:  0   lambda: 1e-01   misfit: 1.59681e+02
# it: 57   it_marq:  1   lambda: 1e+00   misfit: 1.58343e+02
# it: 58   it_marq:  0   lambda: 1e-01   misfit: 1.59437e+02
# it: 58   it_marq:  1   lambda: 1e+00   misfit: 1.58093e+02
# it: 59   it_marq:  0   lambda: 1e-01   misfit: 1.59202e+02
# it: 59   it_marq:  1   lambda: 1e+00   misfit: 1.57849e+02
# it: 60   it_marq:  0   lambda: 1e-01   misfit: 1.58978e+02
# it: 60   it_marq:  1   lambda: 1e+00   misfit: 1.57614e+02
# it: 61   it_marq:  0   lambda: 1e-01   misfit: 1.58762e+02
# it: 61   it_marq:  1   lambda: 1e+00   misfit: 1.57388e+02
# it: 62   it_marq:  0   lambda: 1e-01   misfit: 1.58555e+02
# it: 62   it_marq:  1   lambda: 1e+00   misfit: 1.57170e+02
# it: 63   it_marq:  0   lambda: 1e-01   misfit: 1.58355e+02
# it: 63   it_marq:  1   lambda: 1e+00   misfit: 1.56959e+02
# it: 64   it_marq:  0   lambda: 1e-01   misfit: 1.58162e+02
# it: 64   it_marq:  1   lambda: 1e+00   misfit: 1.56755e+02
# it: 65   it_marq:  0   lambda: 1e-01   misfit: 1.57975e+02
# it: 65   it_marq:  1   lambda: 1e+00   misfit: 1.56557e+02
# it: 66   it_marq:  0   lambda: 1e-01   misfit: 1.57794e+02
# it: 66   it_marq:  1   lambda: 1e+00   misfit: 1.56366e+02
# it: 67   it_marq:  0   lambda: 1e-01   misfit: 1.57619e+02
# it: 67   it_marq:  1   lambda: 1e+00   misfit: 1.56179e+02
# it: 68   it_marq:  0   lambda: 1e-01   misfit: 1.57450e+02
# it: 68   it_marq:  1   lambda: 1e+00   misfit: 1.55999e+02
# it: 69   it_marq:  0   lambda: 1e-01   misfit: 1.57286e+02
# it: 69   it_marq:  1   lambda: 1e+00   misfit: 1.55823e+02
# it: 70   it_marq:  0   lambda: 1e-01   misfit: 1.57127e+02
# it: 70   it_marq:  1   lambda: 1e+00   misfit: 1.55653e+02
# it: 71   it_marq:  0   lambda: 1e-01   misfit: 1.56972e+02
# it: 71   it_marq:  1   lambda: 1e+00   misfit: 1.55487e+02
# it: 72   it_marq:  0   lambda: 1e-01   misfit: 1.56819e+02
# it: 72   it_marq:  1   lambda: 1e+00   misfit: 1.55326e+02
# it: 73   it_marq:  0   lambda: 1e-01   misfit: 1.56722e+02
# it: 73   it_marq:  1   lambda: 1e+00   misfit: 1.55169e+02
# it: 74   it_marq:  0   lambda: 1e-01   misfit: 1.73691e+02
# it: 74   it_marq:  1   lambda: 1e+00   misfit: 1.55016e+02
# it: 75   it_marq:  0   lambda: 1e-01   misfit: 1.65758e+02
# it: 75   it_marq:  1   lambda: 1e+00   misfit: 1.54868e+02
# it: 76   it_marq:  0   lambda: 1e-01   misfit: 1.73402e+02
# it: 76   it_marq:  1   lambda: 1e+00   misfit: 1.54723e+02
# it: 77   it_marq:  0   lambda: 1e-01   misfit: 1.68767e+02
# it: 77   it_marq:  1   lambda: 1e+00   misfit: 1.54583e+02
# it: 78   it_marq:  0   lambda: 1e-01   misfit: 1.73125e+02
# it: 78   it_marq:  1   lambda: 1e+00   misfit: 1.54446e+02
# it: 79   it_marq:  0   lambda: 1e-01   misfit: 1.70719e+02
# it: 79   it_marq:  1   lambda: 1e+00   misfit: 1.54312e+02
# it: 80   it_marq:  0   lambda: 1e-01   misfit: 1.72858e+02
# it: 80   it_marq:  1   lambda: 1e+00   misfit: 1.54182e+02
# it: 81   it_marq:  0   lambda: 1e-01   misfit: 1.71670e+02
# it: 81   it_marq:  1   lambda: 1e+00   misfit: 1.54055e+02
# it: 82   it_marq:  0   lambda: 1e-01   misfit: 1.72598e+02
# it: 82   it_marq:  1   lambda: 1e+00   misfit: 1.53931e+02
# it: 83   it_marq:  0   lambda: 1e-01   misfit: 1.71990e+02
# it: 83   it_marq:  1   lambda: 1e+00   misfit: 1.53808e+02
# it: 84   it_marq:  0   lambda: 1e-01   misfit: 1.72336e+02
# it: 84   it_marq:  1   lambda: 1e+00   misfit: 1.53687e+02
# it: 85   it_marq:  0   lambda: 1e-01   misfit: 1.71976e+02
# it: 85   it_marq:  1   lambda: 1e+00   misfit: 1.53563e+02
# it: 86   it_marq:  0   lambda: 1e-01   misfit: 1.72077e+02
# it: 86   it_marq:  1   lambda: 1e+00   misfit: 1.53437e+02
# it: 87   it_marq:  0   lambda: 1e-01   misfit: 1.71805e+02
# it: 87   it_marq:  1   lambda: 1e+00   misfit: 1.53314e+02
# it: 88   it_marq:  0   lambda: 1e-01   misfit: 1.71834e+02
# it: 88   it_marq:  1   lambda: 1e+00   misfit: 1.53195e+02
# it: 89   it_marq:  0   lambda: 1e-01   misfit: 1.71716e+02
# it: 89   it_marq:  1   lambda: 1e+00   misfit: 1.53079e+02
# it: 90   it_marq:  0   lambda: 1e-01   misfit: 1.70870e+02
# it: 90   it_marq:  1   lambda: 1e+00   misfit: 1.52966e+02
# it: 91   it_marq:  0   lambda: 1e-01   misfit: 2.06645e+02
# it: 91   it_marq:  1   lambda: 1e+00   misfit: 1.52856e+02
# it: 92   it_marq:  0   lambda: 1e-01   misfit: 1.71378e+02
# it: 92   it_marq:  1   lambda: 1e+00   misfit: 1.52748e+02
# it: 93   it_marq:  0   lambda: 1e-01   misfit: 2.06550e+02
# it: 93   it_marq:  1   lambda: 1e+00   misfit: 1.52643e+02
# it: 94   it_marq:  0   lambda: 1e-01   misfit: 2.06539e+02
# it: 94   it_marq:  1   lambda: 1e+00   misfit: 1.52541e+02
# it: 95   it_marq:  0   lambda: 1e-01   misfit: 1.71042e+02
# it: 95   it_marq:  1   lambda: 1e+00   misfit: 1.52441e+02
# it: 96   it_marq:  0   lambda: 1e-01   misfit: 2.06482e+02
# it: 96   it_marq:  1   lambda: 1e+00   misfit: 1.52344e+02
# it: 97   it_marq:  0   lambda: 1e-01   misfit: 2.06458e+02
# it: 97   it_marq:  1   lambda: 1e+00   misfit: 1.52248e+02
# it: 98   it_marq:  0   lambda: 1e-01   misfit: 1.70634e+02
# it: 98   it_marq:  1   lambda: 1e+00   misfit: 1.52156e+02
# it: 99   it_marq:  0   lambda: 1e-01   misfit: 2.06420e+02
# it: 99   it_marq:  1   lambda: 1e+00   misfit: 1.52065e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 8.08957e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 6.54229e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.57740e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 7.71625e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.59156e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 5.14811e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 1.19894e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.89881e+03
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 2.34793e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 4.83794e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.50160e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 5.59687e+03
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 4.79809e+03
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 7.83632e+03
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 1.26636e+04
# it:  8   it_marq:  2   lambda: 1e+02   misfit: 1.13611e+04
# it:  8   it_marq:  3   lambda: 1e+03   misfit: 9.21601e+03
# it:  8   it_marq:  4   lambda: 1e+04   misfit: 4.74900e+03
# it:  9   it_marq:  0   lambda: 1e+03   misfit: 4.73436e+03
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 4.71085e+03
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 4.57224e+03
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 5.19162e+03
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 4.57520e+03
# it: 12   it_marq:  2   lambda: 1e+02   misfit: 4.56538e+03
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 4.58474e+03
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 4.58721e+03
# it: 13   it_marq:  2   lambda: 1e+03   misfit: 4.58544e+03
# it: 13   it_marq:  3   lambda: 1e+04   misfit: 4.57767e+03
# it: 13   it_marq:  4   lambda: 1e+05   misfit: 4.57785e+03
# it: 13   it_marq:  5   lambda: 1e+06   misfit: 4.57786e+03
# it: 13   it_marq:  6   lambda: 1e+07   misfit: 4.57786e+03
# it: 13   it_marq:  7   lambda: 1e+08   misfit: 4.57786e+03
# it: 13   it_marq:  8   lambda: 1e+09   misfit: 4.57786e+03
# it: 13   it_marq:  9   lambda: 1e+10   misfit: 4.57786e+03
# it: 14   it_marq:  0   lambda: 1e+11   misfit: 4.57783e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.22954e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.10669e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.68986e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.85954e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.56463e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 5.94831e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 3.82757e+04
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 2.23049e+04
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 1.32223e+04
# it:  7   it_marq:  0   lambda: 1e-02   misfit: 1.65692e+04
# it:  7   it_marq:  1   lambda: 1e-01   misfit: 1.01260e+04
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 4.66975e+04
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 8.89979e+04
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 7.06311e+04
# it:  8   it_marq:  3   lambda: 1e+01   misfit: 2.67290e+04
# it:  8   it_marq:  4   lambda: 1e+02   misfit: 1.99031e+04
# it:  8   it_marq:  5   lambda: 1e+03   misfit: 7.50780e+03
# it:  9   it_marq:  0   lambda: 1e+02   misfit: 1.21966e+05
# it:  9   it_marq:  1   lambda: 1e+03   misfit: 8.53963e+04
# it:  9   it_marq:  2   lambda: 1e+04   misfit: 6.32606e+04
# it:  9   it_marq:  3   lambda: 1e+05   misfit: 6.43590e+04
# it:  9   it_marq:  4   lambda: 1e+06   misfit: 2.13070e+04
# it:  9   it_marq:  5   lambda: 1e+07   misfit: 1.11330e+04
# it:  9   it_marq:  6   lambda: 1e+08   misfit: 1.11327e+04
# it:  9   it_marq:  7   lambda: 1e+09   misfit: 7.38184e+03
# it: 10   it_marq:  0   lambda: 1e+08   misfit: 7.38124e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.05663e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.21700e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 4.72450e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.21422e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 9.36246e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 6.07672e+03
# it:  6   it_marq:  0   lambda: 1e-03   misfit: 2.47875e+04
# it:  6   it_marq:  1   lambda: 1e-02   misfit: 1.40106e+04
# it:  6   it_marq:  2   lambda: 1e-01   misfit: 2.44975e+03
# it:  7   it_marq:  0   lambda: 1e-02   misfit: 1.29429e+04
# it:  7   it_marq:  1   lambda: 1e-01   misfit: 2.46727e+03
# it:  7   it_marq:  2   lambda: 1e+00   misfit: 1.68629e+03
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 3.29703e+03
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.50706e+03
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 5.97854e+03
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.43996e+03
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 8.32773e+03
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.39551e+03
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.11291e+04
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.34661e+03
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.47963e+04
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.29671e+03
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 2.59352e+04
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.24728e+03
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 3.18628e+04
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.56598e+03
# it: 14   it_marq:  2   lambda: 1e+01   misfit: 1.17674e+03
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 3.22066e+03
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.14579e+03
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 3.83244e+03
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.12940e+03
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 9.29988e+03
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.11956e+03
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 1.03051e+04
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 1.11275e+03
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.03182e+04
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 1.10765e+03
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 1.02076e+04
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 1.10360e+03
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 9.95778e+03
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 1.10023e+03
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 9.15936e+03
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 1.09728e+03
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 1.00228e+04
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 1.09461e+03
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 8.75018e+03
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 1.09212e+03
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 9.92729e+03
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 1.08974e+03
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 8.67350e+03
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 1.08742e+03
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 8.63582e+03
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 1.08513e+03
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 8.62493e+03
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 1.08284e+03
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 8.50695e+03
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 1.08054e+03
# it: 30   it_marq:  0   lambda: 1e+00   misfit: 8.60252e+03
# it: 30   it_marq:  1   lambda: 1e+01   misfit: 1.07823e+03
# it: 31   it_marq:  0   lambda: 1e+00   misfit: 8.24778e+03
# it: 31   it_marq:  1   lambda: 1e+01   misfit: 1.07589e+03
# it: 32   it_marq:  0   lambda: 1e+00   misfit: 1.08245e+04
# it: 32   it_marq:  1   lambda: 1e+01   misfit: 1.07352e+03
# it: 33   it_marq:  0   lambda: 1e+00   misfit: 1.08215e+04
# it: 33   it_marq:  1   lambda: 1e+01   misfit: 1.07112e+03
# it: 34   it_marq:  0   lambda: 1e+00   misfit: 1.14498e+04
# it: 34   it_marq:  1   lambda: 1e+01   misfit: 1.06868e+03
# it: 35   it_marq:  0   lambda: 1e+00   misfit: 1.08649e+04
# it: 35   it_marq:  1   lambda: 1e+01   misfit: 1.06620e+03
# it: 36   it_marq:  0   lambda: 1e+00   misfit: 1.15159e+04
# it: 36   it_marq:  1   lambda: 1e+01   misfit: 1.06369e+03
# it: 37   it_marq:  0   lambda: 1e+00   misfit: 1.11205e+04
# it: 37   it_marq:  1   lambda: 1e+01   misfit: 1.06114e+03
# it: 38   it_marq:  0   lambda: 1e+00   misfit: 1.15775e+04
# it: 38   it_marq:  1   lambda: 1e+01   misfit: 1.10308e+03
# it: 38   it_marq:  2   lambda: 1e+02   misfit: 1.06076e+03
# it: 39   it_marq:  0   lambda: 1e+01   misfit: 1.11443e+03
# it: 39   it_marq:  1   lambda: 1e+02   misfit: 1.06056e+03
# it: 40   it_marq:  0   lambda: 1e+01   misfit: 1.20389e+03
# it: 40   it_marq:  1   lambda: 1e+02   misfit: 1.06031e+03
# it: 41   it_marq:  0   lambda: 1e+01   misfit: 2.68609e+03
# it: 41   it_marq:  1   lambda: 1e+02   misfit: 1.06016e+03
# it: 42   it_marq:  0   lambda: 1e+01   misfit: 1.20807e+03
# it: 42   it_marq:  1   lambda: 1e+02   misfit: 1.05995e+03
# it: 43   it_marq:  0   lambda: 1e+01   misfit: 2.67902e+03
# it: 43   it_marq:  1   lambda: 1e+02   misfit: 1.05982e+03
# it: 44   it_marq:  0   lambda: 1e+01   misfit: 2.60135e+03
# it: 44   it_marq:  1   lambda: 1e+02   misfit: 1.05963e+03
# it: 45   it_marq:  0   lambda: 1e+01   misfit: 2.67140e+03
# it: 45   it_marq:  1   lambda: 1e+02   misfit: 1.05951e+03
# it: 46   it_marq:  0   lambda: 1e+01   misfit: 2.66798e+03
# it: 46   it_marq:  1   lambda: 1e+02   misfit: 1.05933e+03
# it: 47   it_marq:  0   lambda: 1e+01   misfit: 2.66569e+03
# it: 47   it_marq:  1   lambda: 1e+02   misfit: 1.05921e+03
# it: 48   it_marq:  0   lambda: 1e+01   misfit: 6.26238e+03
# it: 48   it_marq:  1   lambda: 1e+02   misfit: 1.05904e+03
# it: 49   it_marq:  0   lambda: 1e+01   misfit: 2.67380e+03
# it: 49   it_marq:  1   lambda: 1e+02   misfit: 1.05892e+03
# it: 50   it_marq:  0   lambda: 1e+01   misfit: 6.25427e+03
# it: 50   it_marq:  1   lambda: 1e+02   misfit: 1.05874e+03
# it: 51   it_marq:  0   lambda: 1e+01   misfit: 2.83544e+03
# it: 51   it_marq:  1   lambda: 1e+02   misfit: 1.05862e+03
# it: 52   it_marq:  0   lambda: 1e+01   misfit: 6.24963e+03
# it: 52   it_marq:  1   lambda: 1e+02   misfit: 1.05845e+03
# it: 53   it_marq:  0   lambda: 1e+01   misfit: 3.86912e+03
# it: 53   it_marq:  1   lambda: 1e+02   misfit: 1.05832e+03
# it: 54   it_marq:  0   lambda: 1e+01   misfit: 6.25265e+03
# it: 54   it_marq:  1   lambda: 1e+02   misfit: 1.05814e+03
# it: 55   it_marq:  0   lambda: 1e+01   misfit: 5.48379e+03
# it: 55   it_marq:  1   lambda: 1e+02   misfit: 1.05801e+03
# it: 56   it_marq:  0   lambda: 1e+01   misfit: 6.30266e+03
# it: 56   it_marq:  1   lambda: 1e+02   misfit: 1.05783e+03
# it: 57   it_marq:  0   lambda: 1e+01   misfit: 6.29516e+03
# it: 57   it_marq:  1   lambda: 1e+02   misfit: 1.05769e+03
# it: 58   it_marq:  0   lambda: 1e+01   misfit: 7.32969e+03
# it: 58   it_marq:  1   lambda: 1e+02   misfit: 1.05750e+03
# it: 59   it_marq:  0   lambda: 1e+01   misfit: 7.88253e+03
# it: 59   it_marq:  1   lambda: 1e+02   misfit: 1.05737e+03
# it: 60   it_marq:  0   lambda: 1e+01   misfit: 7.93841e+03
# it: 60   it_marq:  1   lambda: 1e+02   misfit: 1.05718e+03
# it: 61   it_marq:  0   lambda: 1e+01   misfit: 7.92195e+03
# it: 61   it_marq:  1   lambda: 1e+02   misfit: 1.05703e+03
# it: 62   it_marq:  0   lambda: 1e+01   misfit: 7.93417e+03
# it: 62   it_marq:  1   lambda: 1e+02   misfit: 1.05684e+03
# it: 63   it_marq:  0   lambda: 1e+01   misfit: 7.92814e+03
# it: 63   it_marq:  1   lambda: 1e+02   misfit: 1.05669e+03
# it: 64   it_marq:  0   lambda: 1e+01   misfit: 7.93079e+03
# it: 64   it_marq:  1   lambda: 1e+02   misfit: 1.05649e+03
# it: 65   it_marq:  0   lambda: 1e+01   misfit: 7.92793e+03
# it: 65   it_marq:  1   lambda: 1e+02   misfit: 1.05634e+03
# it: 66   it_marq:  0   lambda: 1e+01   misfit: 7.92768e+03
# it: 66   it_marq:  1   lambda: 1e+02   misfit: 1.05614e+03
# it: 67   it_marq:  0   lambda: 1e+01   misfit: 7.92633e+03
# it: 67   it_marq:  1   lambda: 1e+02   misfit: 1.05598e+03
# it: 68   it_marq:  0   lambda: 1e+01   misfit: 7.92489e+03
# it: 68   it_marq:  1   lambda: 1e+02   misfit: 1.05578e+03
# it: 69   it_marq:  0   lambda: 1e+01   misfit: 9.26283e+03
# it: 69   it_marq:  1   lambda: 1e+02   misfit: 1.05562e+03
# it: 70   it_marq:  0   lambda: 1e+01   misfit: 7.92285e+03
# it: 70   it_marq:  1   lambda: 1e+02   misfit: 1.05542e+03
# it: 71   it_marq:  0   lambda: 1e+01   misfit: 7.92241e+03
# it: 71   it_marq:  1   lambda: 1e+02   misfit: 1.05525e+03
# it: 72   it_marq:  0   lambda: 1e+01   misfit: 7.92100e+03
# it: 72   it_marq:  1   lambda: 1e+02   misfit: 1.05504e+03
# it: 73   it_marq:  0   lambda: 1e+01   misfit: 7.92087e+03
# it: 73   it_marq:  1   lambda: 1e+02   misfit: 1.05488e+03
# it: 74   it_marq:  0   lambda: 1e+01   misfit: 7.91952e+03
# it: 74   it_marq:  1   lambda: 1e+02   misfit: 1.05467e+03
# it: 75   it_marq:  0   lambda: 1e+01   misfit: 7.91959e+03
# it: 75   it_marq:  1   lambda: 1e+02   misfit: 1.05450e+03
# it: 76   it_marq:  0   lambda: 1e+01   misfit: 7.91826e+03
# it: 76   it_marq:  1   lambda: 1e+02   misfit: 1.05428e+03
# it: 77   it_marq:  0   lambda: 1e+01   misfit: 7.91846e+03
# it: 77   it_marq:  1   lambda: 1e+02   misfit: 1.05411e+03
# it: 78   it_marq:  0   lambda: 1e+01   misfit: 7.91741e+03
# it: 78   it_marq:  1   lambda: 1e+02   misfit: 1.05389e+03
# it: 79   it_marq:  0   lambda: 1e+01   misfit: 7.91767e+03
# it: 79   it_marq:  1   lambda: 1e+02   misfit: 1.05372e+03
# it: 80   it_marq:  0   lambda: 1e+01   misfit: 7.91656e+03
# it: 80   it_marq:  1   lambda: 1e+02   misfit: 1.05350e+03
# it: 81   it_marq:  0   lambda: 1e+01   misfit: 7.91709e+03
# it: 81   it_marq:  1   lambda: 1e+02   misfit: 1.05332e+03
# it: 82   it_marq:  0   lambda: 1e+01   misfit: 7.91607e+03
# it: 82   it_marq:  1   lambda: 1e+02   misfit: 1.05310e+03
# it: 83   it_marq:  0   lambda: 1e+01   misfit: 7.91671e+03
# it: 83   it_marq:  1   lambda: 1e+02   misfit: 1.05291e+03
# it: 84   it_marq:  0   lambda: 1e+01   misfit: 7.91581e+03
# it: 84   it_marq:  1   lambda: 1e+02   misfit: 1.05269e+03
# it: 85   it_marq:  0   lambda: 1e+01   misfit: 7.91644e+03
# it: 85   it_marq:  1   lambda: 1e+02   misfit: 1.05251e+03
# it: 86   it_marq:  0   lambda: 1e+01   misfit: 7.91560e+03
# it: 86   it_marq:  1   lambda: 1e+02   misfit: 1.05228e+03
# it: 87   it_marq:  0   lambda: 1e+01   misfit: 7.91644e+03
# it: 87   it_marq:  1   lambda: 1e+02   misfit: 1.05209e+03
# it: 88   it_marq:  0   lambda: 1e+01   misfit: 7.91568e+03
# it: 88   it_marq:  1   lambda: 1e+02   misfit: 1.05186e+03
# it: 89   it_marq:  0   lambda: 1e+01   misfit: 7.91657e+03
# it: 89   it_marq:  1   lambda: 1e+02   misfit: 1.05167e+03
# it: 90   it_marq:  0   lambda: 1e+01   misfit: 7.91591e+03
# it: 90   it_marq:  1   lambda: 1e+02   misfit: 1.05144e+03
# it: 91   it_marq:  0   lambda: 1e+01   misfit: 7.91678e+03
# it: 91   it_marq:  1   lambda: 1e+02   misfit: 1.05125e+03
# it: 92   it_marq:  0   lambda: 1e+01   misfit: 7.91624e+03
# it: 92   it_marq:  1   lambda: 1e+02   misfit: 1.05102e+03
# it: 93   it_marq:  0   lambda: 1e+01   misfit: 7.91722e+03
# it: 93   it_marq:  1   lambda: 1e+02   misfit: 1.05082e+03
# it: 94   it_marq:  0   lambda: 1e+01   misfit: 7.91672e+03
# it: 94   it_marq:  1   lambda: 1e+02   misfit: 1.05059e+03
# it: 95   it_marq:  0   lambda: 1e+01   misfit: 7.91772e+03
# it: 95   it_marq:  1   lambda: 1e+02   misfit: 1.05039e+03
# it: 96   it_marq:  0   lambda: 1e+01   misfit: 7.91739e+03
# it: 96   it_marq:  1   lambda: 1e+02   misfit: 1.05015e+03
# it: 97   it_marq:  0   lambda: 1e+01   misfit: 7.91846e+03
# it: 97   it_marq:  1   lambda: 1e+02   misfit: 1.04995e+03
# it: 98   it_marq:  0   lambda: 1e+01   misfit: 7.91808e+03
# it: 98   it_marq:  1   lambda: 1e+02   misfit: 1.04971e+03
# it: 99   it_marq:  0   lambda: 1e+01   misfit: 7.91925e+03
# it: 99   it_marq:  1   lambda: 1e+02   misfit: 1.04951e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 9.01926e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 7.09211e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.16852e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 9.61025e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.21453e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 6.63769e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 8.78110e+03
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.44121e+03
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 1.28042e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 4.16419e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.05214e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 4.16685e+03
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 3.87786e+03
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 4.14576e+03
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 3.82549e+03
# it:  9   it_marq:  0   lambda: 1e+00   misfit: 4.12465e+03
# it:  9   it_marq:  1   lambda: 1e+01   misfit: 3.80093e+03
# it: 10   it_marq:  0   lambda: 1e+00   misfit: 4.10835e+03
# it: 10   it_marq:  1   lambda: 1e+01   misfit: 3.78547e+03
# it: 11   it_marq:  0   lambda: 1e+00   misfit: 4.09585e+03
# it: 11   it_marq:  1   lambda: 1e+01   misfit: 3.77422e+03
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 4.08449e+03
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 3.76526e+03
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 4.07107e+03
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 3.75767e+03
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 4.05287e+03
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 3.75091e+03
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 4.02930e+03
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 3.74460e+03
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 4.00352e+03
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 3.73840e+03
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 3.98193e+03
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 3.73209e+03
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 3.96991e+03
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 3.72561e+03
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 3.96691e+03
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 3.71908e+03
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 3.96655e+03
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 3.71262e+03
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 3.96200e+03
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 3.70623e+03
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 3.95159e+03
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 3.69978e+03
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 3.93991e+03
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 3.69308e+03
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 3.93393e+03
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 3.68607e+03
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 3.93794e+03
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 3.67888e+03
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 3.95216e+03
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 3.67186e+03
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 3.97519e+03
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 3.66569e+03
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 4.00567e+03
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 3.66100e+03
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 4.04046e+03
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 3.65834e+03
# it: 30   it_marq:  0   lambda: 1e+00   misfit: 4.07601e+03
# it: 30   it_marq:  1   lambda: 1e+01   misfit: 3.65789e+03
# it: 31   it_marq:  0   lambda: 1e+00   misfit: 4.10988e+03
# it: 31   it_marq:  1   lambda: 1e+01   misfit: 3.66008e+03
# it: 31   it_marq:  2   lambda: 1e+02   misfit: 3.65436e+03
# it: 32   it_marq:  0   lambda: 1e+01   misfit: 3.65991e+03
# it: 32   it_marq:  1   lambda: 1e+02   misfit: 3.65265e+03
# it: 33   it_marq:  0   lambda: 1e+01   misfit: 3.65997e+03
# it: 33   it_marq:  1   lambda: 1e+02   misfit: 3.65183e+03
# it: 34   it_marq:  0   lambda: 1e+01   misfit: 3.66018e+03
# it: 34   it_marq:  1   lambda: 1e+02   misfit: 3.65149e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.15083e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 9.33062e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.69044e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.30612e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 3.73263e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.80369e+04
# it:  4   it_marq:  2   lambda: 1e+01   misfit: 1.31025e+04
# it:  4   it_marq:  3   lambda: 1e+02   misfit: 1.13769e+04
# it:  5   it_marq:  0   lambda: 1e+01   misfit: 2.04021e+04
# it:  5   it_marq:  1   lambda: 1e+02   misfit: 1.02161e+04
# it:  6   it_marq:  0   lambda: 1e+01   misfit: 2.00277e+04
# it:  6   it_marq:  1   lambda: 1e+02   misfit: 9.37176e+03
# it:  7   it_marq:  0   lambda: 1e+01   misfit: 1.99125e+04
# it:  7   it_marq:  1   lambda: 1e+02   misfit: 8.73016e+03
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.95980e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 1.14144e+04
# it:  8   it_marq:  2   lambda: 1e+03   misfit: 8.67105e+03
# it:  9   it_marq:  0   lambda: 1e+02   misfit: 1.35476e+04
# it:  9   it_marq:  1   lambda: 1e+03   misfit: 8.61346e+03
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 1.34680e+04
# it: 10   it_marq:  1   lambda: 1e+03   misfit: 8.55740e+03
# it: 11   it_marq:  0   lambda: 1e+02   misfit: 2.14390e+04
# it: 11   it_marq:  1   lambda: 1e+03   misfit: 8.50283e+03
# it: 12   it_marq:  0   lambda: 1e+02   misfit: 2.12983e+04
# it: 12   it_marq:  1   lambda: 1e+03   misfit: 8.44964e+03
# it: 13   it_marq:  0   lambda: 1e+02   misfit: 2.05704e+04
# it: 13   it_marq:  1   lambda: 1e+03   misfit: 8.39775e+03
# it: 14   it_marq:  0   lambda: 1e+02   misfit: 1.69114e+04
# it: 14   it_marq:  1   lambda: 1e+03   misfit: 8.34711e+03
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 1.43003e+04
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 8.29769e+03
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 1.34593e+04
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 8.24942e+03
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 1.31258e+04
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 8.20225e+03
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 1.29353e+04
# it: 18   it_marq:  1   lambda: 1e+03   misfit: 8.15614e+03
# it: 19   it_marq:  0   lambda: 1e+02   misfit: 1.22508e+04
# it: 19   it_marq:  1   lambda: 1e+03   misfit: 8.11106e+03
# it: 20   it_marq:  0   lambda: 1e+02   misfit: 9.99259e+03
# it: 20   it_marq:  1   lambda: 1e+03   misfit: 8.06695e+03
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 8.54271e+03
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 8.02380e+03
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 7.88439e+03
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 5.97999e+03
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 4.92596e+03
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 7.42035e+04
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 3.41010e+03
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 3.85440e+04
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 7.23444e+03
# it: 26   it_marq:  2   lambda: 1e+01   misfit: 3.27136e+03
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 6.76438e+04
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 5.24719e+04
# it: 27   it_marq:  2   lambda: 1e+02   misfit: 4.75136e+04
# it: 27   it_marq:  3   lambda: 1e+03   misfit: 1.47291e+04
# it: 27   it_marq:  4   lambda: 1e+04   misfit: 3.32636e+03
# it: 27   it_marq:  5   lambda: 1e+05   misfit: 3.30355e+03
# it: 27   it_marq:  6   lambda: 1e+06   misfit: 3.30304e+03
# it: 27   it_marq:  7   lambda: 1e+07   misfit: 3.29258e+03
# it: 27   it_marq:  8   lambda: 1e+08   misfit: 3.29242e+03
# it: 27   it_marq:  9   lambda: 1e+09   misfit: 3.29242e+03
# it: 28   it_marq:  0   lambda: 1e+10   misfit: 3.29240e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 6.94677e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 6.29108e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.46947e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.43801e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.80948e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 4.05554e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 3.34173e+04
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 3.62232e+04
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 2.06565e+04
# it:  5   it_marq:  4   lambda: 1e+02   misfit: 4.33806e+03
# it:  6   it_marq:  0   lambda: 1e+01   misfit: 2.23809e+04
# it:  6   it_marq:  1   lambda: 1e+02   misfit: 4.02182e+03
# it:  7   it_marq:  0   lambda: 1e+01   misfit: 3.73636e+04
# it:  7   it_marq:  1   lambda: 1e+02   misfit: 3.80328e+03
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 3.67739e+04
# it:  8   it_marq:  1   lambda: 1e+02   misfit: 3.64660e+03
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 3.62875e+04
# it:  9   it_marq:  1   lambda: 1e+02   misfit: 3.68758e+03
# it:  9   it_marq:  2   lambda: 1e+03   misfit: 3.63172e+03
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 3.51903e+03
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 2.83434e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 3.43127e+03
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 1.92701e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 3.35754e+03
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 1.90853e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 3.29562e+03
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 1.89002e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 4.21191e+03
# it: 14   it_marq:  2   lambda: 1e+03   misfit: 3.28958e+03
# it: 15   it_marq:  0   lambda: 1e+02   misfit: 4.20370e+03
# it: 15   it_marq:  1   lambda: 1e+03   misfit: 3.28375e+03
# it: 16   it_marq:  0   lambda: 1e+02   misfit: 4.19318e+03
# it: 16   it_marq:  1   lambda: 1e+03   misfit: 3.27792e+03
# it: 17   it_marq:  0   lambda: 1e+02   misfit: 4.18300e+03
# it: 17   it_marq:  1   lambda: 1e+03   misfit: 3.27228e+03
# it: 18   it_marq:  0   lambda: 1e+02   misfit: 3.22113e+03
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 4.30249e+03
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 3.17445e+03
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 3.15242e+03
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 1.81322e+03
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 3.03414e+03
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 1.29752e+03
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 1.41056e+03
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 1.07287e+03
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 1.05860e+03
# it: 25   it_marq:  0   lambda: 1e-02   misfit: 2.56668e+03
# it: 25   it_marq:  1   lambda: 1e-01   misfit: 1.77106e+03
# it: 25   it_marq:  2   lambda: 1e+00   misfit: 1.46987e+03
# it: 25   it_marq:  3   lambda: 1e+01   misfit: 8.47927e+02
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 1.47931e+03
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 1.27901e+03
# it: 26   it_marq:  2   lambda: 1e+02   misfit: 8.83655e+02
# it: 26   it_marq:  3   lambda: 1e+03   misfit: 8.46491e+02
# it: 27   it_marq:  0   lambda: 1e+02   misfit: 8.41135e+02
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.30690e+03
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 8.36493e+02
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.30427e+03
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 8.32514e+02
# it: 30   it_marq:  0   lambda: 1e+01   misfit: 1.29908e+03
# it: 30   it_marq:  1   lambda: 1e+02   misfit: 8.29049e+02
# it: 31   it_marq:  0   lambda: 1e+01   misfit: 1.29385e+03
# it: 31   it_marq:  1   lambda: 1e+02   misfit: 8.26002e+02
# it: 32   it_marq:  0   lambda: 1e+01   misfit: 1.28906e+03
# it: 32   it_marq:  1   lambda: 1e+02   misfit: 8.23311e+02
# it: 33   it_marq:  0   lambda: 1e+01   misfit: 1.28484e+03
# it: 33   it_marq:  1   lambda: 1e+02   misfit: 8.20917e+02
# it: 34   it_marq:  0   lambda: 1e+01   misfit: 1.28105e+03
# it: 34   it_marq:  1   lambda: 1e+02   misfit: 8.18762e+02
# it: 35   it_marq:  0   lambda: 1e+01   misfit: 1.27775e+03
# it: 35   it_marq:  1   lambda: 1e+02   misfit: 8.16815e+02
# it: 36   it_marq:  0   lambda: 1e+01   misfit: 1.27485e+03
# it: 36   it_marq:  1   lambda: 1e+02   misfit: 8.15047e+02
# it: 37   it_marq:  0   lambda: 1e+01   misfit: 1.27222e+03
# it: 37   it_marq:  1   lambda: 1e+02   misfit: 8.13430e+02
# it: 38   it_marq:  0   lambda: 1e+01   misfit: 1.24854e+03
# it: 38   it_marq:  1   lambda: 1e+02   misfit: 8.11946e+02
# it: 39   it_marq:  0   lambda: 1e+01   misfit: 9.61545e+02
# it: 39   it_marq:  1   lambda: 1e+02   misfit: 8.10575e+02
# it: 40   it_marq:  0   lambda: 1e+01   misfit: 8.14724e+02
# it: 40   it_marq:  1   lambda: 1e+02   misfit: 8.09304e+02
# it: 41   it_marq:  0   lambda: 1e+01   misfit: 8.02310e+02
# it: 42   it_marq:  0   lambda: 1e+00   misfit: 7.81023e+02
# it: 43   it_marq:  0   lambda: 1e-01   misfit: 7.97466e+02
# it: 43   it_marq:  1   lambda: 1e+00   misfit: 7.67481e+02
# it: 44   it_marq:  0   lambda: 1e-01   misfit: 8.04641e+02
# it: 44   it_marq:  1   lambda: 1e+00   misfit: 8.46752e+02
# it: 44   it_marq:  2   lambda: 1e+01   misfit: 7.65220e+02
# it: 45   it_marq:  0   lambda: 1e+00   misfit: 8.44977e+02
# it: 45   it_marq:  1   lambda: 1e+01   misfit: 7.64120e+02
# it: 46   it_marq:  0   lambda: 1e+00   misfit: 8.43397e+02
# it: 46   it_marq:  1   lambda: 1e+01   misfit: 7.63337e+02
# it: 47   it_marq:  0   lambda: 1e+00   misfit: 8.42202e+02
# it: 47   it_marq:  1   lambda: 1e+01   misfit: 7.62695e+02
# it: 48   it_marq:  0   lambda: 1e+00   misfit: 8.41394e+02
# it: 48   it_marq:  1   lambda: 1e+01   misfit: 7.62135e+02
# it: 49   it_marq:  0   lambda: 1e+00   misfit: 8.79880e+02
# it: 49   it_marq:  1   lambda: 1e+01   misfit: 7.61643e+02
# it: 50   it_marq:  0   lambda: 1e+00   misfit: 8.79252e+02
# it: 50   it_marq:  1   lambda: 1e+01   misfit: 7.61252e+02
# it: 51   it_marq:  0   lambda: 1e+00   misfit: 8.78569e+02
# it: 51   it_marq:  1   lambda: 1e+01   misfit: 7.60916e+02
# it: 52   it_marq:  0   lambda: 1e+00   misfit: 8.77920e+02
# it: 52   it_marq:  1   lambda: 1e+01   misfit: 7.60614e+02
# it: 53   it_marq:  0   lambda: 1e+00   misfit: 8.77250e+02
# it: 53   it_marq:  1   lambda: 1e+01   misfit: 7.60333e+02
# it: 54   it_marq:  0   lambda: 1e+00   misfit: 8.76611e+02
# it: 54   it_marq:  1   lambda: 1e+01   misfit: 7.60066e+02
# it: 55   it_marq:  0   lambda: 1e+00   misfit: 8.76013e+02
# it: 55   it_marq:  1   lambda: 1e+01   misfit: 7.59789e+02
# it: 56   it_marq:  0   lambda: 1e+00   misfit: 8.75495e+02
# it: 56   it_marq:  1   lambda: 1e+01   misfit: 7.59535e+02
# it: 57   it_marq:  0   lambda: 1e+00   misfit: 8.75025e+02
# it: 57   it_marq:  1   lambda: 1e+01   misfit: 7.59306e+02
# it: 58   it_marq:  0   lambda: 1e+00   misfit: 8.74612e+02
# it: 58   it_marq:  1   lambda: 1e+01   misfit: 7.59107e+02
# it: 59   it_marq:  0   lambda: 1e+00   misfit: 8.74236e+02
# it: 59   it_marq:  1   lambda: 1e+01   misfit: 7.58928e+02
# it: 60   it_marq:  0   lambda: 1e+00   misfit: 8.73919e+02
# it: 60   it_marq:  1   lambda: 1e+01   misfit: 7.58778e+02
# it: 61   it_marq:  0   lambda: 1e+00   misfit: 8.73640e+02
# it: 61   it_marq:  1   lambda: 1e+01   misfit: 7.58642e+02
# it: 62   it_marq:  0   lambda: 1e+00   misfit: 8.73428e+02
# it: 62   it_marq:  1   lambda: 1e+01   misfit: 7.58532e+02
# it: 63   it_marq:  0   lambda: 1e+00   misfit: 8.53636e+02
# it: 63   it_marq:  1   lambda: 1e+01   misfit: 7.58434e+02
# it: 64   it_marq:  0   lambda: 1e+00   misfit: 8.53328e+02
# it: 64   it_marq:  1   lambda: 1e+01   misfit: 7.58350e+02
# it: 65   it_marq:  0   lambda: 1e+00   misfit: 8.53057e+02
# it: 65   it_marq:  1   lambda: 1e+01   misfit: 7.58258e+02
# it: 66   it_marq:  0   lambda: 1e+00   misfit: 8.52841e+02
# it: 66   it_marq:  1   lambda: 1e+01   misfit: 7.58175e+02
# it: 67   it_marq:  0   lambda: 1e+00   misfit: 8.40752e+02
# it: 67   it_marq:  1   lambda: 1e+01   misfit: 7.58094e+02
# it: 68   it_marq:  0   lambda: 1e+00   misfit: 8.37969e+02
# it: 68   it_marq:  1   lambda: 1e+01   misfit: 7.58032e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 8.07378e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 6.77527e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.69079e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 6.51765e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 3.84585e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.30339e+04
# it:  4   it_marq:  2   lambda: 1e+01   misfit: 4.01067e+03
# it:  5   it_marq:  0   lambda: 1e+00   misfit: 5.83665e+03
# it:  5   it_marq:  1   lambda: 1e+01   misfit: 3.06885e+03
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.89585e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 4.04305e+03
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.05327e+03
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 1.09590e+04
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 9.60046e+02
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.51563e+04
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 9.39297e+02
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.97444e+04
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 2.41208e+03
# it: 10   it_marq:  2   lambda: 1e+01   misfit: 1.01786e+04
# it: 10   it_marq:  3   lambda: 1e+02   misfit: 9.62749e+03
# it: 10   it_marq:  4   lambda: 1e+03   misfit: 1.00559e+03
# it: 10   it_marq:  5   lambda: 1e+04   misfit: 9.56875e+02
# it: 10   it_marq:  6   lambda: 1e+05   misfit: 9.56967e+02
# it: 10   it_marq:  7   lambda: 1e+06   misfit: 9.56975e+02
# it: 10   it_marq:  8   lambda: 1e+07   misfit: 9.56976e+02
# it: 10   it_marq:  9   lambda: 1e+08   misfit: 9.56976e+02
# it: 11   it_marq:  0   lambda: 1e+09   misfit: 9.56951e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 9.46219e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 7.18631e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.21380e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.90573e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.24743e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 2.30499e+04
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 5.69529e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 2.79881e+04
# it:  5   it_marq:  2   lambda: 1e+01   misfit: 2.32442e+04
# it:  5   it_marq:  3   lambda: 1e+02   misfit: 2.24555e+04
# it:  6   it_marq:  0   lambda: 1e+01   misfit: 1.97579e+04
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 2.05335e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 1.82758e+04
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 2.01978e+04
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 1.75932e+04
# it:  9   it_marq:  0   lambda: 1e+00   misfit: 1.89932e+04
# it:  9   it_marq:  1   lambda: 1e+01   misfit: 1.68122e+04
# it: 10   it_marq:  0   lambda: 1e+00   misfit: 2.12372e+04
# it: 10   it_marq:  1   lambda: 1e+01   misfit: 1.99803e+04
# it: 10   it_marq:  2   lambda: 1e+02   misfit: 2.08246e+04
# it: 10   it_marq:  3   lambda: 1e+03   misfit: 1.82264e+04
# it: 10   it_marq:  4   lambda: 1e+04   misfit: 1.68128e+04
# it: 10   it_marq:  5   lambda: 1e+05   misfit: 1.68146e+04
# it: 10   it_marq:  6   lambda: 1e+06   misfit: 1.68141e+04
# it: 10   it_marq:  7   lambda: 1e+07   misfit: 1.68160e+04
# it: 10   it_marq:  8   lambda: 1e+08   misfit: 1.68160e+04
# it: 10   it_marq:  9   lambda: 1e+09   misfit: 1.68160e+04
# it: 11   it_marq:  0   lambda: 1e+10   misfit: 1.68159e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.08245e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 8.45615e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.16987e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.25790e+04
# it:  3   it_marq:  1   lambda: 1e+01   misfit: 2.07642e+04
# it:  4   it_marq:  0   lambda: 1e+00   misfit: 1.51182e+04
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 8.15795e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.19667e+04
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 4.33329e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 1.79765e+04
# it:  6   it_marq:  2   lambda: 1e+01   misfit: 1.21080e+04
# it:  6   it_marq:  3   lambda: 1e+02   misfit: 1.24918e+04
# it:  6   it_marq:  4   lambda: 1e+03   misfit: 1.25109e+04
# it:  6   it_marq:  5   lambda: 1e+04   misfit: 1.21118e+04
# it:  6   it_marq:  6   lambda: 1e+05   misfit: 1.19661e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 6.26765e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 5.46107e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 2.59755e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 8.31335e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.55246e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 5.43148e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 1.27082e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 4.71419e+03
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 1.40040e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 5.52397e+03
# it:  6   it_marq:  2   lambda: 1e+01   misfit: 8.14887e+03
# it:  6   it_marq:  3   lambda: 1e+02   misfit: 7.88386e+03
# it:  6   it_marq:  4   lambda: 1e+03   misfit: 7.05665e+03
# it:  6   it_marq:  5   lambda: 1e+04   misfit: 4.71079e+03
# it:  7   it_marq:  0   lambda: 1e+03   misfit: 4.70495e+03
# it:  8   it_marq:  0   lambda: 1e+02   misfit: 4.66009e+03
# it:  9   it_marq:  0   lambda: 1e+01   misfit: 4.52950e+03
# it: 10   it_marq:  0   lambda: 1e+00   misfit: 4.74182e+03
# it: 10   it_marq:  1   lambda: 1e+01   misfit: 4.49108e+03
# it: 11   it_marq:  0   lambda: 1e+00   misfit: 4.75364e+03
# it: 11   it_marq:  1   lambda: 1e+01   misfit: 4.47060e+03
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 4.75378e+03
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 4.45754e+03
# ...
# it: 38   it_marq:  0   lambda: 1e-01   misfit: 1.11492e+03
# it: 38   it_marq:  1   lambda: 1e+00   misfit: 7.96967e+02
# it: 39   it_marq:  0   lambda: 1e-01   misfit: 1.11539e+03
# it: 39   it_marq:  1   lambda: 1e+00   misfit: 7.94717e+02
# it: 40   it_marq:  0   lambda: 1e-01   misfit: 1.11808e+03
# it: 40   it_marq:  1   lambda: 1e+00   misfit: 7.94599e+02
# it: 41   it_marq:  0   lambda: 1e-01   misfit: 1.11913e+03
# it: 41   it_marq:  1   lambda: 1e+00   misfit: 7.94772e+02
# it: 41   it_marq:  2   lambda: 1e+01   misfit: 7.83366e+02
# it: 42   it_marq:  0   lambda: 1e+00   misfit: 7.93026e+02
# it: 42   it_marq:  1   lambda: 1e+01   misfit: 7.80239e+02
# it: 43   it_marq:  0   lambda: 1e+00   misfit: 7.92272e+02
# it: 43   it_marq:  1   lambda: 1e+01   misfit: 7.78835e+02
# it: 44   it_marq:  0   lambda: 1e+00   misfit: 7.91722e+02
# it: 44   it_marq:  1   lambda: 1e+01   misfit: 7.77966e+02
# it: 45   it_marq:  0   lambda: 1e+00   misfit: 7.91569e+02
# it: 45   it_marq:  1   lambda: 1e+01   misfit: 7.77545e+02
# it: 46   it_marq:  0   lambda: 1e+00   misfit: 7.91375e+02
# it: 46   it_marq:  1   lambda: 1e+01   misfit: 7.77261e+02
# it: 47   it_marq:  0   lambda: 1e+00   misfit: 7.91461e+02
# it: 47   it_marq:  1   lambda: 1e+01   misfit: 7.77211e+02
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.46525e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.26556e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.58808e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.47358e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.18763e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 1.27309e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 6.71922e+03
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 1.92371e+04
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 1.07749e+04
# it:  6   it_marq:  2   lambda: 1e+00   misfit: 7.59606e+03
# it:  6   it_marq:  3   lambda: 1e+01   misfit: 7.48334e+03
# it:  6   it_marq:  4   lambda: 1e+02   misfit: 8.32256e+03
# it:  6   it_marq:  5   lambda: 1e+03   misfit: 7.99048e+03
# it:  6   it_marq:  6   lambda: 1e+04   misfit: 7.35959e+03
# it:  6   it_marq:  7   lambda: 1e+05   misfit: 7.36031e+03
# it:  6   it_marq:  8   lambda: 1e+06   misfit: 7.36043e+03
# it:  6   it_marq:  9   lambda: 1e+07   misfit: 7.36044e+03
# it:  7   it_marq:  0   lambda: 1e+08   misfit: 7.36562e+03
# it:  7   it_marq:  1   lambda: 1e+09   misfit: 7.36562e+03
# it:  7   it_marq:  2   lambda: 1e+10   misfit: 7.36562e+03
# it:  7   it_marq:  3   lambda: 1e+11   misfit: 7.36562e+03
# it:  7   it_marq:  4   lambda: 1e+12   misfit: 7.36562e+03
# it:  7   it_marq:  5   lambda: 1e+13   misfit: 7.36562e+03
# it:  7   it_marq:  6   lambda: 1e+14   misfit: 7.36562e+03
# it:  7   it_marq:  7   lambda: 1e+15   misfit: 7.36562e+03
# it:  7   it_marq:  8   lambda: 1e+16   misfit: 7.36562e+03
# it:  7   it_marq:  9   lambda: 1e+17   misfit: 7.36562e+03
# it:  8   it_marq:  0   lambda: 1e+18   misfit: 7.36580e+03
# it:  8   it_marq:  1   lambda: 1e+19   misfit: 7.36580e+03
# it:  8   it_marq:  2   lambda: 1e+20   misfit: 7.36580e+03
# it:  8   it_marq:  3   lambda: 1e+21   misfit: 7.36580e+03
# it:  8   it_marq:  4   lambda: 1e+22   misfit: 7.36580e+03
# it:  8   it_marq:  5   lambda: 1e+23   misfit: 7.36580e+03
# it:  8   it_marq:  6   lambda: 1e+24   misfit: 7.36580e+03
# it:  8   it_marq:  7   lambda: 1e+25   misfit: 7.36580e+03
# it:  8   it_marq:  8   lambda: 1e+26   misfit: 7.36580e+03
# it:  8   it_marq:  9   lambda: 1e+27   misfit: 7.36580e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.06871e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.00521e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 7.04282e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 5.24079e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 3.07286e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.10609e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 2.45676e+04
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 9.01120e+04
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 3.18436e+04
# it:  6   it_marq:  2   lambda: 1e+00   misfit: 1.63501e+04
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 6.80450e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 6.68447e+04
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 9.12053e+04
# it:  7   it_marq:  3   lambda: 1e+02   misfit: 1.79697e+05
# it:  7   it_marq:  4   lambda: 1e+03   misfit: 6.01595e+04
# it:  7   it_marq:  5   lambda: 1e+04   misfit: 1.63857e+04
# it:  7   it_marq:  6   lambda: 1e+05   misfit: 1.63950e+04
# it:  7   it_marq:  7   lambda: 1e+06   misfit: 1.63953e+04
# it:  7   it_marq:  8   lambda: 1e+07   misfit: 1.63953e+04
# it:  7   it_marq:  9   lambda: 1e+08   misfit: 1.63953e+04
# it:  8   it_marq:  0   lambda: 1e+09   misfit: 1.63952e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.29781e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.08935e+05
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 4.63628e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 2.08590e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.92855e+03
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.88460e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 8.35178e+04
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 2.19083e+03
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 6.47019e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 4.90453e+04
# it:  6   it_marq:  2   lambda: 1e+01   misfit: 1.77823e+03
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 4.80085e+04
# it:  7   it_marq:  1   lambda: 1e+01   misfit: 1.62235e+03
# it:  8   it_marq:  0   lambda: 1e+00   misfit: 4.74860e+04
# it:  8   it_marq:  1   lambda: 1e+01   misfit: 1.54553e+03
# it:  9   it_marq:  0   lambda: 1e+00   misfit: 4.71698e+04
# it:  9   it_marq:  1   lambda: 1e+01   misfit: 1.49761e+03
# it: 10   it_marq:  0   lambda: 1e+00   misfit: 4.69582e+04
# it: 10   it_marq:  1   lambda: 1e+01   misfit: 4.50180e+04
# it: 10   it_marq:  2   lambda: 1e+02   misfit: 1.49218e+03
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 2.77861e+04
# it: 11   it_marq:  1   lambda: 1e+02   misfit: 1.48727e+03
# it: 12   it_marq:  0   lambda: 1e+01   misfit: 4.49145e+04
# it: 12   it_marq:  1   lambda: 1e+02   misfit: 1.48270e+03
# it: 13   it_marq:  0   lambda: 1e+01   misfit: 4.48520e+04
# it: 13   it_marq:  1   lambda: 1e+02   misfit: 1.47840e+03
# it: 14   it_marq:  0   lambda: 1e+01   misfit: 4.48366e+04
# it: 14   it_marq:  1   lambda: 1e+02   misfit: 1.47433e+03
# it: 15   it_marq:  0   lambda: 1e+01   misfit: 4.48046e+04
# it: 15   it_marq:  1   lambda: 1e+02   misfit: 1.47046e+03
# it: 16   it_marq:  0   lambda: 1e+01   misfit: 4.47731e+04
# it: 16   it_marq:  1   lambda: 1e+02   misfit: 1.46673e+03
# it: 17   it_marq:  0   lambda: 1e+01   misfit: 4.47471e+04
# it: 17   it_marq:  1   lambda: 1e+02   misfit: 1.46313e+03
# it: 18   it_marq:  0   lambda: 1e+01   misfit: 4.47215e+04
# it: 18   it_marq:  1   lambda: 1e+02   misfit: 1.45964e+03
# it: 19   it_marq:  0   lambda: 1e+01   misfit: 4.47001e+04
# it: 19   it_marq:  1   lambda: 1e+02   misfit: 1.45624e+03
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 4.46824e+04
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 4.80917e+03
# it: 20   it_marq:  2   lambda: 1e+03   misfit: 1.45583e+03
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 1.45257e+03
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 4.46646e+04
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.44934e+03
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 4.43969e+04
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.44618e+03
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 3.70375e+04
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 1.44309e+03
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.49935e+04
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.44007e+03
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 4.41739e+03
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 1.43715e+03
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 2.03890e+03
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 1.43429e+03
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.47460e+03
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 1.43149e+03
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.41741e+03
# it: 30   it_marq:  0   lambda: 1e+00   misfit: 1.30281e+03
# it: 31   it_marq:  0   lambda: 1e-01   misfit: 2.45229e+03
# it: 31   it_marq:  1   lambda: 1e+00   misfit: 1.21322e+03
# it: 32   it_marq:  0   lambda: 1e-01   misfit: 2.78259e+03
# it: 32   it_marq:  1   lambda: 1e+00   misfit: 1.14873e+03
# it: 33   it_marq:  0   lambda: 1e-01   misfit: 2.35073e+03
# it: 33   it_marq:  1   lambda: 1e+00   misfit: 1.10297e+03
# it: 34   it_marq:  0   lambda: 1e-01   misfit: 2.10486e+03
# it: 34   it_marq:  1   lambda: 1e+00   misfit: 1.07037e+03
# it: 35   it_marq:  0   lambda: 1e-01   misfit: 1.97734e+03
# it: 35   it_marq:  1   lambda: 1e+00   misfit: 1.14481e+03
# it: 35   it_marq:  2   lambda: 1e+01   misfit: 1.07886e+03
# it: 35   it_marq:  3   lambda: 1e+02   misfit: 1.57590e+03
# it: 35   it_marq:  4   lambda: 1e+03   misfit: 1.06802e+03
# it: 36   it_marq:  0   lambda: 1e+02   misfit: 1.06521e+03
# it: 37   it_marq:  0   lambda: 1e+01   misfit: 1.05671e+03
# it: 38   it_marq:  0   lambda: 1e+00   misfit: 2.20818e+03
# it: 38   it_marq:  1   lambda: 1e+01   misfit: 1.05275e+03
# it: 39   it_marq:  0   lambda: 1e+00   misfit: 4.12501e+03
# it: 39   it_marq:  1   lambda: 1e+01   misfit: 2.36881e+03
# it: 39   it_marq:  2   lambda: 1e+02   misfit: 2.63012e+03
# it: 39   it_marq:  3   lambda: 1e+03   misfit: 1.34667e+03
# it: 39   it_marq:  4   lambda: 1e+04   misfit: 1.15721e+03
# it: 39   it_marq:  5   lambda: 1e+05   misfit: 1.15716e+03
# it: 39   it_marq:  6   lambda: 1e+06   misfit: 1.15716e+03
# it: 39   it_marq:  7   lambda: 1e+07   misfit: 1.15716e+03
# it: 39   it_marq:  8   lambda: 1e+08   misfit: 1.10943e+03
# it: 39   it_marq:  9   lambda: 1e+09   misfit: 1.10886e+03
# it: 40   it_marq:  0   lambda: 1e+10   misfit: 1.10909e+03
# it: 40   it_marq:  1   lambda: 1e+11   misfit: 1.10909e+03
# it: 40   it_marq:  2   lambda: 1e+12   misfit: 1.10909e+03
# it: 40   it_marq:  3   lambda: 1e+13   misfit: 1.10909e+03
# it: 40   it_marq:  4   lambda: 1e+14   misfit: 1.10909e+03
# it: 40   it_marq:  5   lambda: 1e+15   misfit: 1.10909e+03
# it: 40   it_marq:  6   lambda: 1e+16   misfit: 1.10909e+03
# it: 40   it_marq:  7   lambda: 1e+17   misfit: 1.10909e+03
# it: 40   it_marq:  8   lambda: 1e+18   misfit: 1.10909e+03
# it: 40   it_marq:  9   lambda: 1e+19   misfit: 1.10909e+03
# it: 41   it_marq:  0   lambda: 1e+20   misfit: 1.10911e+03
# it: 41   it_marq:  1   lambda: 1e+21   misfit: 1.10911e+03
# it: 41   it_marq:  2   lambda: 1e+22   misfit: 1.10911e+03
# it: 41   it_marq:  3   lambda: 1e+23   misfit: 1.10911e+03
# it: 41   it_marq:  4   lambda: 1e+24   misfit: 1.10911e+03
# it: 41   it_marq:  5   lambda: 1e+25   misfit: 1.10911e+03
# it: 41   it_marq:  6   lambda: 1e+26   misfit: 1.10911e+03
# it: 41   it_marq:  7   lambda: 1e+27   misfit: 1.10911e+03
# it: 41   it_marq:  8   lambda: 1e+28   misfit: 1.10911e+03
# it: 41   it_marq:  9   lambda: 1e+29   misfit: 1.10911e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 9.12070e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 8.30731e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 5.21052e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 3.44104e+04
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.09430e+04
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.33736e+04
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.00993e+04
# it:  6   it_marq:  0   lambda: 1e-02   misfit: 2.67002e+04
# it:  6   it_marq:  1   lambda: 1e-01   misfit: 9.56124e+03
# it:  7   it_marq:  0   lambda: 1e-02   misfit: 3.03339e+04
# it:  7   it_marq:  1   lambda: 1e-01   misfit: 3.83787e+03
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 2.70523e+04
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 1.51165e+04
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 4.18822e+04
# it:  8   it_marq:  3   lambda: 1e+01   misfit: 1.02272e+05
# it:  8   it_marq:  4   lambda: 1e+02   misfit: 1.14920e+05
# it:  8   it_marq:  5   lambda: 1e+03   misfit: 3.80174e+03
# it:  9   it_marq:  0   lambda: 1e+02   misfit: 3.91094e+03
# it:  9   it_marq:  1   lambda: 1e+03   misfit: 4.02578e+03
# it:  9   it_marq:  2   lambda: 1e+04   misfit: 3.92356e+03
# it:  9   it_marq:  3   lambda: 1e+05   misfit: 3.92188e+03
# it:  9   it_marq:  4   lambda: 1e+06   misfit: 3.85662e+03
# it:  9   it_marq:  5   lambda: 1e+07   misfit: 3.81698e+03
# it:  9   it_marq:  6   lambda: 1e+08   misfit: 3.80625e+03
# it:  9   it_marq:  7   lambda: 1e+09   misfit: 3.80260e+03
# it:  9   it_marq:  8   lambda: 1e+10   misfit: 3.80260e+03
# it:  9   it_marq:  9   lambda: 1e+11   misfit: 3.80260e+03
# it: 10   it_marq:  0   lambda: 1e+12   misfit: 3.80269e+03
# it: 10   it_marq:  1   lambda: 1e+13   misfit: 3.80269e+03
# it: 10   it_marq:  2   lambda: 1e+14   misfit: 3.80269e+03
# it: 10   it_marq:  3   lambda: 1e+15   misfit: 3.80269e+03
# it: 10   it_marq:  4   lambda: 1e+16   misfit: 3.80269e+03
# it: 10   it_marq:  5   lambda: 1e+17   misfit: 3.80269e+03
# it: 10   it_marq:  6   lambda: 1e+18   misfit: 3.80269e+03
# it: 10   it_marq:  7   lambda: 1e+19   misfit: 3.80269e+03
# it: 10   it_marq:  8   lambda: 1e+20   misfit: 3.80269e+03
# it: 10   it_marq:  9   lambda: 1e+21   misfit: 3.80269e+03
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.16635e+05
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 8.91432e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.80579e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.33750e+04
# it:  3   it_marq:  1   lambda: 1e+01   misfit: 2.57881e+04
# it:  4   it_marq:  0   lambda: 1e+00   misfit: 1.45602e+04
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 6.36141e+04
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 1.35759e+04
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 3.72155e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 1.83685e+04
# it:  6   it_marq:  2   lambda: 1e+01   misfit: 1.76171e+04
# it:  6   it_marq:  3   lambda: 1e+02   misfit: 1.68484e+04
# it:  6   it_marq:  4   lambda: 1e+03   misfit: 1.48368e+04
# it:  6   it_marq:  5   lambda: 1e+04   misfit: 1.39513e+04
# it:  6   it_marq:  6   lambda: 1e+05   misfit: 1.37958e+04
# it:  6   it_marq:  7   lambda: 1e+06   misfit: 1.37413e+04
# it:  6   it_marq:  8   lambda: 1e+07   misfit: 1.36168e+04
# it:  6   it_marq:  9   lambda: 1e+08   misfit: 1.36052e+04
# it:  7   it_marq:  0   lambda: 1e+09   misfit: 1.35767e+04
# it:  8   it_marq:  0   lambda: 1e+08   misfit: 1.35767e+04
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 7.13438e+04
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 6.00161e+04
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 3.02120e+04
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 9.75276e+03
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 2.50980e+04
# it:  4   it_marq:  1   lambda: 1e+00   misfit: 7.42006e+03
# it:  5   it_marq:  0   lambda: 1e-01   misfit: 9.82475e+03
# it:  5   it_marq:  1   lambda: 1e+00   misfit: 6.80835e+03
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 3.32934e+04
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 5.80368e+03
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 7.14391e+04
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 4.70903e+04
# it:  7   it_marq:  2   lambda: 1e+01   misfit: 5.61400e+04
# it:  7   it_marq:  3   lambda: 1e+02   misfit: 4.58219e+04
# it:  7   it_marq:  4   lambda: 1e+03   misfit: 4.02407e+04
# it:  7   it_marq:  5   lambda: 1e+04   misfit: 5.97713e+03
# it:  7   it_marq:  6   lambda: 1e+05   misfit: 5.68221e+03
# it:  8   it_marq:  0   lambda: 1e+04   misfit: 5.65366e+03
# it:  9   it_marq:  0   lambda: 1e+03   misfit: 5.58832e+03
# it: 10   it_marq:  0   lambda: 1e+02   misfit: 5.02535e+03
# it: 11   it_marq:  0   lambda: 1e+01   misfit: 4.23540e+03
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 4.28955e+03
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 3.96597e+03
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 4.12539e+03
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 3.89647e+03
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 3.93332e+03
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 3.79835e+03
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 4.18344e+03
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 3.80052e+03
# it: 15   it_marq:  2   lambda: 1e+02   misfit: 3.79798e+03

# %% [markdown]
# # Results

# %%
inversion['results'] = inversion_results

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)
