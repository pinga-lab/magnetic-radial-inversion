# %% [markdown]
# # Diorama single L1 TFA Inversion

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import os
import pandas as pd

from fatiando.vis import mpl
from fatiando.utils import ang2vec
from fatiando.gravmag import polyprism
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing Diorama TFA data

# %%
data = pd.read_csv('diorama_decimated_tfa_residual.txt', skipinitialspace=True, delim_whitespace=True)

# %%
data['GPSALT'] = data['GPSALT']

# %%
xp = data['X'].get_values()
yp = data['Y'].get_values()
zp = data['GPSALT'].get_values()
dobs = data['mag_res2'].get_values()

# %%
np.min(zp)
# Out:
# -337.79

# %% [markdown]
# ### Parameters of the initial model

# %%
M = 20 # number of vertices per prism
L = 6 # number of prisms
P = L*(M+2) + 1 # number of parameters

#figura
incs = -46.
decs = 24.
intensity = 16.
props = {'magnetization': ang2vec(intensity, incs, decs)}

# depth to the top, thickness and radius
z0 = 50.
dz = 350.
r = 1200.

x0, y0 = [8212500., 478200.]

# main field
inc, dec = [-19.5, -18.]

rin = np.zeros(M) + r
m0 = np.hstack((rin, np.array([x0, y0])))
m0 = np.resize(m0, P - 1) # inicial parameters vector
m0 = np.hstack((m0, dz))
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms

# predict data
d0 = polyprism.tf(xp, yp, zp, model0, inc, dec)

# %%
plt.figure(figsize=(6,5))
plt.title('Obs TFA', fontsize=20)
plt.tricontourf(yp, xp, dobs, 20, cmap='RdBu_r').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.title('Predicted TFA', fontsize=20)
plt.tricontourf(yp, xp, d0, 20, cmap='RdBu_r').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)
plt.show()

# %% [markdown]
# ### Limits

# %%
# limits for parameters in meters
rmin = 10.
rmax = 1500.
x0min = 8212500.
x0max = 8213500.
y0min = 478000.
y0max = 479000.
dzmin = 10.
dzmax = 1000.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

# %% [markdown]
# ### Variation

# %%
# variation for derivatives
deltax = 0.01*np.max(100.)
deltay = 0.01*np.max(100.)
deltar = 0.01*np.max(100.)
deltaz = 0.01*np.max(100.)

# %% [markdown]
# ### Outcropping parameters

# %%
# outcropping body parameters
m_out = np.zeros(M + 2)
#m_out = model['param_vec'][:M+2]

# %% [markdown]
# ### Folder to save the results

# %%
mypath = 'L1_tfa_inversion/V%d_L%d_inc%d_dec%d_r%d_int%d_z0%d_dz%d' % (M, L, incs, decs, r, intensity, z0, dz)
if not os.path.isdir(mypath):
    os.makedirs(mypath)

# %%
mypath
# Out:
# 'L1_tfa_inversion/V20_L6_inc-46_dec24_r1200_int16_z050_dz350'

# %%
# output of inversion
inversion = dict()

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 10.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 1.0e-4  # adjacent radial distances within each prism
a2 = 1.0e-4   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 1.0e-4    # vertically adjacent origins
a6 = 1.0e-6   # zero order Tikhonov on adjacent radial distances
a7 = 1.0e-6     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %%
itmax = 30
itmax_marq = 10
tol = 1.0e-4     # stop criterion

# %%
inversion['x'] = xp
inversion['y'] = yp
inversion['z'] = zp
inversion['observed_data'] = dobs

# %%
inversion['inc_dec'] = [incs, decs]
inversion['z0'] = z0
inversion['initial_dz'] = dz
inversion['intial_r'] = r
inversion['limits'] = [rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax]
inversion['regularization'] = np.array([a1, a2, a3, a4, a5, a6, a7])
inversion['tol'] = tol
inversion['main_field'] = [-21.5, -18.7]

# %% [markdown]
# ### Inversion

# %%
d_fit, m_est, model_est, phi_list, model_list, res_list = mfun.l1_levmarq_tf(
    xp, yp, zp, m0, M, L, delta,
    itmax, itmax_marq, lamb,
    dlamb, tol, mmin, mmax,
    m_out, dobs, inc, dec,
    model0[0].props, alpha, z0, dz
)
# Out:
# it:  0   it_marq:  0   lambda: 1e+01   init obj.: 3.65008e+02  fin obj.: 4.22253e+02
# it:  0   it_marq:  1   lambda: 1e+02   init obj.: 3.65008e+02  fin obj.: 3.77648e+02
# it:  0   it_marq:  2   lambda: 1e+03   init obj.: 3.65008e+02  fin obj.: 3.79646e+02
# it:  0   it_marq:  3   lambda: 1e+04   init obj.: 3.65008e+02  fin obj.: 3.79850e+02
# it:  0   it_marq:  4   lambda: 1e+05   init obj.: 3.65008e+02  fin obj.: 3.79871e+02
# it:  0   it_marq:  5   lambda: 1e+06   init obj.: 3.65008e+02  fin obj.: 3.79873e+02
# it:  0   it_marq:  6   lambda: 1e+07   init obj.: 3.65008e+02  fin obj.: 3.79873e+02
# it:  0   it_marq:  7   lambda: 1e+08   init obj.: 3.65008e+02  fin obj.: 3.79873e+02
# it:  0   it_marq:  8   lambda: 1e+09   init obj.: 3.65008e+02  fin obj.: 3.79873e+02
# it:  0   it_marq:  9   lambda: 1e+10   init obj.: 3.65008e+02  fin obj.: 3.79872e+02
# it:  1   it_marq:  0   lambda: 1e+11   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  1   lambda: 1e+12   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  2   lambda: 1e+13   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  3   lambda: 1e+14   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  4   lambda: 1e+15   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  5   lambda: 1e+16   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  6   lambda: 1e+17   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  7   lambda: 1e+18   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  8   lambda: 1e+19   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  1   it_marq:  9   lambda: 1e+20   init obj.: 3.65008e+02  fin obj.: 3.79878e+02
# it:  2   it_marq:  0   lambda: 1e+21   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  1   lambda: 1e+22   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  2   lambda: 1e+23   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  3   lambda: 1e+24   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  4   lambda: 1e+25   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  5   lambda: 1e+26   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  6   lambda: 1e+27   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  7   lambda: 1e+28   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  8   lambda: 1e+29   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  2   it_marq:  9   lambda: 1e+30   init obj.: 3.65008e+02  fin obj.: 3.79884e+02
# it:  3   it_marq:  0   lambda: 1e+31   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  1   lambda: 1e+32   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  2   lambda: 1e+33   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  3   lambda: 1e+34   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  4   lambda: 1e+35   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  5   lambda: 1e+36   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  6   lambda: 1e+37   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  7   lambda: 1e+38   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  8   lambda: 1e+39   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  3   it_marq:  9   lambda: 1e+40   init obj.: 3.65008e+02  fin obj.: 3.79890e+02
# it:  4   it_marq:  0   lambda: 1e+41   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  1   lambda: 1e+42   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  2   lambda: 1e+43   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  3   lambda: 1e+44   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  4   lambda: 1e+45   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  5   lambda: 1e+46   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  6   lambda: 1e+47   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  7   lambda: 1e+48   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  8   lambda: 1e+49   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  4   it_marq:  9   lambda: 1e+50   init obj.: 3.65008e+02  fin obj.: 3.79896e+02
# it:  5   it_marq:  0   lambda: 1e+51   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  1   lambda: 1e+52   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  2   lambda: 1e+53   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  3   lambda: 1e+54   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  4   lambda: 1e+55   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  5   lambda: 1e+56   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  6   lambda: 1e+57   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  7   lambda: 1e+58   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  8   lambda: 1e+59   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  5   it_marq:  9   lambda: 1e+60   init obj.: 3.65008e+02  fin obj.: 3.79902e+02
# it:  6   it_marq:  0   lambda: 1e+61   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  1   lambda: 1e+62   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  2   lambda: 1e+63   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  3   lambda: 1e+64   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  4   lambda: 1e+65   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  5   lambda: 1e+66   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  6   lambda: 1e+67   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  7   lambda: 1e+68   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  8   lambda: 1e+69   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  6   it_marq:  9   lambda: 1e+70   init obj.: 3.65008e+02  fin obj.: 3.79908e+02
# it:  7   it_marq:  0   lambda: 1e+71   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  1   lambda: 1e+72   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  2   lambda: 1e+73   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  3   lambda: 1e+74   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  4   lambda: 1e+75   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  5   lambda: 1e+76   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  6   lambda: 1e+77   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  7   lambda: 1e+78   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  8   lambda: 1e+79   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  7   it_marq:  9   lambda: 1e+80   init obj.: 3.65008e+02  fin obj.: 3.79914e+02
# it:  8   it_marq:  0   lambda: 1e+81   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  1   lambda: 1e+82   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  2   lambda: 1e+83   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  3   lambda: 1e+84   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  4   lambda: 1e+85   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  5   lambda: 1e+86   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  6   lambda: 1e+87   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  7   lambda: 1e+88   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  8   lambda: 1e+89   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  8   it_marq:  9   lambda: 1e+90   init obj.: 3.65008e+02  fin obj.: 3.79919e+02
# it:  9   it_marq:  0   lambda: 1e+91   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  1   lambda: 1e+92   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  2   lambda: 1e+93   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  3   lambda: 1e+94   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  4   lambda: 1e+95   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  5   lambda: 1e+96   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  6   lambda: 1e+97   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  7   lambda: 1e+98   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  8   lambda: 1e+99   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it:  9   it_marq:  9   lambda: 1e+100   init obj.: 3.65008e+02  fin obj.: 3.79925e+02
# it: 10   it_marq:  0   lambda: 1e+101   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  1   lambda: 1e+102   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  2   lambda: 1e+103   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  3   lambda: 1e+104   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  4   lambda: 1e+105   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  5   lambda: 1e+106   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  6   lambda: 1e+107   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  7   lambda: 1e+108   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  8   lambda: 1e+109   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 10   it_marq:  9   lambda: 1e+110   init obj.: 3.65008e+02  fin obj.: 3.79931e+02
# it: 11   it_marq:  0   lambda: 1e+111   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  1   lambda: 1e+112   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  2   lambda: 1e+113   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  3   lambda: 1e+114   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  4   lambda: 1e+115   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  5   lambda: 1e+116   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  6   lambda: 1e+117   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  7   lambda: 1e+118   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  8   lambda: 1e+119   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 11   it_marq:  9   lambda: 1e+120   init obj.: 3.65008e+02  fin obj.: 3.79937e+02
# it: 12   it_marq:  0   lambda: 1e+121   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  1   lambda: 1e+122   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  2   lambda: 1e+123   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  3   lambda: 1e+124   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  4   lambda: 1e+125   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  5   lambda: 1e+126   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  6   lambda: 1e+127   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  7   lambda: 1e+128   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  8   lambda: 1e+129   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 12   it_marq:  9   lambda: 1e+130   init obj.: 3.65008e+02  fin obj.: 3.79943e+02
# it: 13   it_marq:  0   lambda: 1e+131   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  1   lambda: 1e+132   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  2   lambda: 1e+133   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  3   lambda: 1e+134   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  4   lambda: 1e+135   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  5   lambda: 1e+136   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  6   lambda: 1e+137   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  7   lambda: 1e+138   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  8   lambda: 1e+139   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 13   it_marq:  9   lambda: 1e+140   init obj.: 3.65008e+02  fin obj.: 3.79949e+02
# it: 14   it_marq:  0   lambda: 1e+141   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  1   lambda: 1e+142   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  2   lambda: 1e+143   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  3   lambda: 1e+144   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  4   lambda: 1e+145   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  5   lambda: 1e+146   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  6   lambda: 1e+147   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  7   lambda: 1e+148   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  8   lambda: 1e+149   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 14   it_marq:  9   lambda: 1e+150   init obj.: 3.65008e+02  fin obj.: 3.79955e+02
# it: 15   it_marq:  0   lambda: 1e+151   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  1   lambda: 1e+152   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  2   lambda: 1e+153   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  3   lambda: 1e+154   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  4   lambda: 1e+155   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  5   lambda: 1e+156   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  6   lambda: 1e+157   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  7   lambda: 1e+158   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  8   lambda: 1e+159   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 15   it_marq:  9   lambda: 1e+160   init obj.: 3.65008e+02  fin obj.: 3.79961e+02
# it: 16   it_marq:  0   lambda: 1e+161   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  1   lambda: 1e+162   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  2   lambda: 1e+163   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  3   lambda: 1e+164   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  4   lambda: 1e+165   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  5   lambda: 1e+166   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  6   lambda: 1e+167   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  7   lambda: 1e+168   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  8   lambda: 1e+169   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 16   it_marq:  9   lambda: 1e+170   init obj.: 3.65008e+02  fin obj.: 3.79967e+02
# it: 17   it_marq:  0   lambda: 1e+171   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  1   lambda: 1e+172   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  2   lambda: 1e+173   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  3   lambda: 1e+174   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  4   lambda: 1e+175   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  5   lambda: 1e+176   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  6   lambda: 1e+177   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  7   lambda: 1e+178   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  8   lambda: 1e+179   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 17   it_marq:  9   lambda: 1e+180   init obj.: 3.65008e+02  fin obj.: 3.79973e+02
# it: 18   it_marq:  0   lambda: 1e+181   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  1   lambda: 1e+182   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  2   lambda: 1e+183   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  3   lambda: 1e+184   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  4   lambda: 1e+185   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  5   lambda: 1e+186   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  6   lambda: 1e+187   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  7   lambda: 1e+188   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  8   lambda: 1e+189   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 18   it_marq:  9   lambda: 1e+190   init obj.: 3.65008e+02  fin obj.: 3.79979e+02
# it: 19   it_marq:  0   lambda: 1e+191   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  1   lambda: 1e+192   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  2   lambda: 1e+193   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  3   lambda: 1e+194   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  4   lambda: 1e+195   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  5   lambda: 1e+196   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  6   lambda: 1e+197   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  7   lambda: 1e+198   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  8   lambda: 1e+199   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 19   it_marq:  9   lambda: 1e+200   init obj.: 3.65008e+02  fin obj.: 3.79984e+02
# it: 20   it_marq:  0   lambda: 1e+201   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  1   lambda: 1e+202   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  2   lambda: 1e+203   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  3   lambda: 1e+204   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  4   lambda: 1e+205   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  5   lambda: 1e+206   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  6   lambda: 1e+207   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  7   lambda: 1e+208   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  8   lambda: 1e+209   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 20   it_marq:  9   lambda: 1e+210   init obj.: 3.65008e+02  fin obj.: 3.79990e+02
# it: 21   it_marq:  0   lambda: 1e+211   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  1   lambda: 1e+212   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  2   lambda: 1e+213   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  3   lambda: 1e+214   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  4   lambda: 1e+215   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  5   lambda: 1e+216   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  6   lambda: 1e+217   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  7   lambda: 1e+218   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  8   lambda: 1e+219   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 21   it_marq:  9   lambda: 1e+220   init obj.: 3.65008e+02  fin obj.: 3.79996e+02
# it: 22   it_marq:  0   lambda: 1e+221   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  1   lambda: 1e+222   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  2   lambda: 1e+223   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  3   lambda: 1e+224   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  4   lambda: 1e+225   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  5   lambda: 1e+226   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  6   lambda: 1e+227   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  7   lambda: 1e+228   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  8   lambda: 1e+229   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 22   it_marq:  9   lambda: 1e+230   init obj.: 3.65008e+02  fin obj.: 3.80002e+02
# it: 23   it_marq:  0   lambda: 1e+231   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  1   lambda: 1e+232   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  2   lambda: 1e+233   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  3   lambda: 1e+234   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  4   lambda: 1e+235   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  5   lambda: 1e+236   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  6   lambda: 1e+237   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  7   lambda: 1e+238   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  8   lambda: 1e+239   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 23   it_marq:  9   lambda: 1e+240   init obj.: 3.65008e+02  fin obj.: 3.80008e+02
# it: 24   it_marq:  0   lambda: 1e+241   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  1   lambda: 1e+242   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  2   lambda: 1e+243   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  3   lambda: 1e+244   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  4   lambda: 1e+245   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  5   lambda: 1e+246   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  6   lambda: 1e+247   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  7   lambda: 1e+248   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  8   lambda: 1e+249   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 24   it_marq:  9   lambda: 1e+250   init obj.: 3.65008e+02  fin obj.: 3.80014e+02
# it: 25   it_marq:  0   lambda: 1e+251   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  1   lambda: 1e+252   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  2   lambda: 1e+253   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  3   lambda: 1e+254   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  4   lambda: 1e+255   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  5   lambda: 1e+256   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  6   lambda: 1e+257   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  7   lambda: 1e+258   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  8   lambda: 1e+259   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 25   it_marq:  9   lambda: 1e+260   init obj.: 3.65008e+02  fin obj.: 3.80020e+02
# it: 26   it_marq:  0   lambda: 1e+261   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  1   lambda: 1e+262   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  2   lambda: 1e+263   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  3   lambda: 1e+264   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  4   lambda: 1e+265   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  5   lambda: 1e+266   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  6   lambda: 1e+267   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  7   lambda: 1e+268   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  8   lambda: 1e+269   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 26   it_marq:  9   lambda: 1e+270   init obj.: 3.65008e+02  fin obj.: 3.80026e+02
# it: 27   it_marq:  0   lambda: 1e+271   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  1   lambda: 1e+272   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  2   lambda: 1e+273   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  3   lambda: 1e+274   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  4   lambda: 1e+275   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  5   lambda: 1e+276   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  6   lambda: 1e+277   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  7   lambda: 1e+278   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  8   lambda: 1e+279   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 27   it_marq:  9   lambda: 1e+280   init obj.: 3.65008e+02  fin obj.: 3.80032e+02
# it: 28   it_marq:  0   lambda: 1e+281   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  1   lambda: 1e+282   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  2   lambda: 1e+283   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  3   lambda: 1e+284   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  4   lambda: 1e+285   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  5   lambda: 1e+286   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  6   lambda: 1e+287   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  7   lambda: 1e+288   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  8   lambda: 1e+289   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 28   it_marq:  9   lambda: 1e+290   init obj.: 3.65008e+02  fin obj.: 3.80038e+02
# it: 29   it_marq:  0   lambda: 1e+291   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  1   lambda: 1e+292   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  2   lambda: 1e+293   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  3   lambda: 1e+294   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  4   lambda: 1e+295   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  5   lambda: 1e+296   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  6   lambda: 1e+297   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  7   lambda: 1e+298   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  8   lambda: 1e+299   init obj.: 3.65008e+02  fin obj.: 3.80043e+02
# it: 29   it_marq:  9   lambda: 1e+300   init obj.: 3.65008e+02  fin obj.: 3.80043e+02

# %% [markdown]
# # Results

# %%
inversion['data_fit'] = d_fit
inversion['estimate'] = m_est
inversion['prisms'] = model_est
inversion['estimated_models'] = model_list
inversion['objective'] = phi_list
inversion['residual'] = dobs - d_fit
inversion['residual_list'] = res_list
inversion['initial_estimate'] = model0

# %%
file_name = mypath+'/inversion.pickle'
with open(file_name, 'w') as f:
    pickle.dump(inversion, f)

# %%
mypath
# Out:
# 'L1_tfa_inversion/V20_L6_inc-46_dec24_r1200_int16_z050_dz350'
