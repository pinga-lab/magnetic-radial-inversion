# %% [markdown]
# # Inversion of amplitude of anomalous magnetic field data produced by a synthetic kimberlitic model

# %% [markdown]
# This notebook runs inversion of amplitude of anomalous magnetic field data using Levenberg-Marquadt's algorithm. The data was generated from a kimberlitic model using the poligonal prisms function from fatiando.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../../synthetic_data/kimberlite/kimberlite_model.pickle') as w:
        kimberlite_model = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/kimberlite_true.png')

# %% [markdown]
# ### Observation points and observed data

# %%
with open('../../synthetic_data/grids/regular_grid.pickle') as w:
        regular_grid = pickle.load(w)

# %%
with open('../../synthetic_data/kimberlite/kimberlite_data.pickle') as w:
        kimberlite_data = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/obs_amf.png', width=400, height=400)

# %% [markdown]
# ### Parameters for inversion

# %%
M = 10 # number of vertices per prism
L = 8 # number of prisms
P = L*(M+2) + 1 # number of parameters

# limits for parameters in meters
rmin = 10.
rmax = 1300.
x0min = -1300.
x0max = 1300.
y0min = -1300.
y0max = 1300.
dzmin = 10.
dzmax = 300.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

itmax = 30
itmax_marq = 10
epsilon = 1.0e-5     # stop criterion

deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)# increment of derivatives
deltaz = 0.01*np.max(dzmax)
m_out = np.zeros(M + 2)  # outcropping body parameters
#m_out = kimberlite_model['param_vec'][:M+2]

inc = kimberlite_model['inc']
dec = kimberlite_model['dec']
z0 = kimberlite_model['z0']
dz = 200.
props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc, dec)}
dobs = kimberlite_data['amf']
xp = regular_grid['xp']
yp = regular_grid['yp']
zp = regular_grid['zp']
N = regular_grid['N']

rin = np.zeros(M) + 600.
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) # inicial parameters vector
m0 = np.hstack((m0, dz))
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms
d0 = np.sqrt(polyprism.bx(xp, yp, zp, model0)**2. + \
             polyprism.by(xp, yp, zp, model0)**2. + \
             polyprism.bz(xp, yp, zp, model0)**2.)

# %% [markdown]
# ### Plotting the source and intial estimate

# %% [raw]
# bounds = [-700., 700., -700., 700., 50., 1750.]
#
# red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
# white, black = (1, 1, 1), (0, 0, 0),
#
# # Show the model
# scene = myv.figure()
# true = myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue)
# myv.polyprisms(model0, 'magnetization', opacity=.3, color=red)
#
# ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
# ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
# ax.axes.font_factor = 1.65
# scene.scene.camera.position = [-3919.9507356190898, -1492.5522124519537, 257.35943615138984]
# scene.scene.camera.focal_point = [3.2652212480582674e-12, -5.5975221395284579e-12, 500.00000000000028]
# scene.scene.camera.view_angle = 30.0
# scene.scene.camera.view_up = [0.028518032872962465, 0.086986891505218447, -0.99580118623514213]
# scene.scene.camera.clipping_range = [2313.2627909979883, 6588.5353642863038]
# scene.scene.camera.compute_view_plane_normal()
# scene.scene.render()
#
# myv.wall_bottom(ax.axes.bounds, opacity=0.2)
# myv.wall_north(ax.axes.bounds)
#
# myv.savefig('figs/kimberlite_amf_td_true_initial.png')
# myv.show()

# %%
img(filename='figs/kimberlite_amf_td_true_initial.png')

# %% [markdown]
# ### Observed AMF with initial estimate

# %%
plt.figure(figsize=(6,5))
plt.title('Observed AMF', fontsize=20)
plt.tricontourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
plt.savefig('figs/kimberlite_amf_obs_data_true_inital.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_amf_obs_data_true_inital.png', width=400, height=400)

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.001   # adjacent radial distances within each prism
a2 = 0.003   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.06     # vertically adjacent origins
a6 = 0.00001   # zero order Tikhonov on adjacent radial distances
a7 = 0.000001     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Inversion

# %%
d_fit, m_est, model_est, phi_list = mfun.levmarq_amf(xp, yp, zp, m0, M, L, delta, itmax,
                                                    itmax_marq, lamb, dlamb, epsilon,
                                                    mmin, mmax, m_out, dobs, props, alpha, z0, dz)
# Out:
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.9428e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 2.8965e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.1862e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.1841e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.1795e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.9710e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 5.1690e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.9520e+03
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 4.0098e+03
# it:  5   it_marq:  4   lambda: 1e+02   misfit: 1.3744e+03
# it:  5   it_marq:  5   lambda: 1e+03   misfit: 9.0430e+01
# it:  5   it_marq:  6   lambda: 1e+04   misfit: 4.0770e+01
# it:  6   it_marq:  0   lambda: 1e+03   misfit: 4.0466e+01
# it:  7   it_marq:  0   lambda: 1e+02   misfit: 3.7769e+01
# it:  8   it_marq:  0   lambda: 1e+01   misfit: 1.5604e+01
# it:  9   it_marq:  0   lambda: 1e+00   misfit: 9.7476e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.4337e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 6.3585e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.2167e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 4.4521e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 8.8175e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 3.3244e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 1.1044e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 5.3849e+00
# it: 13   it_marq:  2   lambda: 1e+01   misfit: 3.1731e+00
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 2.5049e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 3.7052e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 2.0492e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 2.9655e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 1.7268e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 2.2620e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 1.4950e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 1.7662e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 1.3272e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 1.4298e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 1.2057e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 1.2082e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 1.1182e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 1.0688e+00
# it: 22   it_marq:  0   lambda: 1e-02   misfit: 9.4270e-01
# it: 23   it_marq:  0   lambda: 1e-03   misfit: 4.7313e+00
# it: 23   it_marq:  1   lambda: 1e-02   misfit: 2.4632e+00
# it: 23   it_marq:  2   lambda: 1e-01   misfit: 1.0614e+00
# it: 23   it_marq:  3   lambda: 1e+00   misfit: 8.8698e-01
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 1.0608e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 9.0761e-01
# it: 24   it_marq:  2   lambda: 1e+01   misfit: 8.9272e-01
# it: 24   it_marq:  3   lambda: 1e+02   misfit: 8.9331e-01
# it: 24   it_marq:  4   lambda: 1e+03   misfit: 8.9419e-01
# it: 24   it_marq:  5   lambda: 1e+04   misfit: 8.9432e-01
# it: 24   it_marq:  6   lambda: 1e+05   misfit: 8.9434e-01
# it: 24   it_marq:  7   lambda: 1e+06   misfit: 8.9434e-01
# it: 24   it_marq:  8   lambda: 1e+07   misfit: 8.9434e-01
# it: 24   it_marq:  9   lambda: 1e+08   misfit: 8.9434e-01
# it: 25   it_marq:  0   lambda: 1e+09   misfit: 8.9434e-01
# it: 25   it_marq:  1   lambda: 1e+10   misfit: 8.9434e-01
# it: 25   it_marq:  2   lambda: 1e+11   misfit: 8.9434e-01
# it: 25   it_marq:  3   lambda: 1e+12   misfit: 8.9434e-01
# it: 25   it_marq:  4   lambda: 1e+13   misfit: 8.9434e-01
# it: 25   it_marq:  5   lambda: 1e+14   misfit: 8.9434e-01
# it: 25   it_marq:  6   lambda: 1e+15   misfit: 8.9434e-01
# it: 25   it_marq:  7   lambda: 1e+16   misfit: 8.9434e-01
# it: 25   it_marq:  8   lambda: 1e+17   misfit: 8.9434e-01
# it: 25   it_marq:  9   lambda: 1e+18   misfit: 8.9434e-01
# it: 26   it_marq:  0   lambda: 1e+19   misfit: 8.9434e-01
# it: 26   it_marq:  1   lambda: 1e+20   misfit: 8.9434e-01
# it: 26   it_marq:  2   lambda: 1e+21   misfit: 8.9434e-01
# it: 26   it_marq:  3   lambda: 1e+22   misfit: 8.9434e-01
# it: 26   it_marq:  4   lambda: 1e+23   misfit: 8.9434e-01
# it: 26   it_marq:  5   lambda: 1e+24   misfit: 8.9434e-01
# it: 26   it_marq:  6   lambda: 1e+25   misfit: 8.9434e-01
# it: 26   it_marq:  7   lambda: 1e+26   misfit: 8.9434e-01
# it: 26   it_marq:  8   lambda: 1e+27   misfit: 8.9434e-01
# it: 26   it_marq:  9   lambda: 1e+28   misfit: 8.9434e-01
# it: 27   it_marq:  0   lambda: 1e+29   misfit: 8.9434e-01
# it: 27   it_marq:  1   lambda: 1e+30   misfit: 8.9434e-01
# it: 27   it_marq:  2   lambda: 1e+31   misfit: 8.9434e-01
# it: 27   it_marq:  3   lambda: 1e+32   misfit: 8.9434e-01
# it: 27   it_marq:  4   lambda: 1e+33   misfit: 8.9434e-01
# it: 27   it_marq:  5   lambda: 1e+34   misfit: 8.9434e-01
# it: 27   it_marq:  6   lambda: 1e+35   misfit: 8.9434e-01
# it: 27   it_marq:  7   lambda: 1e+36   misfit: 8.9434e-01
# it: 27   it_marq:  8   lambda: 1e+37   misfit: 8.9434e-01
# it: 27   it_marq:  9   lambda: 1e+38   misfit: 8.9434e-01
# it: 28   it_marq:  0   lambda: 1e+39   misfit: 8.9434e-01
# it: 28   it_marq:  1   lambda: 1e+40   misfit: 8.9434e-01
# it: 28   it_marq:  2   lambda: 1e+41   misfit: 8.9434e-01
# it: 28   it_marq:  3   lambda: 1e+42   misfit: 8.9434e-01
# it: 28   it_marq:  4   lambda: 1e+43   misfit: 8.9434e-01
# it: 28   it_marq:  5   lambda: 1e+44   misfit: 8.9434e-01
# it: 28   it_marq:  6   lambda: 1e+45   misfit: 8.9434e-01
# it: 28   it_marq:  7   lambda: 1e+46   misfit: 8.9434e-01
# it: 28   it_marq:  8   lambda: 1e+47   misfit: 8.9434e-01
# it: 28   it_marq:  9   lambda: 1e+48   misfit: 8.9434e-01
# it: 29   it_marq:  0   lambda: 1e+49   misfit: 8.9434e-01
# it: 29   it_marq:  1   lambda: 1e+50   misfit: 8.9434e-01
# it: 29   it_marq:  2   lambda: 1e+51   misfit: 8.9434e-01
# it: 29   it_marq:  3   lambda: 1e+52   misfit: 8.9434e-01
# it: 29   it_marq:  4   lambda: 1e+53   misfit: 8.9434e-01
# it: 29   it_marq:  5   lambda: 1e+54   misfit: 8.9434e-01
# it: 29   it_marq:  6   lambda: 1e+55   misfit: 8.9434e-01
# it: 29   it_marq:  7   lambda: 1e+56   misfit: 8.9434e-01
# it: 29   it_marq:  8   lambda: 1e+57   misfit: 8.9434e-01
# it: 29   it_marq:  9   lambda: 1e+58   misfit: 8.9434e-01

# %% [markdown]
# # Results

# %%
res = dobs - d_fit
res_norm = (res - np.mean(res))/np.std(res) # residue normalization

# %%
plt.figure(figsize=(6,5))
plt.title("Residual data", fontsize = 18)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm, regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
#estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
#estimate.set_label('Final estimate')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()
plt.savefig('figs/kimberlite_amf_td_fit.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_amf_td_fit.png', width=400, height=400)
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plt.figure(figsize=(6,5))
plt.title('Histogram', fontsize = 20)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res_norm), np.std(res_norm)), fontsize=20)
nbins = int((np.max(res_norm) - np.min(res_norm)))
n, bins, patches = plt.hist(res_norm,bins=nbins, normed=True, color='blue')
gauss = normpdf(bins, np.mean(res_norm), np.std(res_norm))
plt.plot(bins, gauss, 'k--', linewidth=2., label='Gaussian')
plt.ylim(0.,0.5)
plt.xlim(-10., 10.)
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')

plt.savefig('figs/kimberlite_amf_td_hist.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_amf_td_hist.png', width=400, height=400)

# %%
plt.title('Convergence', fontsize = 18)
plt.xlabel('Iteration number')
plt.plot(phi_list, 'b-', label='Misfit value')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')

plt.savefig('figs/kimberlite_amf_td_convergence.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_amf_td_convergence.png', width=400, height=400)

# %%
bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-0.089204656936016313, -0.066107174155361687, -0.04083578885723696]
scene.scene.camera.focal_point = [1.1820671636724554e-16, 1.3134079596360617e-17, -1.9701119394540926e-17]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.24683390337942718, 0.24593292331329802, -0.93733132955911114]
scene.scene.camera.clipping_range = [0.057117737884348194, 0.1956040854922288]
scene.scene.camera.compute_view_plane_normal()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_td_bolacha1.png')
myv.show()

img(filename='figs/kimberlite_amf_td_bolacha1.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [1387.431758173668, 3940.587088035918, -711.23575855995603]
scene.scene.camera.focal_point = [-1.9226665366075403e-12, -3.8453330732150806e-12, 425.00000000000171]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.053368194299606389, -0.25926638141600067, -0.96433022316250794]
scene.scene.camera.clipping_range = [2297.6930207290479, 6897.4792769581109]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_td_bolacha2.png')
myv.show()

img(filename='figs/kimberlite_amf_td_bolacha2.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-312.73912567501554, -3561.7262362085721, 287.67386774078057]
scene.scene.camera.focal_point = [1.9226665366075399e-12, -2.4033331707594249e-12, 425.00000000000017]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.13341196746632145, 0.026483446094695474, -0.99070675480674641]
scene.scene.camera.clipping_range = [1993.7950353893316, 5580.9677877221075]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_td_bolacha3.png')
myv.show()

img(filename='figs/kimberlite_amf_td_bolacha3.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-1358.4495936442941, 3241.6425529534445, 1095.0196037678566]
scene.scene.camera.focal_point = [1.1115415914762344e-12, 4.8066663415188518e-13, 424.99999999999943]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.069838400113651236, 0.17376780317072943, -0.98230715585848405]
scene.scene.camera.clipping_range = [1555.7568575367334, 6132.3676045661978]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_td_bolacha4.png')
myv.show()

img(filename='figs/kimberlite_amf_td_bolacha4.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-330e3d66819b> in <module>()
#      53 myv.wall_north(ax.axes.bounds)
#      54 #myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
# ---> 55 myv.savefig('figs/kimberlite_amf_td_bolacha2.png')
#      56 myv.show()
#      57
#
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.pyc in savefig(fname, magnification)
#     131     _lazy_import_mlab()
#     132     if magnification is None:
# --> 133         mlab.savefig(fname)
#     134     else:
#     135         mlab.savefig(fname, magnification=magnification)
#
# /home/leonardo/anaconda2/lib/python2.7/site-packages/mayavi/tools/figure.pyc in savefig(filename, size, figure, magnification, **kwargs)
#     248                             **kwargs)
#     249     finally:
# --> 250         figure.scene.magnification = int(current_mag)
#     251
#     252
#
# AttributeError: 'NoneType' object has no attribute 'magnification'
