# %% [markdown]
# # Inversion of total field anomaly data produced by a synthetic kimberlitic model

# %% [markdown]
# This notebook runs inversion of total field anomaly data using Levenberg-Marquadt's algorithm. The data was generated from a synthetic kimberlitic model using the polygonal prisms function from fatiando.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../synthetic_data/kimberlite/kimberlite_model.pickle') as w:
        kimberlite_model = pickle.load(w)

# %%
img(filename='../synthetic_data/kimberlite/kimberlite_true.png')

# %% [markdown]
# ### Observation points and observed data

# %%
with open('../synthetic_data/grids/regular_grid.pickle') as w:
        regular_grid = pickle.load(w)

# %%
with open('../synthetic_data/kimberlite/kimberlite_data.pickle') as w:
        kimberlite_data = pickle.load(w)

# %%
img(filename='../synthetic_data/kimberlite/obs_tfa.png', width=400, height=400)

# %% [markdown]
# ### Parameters for inversion

# %%
M = 10 # number of vertices per prism
L = 8 # number of prisms
P = L*(M+2) + 1 # number of parameters

# limits for parameters in meters
rmin = 10.
rmax = 1300.
x0min = -1300.
x0max = 1300.
y0min = -1300.
y0max = 1300.
dzmin = 10.
dzmax = 300.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

itmax = 30
itmax_marq = 10
epsilon = 1.0e-5     # stop criterion

deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)# increment of derivatives
deltaz = 0.01*np.max(dzmax)
m_out = np.zeros(M + 2)  # outcropping body parameters
#m_out = kimberlite_model['param_vec'][:M+2]

inc = -19.7
dec = - 14.3
z0 = kimberlite_model['z0']
dz = 200.
props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc, dec)}
dobs = kimberlite_data['tfa_obs']
xp = regular_grid['xp']
yp = regular_grid['yp']
zp = regular_grid['zp']
N = regular_grid['N']#[0]*regular_grid['shape'][1]

rin = np.zeros(M) + 600.
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) # inicial parameters vector
m0 = np.hstack((m0, dz))
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms
d0 = polyprism.tf(xp, yp, zp, model0, inc, dec) # predict data
res0 = dobs - d0

# %% [markdown]
# ### Plotting the source and intial estimate

# %% [raw]
# bounds = [-700., 700., -700., 700., -100., 950.]
#
# red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
# white, black = (1, 1, 1), (0, 0, 0),
#
# # Show the model
# scene = myv.figure()
# true = myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue)
# myv.polyprisms(model0, 'magnetization', opacity=.32, color=red)
#
# ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
# ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
# ax.axes.font_factor = 1.65
# scene.scene.camera.position = [-3566.1035732701748, -2440.7585385434886, 160.74965988407459]
# scene.scene.camera.focal_point = [-1.9226665366075395e-12, -3.3646664390631945e-12, 425.00000000000159]
# scene.scene.camera.view_angle = 30.0
# scene.scene.camera.view_up = [0.018389012839469615, 0.081023817450175964, -0.99654251550678474]
# scene.scene.camera.clipping_range = [2289.6962031406597, 6907.5456227163704]
# scene.scene.camera.compute_view_plane_normal()
# scene.scene.render()
#
# myv.wall_bottom(ax.axes.bounds, opacity=0.2)
# myv.wall_north(ax.axes.bounds)
#
# myv.savefig('figs/kimberlite_tfa_wd_true_initial.png')
# myv.show()

# %%
img(filename='figs/kimberlite_tfa_wd_true_initial.png')

# %% [markdown]
# ### Observed TFA with initial estimate

# %%
plt.figure(figsize=(6,5))
plt.title('Observed TFA', fontsize=20)
plt.tricontourf(regular_grid['yp'], regular_grid['xp'], kimberlite_data['tfa_obs'], 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)
plt.savefig('figs/kimberlite_tfa_wd_obs_data_true_inital.png', dpi=300)
plt.show()

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.007   # adjacent radial distances within each prism
a2 = 0.01   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.5     # vertically adjacent origins
a6 = 0.0001   # zero order Tikhonov on adjacent radial distances
a7 = 0.0001     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Inversion

# %%
d_fit, m_est, model_est, phi_list = mfun.levmarq_tf(xp, yp, zp, m0, M, L, delta, itmax,
                                                    itmax_marq, lamb, dlamb, epsilon,
                                                    mmin, mmax, m_out, dobs, inc, dec,
                                                    props, alpha, z0, dz)
# Out:
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.76877e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.55737e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 7.25278e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.91156e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 9.76262e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.18715e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.08211e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 3.54332e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 2.15119e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.79670e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 2.26814e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.72903e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 2.60013e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.70495e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 2.87684e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.70252e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 3.11224e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.71552e+01
# it: 10   it_marq:  2   lambda: 1e+01   misfit: 1.64975e+01
# it: 11   it_marq:  0   lambda: 1e+00   misfit: 1.70677e+01
# it: 11   it_marq:  1   lambda: 1e+01   misfit: 1.63255e+01
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 1.70247e+01
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 1.62524e+01
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 1.70082e+01
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 1.62170e+01
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 1.70077e+01
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 1.61980e+01
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 1.70170e+01
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.61874e+01
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 1.70326e+01
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.61817e+01
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 1.70524e+01
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.61790e+01
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 1.70755e+01
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 1.61787e+01
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.71009e+01
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 1.61801e+01
# it: 19   it_marq:  2   lambda: 1e+02   misfit: 1.61739e+01
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.61783e+01
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.61702e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.61767e+01
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.61670e+01
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.61754e+01
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.61642e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 1.61743e+01
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.61619e+01
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 1.61733e+01
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 1.61598e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.61726e+01
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.61581e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.61719e+01
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 1.61565e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 1.61714e+01
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 1.61552e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.61709e+01
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 1.61541e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.61706e+01
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 1.61532e+01

# %% [markdown]
# # Results

# %%
res = dobs - d_fit

# %%
residual = plt.figure(figsize=(6,5))
plt.title("Residual data", fontsize = 18)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res, regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
#estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
estimate.set_label('Final estimate')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()
plt.savefig('figs/kimberlite_tfa_wd_fit.png', dpi=300)
plt.show()
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plt.figure(figsize=(6,5))
plt.title('Histogram', fontsize = 20)
plt.xlabel('$\mu$ = %.7f  $\sigma$ = %.7f' % (np.mean(res), np.std(res)), fontsize=20)
nbins = 20
n, bins, patches = plt.hist(res,bins=nbins, normed=True, color='blue')
gauss = normpdf(bins, np.mean(res), np.std(res))
plt.plot(bins, gauss, 'k--', linewidth=2., label='Gaussian')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)

plt.savefig('figs/kimberlite_tfa_wd_hist.png', dpi=300)
plt.show()

# %%
plt.title('Convergence', fontsize = 18)
plt.xlabel('Iteration number')
plt.plot(phi_list, 'b-', label='Misfit value')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1)

plt.savefig('figs/kimberlite_tfa_wd_convergence.png', dpi=300)
plt.show()

# %%
bounds = [-700., 700., -700., 700., -100., 950.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-0.089204656936016313, -0.066107174155361687, -0.04083578885723696]
scene.scene.camera.focal_point = [1.1820671636724554e-16, 1.3134079596360617e-17, -1.9701119394540926e-17]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.24683390337942718, 0.24593292331329802, -0.93733132955911114]
scene.scene.camera.clipping_range = [0.057117737884348194, 0.1956040854922288]
scene.scene.camera.compute_view_plane_normal()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_wd_bolacha1.png')
myv.show()

img(filename='figs/kimberlite_tfa_wd_bolacha1.png')

bounds = [-700., 700., -700., 700., -100., 950.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [1387.431758173668, 3940.587088035918, -711.23575855995603]
scene.scene.camera.focal_point = [-1.9226665366075403e-12, -3.8453330732150806e-12, 425.00000000000171]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.053368194299606389, -0.25926638141600067, -0.96433022316250794]
scene.scene.camera.clipping_range = [2297.6930207290479, 6897.4792769581109]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_wd_bolacha2.png')
myv.show()

img(filename='figs/kimberlite_tfa_wd_bolacha2.png')

bounds = [-700., 700., -700., 700., -100., 950.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-312.73912567501554, -3561.7262362085721, 287.67386774078057]
scene.scene.camera.focal_point = [1.9226665366075399e-12, -2.4033331707594249e-12, 425.00000000000017]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.13341196746632145, 0.026483446094695474, -0.99070675480674641]
scene.scene.camera.clipping_range = [1993.7950353893316, 5580.9677877221075]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_wd_bolacha3.png')
myv.show()

img(filename='figs/kimberlite_tfa_wd_bolacha3.png')

bounds = [-700., 700., -700., 700., -100., 950.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est, 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-1358.4495936442941, 3241.6425529534445, 1095.0196037678566]
scene.scene.camera.focal_point = [1.1115415914762344e-12, 4.8066663415188518e-13, 424.99999999999943]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.069838400113651236, 0.17376780317072943, -0.98230715585848405]
scene.scene.camera.clipping_range = [1555.7568575367334, 6132.3676045661978]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_wd_bolacha4.png')
myv.show()

img(filename='figs/kimberlite_tfa_wd_bolacha4.png')
