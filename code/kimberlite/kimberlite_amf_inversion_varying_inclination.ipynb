# %% [markdown]
# # Inversion of amplitude of anomalous magnetic field data produced by a synthetic kimberlitic model varying the magnetic inclination

# %% [markdown]
# This notebook runs inversion of amplitude of anomalous magnetic field data using Levenberg-Marquadt's algorithm. The data was generated from a kimberlitic model using the poligonal prisms function from fatiando.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../../synthetic_data/kimberlite/kimberlite_model.pickle') as w:
        kimberlite_model = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/kimberlite_true.png')

# %% [markdown]
# ### Observation points and observed data

# %%
with open('../../synthetic_data/grids/regular_grid.pickle') as w:
        regular_grid = pickle.load(w)

# %%
with open('../../synthetic_data/kimberlite/kimberlite_data.pickle') as w:
        kimberlite_data = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/obs_amf.png', width=400, height=400)

# %% [markdown]
# ### Parameters for inversion

# %%
M = 10 # number of vertices per prism
L = 8 # number of prisms
P = L*(M+2) + 1 # number of parameters

# limits for parameters in meters
rmin = 10.
rmax = 1300.
x0min = -1300.
x0max = 1300.
y0min = -1300.
y0max = 1300.
dzmin = 10.
dzmax = 300.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

itmax = 30
itmax_marq = 10
epsilon = 1.0e-5     # stop criterion

deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)# increment of derivatives
deltaz = 0.01*np.max(dzmax)
m_out = np.zeros(M + 2)  # outcropping body parameters
#m_out = kimberlite_model['param_vec'][:M+2]

inc = kimberlite_model['inc']
dec = kimberlite_model['dec']
z0 = kimberlite_model['z0']
dz = 200.
props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc, dec)}
dobs = kimberlite_data['amf_obs']
xp = regular_grid['xp']
yp = regular_grid['yp']
zp = regular_grid['zp']
N = regular_grid['N']

rin = np.zeros(M) + 600.
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) # inicial parameters vector
m0 = np.hstack((m0, dz))
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms
d0 = np.sqrt(polyprism.bx(xp, yp, zp, model0)**2. + \
             polyprism.by(xp, yp, zp, model0)**2. + \
             polyprism.bz(xp, yp, zp, model0)**2.)

# %% [markdown]
# ### Plotting the source and intial estimate

# %% [raw]
# bounds = [-700., 700., -700., 700., 50., 1750.]
#
# red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
# white, black = (1, 1, 1), (0, 0, 0),
#
# # Show the model
# scene = myv.figure()
# true = myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue)
# myv.polyprisms(model0, 'magnetization', opacity=.3, color=red)
#
# ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
# ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
# ax.axes.font_factor = 1.65
# scene.scene.camera.position = [-3919.9507356190898, -1492.5522124519537, 257.35943615138984]
# scene.scene.camera.focal_point = [3.2652212480582674e-12, -5.5975221395284579e-12, 500.00000000000028]
# scene.scene.camera.view_angle = 30.0
# scene.scene.camera.view_up = [0.028518032872962465, 0.086986891505218447, -0.99580118623514213]
# scene.scene.camera.clipping_range = [2313.2627909979883, 6588.5353642863038]
# scene.scene.camera.compute_view_plane_normal()
# scene.scene.render()
#
# myv.wall_bottom(ax.axes.bounds, opacity=0.2)
# myv.wall_north(ax.axes.bounds)
#
# myv.savefig('figs/kimberlite_amf_td_true_initial.png')
# myv.show()

# %%
img(filename='figs/kimberlite_amf_td_true_initial.png')

# %% [markdown]
# ### Observed AMF with initial estimate

# %%
plt.figure(figsize=(6,5))
plt.title('Observed AMF', fontsize=20)
plt.tricontourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
plt.savefig('figs/kimberlite_amf_obs_data_true_inital.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_amf_obs_data_true_inital.png', width=400, height=400)

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.002   # adjacent radial distances within each prism
a2 = 0.01   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.06     # vertically adjacent origins
a6 = 0.000001   # zero order Tikhonov on adjacent radial distances
a7 = 0.0000001     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Inversion

# %%
d_fit_list = []
m_est_list = []
model_est_list = []
phi_list_list = []

for i in range(10):
    print 'inclination:', inc + i
    props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc + i, dec)}
    d_fit, m_est, model_est, phi_list = mfun.levmarq_amf(xp, yp, zp, m0, M, L, delta, itmax,
                                                        itmax_marq, lamb, dlamb, epsilon,
                                                        mmin, mmax, m_out, dobs, props, alpha, z0, dz)
    d_fit_list.append(d_fit)
    m_est_list.append(m_est)
    model_est_list.append(model_est)
    phi_list_list.append(phi_list)
# Out:
# inclination: -21.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.9979e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.1799e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.3372e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.1022e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 3.3293e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 1.1440e+02
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 9.6343e+01
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 1.6475e+01
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 2.6123e+01
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 1.3028e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 2.1959e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.1027e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 1.8162e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 9.8185e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.5241e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 9.0140e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.3054e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.4394e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.1426e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.0128e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.0216e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 7.6900e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 9.3142e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 7.4438e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 8.6386e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 7.2552e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.1298e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 7.1103e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 7.7447e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 6.9990e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 7.4526e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 6.9134e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 7.2311e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 6.8479e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 7.0638e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 6.7982e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 6.9386e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 6.7609e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 6.8465e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 6.7336e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 6.7807e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 6.7143e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 6.7360e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 6.7017e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 6.7084e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 6.6945e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 6.6947e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 6.6918e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 6.6926e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 6.6930e+00
# it: 26   it_marq:  2   lambda: 1e+01   misfit: 6.6921e+00
# it: 26   it_marq:  3   lambda: 1e+02   misfit: 6.6937e+00
# it: 26   it_marq:  4   lambda: 1e+03   misfit: 6.6944e+00
# it: 26   it_marq:  5   lambda: 1e+04   misfit: 6.6944e+00
# it: 26   it_marq:  6   lambda: 1e+05   misfit: 6.6945e+00
# it: 26   it_marq:  7   lambda: 1e+06   misfit: 6.6945e+00
# it: 26   it_marq:  8   lambda: 1e+07   misfit: 6.6945e+00
# it: 26   it_marq:  9   lambda: 1e+08   misfit: 6.6945e+00
# it: 27   it_marq:  0   lambda: 1e+09   misfit: 6.6947e+00
# it: 27   it_marq:  1   lambda: 1e+10   misfit: 6.6947e+00
# it: 27   it_marq:  2   lambda: 1e+11   misfit: 6.6947e+00
# it: 27   it_marq:  3   lambda: 1e+12   misfit: 6.6947e+00
# it: 27   it_marq:  4   lambda: 1e+13   misfit: 6.6947e+00
# it: 27   it_marq:  5   lambda: 1e+14   misfit: 6.6947e+00
# it: 27   it_marq:  6   lambda: 1e+15   misfit: 6.6947e+00
# it: 27   it_marq:  7   lambda: 1e+16   misfit: 6.6947e+00
# it: 27   it_marq:  8   lambda: 1e+17   misfit: 6.6947e+00
# it: 27   it_marq:  9   lambda: 1e+18   misfit: 6.6947e+00
# it: 28   it_marq:  0   lambda: 1e+19   misfit: 6.6949e+00
# it: 28   it_marq:  1   lambda: 1e+20   misfit: 6.6949e+00
# it: 28   it_marq:  2   lambda: 1e+21   misfit: 6.6949e+00
# it: 28   it_marq:  3   lambda: 1e+22   misfit: 6.6949e+00
# it: 28   it_marq:  4   lambda: 1e+23   misfit: 6.6949e+00
# it: 28   it_marq:  5   lambda: 1e+24   misfit: 6.6949e+00
# it: 28   it_marq:  6   lambda: 1e+25   misfit: 6.6949e+00
# it: 28   it_marq:  7   lambda: 1e+26   misfit: 6.6949e+00
# it: 28   it_marq:  8   lambda: 1e+27   misfit: 6.6949e+00
# it: 28   it_marq:  9   lambda: 1e+28   misfit: 6.6949e+00
# it: 29   it_marq:  0   lambda: 1e+29   misfit: 6.6951e+00
# it: 29   it_marq:  1   lambda: 1e+30   misfit: 6.6951e+00
# it: 29   it_marq:  2   lambda: 1e+31   misfit: 6.6951e+00
# it: 29   it_marq:  3   lambda: 1e+32   misfit: 6.6951e+00
# it: 29   it_marq:  4   lambda: 1e+33   misfit: 6.6951e+00
# it: 29   it_marq:  5   lambda: 1e+34   misfit: 6.6951e+00
# it: 29   it_marq:  6   lambda: 1e+35   misfit: 6.6951e+00
# it: 29   it_marq:  7   lambda: 1e+36   misfit: 6.6951e+00
# it: 29   it_marq:  8   lambda: 1e+37   misfit: 6.6951e+00
# it: 29   it_marq:  9   lambda: 1e+38   misfit: 6.6951e+00
# inclination: -20.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.9470e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.1396e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.3227e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.0844e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.0713e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.5217e+02
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 3.1117e+02
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 1.9693e+01
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 3.1911e+01
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 1.4277e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 2.7146e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.1879e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 2.2445e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.0605e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.8853e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 9.7739e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.6159e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 9.1762e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.4162e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.7325e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.2687e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.4009e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 1.1590e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.1522e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 1.0761e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 7.9649e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 1.0125e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 7.8227e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 9.6294e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 7.7142e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 9.2391e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 7.6311e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.9285e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 7.5676e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.6794e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 7.5193e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.4786e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 7.4832e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.3161e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 7.4571e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 8.1844e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 7.4391e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 8.0777e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 7.4279e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 7.9916e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 7.4224e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 7.9226e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 7.4218e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 7.8678e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 7.4252e+00
# it: 26   it_marq:  2   lambda: 1e+01   misfit: 7.4190e+00
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 7.4322e+00
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 7.4265e+00
# it: 27   it_marq:  2   lambda: 1e+02   misfit: 7.4243e+00
# it: 27   it_marq:  3   lambda: 1e+03   misfit: 7.4242e+00
# it: 27   it_marq:  4   lambda: 1e+04   misfit: 7.4242e+00
# it: 27   it_marq:  5   lambda: 1e+05   misfit: 7.4242e+00
# it: 27   it_marq:  6   lambda: 1e+06   misfit: 7.4242e+00
# it: 27   it_marq:  7   lambda: 1e+07   misfit: 7.4242e+00
# it: 27   it_marq:  8   lambda: 1e+08   misfit: 7.4242e+00
# it: 27   it_marq:  9   lambda: 1e+09   misfit: 7.4242e+00
# it: 28   it_marq:  0   lambda: 1e+10   misfit: 7.4239e+00
# it: 29   it_marq:  0   lambda: 1e+09   misfit: 7.4236e+00
# inclination: -19.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.8988e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.1015e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.3094e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.0745e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 4.9557e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 7.3493e+02
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 6.2890e+02
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 2.8097e+01
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 3.9629e+01
# it:  6   it_marq:  1   lambda: 1e+00   misfit: 1.6515e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 3.3794e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.3015e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 2.7464e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.1586e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 2.3016e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.0737e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.9825e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.0148e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.7544e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 9.7265e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.5902e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 9.4226e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 1.4689e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 9.2007e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 1.3768e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 9.0360e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 1.3054e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.9119e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 1.2490e+01
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.8178e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 1.2043e+01
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.7472e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 1.1686e+01
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 8.6953e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 1.1401e+01
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 8.6590e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 1.1174e+01
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 8.6356e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 1.0993e+01
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 8.6226e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 1.0850e+01
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 8.6181e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 1.0738e+01
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 8.6204e+00
# it: 23   it_marq:  2   lambda: 1e+01   misfit: 8.5918e+00
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 8.6310e+00
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 8.6066e+00
# it: 24   it_marq:  2   lambda: 1e+02   misfit: 8.6037e+00
# it: 24   it_marq:  3   lambda: 1e+03   misfit: 8.6040e+00
# it: 24   it_marq:  4   lambda: 1e+04   misfit: 8.6041e+00
# it: 24   it_marq:  5   lambda: 1e+05   misfit: 8.6041e+00
# it: 24   it_marq:  6   lambda: 1e+06   misfit: 8.6041e+00
# it: 24   it_marq:  7   lambda: 1e+07   misfit: 8.6041e+00
# it: 24   it_marq:  8   lambda: 1e+08   misfit: 8.6041e+00
# it: 24   it_marq:  9   lambda: 1e+09   misfit: 8.6041e+00
# it: 25   it_marq:  0   lambda: 1e+10   misfit: 8.6031e+00
# it: 26   it_marq:  0   lambda: 1e+09   misfit: 8.6022e+00
# it: 27   it_marq:  0   lambda: 1e+08   misfit: 8.6013e+00
# it: 28   it_marq:  0   lambda: 1e+07   misfit: 8.6004e+00
# it: 29   it_marq:  0   lambda: 1e+06   misfit: 8.5995e+00
# inclination: -18.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.8533e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.0657e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2973e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.0726e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 5.9684e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 1.1241e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 9.1909e+02
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.9899e+01
# it:  6   it_marq:  0   lambda: 1e-01   misfit: 3.9304e+01
# it:  7   it_marq:  0   lambda: 1e-02   misfit: 2.5378e+02
# it:  7   it_marq:  1   lambda: 1e-01   misfit: 1.2932e+02
# it:  7   it_marq:  2   lambda: 1e+00   misfit: 1.7370e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 1.1171e+01
# it:  9   it_marq:  0   lambda: 1e-02   misfit: 2.5646e+02
# it:  9   it_marq:  1   lambda: 1e-01   misfit: 2.6696e+01
# it:  9   it_marq:  2   lambda: 1e+00   misfit: 9.9696e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 2.6445e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 9.8149e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 2.5792e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 9.8985e+00
# it: 11   it_marq:  2   lambda: 1e+01   misfit: 9.7361e+00
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 9.9442e+00
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 9.7678e+00
# it: 12   it_marq:  2   lambda: 1e+02   misfit: 9.7535e+00
# it: 12   it_marq:  3   lambda: 1e+03   misfit: 9.7440e+00
# it: 12   it_marq:  4   lambda: 1e+04   misfit: 9.7430e+00
# it: 12   it_marq:  5   lambda: 1e+05   misfit: 9.7429e+00
# it: 12   it_marq:  6   lambda: 1e+06   misfit: 9.7429e+00
# it: 12   it_marq:  7   lambda: 1e+07   misfit: 9.7429e+00
# it: 12   it_marq:  8   lambda: 1e+08   misfit: 9.7429e+00
# it: 12   it_marq:  9   lambda: 1e+09   misfit: 9.7429e+00
# it: 13   it_marq:  0   lambda: 1e+10   misfit: 9.7404e+00
# it: 14   it_marq:  0   lambda: 1e+09   misfit: 9.7380e+00
# it: 15   it_marq:  0   lambda: 1e+08   misfit: 9.7356e+00
# it: 16   it_marq:  0   lambda: 1e+07   misfit: 9.7333e+00
# it: 17   it_marq:  0   lambda: 1e+06   misfit: 9.7310e+00
# it: 18   it_marq:  0   lambda: 1e+05   misfit: 9.7287e+00
# it: 19   it_marq:  0   lambda: 1e+04   misfit: 9.7266e+00
# it: 20   it_marq:  0   lambda: 1e+03   misfit: 9.7259e+00
# it: 21   it_marq:  0   lambda: 1e+02   misfit: 9.7371e+00
# it: 21   it_marq:  1   lambda: 1e+03   misfit: 9.7255e+00
# it: 22   it_marq:  0   lambda: 1e+02   misfit: 9.7374e+00
# it: 22   it_marq:  1   lambda: 1e+03   misfit: 9.7253e+00
# it: 23   it_marq:  0   lambda: 1e+02   misfit: 9.7378e+00
# it: 23   it_marq:  1   lambda: 1e+03   misfit: 9.7253e+00
# inclination: -17.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.8106e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.0321e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2863e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.0784e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 7.0924e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 1.5732e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.3115e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 1.0067e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 4.6141e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 2.7752e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.0819e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 1.9142e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 4.3583e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.5731e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 3.8189e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.4155e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 3.3191e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.3262e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 2.9075e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.2684e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 2.5993e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.2282e+01
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 2.3810e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.1996e+01
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 2.2299e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.1795e+01
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 2.1252e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 1.1656e+01
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 2.0525e+01
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 1.1559e+01
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 2.0035e+01
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 1.1488e+01
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 1.9749e+01
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 1.1441e+01
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 1.9667e+01
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 1.1423e+01
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 1.9806e+01
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 1.1450e+01
# it: 20   it_marq:  2   lambda: 1e+01   misfit: 1.1336e+01
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 1.1468e+01
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 1.1370e+01
# it: 21   it_marq:  2   lambda: 1e+02   misfit: 1.1361e+01
# it: 21   it_marq:  3   lambda: 1e+03   misfit: 1.1359e+01
# it: 21   it_marq:  4   lambda: 1e+04   misfit: 1.1359e+01
# it: 21   it_marq:  5   lambda: 1e+05   misfit: 1.1359e+01
# it: 21   it_marq:  6   lambda: 1e+06   misfit: 1.1359e+01
# it: 21   it_marq:  7   lambda: 1e+07   misfit: 1.1359e+01
# it: 21   it_marq:  8   lambda: 1e+08   misfit: 1.1359e+01
# it: 21   it_marq:  9   lambda: 1e+09   misfit: 1.1359e+01
# it: 22   it_marq:  0   lambda: 1e+10   misfit: 1.1356e+01
# it: 23   it_marq:  0   lambda: 1e+09   misfit: 1.1354e+01
# it: 24   it_marq:  0   lambda: 1e+08   misfit: 1.1352e+01
# it: 25   it_marq:  0   lambda: 1e+07   misfit: 1.1349e+01
# it: 26   it_marq:  0   lambda: 1e+06   misfit: 1.1347e+01
# it: 27   it_marq:  0   lambda: 1e+05   misfit: 1.1345e+01
# it: 28   it_marq:  0   lambda: 1e+04   misfit: 1.1343e+01
# it: 29   it_marq:  0   lambda: 1e+03   misfit: 1.1341e+01
# inclination: -16.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.7706e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 3.0008e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2765e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.0919e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.3075e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.1170e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.9584e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 2.0509e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 5.2045e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 3.3448e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.5966e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 2.1743e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 4.9309e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.7566e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 4.4309e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.5860e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 3.8698e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.4952e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 3.3894e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.4373e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 3.0559e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.3982e+01
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 2.8406e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.3719e+01
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 2.7014e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.3540e+01
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 2.6135e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 1.3412e+01
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 2.5696e+01
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 1.3325e+01
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 2.5705e+01
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 1.3297e+01
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 2.6193e+01
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 1.3367e+01
# it: 18   it_marq:  2   lambda: 1e+01   misfit: 1.3198e+01
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.3401e+01
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 1.3256e+01
# it: 19   it_marq:  2   lambda: 1e+02   misfit: 1.3233e+01
# it: 19   it_marq:  3   lambda: 1e+03   misfit: 1.3226e+01
# it: 19   it_marq:  4   lambda: 1e+04   misfit: 1.3225e+01
# it: 19   it_marq:  5   lambda: 1e+05   misfit: 1.3225e+01
# it: 19   it_marq:  6   lambda: 1e+06   misfit: 1.3225e+01
# it: 19   it_marq:  7   lambda: 1e+07   misfit: 1.3225e+01
# it: 19   it_marq:  8   lambda: 1e+08   misfit: 1.3225e+01
# it: 19   it_marq:  9   lambda: 1e+09   misfit: 1.3225e+01
# it: 20   it_marq:  0   lambda: 1e+10   misfit: 1.3223e+01
# it: 21   it_marq:  0   lambda: 1e+09   misfit: 1.3220e+01
# it: 22   it_marq:  0   lambda: 1e+08   misfit: 1.3217e+01
# it: 23   it_marq:  0   lambda: 1e+07   misfit: 1.3214e+01
# it: 24   it_marq:  0   lambda: 1e+06   misfit: 1.3211e+01
# it: 25   it_marq:  0   lambda: 1e+05   misfit: 1.3209e+01
# it: 26   it_marq:  0   lambda: 1e+04   misfit: 1.3206e+01
# it: 27   it_marq:  0   lambda: 1e+03   misfit: 1.3204e+01
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 1.3214e+01
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 1.3204e+01
# it: 29   it_marq:  0   lambda: 1e+02   misfit: 1.3215e+01
# it: 29   it_marq:  1   lambda: 1e+03   misfit: 1.3203e+01
# inclination: -15.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.7333e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 2.9719e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2678e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.1129e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 9.5914e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.8566e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 2.8398e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 3.7687e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 5.7614e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 3.8711e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.6077e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 2.4621e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 5.3944e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.9620e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 4.9589e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.7743e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 4.3726e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.6793e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 3.8848e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.6215e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 3.5658e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.5847e+01
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 3.3651e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.5601e+01
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 3.2507e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.5427e+01
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 3.2201e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 1.5331e+01
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 3.2765e+01
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 1.5372e+01
# it: 16   it_marq:  2   lambda: 1e+01   misfit: 1.5228e+01
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 1.5407e+01
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.5305e+01
# it: 17   it_marq:  2   lambda: 1e+02   misfit: 1.5275e+01
# it: 17   it_marq:  3   lambda: 1e+03   misfit: 1.5261e+01
# it: 17   it_marq:  4   lambda: 1e+04   misfit: 1.5259e+01
# it: 17   it_marq:  5   lambda: 1e+05   misfit: 1.5259e+01
# it: 17   it_marq:  6   lambda: 1e+06   misfit: 1.5259e+01
# it: 17   it_marq:  7   lambda: 1e+07   misfit: 1.5259e+01
# it: 17   it_marq:  8   lambda: 1e+08   misfit: 1.5259e+01
# it: 17   it_marq:  9   lambda: 1e+09   misfit: 1.5259e+01
# it: 18   it_marq:  0   lambda: 1e+10   misfit: 1.5256e+01
# it: 19   it_marq:  0   lambda: 1e+09   misfit: 1.5253e+01
# it: 20   it_marq:  0   lambda: 1e+08   misfit: 1.5250e+01
# it: 21   it_marq:  0   lambda: 1e+07   misfit: 1.5247e+01
# it: 22   it_marq:  0   lambda: 1e+06   misfit: 1.5244e+01
# it: 23   it_marq:  0   lambda: 1e+05   misfit: 1.5241e+01
# it: 24   it_marq:  0   lambda: 1e+04   misfit: 1.5239e+01
# it: 25   it_marq:  0   lambda: 1e+03   misfit: 1.5238e+01
# it: 26   it_marq:  0   lambda: 1e+02   misfit: 1.5256e+01
# it: 26   it_marq:  1   lambda: 1e+03   misfit: 1.5238e+01
# it: 26   it_marq:  2   lambda: 1e+04   misfit: 1.5236e+01
# it: 27   it_marq:  0   lambda: 1e+03   misfit: 1.5236e+01
# it: 28   it_marq:  0   lambda: 1e+02   misfit: 1.5255e+01
# it: 28   it_marq:  1   lambda: 1e+03   misfit: 1.5236e+01
# it: 28   it_marq:  2   lambda: 1e+04   misfit: 1.5234e+01
# it: 29   it_marq:  0   lambda: 1e+03   misfit: 1.5234e+01
# inclination: -14.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.6989e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 2.9452e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2603e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.1411e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.0920e+02
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.8623e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 3.5446e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 5.6326e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 6.2326e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.2288e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.4536e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 2.7440e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 5.6557e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 2.1804e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 5.3867e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.9755e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 4.8812e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.8767e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 4.4382e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.8202e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 4.1335e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.7841e+01
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 3.9626e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.7593e+01
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 3.9361e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.7480e+01
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 4.0527e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 1.7610e+01
# it: 15   it_marq:  2   lambda: 1e+01   misfit: 1.7398e+01
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 1.7680e+01
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.7517e+01
# it: 16   it_marq:  2   lambda: 1e+02   misfit: 1.7461e+01
# it: 16   it_marq:  3   lambda: 1e+03   misfit: 1.7435e+01
# it: 16   it_marq:  4   lambda: 1e+04   misfit: 1.7432e+01
# it: 16   it_marq:  5   lambda: 1e+05   misfit: 1.7432e+01
# it: 16   it_marq:  6   lambda: 1e+06   misfit: 1.7432e+01
# it: 16   it_marq:  7   lambda: 1e+07   misfit: 1.7432e+01
# it: 16   it_marq:  8   lambda: 1e+08   misfit: 1.7432e+01
# it: 16   it_marq:  9   lambda: 1e+09   misfit: 1.7432e+01
# it: 17   it_marq:  0   lambda: 1e+10   misfit: 1.7429e+01
# it: 18   it_marq:  0   lambda: 1e+09   misfit: 1.7426e+01
# it: 19   it_marq:  0   lambda: 1e+08   misfit: 1.7422e+01
# it: 20   it_marq:  0   lambda: 1e+07   misfit: 1.7419e+01
# it: 21   it_marq:  0   lambda: 1e+06   misfit: 1.7416e+01
# it: 22   it_marq:  0   lambda: 1e+05   misfit: 1.7413e+01
# it: 23   it_marq:  0   lambda: 1e+04   misfit: 1.7410e+01
# it: 24   it_marq:  0   lambda: 1e+03   misfit: 1.7411e+01
# it: 24   it_marq:  1   lambda: 1e+04   misfit: 1.7408e+01
# it: 25   it_marq:  0   lambda: 1e+03   misfit: 1.7408e+01
# it: 25   it_marq:  1   lambda: 1e+04   misfit: 1.7405e+01
# it: 26   it_marq:  0   lambda: 1e+03   misfit: 1.7406e+01
# it: 26   it_marq:  1   lambda: 1e+04   misfit: 1.7403e+01
# it: 27   it_marq:  0   lambda: 1e+03   misfit: 1.7403e+01
# it: 27   it_marq:  1   lambda: 1e+04   misfit: 1.7400e+01
# it: 28   it_marq:  0   lambda: 1e+03   misfit: 1.7401e+01
# it: 28   it_marq:  1   lambda: 1e+04   misfit: 1.7398e+01
# it: 29   it_marq:  0   lambda: 1e+03   misfit: 1.7399e+01
# it: 29   it_marq:  1   lambda: 1e+04   misfit: 1.7395e+01
# inclination: -13.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.6673e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 2.9209e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2539e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.1761e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.2268e+02
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 5.0171e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 4.0737e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 7.1125e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 6.5552e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.3963e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.5364e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 2.9990e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 5.7208e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 2.4081e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 5.7838e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 2.1905e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 5.4245e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 2.0889e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 5.0223e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 2.0311e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 4.7553e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.9933e+01
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 4.6993e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 1.9759e+01
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 4.8537e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 1.9940e+01
# it: 14   it_marq:  2   lambda: 1e+01   misfit: 1.9710e+01
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 2.0035e+01
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.9869e+01
# it: 15   it_marq:  2   lambda: 1e+02   misfit: 1.9788e+01
# it: 15   it_marq:  3   lambda: 1e+03   misfit: 1.9750e+01
# it: 15   it_marq:  4   lambda: 1e+04   misfit: 1.9746e+01
# it: 15   it_marq:  5   lambda: 1e+05   misfit: 1.9745e+01
# it: 15   it_marq:  6   lambda: 1e+06   misfit: 1.9745e+01
# it: 15   it_marq:  7   lambda: 1e+07   misfit: 1.9745e+01
# it: 15   it_marq:  8   lambda: 1e+08   misfit: 1.9745e+01
# it: 15   it_marq:  9   lambda: 1e+09   misfit: 1.9745e+01
# it: 16   it_marq:  0   lambda: 1e+10   misfit: 1.9742e+01
# it: 17   it_marq:  0   lambda: 1e+09   misfit: 1.9739e+01
# it: 18   it_marq:  0   lambda: 1e+08   misfit: 1.9736e+01
# it: 19   it_marq:  0   lambda: 1e+07   misfit: 1.9733e+01
# it: 20   it_marq:  0   lambda: 1e+06   misfit: 1.9729e+01
# it: 21   it_marq:  0   lambda: 1e+05   misfit: 1.9726e+01
# it: 22   it_marq:  0   lambda: 1e+04   misfit: 1.9724e+01
# it: 23   it_marq:  0   lambda: 1e+03   misfit: 1.9726e+01
# it: 23   it_marq:  1   lambda: 1e+04   misfit: 1.9722e+01
# it: 24   it_marq:  0   lambda: 1e+03   misfit: 1.9724e+01
# it: 24   it_marq:  1   lambda: 1e+04   misfit: 1.9719e+01
# it: 25   it_marq:  0   lambda: 1e+03   misfit: 1.9722e+01
# it: 25   it_marq:  1   lambda: 1e+04   misfit: 1.9717e+01
# it: 26   it_marq:  0   lambda: 1e+03   misfit: 1.9720e+01
# it: 26   it_marq:  1   lambda: 1e+04   misfit: 1.9715e+01
# it: 27   it_marq:  0   lambda: 1e+03   misfit: 1.9717e+01
# it: 27   it_marq:  1   lambda: 1e+04   misfit: 1.9713e+01
# it: 28   it_marq:  0   lambda: 1e+03   misfit: 1.9715e+01
# it: 28   it_marq:  1   lambda: 1e+04   misfit: 1.9710e+01
# it: 29   it_marq:  0   lambda: 1e+03   misfit: 1.9713e+01
# it: 29   it_marq:  1   lambda: 1e+04   misfit: 1.9708e+01
# inclination: -12.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 3.6386e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 2.8989e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 1.2485e+03
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 4.2174e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.3608e+02
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 6.0802e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 4.4628e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 8.4499e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 6.6613e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 4.4364e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 5.9814e+01
# it:  7   it_marq:  1   lambda: 1e+00   misfit: 3.2264e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 5.6816e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 2.6438e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 6.1732e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 2.4186e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 5.9629e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 2.3121e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 5.6304e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 2.2497e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 5.5037e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 2.2175e+01
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 5.6534e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 2.2309e+01
# it: 13   it_marq:  2   lambda: 1e+01   misfit: 2.2160e+01
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 2.2403e+01
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 2.2346e+01
# it: 14   it_marq:  2   lambda: 1e+02   misfit: 2.2253e+01
# it: 14   it_marq:  3   lambda: 1e+03   misfit: 2.2203e+01
# it: 14   it_marq:  4   lambda: 1e+04   misfit: 2.2196e+01
# it: 14   it_marq:  5   lambda: 1e+05   misfit: 2.2196e+01
# it: 14   it_marq:  6   lambda: 1e+06   misfit: 2.2196e+01
# it: 14   it_marq:  7   lambda: 1e+07   misfit: 2.2196e+01
# it: 14   it_marq:  8   lambda: 1e+08   misfit: 2.2196e+01
# it: 14   it_marq:  9   lambda: 1e+09   misfit: 2.2196e+01
# it: 15   it_marq:  0   lambda: 1e+10   misfit: 2.2193e+01
# it: 16   it_marq:  0   lambda: 1e+09   misfit: 2.2190e+01
# it: 17   it_marq:  0   lambda: 1e+08   misfit: 2.2187e+01
# it: 18   it_marq:  0   lambda: 1e+07   misfit: 2.2185e+01
# it: 19   it_marq:  0   lambda: 1e+06   misfit: 2.2182e+01
# it: 20   it_marq:  0   lambda: 1e+05   misfit: 2.2179e+01
# it: 21   it_marq:  0   lambda: 1e+04   misfit: 2.2177e+01
# it: 22   it_marq:  0   lambda: 1e+03   misfit: 2.2182e+01
# it: 22   it_marq:  1   lambda: 1e+04   misfit: 2.2176e+01
# it: 23   it_marq:  0   lambda: 1e+03   misfit: 2.2180e+01
# it: 23   it_marq:  1   lambda: 1e+04   misfit: 2.2174e+01
# it: 24   it_marq:  0   lambda: 1e+03   misfit: 2.2178e+01
# it: 24   it_marq:  1   lambda: 1e+04   misfit: 2.2172e+01
# it: 25   it_marq:  0   lambda: 1e+03   misfit: 2.2177e+01
# it: 25   it_marq:  1   lambda: 1e+04   misfit: 2.2170e+01
# it: 26   it_marq:  0   lambda: 1e+03   misfit: 2.2175e+01
# it: 26   it_marq:  1   lambda: 1e+04   misfit: 2.2169e+01
# it: 27   it_marq:  0   lambda: 1e+03   misfit: 2.2174e+01
# it: 27   it_marq:  1   lambda: 1e+04   misfit: 2.2167e+01
# it: 28   it_marq:  0   lambda: 1e+03   misfit: 2.2172e+01
# it: 28   it_marq:  1   lambda: 1e+04   misfit: 2.2166e+01
# it: 29   it_marq:  0   lambda: 1e+03   misfit: 2.2171e+01
# it: 29   it_marq:  1   lambda: 1e+04   misfit: 2.2164e+01

# %% [markdown]
# # Results

# %%
inc_list = []
for i in range(10):
    inc_list.append(inc + i)

# %%
res_norm = []
for d in d_fit_list:
    res = dobs - d
    res_norm.append((res - np.mean(res))/np.std(res)) # residue normalization

# %%
plt.figure(figsize=(12,20))
plt.subplot(5, 2, 1)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[0], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[0], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()
plt.suptitle('Residual data', fontsize=20)

plt.subplot(5, 2, 2)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[1], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[1], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 3)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[2], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[2], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 4)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[3], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[3], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 5)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[4], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[4], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 6)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[5], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[5], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 7)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[6], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[6], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 8)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[7], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[7], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 9)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[8], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[8], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 10)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[9], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[9], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.savefig('figs/kimberlite_amf_varying_inclination_fit.png', dpi=300)
#plt.show()

img(filename='figs/kimberlite_amf_varying_inclination_fit.png')

# %%
bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-0.089204656936016313, -0.066107174155361687, -0.04083578885723696]
scene.scene.camera.focal_point = [1.1820671636724554e-16, 1.3134079596360617e-17, -1.9701119394540926e-17]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.24683390337942718, 0.24593292331329802, -0.93733132955911114]
scene.scene.camera.clipping_range = [0.057117737884348194, 0.1956040854922288]
scene.scene.camera.compute_view_plane_normal()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_varying_inc_bolacha1.png')
myv.show()

img(filename='figs/kimberlite_amf_varying_inc_bolacha1.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [1387.431758173668, 3940.587088035918, -711.23575855995603]
scene.scene.camera.focal_point = [-1.9226665366075403e-12, -3.8453330732150806e-12, 425.00000000000171]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.053368194299606389, -0.25926638141600067, -0.96433022316250794]
scene.scene.camera.clipping_range = [2297.6930207290479, 6897.4792769581109]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_varying_inc_bolacha2.png')
myv.show()

img(filename='figs/kimberlite_amf_varying_inc_bolacha2.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-312.73912567501554, -3561.7262362085721, 287.67386774078057]
scene.scene.camera.focal_point = [1.9226665366075399e-12, -2.4033331707594249e-12, 425.00000000000017]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.13341196746632145, 0.026483446094695474, -0.99070675480674641]
scene.scene.camera.clipping_range = [1993.7950353893316, 5580.9677877221075]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_varying_inc_bolacha3.png')
myv.show()

img(filename='figs/kimberlite_amf_varying_inc_bolacha3.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-1358.4495936442941, 3241.6425529534445, 1095.0196037678566]
scene.scene.camera.focal_point = [1.1115415914762344e-12, 4.8066663415188518e-13, 424.99999999999943]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.069838400113651236, 0.17376780317072943, -0.98230715585848405]
scene.scene.camera.clipping_range = [1555.7568575367334, 6132.3676045661978]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_amf_varying_inc_bolacha4.png')
myv.show()

img(filename='figs/kimberlite_amf_varying_inc_bolacha4.png')
