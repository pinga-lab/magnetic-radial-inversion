# %% [markdown]
# # Inversion of amplitude of total field anomaly data produced by a synthetic kimberlitic model varying the magnetic inclination

# %% [markdown]
# This notebook runs inversion of amplitude of total field anomaly data using Levenberg-Marquadt's algorithm. The data was generated from a kimberlitic model using the poligonal prisms function from fatiando.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../../synthetic_data/kimberlite/kimberlite_model.pickle') as w:
        kimberlite_model = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/kimberlite_true.png')

# %% [markdown]
# ### Observation points and observed data

# %%
with open('../../synthetic_data/grids/regular_grid.pickle') as w:
        regular_grid = pickle.load(w)

# %%
with open('../../synthetic_data/kimberlite/kimberlite_data.pickle') as w:
        kimberlite_data = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/obs_tfa.png', width=400, height=400)

# %% [markdown]
# ### Parameters for inversion

# %%
M = 10 # number of vertices per prism
L = 8 # number of prisms
P = L*(M+2) + 1 # number of parameters

# limits for parameters in meters
rmin = 10.
rmax = 1300.
x0min = -1300.
x0max = 1300.
y0min = -1300.
y0max = 1300.
dzmin = 10.
dzmax = 300.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

itmax = 30
itmax_marq = 10
epsilon = 1.0e-5     # stop criterion

deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)# increment of derivatives
deltaz = 0.01*np.max(dzmax)
m_out = np.zeros(M + 2)  # outcropping body parameters
#m_out = kimberlite_model['param_vec'][:M+2]

inc = kimberlite_model['inc']
dec = kimberlite_model['dec']
z0 = kimberlite_model['z0']
dz = 200.
props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc, dec)}
dobs = kimberlite_data['tfa_obs']
xp = regular_grid['xp']
yp = regular_grid['yp']
zp = regular_grid['zp']
N = regular_grid['N']

rin = np.zeros(M) + 600.
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) # inicial parameters vector
m0 = np.hstack((m0, dz))
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms
d0 = np.sqrt(polyprism.bx(xp, yp, zp, model0)**2. + \
             polyprism.by(xp, yp, zp, model0)**2. + \
             polyprism.bz(xp, yp, zp, model0)**2.)

# %% [markdown]
# ### Plotting the source and intial estimate

# %% [raw]
# bounds = [-700., 700., -700., 700., 50., 1750.]
#
# red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
# white, black = (1, 1, 1), (0, 0, 0),
#
# # Show the model
# scene = myv.figure()
# true = myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue)
# myv.polyprisms(model0, 'magnetization', opacity=.3, color=red)
#
# ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
# ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
# ax.axes.font_factor = 1.65
# scene.scene.camera.position = [-3919.9507356190898, -1492.5522124519537, 257.35943615138984]
# scene.scene.camera.focal_point = [3.2652212480582674e-12, -5.5975221395284579e-12, 500.00000000000028]
# scene.scene.camera.view_angle = 30.0
# scene.scene.camera.view_up = [0.028518032872962465, 0.086986891505218447, -0.99580118623514213]
# scene.scene.camera.clipping_range = [2313.2627909979883, 6588.5353642863038]
# scene.scene.camera.compute_view_plane_normal()
# scene.scene.render()
#
# myv.wall_bottom(ax.axes.bounds, opacity=0.2)
# myv.wall_north(ax.axes.bounds)
#
# myv.savefig('figs/kimberlite_amf_td_true_initial.png')
# myv.show()

# %%
img(filename='figs/kimberlite_amf_td_true_initial.png')

# %% [markdown]
# ### Observed AMF with initial estimate

# %%
plt.figure(figsize=(6,5))
plt.title('Observed TFA', fontsize=20)
plt.tricontourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
plt.savefig('figs/kimberlite_tfa_obs_data_true_inital.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_tfa_obs_data_true_inital.png', width=400, height=400)

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.003   # adjacent radial distances within each prism
a2 = 0.006   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.03     # vertically adjacent origins
a6 = 0.00001   # zero order Tikhonov on adjacent radial distances
a7 = 0.000001     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Inversion

# %%
d_fit_list = []
m_est_list = []
model_est_list = []
phi_list_list = []

for i in range(10):
    print 'inclination:', inc + i
    props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc + i, dec)}
    d_fit, m_est, model_est, phi_list = mfun.levmarq_tf(xp, yp, zp, m0, M, L, delta, itmax,
                                                        itmax_marq, lamb, dlamb, epsilon,
                                                        mmin, mmax, m_out, dobs, inc, dec,
                                                        props, alpha, z0, dz)
    d_fit_list.append(d_fit)
    m_est_list.append(m_est)
    model_est_list.append(model_est)
    phi_list_list.append(phi_list)
# Out:
# inclination: -21.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7747e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.5009e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3751e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7351e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.3255e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.0728e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.5213e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.6749e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.2047e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 9.9774e+00
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 8.8041e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 9.6379e+00
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 8.9399e+00
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.3765e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 8.6398e+00
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.2450e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 8.4799e+00
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.1772e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 8.3724e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.1320e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 8.2925e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.0982e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 8.2304e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.0714e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 8.1811e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.0497e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.1410e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.0315e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 8.1081e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.0161e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.0807e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.0028e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.0575e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 7.9913e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.0378e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 7.9812e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.0209e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 7.9722e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.0063e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 7.9642e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 7.9935e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 7.9570e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 7.9823e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 7.9504e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 7.9723e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 7.9444e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 7.9635e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 7.9390e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 7.9556e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit:
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.2154e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 2.0682e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.1746e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 2.6619e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.1620e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 2.9949e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.1660e+01
# it: 10   it_marq:  2   lambda: 1e+01   misfit: 1.0795e+01
# it: 11   it_marq:  0   lambda: 1e+00   misfit: 1.1520e+01
# it: 11   it_marq:  1   lambda: 1e+01   misfit: 1.0568e+01
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 1.1449e+01
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 1.0485e+01
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 1.1418e+01
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 1.0446e+01
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 1.1408e+01
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 1.0423e+01
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 1.1411e+01
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.0409e+01
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 1.1420e+01
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.0398e+01
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 1.1434e+01
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.0390e+01
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 1.1451e+01
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 1.0385e+01
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.1471e+01
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 1.0381e+01
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 1.1494e+01
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 1.0379e+01
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 1.1519e+01
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 1.0378e+01
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 1.1547e+01
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 1.0379e+01
# it: 22   it_marq:  2   lambda: 1e+02   misfit: 1.0371e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 1.0376e+01
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.0366e+01
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 1.0374e+01
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 1.0361e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.0371e+01
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.0357e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.0369e+01
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 1.0354e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 1.0368e+01
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 1.0352e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.0366e+01
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 1.0349e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.0365e+01
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 1.0348e+01
# inclination: -12.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7198e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4532e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.1697e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.6917e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 1.2672e+02
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.1355e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 2.2453e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 1.3376e+03
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 2.3536e+02
# it:  5   it_marq:  4   lambda: 1e+02   misfit: 9.9565e+01
# it:  6   it_marq:  0   lambda: 1e+01   misfit: 2.7301e+01
# it:  7   it_marq:  0   lambda: 1e+00   misfit: 1.3040e+01
# it:  8   it_marq:  0   lambda: 1e-01   misfit: 2.5201e+01
# it:  8   it_marq:  1   lambda: 1e+00   misfit: 1.2698e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 3.3052e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.2642e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 3.7350e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.2796e+01
# it: 10   it_marq:  2   lambda: 1e+01   misfit: 1.1599e+01
# it: 11   it_marq:  0   lambda: 1e+00   misfit: 1.2635e+01
# it: 11   it_marq:  1   lambda: 1e+01   misfit: 1.1314e+01
# it: 12   it_marq:  0   lambda: 1e+00   misfit: 1.2554e+01
# it: 12   it_marq:  1   lambda: 1e+01   misfit: 1.1212e+01
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 1.2525e+01
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 1.1167e+01
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 1.2523e+01
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 1.1143e+01
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 1.2536e+01
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 1.1129e+01
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 1.2559e+01
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 1.1120e+01
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 1.2589e+01
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 1.1115e+01
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 1.2624e+01
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 1.1113e+01
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.2664e+01
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 1.1114e+01
# it: 19   it_marq:  2   lambda: 1e+02   misfit: 1.1104e+01
# it: 20   it_marq:  0   lambda: 1e+01   misfit: 1.1110e+01
# it: 20   it_marq:  1   lambda: 1e+02   misfit: 1.1097e+01
# it: 21   it_marq:  0   lambda: 1e+01   misfit: 1.1106e+01
# it: 21   it_marq:  1   lambda: 1e+02   misfit: 1.1090e+01
# it: 22   it_marq:  0   lambda: 1e+01   misfit: 1.1103e+01
# it: 22   it_marq:  1   lambda: 1e+02   misfit: 1.1085e+01
# it: 23   it_marq:  0   lambda: 1e+01   misfit: 1.1101e+01
# it: 23   it_marq:  1   lambda: 1e+02   misfit: 1.1081e+01
# it: 24   it_marq:  0   lambda: 1e+01   misfit: 1.1098e+01
# it: 24   it_marq:  1   lambda: 1e+02   misfit: 1.1077e+01
# it: 25   it_marq:  0   lambda: 1e+01   misfit: 1.1096e+01
# it: 25   it_marq:  1   lambda: 1e+02   misfit: 1.1074e+01
# it: 26   it_marq:  0   lambda: 1e+01   misfit: 1.1095e+01
# it: 26   it_marq:  1   lambda: 1e+02   misfit: 1.1072e+01
# it: 27   it_marq:  0   lambda: 1e+01   misfit: 1.1094e+01
# it: 27   it_marq:  1   lambda: 1e+02   misfit: 1.1070e+01
# it: 28   it_marq:  0   lambda: 1e+01   misfit: 1.1092e+01
# it: 28   it_marq:  1   lambda: 1e+02   misfit: 1.1068e+01
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 1.1091e+01
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 1.1066e+01

# %% [markdown]
# # Results

# %%
inc_list = []
for i in range(10):
    inc_list.append(inc + i)

# %%
res_norm = []
for d in d_fit_list:
    res = dobs - d
    res_norm.append((res - np.mean(res))/np.std(res)) # residue normalization

# %%
plt.figure(figsize=(12,20))
plt.subplot(5, 2, 1)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[0], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[0], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()
plt.suptitle('Residual data', fontsize=20)

plt.subplot(5, 2, 2)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[1], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[1], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 3)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[2], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[2], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 4)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[3], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[3], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 5)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[4], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[4], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 6)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[5], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[5], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 7)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[6], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[6], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 8)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[7], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[7], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 9)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[8], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[8], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 10)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[9], dec), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[9], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.savefig('figs/kimberlite_tfa_varying_inclination_fit.png', dpi=300)
#plt.show()

img(filename='figs/kimberlite_tfa_varying_inclination_fit.png')
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-0.089204656936016313, -0.066107174155361687, -0.04083578885723696]
scene.scene.camera.focal_point = [1.1820671636724554e-16, 1.3134079596360617e-17, -1.9701119394540926e-17]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.24683390337942718, 0.24593292331329802, -0.93733132955911114]
scene.scene.camera.clipping_range = [0.057117737884348194, 0.1956040854922288]
scene.scene.camera.compute_view_plane_normal()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha1.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha1.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [1387.431758173668, 3940.587088035918, -711.23575855995603]
scene.scene.camera.focal_point = [-1.9226665366075403e-12, -3.8453330732150806e-12, 425.00000000000171]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.053368194299606389, -0.25926638141600067, -0.96433022316250794]
scene.scene.camera.clipping_range = [2297.6930207290479, 6897.4792769581109]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha2.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha2.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-312.73912567501554, -3561.7262362085721, 287.67386774078057]
scene.scene.camera.focal_point = [1.9226665366075399e-12, -2.4033331707594249e-12, 425.00000000000017]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.13341196746632145, 0.026483446094695474, -0.99070675480674641]
scene.scene.camera.clipping_range = [1993.7950353893316, 5580.9677877221075]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha3.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha3.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-1358.4495936442941, 3241.6425529534445, 1095.0196037678566]
scene.scene.camera.focal_point = [1.1115415914762344e-12, 4.8066663415188518e-13, 424.99999999999943]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.069838400113651236, 0.17376780317072943, -0.98230715585848405]
scene.scene.camera.clipping_range = [1555.7568575367334, 6132.3676045661978]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha4.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha4.png')
