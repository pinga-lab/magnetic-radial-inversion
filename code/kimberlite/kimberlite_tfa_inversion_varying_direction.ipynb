# %% [markdown]
# # Inversion of amplitude of total field anomaly data produced by a synthetic kimberlitic model varying the magnetization direction

# %% [markdown]
# This notebook runs inversion of amplitude of total field anomaly data using Levenberg-Marquadt's algorithm. The data was generated from a kimberlitic model using the poligonal prisms function from fatiando.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle

from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# /home/vital/anaconda2/lib/python2.7/site-packages/fatiando/vis/myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %% [markdown]
# ### Auxiliary functions

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %% [markdown]
# # Input

# %% [markdown]
# ### Importing model parameters

# %%
with open('../../synthetic_data/kimberlite/kimberlite_model.pickle') as w:
        kimberlite_model = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/kimberlite_true.png')

# %% [markdown]
# ### Observation points and observed data

# %%
with open('../../synthetic_data/grids/regular_grid.pickle') as w:
        regular_grid = pickle.load(w)

# %%
with open('../../synthetic_data/kimberlite/kimberlite_data.pickle') as w:
        kimberlite_data = pickle.load(w)

# %%
img(filename='../../synthetic_data/kimberlite/obs_tfa.png', width=400, height=400)

# %% [markdown]
# ### Parameters for inversion

# %%
M = 10 # number of vertices per prism
L = 8 # number of prisms
P = L*(M+2) + 1 # number of parameters

# limits for parameters in meters
rmin = 10.
rmax = 1300.
x0min = -1300.
x0max = 1300.
y0min = -1300.
y0max = 1300.
dzmin = 10.
dzmax = 300.

mmin, mmax = mfun.build_range_param(M, L, rmin, rmax, x0min, x0max, y0min, y0max, dzmin, dzmax)

itmax = 30
itmax_marq = 10
epsilon = 1.0e-5     # stop criterion

deltax = 0.01*np.max(x0max)
deltay = 0.01*np.max(y0max)
deltar = 0.01*np.max(rmax)# increment of derivatives
deltaz = 0.01*np.max(dzmax)
m_out = np.zeros(M + 2)  # outcropping body parameters
#m_out = kimberlite_model['param_vec'][:M+2]

inc = kimberlite_model['inc']
dec = kimberlite_model['dec']
z0 = kimberlite_model['z0']
dz = 200.
props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc, dec)}
dobs = kimberlite_data['tfa_obs']
xp = regular_grid['xp']
yp = regular_grid['yp']
zp = regular_grid['zp']
N = regular_grid['N']

rin = np.zeros(M) + 600.
m0 = np.hstack((rin, np.zeros(2)))
m0 = np.resize(m0, P - 1) # inicial parameters vector
m0 = np.hstack((m0, dz))
model0 = mfun.param2polyprism(m0, M, L, z0, props) # list of classes of prisms
d0 = np.sqrt(polyprism.bx(xp, yp, zp, model0)**2. + \
             polyprism.by(xp, yp, zp, model0)**2. + \
             polyprism.bz(xp, yp, zp, model0)**2.)

# %% [markdown]
# ### Plotting the source and intial estimate

# %% [raw]
# bounds = [-700., 700., -700., 700., 50., 1750.]
#
# red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
# white, black = (1, 1, 1), (0, 0, 0),
#
# # Show the model
# scene = myv.figure()
# true = myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue)
# myv.polyprisms(model0, 'magnetization', opacity=.3, color=red)
#
# ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
# ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
# ax.axes.font_factor = 1.65
# scene.scene.camera.position = [-3919.9507356190898, -1492.5522124519537, 257.35943615138984]
# scene.scene.camera.focal_point = [3.2652212480582674e-12, -5.5975221395284579e-12, 500.00000000000028]
# scene.scene.camera.view_angle = 30.0
# scene.scene.camera.view_up = [0.028518032872962465, 0.086986891505218447, -0.99580118623514213]
# scene.scene.camera.clipping_range = [2313.2627909979883, 6588.5353642863038]
# scene.scene.camera.compute_view_plane_normal()
# scene.scene.render()
#
# myv.wall_bottom(ax.axes.bounds, opacity=0.2)
# myv.wall_north(ax.axes.bounds)
#
# myv.savefig('figs/kimberlite_amf_td_true_initial.png')
# myv.show()

# %%
img(filename='figs/kimberlite_amf_td_true_initial.png')

# %% [markdown]
# ### Observed AMF with initial estimate

# %%
plt.figure(figsize=(6,5))
plt.title('Observed TFA', fontsize=20)
plt.tricontourf(yp, xp, dobs, 40, cmap='jet').ax.tick_params(labelsize=12)
plt.xlabel('$y$(km)', fontsize=18)
plt.ylabel('$x$(km)', fontsize=18)
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.tick_params(labelsize=13)
#source = mpl.polygon(kimberlite_model['prisms'][0], '.-k', xy2ne=True)
estimate = mpl.polygon(model0[0], '.-r', xy2ne=True)
#source.set_label('Outcropping polygon')
estimate.set_label('Initial estimate')
clb.ax.set_title('nT')
mpl.m2km()
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
plt.savefig('figs/kimberlite_tfa_obs_data_true_inital.png', dpi=300)
#plt.show()
img(filename='figs/kimberlite_tfa_obs_data_true_inital.png', width=400, height=400)

# %% [markdown]
# ### Regularization parameters

# %%
#lamb = th*0.01 # Marquadt's parameter
lamb = 1000.0
dlamb = 10.      # step for Marquadt's parameter

a1 = 0.003   # adjacent radial distances within each prism
a2 = 0.006   # vertically adjacent radial distances
a3 = 0.     # outcropping cross-section
a4 = 0.     # outcropping origin
a5 = 0.03     # vertically adjacent origins
a6 = 0.00001   # zero order Tikhonov on adjacent radial distances
a7 = 0.000001     # zero order Tikhonov on thickness of each prism

# %%
delta = np.array([deltax, deltay, deltar, deltaz])
alpha = np.array([a1, a2, a3, a4, a5, a6, a7])

# %% [markdown]
# ### Inversion

# %%
d_fit_list = []
m_est_list = []
model_est_list = []
phi_list_list = []

for i in range(10):
    print 'inclination:', inc + i
    props = {'magnetization': utils.ang2vec(
        kimberlite_model['intensity'], inc + i*0.2, dec + i*0.8)}
    d_fit, m_est, model_est, phi_list = mfun.levmarq_tf(xp, yp, zp, m0, M, L, delta, itmax,
                                                        itmax_marq, lamb, dlamb, epsilon,
                                                        mmin, mmax, m_out, dobs, inc, dec,
                                                        props, alpha, z0, dz)
    d_fit_list.append(d_fit)
    m_est_list.append(m_est)
    model_est_list.append(model_est)
    phi_list_list.append(phi_list)
# Out:
# inclination: -21.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7747e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.5009e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3751e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7351e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.3255e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.0728e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.5213e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.6749e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.2047e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 9.9774e+00
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 8.8041e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 9.6379e+00
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 8.9399e+00
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.3765e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 8.6398e+00
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.2450e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 8.4799e+00
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.1772e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 8.3724e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.1320e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 8.2925e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.0982e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 8.2304e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.0714e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 8.1811e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.0497e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.1410e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.0315e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 8.1081e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.0161e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.0807e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.0028e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.0575e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 7.9913e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.0378e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 7.9812e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.0209e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 7.9722e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.0063e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 7.9642e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 7.9935e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 7.9570e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 7.9823e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 7.9504e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 7.9723e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 7.9444e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 7.9635e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 7.9390e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 7.9556e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 7.9339e+00
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 7.9485e+00
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 7.9293e+00
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 7.9421e+00
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 7.9250e+00
# it: 29   it_marq:  0   lambda: 1e-01   misfit: 7.9362e+00
# it: 29   it_marq:  1   lambda: 1e+00   misfit: 7.9210e+00
# inclination: -20.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7718e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4985e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3640e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7298e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.3833e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.0636e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.5157e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.6786e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.2523e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.0018e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 8.8316e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 9.7753e+00
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 8.9892e+00
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.3856e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 8.6773e+00
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.2496e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 8.5106e+00
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.1795e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 8.3983e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.1326e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 8.3144e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.0974e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 8.2490e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.0695e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 8.1966e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.0466e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.1540e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.0275e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 8.1187e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.0112e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.0892e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 7.9971e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.0642e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 7.9848e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.0428e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 7.9739e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.0243e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 7.9643e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.0083e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 7.9556e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 7.9942e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 7.9477e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 7.9818e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 7.9406e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 7.9707e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 7.9340e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 7.9609e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 7.9280e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 7.9520e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 7.9224e+00
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 7.9440e+00
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 7.9173e+00
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 7.9368e+00
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 7.9125e+00
# it: 29   it_marq:  0   lambda: 1e-01   misfit: 7.9302e+00
# it: 29   it_marq:  1   lambda: 1e+00   misfit: 7.9080e+00
# inclination: -19.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7687e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4959e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3526e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7249e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.4419e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.0501e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.5099e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.6997e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.3253e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.0126e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 8.9256e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 1.0185e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 9.1582e+00
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.4473e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 8.8271e+00
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.3050e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 8.6518e+00
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.2326e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 8.5338e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.1845e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 8.4455e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.1486e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 8.3762e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.1202e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 8.3204e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.0971e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.2747e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.0777e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 8.2367e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.0613e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.2047e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.0472e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.1774e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 8.0348e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.1540e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 8.0239e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.1337e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 8.0143e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.1159e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 8.0056e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 8.1003e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 7.9978e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 8.0866e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 7.9906e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 8.0743e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 7.9841e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 8.0634e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 7.9782e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 8.0536e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 7.9727e+00
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 8.0447e+00
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 7.9676e+00
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 8.0368e+00
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 7.9628e+00
# it: 29   it_marq:  0   lambda: 1e-01   misfit: 8.0296e+00
# it: 29   it_marq:  1   lambda: 1e+00   misfit: 7.9584e+00
# inclination: -18.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7654e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4931e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3410e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7204e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.5015e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.0326e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.5044e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.7385e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.4219e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.0301e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 9.0912e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 1.0970e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 9.4710e+00
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.5638e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 9.1129e+00
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.4128e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 8.9278e+00
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.3380e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 8.8048e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.2892e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 8.7128e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.2533e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 8.6406e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.2253e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 8.5824e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.2026e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.5345e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.1838e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 8.4946e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.1680e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.4610e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.1545e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.4323e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 8.1429e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.4077e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 8.1326e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.3865e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 8.1236e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.3680e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 8.1155e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 8.3520e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 8.1082e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 8.3380e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 8.1016e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 8.3258e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 8.0957e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 8.3151e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 8.0902e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 8.3059e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 8.0852e+00
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 8.2980e+00
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 8.0806e+00
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 8.2912e+00
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 8.0764e+00
# it: 29   it_marq:  0   lambda: 1e-01   misfit: 8.2856e+00
# it: 29   it_marq:  1   lambda: 1e+00   misfit: 8.0725e+00
# inclination: -17.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7619e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4902e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3290e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7162e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.5624e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 3.0110e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.4996e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.7950e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.5405e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.0543e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 9.3347e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 1.2297e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 9.9641e+00
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.7375e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 9.5712e+00
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.5752e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 9.3774e+00
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.4978e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 9.2525e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.4490e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 9.1604e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.4138e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 9.0887e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.3869e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 9.0312e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.3656e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 8.9842e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.3482e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 8.9454e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.3339e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 8.9130e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.3218e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 8.8860e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 8.3115e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 8.8634e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 8.3026e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 8.8446e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 8.2948e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 8.8294e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 8.2880e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 8.8174e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 8.2820e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 8.8085e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 8.2767e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 8.8028e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 8.2721e+00
# it: 25   it_marq:  0   lambda: 1e-01   misfit: 8.8003e+00
# it: 25   it_marq:  1   lambda: 1e+00   misfit: 8.2681e+00
# it: 26   it_marq:  0   lambda: 1e-01   misfit: 8.8013e+00
# it: 26   it_marq:  1   lambda: 1e+00   misfit: 8.2647e+00
# it: 27   it_marq:  0   lambda: 1e-01   misfit: 8.8062e+00
# it: 27   it_marq:  1   lambda: 1e+00   misfit: 8.2620e+00
# it: 28   it_marq:  0   lambda: 1e-01   misfit: 8.8156e+00
# it: 28   it_marq:  1   lambda: 1e+00   misfit: 8.2601e+00
# it: 29   it_marq:  0   lambda: 1e-01   misfit: 8.8303e+00
# it: 29   it_marq:  1   lambda: 1e+00   misfit: 8.2589e+00
# inclination: -16.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7581e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4871e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3168e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7125e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.6248e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.9855e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.4957e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.8691e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.6799e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.0851e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 9.6638e+00
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 1.4397e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 1.0685e+01
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 8.9712e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.0250e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 8.7946e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.0052e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.7147e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 9.9319e+00
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.6665e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 9.8463e+00
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.6332e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 9.7812e+00
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.6086e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 9.7300e+00
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.5897e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 9.6895e+00
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.5750e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 9.6575e+00
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.5633e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 9.6327e+00
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.5540e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 9.6147e+00
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 8.5464e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 9.6032e+00
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 8.5404e+00
# it: 20   it_marq:  0   lambda: 1e-01   misfit: 9.5985e+00
# it: 20   it_marq:  1   lambda: 1e+00   misfit: 8.5358e+00
# it: 21   it_marq:  0   lambda: 1e-01   misfit: 9.6015e+00
# it: 21   it_marq:  1   lambda: 1e+00   misfit: 8.5325e+00
# it: 22   it_marq:  0   lambda: 1e-01   misfit: 9.6132e+00
# it: 22   it_marq:  1   lambda: 1e+00   misfit: 8.5307e+00
# it: 23   it_marq:  0   lambda: 1e-01   misfit: 9.6354e+00
# it: 23   it_marq:  1   lambda: 1e+00   misfit: 8.5304e+00
# it: 24   it_marq:  0   lambda: 1e-01   misfit: 9.6710e+00
# it: 24   it_marq:  1   lambda: 1e+00   misfit: 8.5322e+00
# it: 24   it_marq:  2   lambda: 1e+01   misfit: 8.4680e+00
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 8.5195e+00
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 8.4495e+00
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 8.5127e+00
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 8.4422e+00
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 8.5089e+00
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 8.4386e+00
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 8.5066e+00
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 8.4364e+00
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 8.5051e+00
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 8.4349e+00
# inclination: -15.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7542e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4838e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.3042e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7092e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.6889e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.9558e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.4929e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 4.9603e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 3.8391e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.1226e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.0088e+01
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 1.7523e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 1.1688e+01
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 9.2678e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.1202e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 9.0737e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.1007e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 8.9915e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.0902e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 8.9452e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.0831e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 8.9153e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 1.0781e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 8.8948e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 1.0744e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 8.8805e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 1.0719e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 8.8708e+00
# it: 16   it_marq:  0   lambda: 1e-01   misfit: 1.0706e+01
# it: 16   it_marq:  1   lambda: 1e+00   misfit: 8.8644e+00
# it: 17   it_marq:  0   lambda: 1e-01   misfit: 1.0705e+01
# it: 17   it_marq:  1   lambda: 1e+00   misfit: 8.8610e+00
# it: 18   it_marq:  0   lambda: 1e-01   misfit: 1.0717e+01
# it: 18   it_marq:  1   lambda: 1e+00   misfit: 8.8602e+00
# it: 19   it_marq:  0   lambda: 1e-01   misfit: 1.0747e+01
# it: 19   it_marq:  1   lambda: 1e+00   misfit: 8.8624e+00
# it: 19   it_marq:  2   lambda: 1e+01   misfit: 8.7611e+00
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 8.8427e+00
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 8.7322e+00
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 8.8321e+00
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 8.7210e+00
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 8.8261e+00
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 8.7157e+00
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 8.8225e+00
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 8.7126e+00
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 8.8203e+00
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 8.7104e+00
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 8.8189e+00
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 8.7087e+00
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 8.8179e+00
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 8.7073e+00
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 8.8172e+00
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 8.7061e+00
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 8.8168e+00
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 8.7050e+00
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 8.8165e+00
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 8.7040e+00
# inclination: -14.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7500e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4804e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.2914e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7062e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.7551e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.9218e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.4909e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 5.0678e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 4.0170e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.1668e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.0617e+01
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 2.1895e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 1.3021e+01
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 9.6298e+00
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.2473e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 9.4150e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.2292e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 9.3314e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.2211e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 9.2889e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.2165e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 9.2650e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 1.2140e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 9.2518e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 1.2131e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 9.2459e+00
# it: 15   it_marq:  0   lambda: 1e-01   misfit: 1.2141e+01
# it: 15   it_marq:  1   lambda: 1e+00   misfit: 9.2459e+00
# inclination: -13.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7457e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4768e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.2782e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7037e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.8235e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.8829e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.4894e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 5.1903e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 4.2130e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.2179e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.1264e+01
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 2.7616e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 1.4713e+01
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 1.0059e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.4093e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 9.8210e+00
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.3937e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 9.7373e+00
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.3890e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 9.7018e+00
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.3880e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 9.6880e+00
# it: 13   it_marq:  0   lambda: 1e-01   misfit: 1.3895e+01
# it: 13   it_marq:  1   lambda: 1e+00   misfit: 9.6876e+00
# it: 14   it_marq:  0   lambda: 1e-01   misfit: 1.3938e+01
# it: 14   it_marq:  1   lambda: 1e+00   misfit: 9.6974e+00
# it: 14   it_marq:  2   lambda: 1e+01   misfit: 9.4810e+00
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 9.6583e+00
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 9.4218e+00
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 9.6374e+00
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 9.3998e+00
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 9.6262e+00
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 9.3898e+00
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 9.6201e+00
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 9.3844e+00
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 9.6168e+00
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 9.3811e+00
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 9.6151e+00
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 9.3787e+00
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 9.6145e+00
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 9.3770e+00
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 9.6144e+00
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 9.3756e+00
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 9.6149e+00
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 9.3746e+00
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 9.6157e+00
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 9.3737e+00
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 9.6169e+00
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 9.3730e+00
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 9.6183e+00
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 9.3725e+00
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 9.6199e+00
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 9.3721e+00
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 9.6218e+00
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 9.3718e+00
# it: 29   it_marq:  0   lambda: 1e+00   misfit: 9.6240e+00
# it: 29   it_marq:  1   lambda: 1e+01   misfit: 9.3717e+00
# inclination: -12.5
# it:  0   it_marq:  0   lambda: 1e+03   misfit: 1.7411e+03
# it:  1   it_marq:  0   lambda: 1e+02   misfit: 1.4731e+03
# it:  2   it_marq:  0   lambda: 1e+01   misfit: 6.2648e+02
# it:  3   it_marq:  0   lambda: 1e+00   misfit: 1.7015e+02
# it:  4   it_marq:  0   lambda: 1e-01   misfit: 8.8944e+01
# it:  5   it_marq:  0   lambda: 1e-02   misfit: 2.8388e+03
# it:  5   it_marq:  1   lambda: 1e-01   misfit: 1.4876e+03
# it:  5   it_marq:  2   lambda: 1e+00   misfit: 5.3260e+02
# it:  5   it_marq:  3   lambda: 1e+01   misfit: 4.4261e+01
# it:  6   it_marq:  0   lambda: 1e+00   misfit: 1.2760e+01
# it:  7   it_marq:  0   lambda: 1e-01   misfit: 1.2043e+01
# it:  8   it_marq:  0   lambda: 1e-02   misfit: 3.4627e+01
# it:  8   it_marq:  1   lambda: 1e-01   misfit: 1.6766e+01
# it:  8   it_marq:  2   lambda: 1e+00   misfit: 1.0557e+01
# it:  9   it_marq:  0   lambda: 1e-01   misfit: 1.6071e+01
# it:  9   it_marq:  1   lambda: 1e+00   misfit: 1.0293e+01
# it: 10   it_marq:  0   lambda: 1e-01   misfit: 1.5953e+01
# it: 10   it_marq:  1   lambda: 1e+00   misfit: 1.0212e+01
# it: 11   it_marq:  0   lambda: 1e-01   misfit: 1.5952e+01
# it: 11   it_marq:  1   lambda: 1e+00   misfit: 1.0189e+01
# it: 12   it_marq:  0   lambda: 1e-01   misfit: 1.5991e+01
# it: 12   it_marq:  1   lambda: 1e+00   misfit: 1.0192e+01
# it: 12   it_marq:  2   lambda: 1e+01   misfit: 9.9117e+00
# it: 13   it_marq:  0   lambda: 1e+00   misfit: 1.0140e+01
# it: 13   it_marq:  1   lambda: 1e+01   misfit: 9.8329e+00
# it: 14   it_marq:  0   lambda: 1e+00   misfit: 1.0112e+01
# it: 14   it_marq:  1   lambda: 1e+01   misfit: 9.8035e+00
# it: 15   it_marq:  0   lambda: 1e+00   misfit: 1.0097e+01
# it: 15   it_marq:  1   lambda: 1e+01   misfit: 9.7901e+00
# it: 16   it_marq:  0   lambda: 1e+00   misfit: 1.0089e+01
# it: 16   it_marq:  1   lambda: 1e+01   misfit: 9.7828e+00
# it: 17   it_marq:  0   lambda: 1e+00   misfit: 1.0084e+01
# it: 17   it_marq:  1   lambda: 1e+01   misfit: 9.7782e+00
# it: 18   it_marq:  0   lambda: 1e+00   misfit: 1.0082e+01
# it: 18   it_marq:  1   lambda: 1e+01   misfit: 9.7749e+00
# it: 19   it_marq:  0   lambda: 1e+00   misfit: 1.0081e+01
# it: 19   it_marq:  1   lambda: 1e+01   misfit: 9.7724e+00
# it: 20   it_marq:  0   lambda: 1e+00   misfit: 1.0081e+01
# it: 20   it_marq:  1   lambda: 1e+01   misfit: 9.7705e+00
# it: 21   it_marq:  0   lambda: 1e+00   misfit: 1.0082e+01
# it: 21   it_marq:  1   lambda: 1e+01   misfit: 9.7690e+00
# it: 22   it_marq:  0   lambda: 1e+00   misfit: 1.0083e+01
# it: 22   it_marq:  1   lambda: 1e+01   misfit: 9.7678e+00
# it: 23   it_marq:  0   lambda: 1e+00   misfit: 1.0084e+01
# it: 23   it_marq:  1   lambda: 1e+01   misfit: 9.7669e+00
# it: 24   it_marq:  0   lambda: 1e+00   misfit: 1.0086e+01
# it: 24   it_marq:  1   lambda: 1e+01   misfit: 9.7662e+00
# it: 25   it_marq:  0   lambda: 1e+00   misfit: 1.0088e+01
# it: 25   it_marq:  1   lambda: 1e+01   misfit: 9.7657e+00
# it: 26   it_marq:  0   lambda: 1e+00   misfit: 1.0091e+01
# it: 26   it_marq:  1   lambda: 1e+01   misfit: 9.7654e+00
# it: 27   it_marq:  0   lambda: 1e+00   misfit: 1.0093e+01
# it: 27   it_marq:  1   lambda: 1e+01   misfit: 9.7652e+00
# it: 28   it_marq:  0   lambda: 1e+00   misfit: 1.0097e+01
# it: 28   it_marq:  1   lambda: 1e+01   misfit: 9.7653e+00
# it: 28   it_marq:  2   lambda: 1e+02   misfit: 9.7630e+00
# it: 29   it_marq:  0   lambda: 1e+01   misfit: 9.7644e+00
# it: 29   it_marq:  1   lambda: 1e+02   misfit: 9.7613e+00

# %% [markdown]
# # Results

# %%
inc_list = []
dec_list = []
for i in range(10):
    inc_list.append(inc + i*0.2)
    dec_list.append(dec + i*0.8)

# %%
res_norm = []
for d in d_fit_list:
    res = dobs - d
    res_norm.append((res - np.mean(res))/np.std(res)) # residue normalization

# %%
plt.figure(figsize=(12,20))
plt.subplot(5, 2, 1)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[0], dec_list[0]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[0], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()
plt.suptitle('Residual data', fontsize=20)

plt.subplot(5, 2, 2)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[1], dec_list[1]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[1], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 3)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[2], dec_list[2]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[2], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 4)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[3], dec_list[3]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[3], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 5)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[4], dec_list[4]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[4], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 6)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[5], dec_list[5]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[5], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 7)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[6], dec_list[6]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[6], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 8)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[7], dec_list[7]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[7], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 9)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[8], dec_list[8]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[8], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.subplot(5, 2, 10)
#plt.title("Residual data", fontsize = 18)
plt.text(-1500., 1500., r'inc = %s dec = %s' % (inc_list[9], dec_list[9]), fontsize=10)
plt.axis('scaled')
nlevels = mpl.contourf(yp, xp, res_norm[9], regular_grid['shape'], 20, cmap='jet')
plt.xlabel('East y (km)')
plt.ylabel('North x (km)')
clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
clb.ax.set_title('nT')
plt.legend(loc=0, fontsize=12, shadow=bool, framealpha=1, edgecolor='black')
mpl.m2km()

plt.savefig('figs/kimberlite_tfa_varying_dir_fit.png', dpi=300)
#plt.show()

img(filename='figs/kimberlite_tfa_varying_dir_fit.png')
# Out:
# /home/vital/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-0.089204656936016313, -0.066107174155361687, -0.04083578885723696]
scene.scene.camera.focal_point = [1.1820671636724554e-16, 1.3134079596360617e-17, -1.9701119394540926e-17]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.24683390337942718, 0.24593292331329802, -0.93733132955911114]
scene.scene.camera.clipping_range = [0.057117737884348194, 0.1956040854922288]
scene.scene.camera.compute_view_plane_normal()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha1.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha1.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [1387.431758173668, 3940.587088035918, -711.23575855995603]
scene.scene.camera.focal_point = [-1.9226665366075403e-12, -3.8453330732150806e-12, 425.00000000000171]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.053368194299606389, -0.25926638141600067, -0.96433022316250794]
scene.scene.camera.clipping_range = [2297.6930207290479, 6897.4792769581109]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha2.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha2.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-312.73912567501554, -3561.7262362085721, 287.67386774078057]
scene.scene.camera.focal_point = [1.9226665366075399e-12, -2.4033331707594249e-12, 425.00000000000017]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.13341196746632145, 0.026483446094695474, -0.99070675480674641]
scene.scene.camera.clipping_range = [1993.7950353893316, 5580.9677877221075]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha3.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha3.png')

bounds = [-700., 700., -700., 700., -100., 1150.]

red, green, blue = (1, 0, 0), (0, 1, 0), (0, 0, 1)
white, black = (1, 1, 1), (0, 0, 0),

# Show the model
scene = myv.figure()
myv.polyprisms(kimberlite_model['prisms'], 'magnetization', color=blue, linewidth=1., opacity=.5, edges=False)
myv.polyprisms(model_est_list[-1], 'magnetization', color=red, linewidth=1.)


ax = myv.axes(myv.outline(bounds), ranges=[i * 0.001 for i in bounds])
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x (km)', 'y (km)', 'z (km)'
ax.axes.font_factor = 1.5
scene.scene.camera.position = [-1358.4495936442941, 3241.6425529534445, 1095.0196037678566]
scene.scene.camera.focal_point = [1.1115415914762344e-12, 4.8066663415188518e-13, 424.99999999999943]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.069838400113651236, 0.17376780317072943, -0.98230715585848405]
scene.scene.camera.clipping_range = [1555.7568575367334, 6132.3676045661978]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()

myv.wall_bottom(ax.axes.bounds, opacity=0.2)
myv.wall_north(ax.axes.bounds)
#myv.title('bolacha', color=(0, 0, 0), size=1.3, height=0.5)
myv.savefig('figs/kimberlite_tfa_varying_inc_bolacha4.png')
myv.show()

img(filename='figs/kimberlite_tfa_varying_inc_bolacha4.png')
