# %% [markdown]
# # Visualization of inversion - Kimberlite data

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
import matplotlib.pyplot as plt
import cPickle as pickle
import os
import matplotlib as mpb

from mpl_toolkits.axes_grid.inset_locator import inset_axes
from fatiando import utils
from fatiando.gravmag import polyprism
from fatiando.gravmag.transform import reduce_to_pole
from fatiando.mesher import PolygonalPrism
from fatiando.vis import mpl, myv
from matplotlib import colors, ticker, cm
from IPython.display import Image as img
from matplotlib.mlab import normpdf
# Out:
# C:\Users\bes064\AppData\Local\Continuum\anaconda2\lib\site-packages\fatiando\vis\mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# C:\Users\bes064\AppData\Local\Continuum\anaconda2\lib\site-packages\fatiando\vis\myv.py:51: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %%
import sys
sys.path.insert(0, '../../code')

import mag_polyprism_functions as mfun

# %%
mypath = 'data/flightlines_grid_1600pts_16km/tfa_inversion/'

# %%
results = []
with open(mypath+'inc50_dec-15_r700_int6_z00_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int6_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int6_z0100_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z00_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z0100_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int4_z00_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int4_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int4_z0100_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc55_dec-10_r700_int5_z00_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc55_dec-10_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc55_dec-10_r700_int5_z0100_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z00_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z0100_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc45_dec-20_r700_int5_z00_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc45_dec-20_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc45_dec-20_r700_int5_z0100_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc45_dec-20_r700_int6_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int6_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc55_dec-10_r700_int6_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc45_dec-20_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc55_dec-10_r700_int5_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc45_dec-20_r700_int4_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'inc50_dec-15_r700_int4_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))
with open(mypath+'/inc55_dec-10_r700_int4_z050_dz220/inversion.pickle') as w:
        results.append(pickle.load(w))

# %%
with open('data/model.pickle') as w:
        model = pickle.load(w)

# %%
verts_true = mfun.plot_prisms(model['prisms'])
results_verts = []
for r in results:
    results_verts.append(mfun.plot_prisms(r['prisms']))

# %%
xp = results[0]['x']
yp = results[0]['y']
zp = results[0]['z']

# %%
fig = plt.figure(figsize=(22,18))

norm=mpb.colors.Normalize(vmin=np.min(results[4]['residual']), vmax=np.min(results[4]['residual'])*(-1))

for i in range(9):
    ax = fig.add_subplot(3,3,i+1, projection='3d')
    ax.add_collection3d(Poly3DCollection(verts_true, 
        alpha=0.3, facecolor='b', linewidths=0.5, edgecolors='k'))
    ax.add_collection3d(Poly3DCollection(results_verts[i], alpha=0.5, 
         facecolor='r', linewidths=0.5, edgecolors='k'))

    ax.set_xlim(-2000, 2000, 100)
    ax.set_xticks(np.linspace(-2000, 2000, 5))
    ax.set_ylim(-2000, 2000, 100)
    ax.set_yticks(np.linspace(-2000, 2000, 5))
    ax.set_zlim(1500, -150, 100)
    ax.set_zticks(np.linspace(1500, -150, 12))
    ax.set_xlabel('Y (m)')
    ax.set_ylabel('X (m)')
    ax.set_zlabel('Z (m)')
    ax.view_init(10, -45)

    ax.tricontourf(xp, yp, results[i]['residual'],
                    zdir='z', offset=-150, cmap='RdBu_r', norm=norm)
plt.savefig(mypath+'kimberlite_3d_estimates_topxint.png', dpi=300)
plt.show()

# %%
# plot
fig = plt.figure(figsize=(20,18))
#plt.suptitle('Residual', fontsize=20)
norm=mpb.colors.Normalize(vmin=np.min(results[4]['residual']), vmax=np.min(results[4]['residual'])*(-1))
for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.tricontourf(yp, xp, results[i]['residual'], 20, cmap='RdBu_r', norm=norm).ax.tick_params(labelsize=12)
    plt.ylabel('$x$(m)', fontsize=18)
    plt.xlabel('$y$(m)', fontsize=18)
    plt.xlim(np.min(yp), np.max(yp))
    plt.ylim(np.min(xp), np.max(xp))
    clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
    clb.ax.tick_params(labelsize=13)
    clb.ax.set_title('nT')
    inset = inset_axes(ax, width="30%", height="20%", loc=1)
    mean = np.mean(results[i]['residual'])
    std = np.std(results[i]['residual'])
    nbins=30
    n, bins, patches = plt.hist(results[i]['residual'],bins=nbins, normed=True, color='blue')
    gauss = normpdf(bins, mean, std)
    plt.plot(bins, gauss, 'k--', linewidth=1., label='Gaussian')
    #plt.title('Probability')
    plt.xticks([])
    plt.yticks([])
plt.savefig(mypath+'kimberlite_3d_residual_topxint.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(22,18))

norm=mpb.colors.Normalize(vmin=np.min(results[4]['residual']), vmax=np.min(results[4]['residual'])*(-1))

for i in range(9):
    ax = fig.add_subplot(3,3,i+1, projection='3d')
    ax.add_collection3d(Poly3DCollection(verts_true, 
        alpha=0.3, facecolor='b', linewidths=0.5, edgecolors='k'))
    ax.add_collection3d(Poly3DCollection(results_verts[i+9], alpha=0.5, 
         facecolor='r', linewidths=0.5, edgecolors='k'))

    ax.set_xlim(-2000, 2000, 100)
    ax.set_xticks(np.linspace(-2000, 2000, 5))
    ax.set_ylim(-2000, 2000, 100)
    ax.set_yticks(np.linspace(-2000, 2000, 5))
    ax.set_zlim(1500, -150, 100)
    ax.set_zticks(np.linspace(1500, -150, 12))
    ax.set_xlabel('Y (m)')
    ax.set_ylabel('X (m)')
    ax.set_zlabel('Z (m)')
    ax.view_init(10, -45)

    ax.tricontourf(xp, yp, results[i+9]['residual'],
                    zdir='z', offset=-150, cmap='RdBu_r', norm=norm)
plt.savefig(mypath+'kimberlite_3d_estimates_topxdir.png', dpi=300)
plt.show()

# %%
# plot
fig = plt.figure(figsize=(20,18))
#plt.suptitle('Residual', fontsize=20)
norm=mpb.colors.Normalize(vmin=np.min(results[4]['residual']), vmax=np.min(results[4]['residual'])*(-1))
for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.tricontourf(yp, xp, results[i+9]['residual'], 20, cmap='RdBu_r', norm=norm).ax.tick_params(labelsize=12)
    plt.ylabel('$x$(m)', fontsize=18)
    plt.xlabel('$y$(m)', fontsize=18)
    plt.xlim(np.min(yp), np.max(yp))
    plt.ylim(np.min(xp), np.max(xp))
    clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
    clb.ax.tick_params(labelsize=13)
    clb.ax.set_title('nT')
    inset = inset_axes(ax, width="30%", height="20%", loc=1)
    mean = np.mean(results[i+9]['residual'])
    std = np.std(results[i+9]['residual'])
    nbins=30
    n, bins, patches = plt.hist(results[i+9]['residual'],bins=nbins, normed=True, color='blue')
    gauss = normpdf(bins, mean, std)
    plt.plot(bins, gauss, 'k--', linewidth=1., label='Gaussian')
    plt.xticks([])
    plt.yticks([])
plt.savefig(mypath+'kimberlite_3d_residual_topxdir.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(22,18))

norm=mpb.colors.Normalize(vmin=np.min(results[4]['residual']), vmax=np.min(results[4]['residual'])*(-1))

for i in range(9):
    ax = fig.add_subplot(3,3,i+1, projection='3d')
    ax.add_collection3d(Poly3DCollection(verts_true, 
        alpha=0.3, facecolor='b', linewidths=0.5, edgecolors='k'))
    ax.add_collection3d(Poly3DCollection(results_verts[i+18], alpha=0.5, 
         facecolor='r', linewidths=0.5, edgecolors='k'))

    ax.set_xlim(-2000, 2000, 100)
    ax.set_xticks(np.linspace(-2000, 2000, 5))
    ax.set_ylim(-2000, 2000, 100)
    ax.set_yticks(np.linspace(-2000, 2000, 5))
    ax.set_zlim(1500, -150, 100)
    ax.set_zticks(np.linspace(1500, -150, 12))
    ax.set_xlabel('Y (m)')
    ax.set_ylabel('X (m)')
    ax.set_zlabel('Z (m)')
    ax.view_init(10, -45)

    ax.tricontourf(xp, yp, results[i+18]['residual'],
                    zdir='z', offset=-150, cmap='RdBu_r', norm=norm)
plt.savefig(mypath+'kimberlite_3d_estimates_dirxint.png', dpi=300)
plt.show()

# %%
# plot
fig = plt.figure(figsize=(20,18))
#plt.suptitle('Residual', fontsize=20)
norm=mpb.colors.Normalize(vmin=np.min(results[4]['residual']), vmax=np.min(results[4]['residual'])*(-1))
for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.tricontourf(yp, xp, results[i+18]['residual'], 20, cmap='RdBu_r', norm=norm).ax.tick_params(labelsize=12)
    plt.ylabel('$x$(m)', fontsize=18)
    plt.xlabel('$y$(m)', fontsize=18)
    plt.xlim(np.min(yp), np.max(yp))
    plt.ylim(np.min(xp), np.max(xp))
    clb = plt.colorbar(pad=0.025, aspect=40, shrink=1)
    clb.ax.tick_params(labelsize=13)
    clb.ax.set_title('nT')
    inset = inset_axes(ax, width="30%", height="20%", loc=1)
    mean = np.mean(results[i+18]['residual'])
    std = np.std(results[i+18]['residual'])
    nbins=30
    n, bins, patches = plt.hist(results[i+18]['residual'],bins=nbins, normed=True, color='blue')
    gauss = normpdf(bins, mean, std)
    plt.plot(bins, gauss, 'k--', linewidth=1., label='Gaussian')
    plt.xticks([])
    plt.yticks([])
plt.savefig(mypath+'kimberlite_3d_residual_dirxint.png', dpi=300)
plt.show()
