# %% [markdown]
# # Regional separation

# %% [markdown]
# ### Importing packages

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from fatiando.vis import mpl
import pandas as pd
import matplotlib as mpb
# Out:
# /home/leonardo/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %% [markdown]
# ### Importing Anitapolis TFA data

# %%
dataset = pd.read_csv('anitapolis_large_decimated.txt', skipinitialspace=True, delim_whitespace=True)

# %%
xp = dataset['X'].get_values()
yp = dataset['Y'].get_values()
lat = dataset['LAT'].get_values()
long = dataset['LONG'].get_values()
zp = - dataset['GPSALT'].get_values()
dobs = dataset['MAGIGRF'].get_values()
alt = dataset['ALTURA'].get_values()
N = xp.size # número de pontos

# %% [markdown]
# ### Data plot

# %%
plt.figure(figsize=(6,5))

plt.subplot(1,1,1)
plt.title("Total-field anomaly (nT)")
#plt.axis('scaled')
norm=mpb.colors.Normalize(vmin=-np.max(dobs), vmax=np.max(dobs))
plt.tricontourf(yp, xp, dobs, 30, cmap ='RdBu_r', norm=norm)
plt.colorbar()
#plt.plot(yp, xp, 'ok', markersize=0.5)
plt.xlabel('y (km)')
plt.ylabel('x (km)')
#mpl.m2km()

plt.tight_layout(pad = 2.)

plt.show()

# %% [markdown]
# ### Simple polynomial fitting

# %%
A = np.vstack((np.ones(N), xp, yp)).T

# %%
p1 = np.linalg.solve(np.dot(A.T,A),np.dot(A.T,dobs))

# %%
tfa_regional1 = np.dot(A,p1)

# %%
tfa_residual1 = dobs - tfa_regional1

# %%
#plt.close('all')
plt.figure(figsize=(12,10))

plt.subplot(2,2,1)
plt.title("Observed data (nT)")
norm=mpb.colors.Normalize(vmin=-np.max(dobs), vmax=np.max(dobs))
#plt.axis('scaled')
plt.tricontourf(yp, xp, dobs, 30, cmap = plt.get_cmap('RdBu_r'), norm=norm)
plt.colorbar()
plt.xlabel('y (km)')
plt.ylabel('x (km)')
mpl.m2km()

plt.subplot(2,2,2)
plt.title("Regional data (nT)")
#plt.axis('scaled')
norm=mpb.colors.Normalize(vmin=np.min(tfa_regional1), vmax=-np.min(tfa_regional1))
plt.tricontourf(yp, xp, tfa_regional1, 15, cmap = plt.get_cmap('RdBu_r'), norm=norm)
plt.colorbar()
plt.xlabel('y (km)')
plt.ylabel('x (km)')
mpl.m2km()

plt.subplot(2,2,3)
plt.title("Residual data (nT)")
#plt.axis('scaled')
norm=mpb.colors.Normalize(vmin=-np.max(tfa_residual1), vmax=np.max(tfa_residual1))
plt.tricontourf(yp, xp, tfa_residual1, 30, cmap = plt.get_cmap('RdBu_r'), norm=norm)
plt.colorbar()
plt.xlabel('y (km)')
plt.ylabel('x (km)')
mpl.m2km()

# plt.subplot(2,2,4)
# plt.title("Campo esfera (nT)")
# #plt.axis('scaled')
# plt.tricontourf(yp, xp, dobs, 15, cmap = plt.get_cmap('RdBu_r'))
# plt.colorbar()
# plt.xlabel('y (km)')
# plt.ylabel('x (km)')
# mpl.m2km()

plt.tight_layout(pad = 2.)

plt.show()

# %%
dataset.insert(3, "mag_res", tfa_residual1)

# %%
dataset.insert(4, "reg", tfa_regional1)

# %%
dataset.to_csv('anitapolis_large_decimated_tfa_residual.txt', sep=' ')

# %%
mask = (dataset['Y'] <= 693000.) & (dataset['Y'] >= 683000.) & (dataset['X'] <= 6926000.) & (dataset['X'] >= 6916000.)
data = dataset[mask]
data.reset_index(inplace=True)

# %%
#plt.close('all')
plt.figure(figsize=(12,10))

plt.subplot(2,2,1)
plt.title("Observed data (nT)")
#norm=mpb.colors.Normalize(vmin=-np.max(dobs), vmax=np.max(dobs))
#plt.axis('scaled')
plt.tricontourf(data['Y'], data['X'], data['MAGIGRF'], 30, cmap ='RdBu_r')
plt.colorbar()
plt.xlabel('y (km)')
plt.ylabel('x (km)')
mpl.m2km()

plt.subplot(2,2,2)
plt.title("Regional data (nT)")
#plt.axis('scaled')
norm=mpb.colors.Normalize(vmin=np.min(tfa_regional1), vmax=-np.min(tfa_regional1))
plt.tricontourf(data['Y'], data['X'], data['reg'], 15, cmap = plt.get_cmap('RdBu_r'), norm=norm)
plt.colorbar()
plt.xlabel('y (km)')
plt.ylabel('x (km)')
mpl.m2km()

plt.subplot(2,2,3)
plt.title("Residual data (nT)")
#plt.axis('scaled')
norm=mpb.colors.Normalize(vmin=-np.max(tfa_residual1), vmax=np.max(tfa_residual1))
plt.tricontourf(data['Y'], data['X'], data['mag_res'], 30, cmap = plt.get_cmap('RdBu_r'), norm=norm)
plt.colorbar()
plt.xlabel('y (km)')
plt.ylabel('x (km)')
mpl.m2km()

# plt.subplot(2,2,4)
# plt.title("Campo esfera (nT)")
# #plt.axis('scaled')
# plt.tricontourf(data['Y'], data['X'], dobs, 15, cmap = plt.get_cmap('RdBu_r'))
# plt.colorbar()
# plt.xlabel('y (km)')
# plt.ylabel('x (km)')
# mpl.m2km()

plt.tight_layout(pad = 2.)

plt.show()

# %%
data.to_csv('anitapolis_decimated_tfa_residual_cut.txt', sep=' ')
